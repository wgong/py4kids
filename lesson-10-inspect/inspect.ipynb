# %% [markdown]
# ## Inspect Live Objects
#
# - https://pymotw.com/3/inspect/index.html

# %%
src_code = '''
# filename: example.py
# This comment appears first
# and spans 2 lines.

# This comment does not show up in the output of getcomments().

"""Sample file to serve as the basis for inspect examples.
"""


def module_level_function(arg1, arg2='default', *args, **kwargs):
    """This function is declared in the module."""
    local_variable = arg1 * 2
    return local_variable


class A(object):
    """The A class."""

    def __init__(self, name):
        self.name = name

    def get_name(self):
        "Returns the name of the instance."
        return self.name


instance_of_a = A('sample_instance')


class B(A):
    """This is the B class.
    It is derived from A.
    """

    # This method is not part of A.
    def do_something(self):
        """Does some work"""

    def get_name(self):
        "Overrides version from A"
        return 'B(' + self.name + ')'
'''

# %%
filename = src_code.split('\n')[1].replace('#', '').split(':')[1].strip()

# %%
with open(filename, 'w') as f:
    f.write(src_code)

# %%
# !ls
# Out:
# example.py  inspect.ipynb  __pycache__

# %% [markdown]
# ## Inspecting Modules

# %%
import inspect
import example

for name, data in inspect.getmembers(example):
    if not name.startswith('__'):
        print('{} : {!r}'.format(name, data))
        # {!r} calls __repr__()
# Out:
# A : <class 'example.A'>
# B : <class 'example.B'>
# instance_of_a : <example.A object at 0x7f68fc20f828>
# module_level_function : <function module_level_function at 0x7f68fc24ebf8>

# %%
import inspect
import example

# predicate argument can be used to filter the types of objects returned
for name, data in inspect.getmembers(example, inspect.isclass):
    if not name.startswith('__'):
        print('{} : {!r}'.format(name, data))
        # {!r} calls __repr__()
# Out:
# A : <class 'example.A'>
# B : <class 'example.B'>

# %% [markdown]
# ## Inspecting Classes

# %%
import inspect
from pprint import pprint

import example

pprint(inspect.getmembers(example.A))  # , width=65)
# Out:
# [('__class__', <class 'type'>),
#  ('__delattr__', <slot wrapper '__delattr__' of 'object' objects>),
#  ('__dict__',
#   mappingproxy({'__dict__': <attribute '__dict__' of 'A' objects>,
#                 '__doc__': 'The A class.',
#                 '__init__': <function A.__init__ at 0x7f68fc210048>,
#                 '__module__': 'example',
#                 '__weakref__': <attribute '__weakref__' of 'A' objects>,
#                 'get_name': <function A.get_name at 0x7f68fc2100d0>})),
#  ('__dir__', <method '__dir__' of 'object' objects>),
#  ('__doc__', 'The A class.'),
#  ('__eq__', <slot wrapper '__eq__' of 'object' objects>),
#  ('__format__', <method '__format__' of 'object' objects>),
#  ('__ge__', <slot wrapper '__ge__' of 'object' objects>),
#  ('__getattribute__', <slot wrapper '__getattribute__' of 'object' objects>),
#  ('__gt__', <slot wrapper '__gt__' of 'object' objects>),
#  ('__hash__', <slot wrapper '__hash__' of 'object' objects>),
#  ('__init__', <function A.__init__ at 0x7f68fc210048>),
#  ('__init_subclass__',
#   <built-in method __init_subclass__ of type object at 0x55c2a2098528>),
#  ('__le__', <slot wrapper '__le__' of 'object' objects>),
#  ('__lt__', <slot wrapper '__lt__' of 'object' objects>),
#  ('__module__', 'example'),
#  ('__ne__', <slot wrapper '__ne__' of 'object' objects>),
#  ('__new__', <built-in method __new__ of type object at 0x55c29fa10660>),
#  ('__reduce__', <method '__reduce__' of 'object' objects>),
#  ('__reduce_ex__', <method '__reduce_ex__' of 'object' objects>),
#  ('__repr__', <slot wrapper '__repr__' of 'object' objects>),
#  ('__setattr__', <slot wrapper '__setattr__' of 'object' objects>),
#  ('__sizeof__', <method '__sizeof__' of 'object' objects>),
#  ('__str__', <slot wrapper '__str__' of 'object' objects>),
#  ('__subclasshook__',
#   <built-in method __subclasshook__ of type object at 0x55c2a2098528>),
#  ('__weakref__', <attribute '__weakref__' of 'A' objects>),
#  ('get_name', <function A.get_name at 0x7f68fc2100d0>)]

# %%
import inspect
from pprint import pprint

import example

pprint(inspect.getmembers(example.A, inspect.isfunction))

pprint(inspect.getmembers(example.A, inspect.ismethod))

pprint(inspect.getmembers(example.B, inspect.isfunction))
# Out:
# [('__init__', <function A.__init__ at 0x7f68fc210048>),
#  ('get_name', <function A.get_name at 0x7f68fc2100d0>)]
# []
# [('__init__', <function A.__init__ at 0x7f68fc210048>),
#  ('do_something', <function B.do_something at 0x7f68fc210158>),
#  ('get_name', <function B.get_name at 0x7f68fc2101e0>)]

# %% [markdown]
# ## Inspecting Instances

# %%
import inspect
from pprint import pprint

import example

a = example.A(name='inspect_getmembers')
pprint(inspect.getmembers(a, inspect.isfunction))
pprint(inspect.getmembers(a, inspect.ismethod))
# Out:
# []
# [('__init__',
#   <bound method A.__init__ of <example.A object at 0x7f68dfcf5940>>),
#  ('get_name',
#   <bound method A.get_name of <example.A object at 0x7f68dfcf5940>>)]

# %% [markdown]
# ## Documentation Strings

# %%
import inspect
import example

print('B.__doc__:')
print(example.B.__doc__)

print('\ngetdoc(B):')
print(inspect.getdoc(example.B))

print('\nget method comment:')
print(inspect.getcomments(example.B.do_something))

print('\nget module comments:')
print(inspect.getcomments(example))
# Out:
# B.__doc__:
# This is the B class.
#     It is derived from A.
#
#
# getdoc(B):
# This is the B class.
# It is derived from A.
#
# get method comment:
# # This method is not part of A.
#
#
# get module comments:
# # filename: example.py
# # This comment appears first
# # and spans 2 lines.

# %% [markdown]
# ## Retrieving Source

# %%
import inspect
import example

# %%
print(inspect.getsource(example))
# Out:
# # filename: example.py
# # This comment appears first
# # and spans 2 lines.
#
# # This comment does not show up in the output of getcomments().
#
# """Sample file to serve as the basis for inspect examples.
# """
#
#
# def module_level_function(arg1, arg2='default', *args, **kwargs):
#     """This function is declared in the module."""
#     local_variable = arg1 * 2
#     return local_variable
#
#
# class A(object):
#     """The A class."""
#
#     def __init__(self, name):
#         self.name = name
#
#     def get_name(self):
#         "Returns the name of the instance."
#         return self.name
#
#
# instance_of_a = A('sample_instance')
#
#
# class B(A):
#     """This is the B class.
#     It is derived from A.
#     """
#
#     # This method is not part of A.
#     def do_something(self):
#         """Does some work"""
#
#     def get_name(self):
#         "Overrides version from A"
#         return 'B(' + self.name + ')'

# %%
print(inspect.getsource(example.A))
# Out:
# class A(object):
#     """The A class."""
#
#     def __init__(self, name):
#         self.name = name
#
#     def get_name(self):
#         "Returns the name of the instance."
#         return self.name

# %%
print(inspect.getsource(example.A.get_name))
# Out:
#     def get_name(self):
#         "Returns the name of the instance."
#         return self.name

# %%
pprint(inspect.getsourcelines(example.A.get_name)[0])
# Out:
# ['    def get_name(self):\n',
#  '        "Returns the name of the instance."\n',
#  '        return self.name\n']

# %% [markdown]
# ## Method and Function Signatures

# %%
import inspect
import example

sig = inspect.signature(example.module_level_function)
print('module_level_function{}'.format(sig))

print('\nParameter details:')
for name, param in sig.parameters.items():
    if param.kind == inspect.Parameter.POSITIONAL_ONLY:
        print('  {} (positional-only)'.format(name))
    elif param.kind == inspect.Parameter.POSITIONAL_OR_KEYWORD:
        if param.default != inspect.Parameter.empty:
            print('  {}={!r}'.format(name, param.default))
        else:
            print('  {}'.format(name))
    elif param.kind == inspect.Parameter.VAR_POSITIONAL:
        print('  *{}'.format(name))
    elif param.kind == inspect.Parameter.KEYWORD_ONLY:
        if param.default != inspect.Parameter.empty:
            print('  {}={!r} (keyword-only)'.format(
                name, param.default))
        else:
            print('  {} (keyword-only)'.format(name))
    elif param.kind == inspect.Parameter.VAR_KEYWORD:
        print('  **{}'.format(name))
# Out:
# module_level_function(arg1, arg2='default', *args, **kwargs)
#
# Parameter details:
#   arg1
#   arg2='default'
#   *args
#   **kwargs

# %% [markdown]
# ##  Stack and Frames

# %% [markdown]
# In addition to introspection of code objects, inspect includes functions for inspecting the runtime environment while a program is being executed.
#
# currentframe() returns the frame at the top of the stack (for the current function).

# %%
import inspect
import pprint


def recurse(limit, keyword='default', *, kwonly='must be named'):
    local_variable = '.' * limit
    keyword = 'changed value of argument'
    frame = inspect.currentframe()
    print('line {} of {}'.format(frame.f_lineno,
                                 frame.f_code.co_filename))
    print('locals:')
    pprint.pprint(frame.f_locals)
    print()
    if limit <= 0:
        return
    recurse(limit - 1)
    return local_variable

if __name__ == '__main__':
    recurse(2)
# Out:
# line 9 of <ipython-input-52-d52136f9aae2>
# locals:
# {'frame': <frame at 0x7f68deac2b58, file '<ipython-input-52-d52136f9aae2>', line 12, code recurse>,
#  'keyword': 'changed value of argument',
#  'kwonly': 'must be named',
#  'limit': 2,
#  'local_variable': '..'}
#
# line 9 of <ipython-input-52-d52136f9aae2>
# locals:
# {'frame': <frame at 0x55c2a2143fc8, file '<ipython-input-52-d52136f9aae2>', line 12, code recurse>,
#  'keyword': 'changed value of argument',
#  'kwonly': 'must be named',
#  'limit': 1,
#  'local_variable': '.'}
#
# line 9 of <ipython-input-52-d52136f9aae2>
# locals:
# {'frame': <frame at 0x55c2a213fdf8, file '<ipython-input-52-d52136f9aae2>', line 12, code recurse>,
#  'keyword': 'changed value of argument',
#  'kwonly': 'must be named',
#  'limit': 0,
#  'local_variable': ''}

# %%
import inspect
import pprint


def show_stack():
    for level in inspect.stack():
        print('{}[{}]\n  -> {}'.format(
            level.frame.f_code.co_filename,
            level.lineno,
            level.code_context[level.index].strip(),
        ))
        pprint.pprint(level.frame.f_locals)
        print()


def recurse(limit):
    local_variable = '.' * limit
    if limit <= 0:
        show_stack()
        return
    recurse(limit - 1)
    return local_variable


if __name__ == '__main__':
    recurse(1)
# Out:
# <ipython-input-54-993a2a265529>[6]
#   -> for level in inspect.stack():
# {'level': FrameInfo(frame=<frame at 0x7f68de8ee3e8, file '<ipython-input-54-993a2a265529>', line 12, code show_stack>, filename='<ipython-input-54-993a2a265529>', lineno=6, function='show_stack', code_context=['    for level in inspect.stack():\n'], index=0)}
#
# <ipython-input-54-993a2a265529>[19]
#   -> show_stack()
# {'limit': 0, 'local_variable': ''}
#
# <ipython-input-54-993a2a265529>[21]
#   -> recurse(limit - 1)
# {'limit': 1, 'local_variable': '.'}
#
# <ipython-input-54-993a2a265529>[26]
#   -> recurse(1)
# {'In': ['',
#         "get_ipython().system('ls')",
#         'src_code = """\n'
#         '# filename: example.py\n'
#         '\n'
#         '# This comment appears first\n'
#         '# and spans 2 lines.\n'
#         '\n'
#         '# This comment does not show up in the output of getcomments().\n'
#         '\n'
#         '"""Sample file to serve as the basis for inspect examples.\n'
#         '"""\n'
#         '\n'
#         '\n'
#         "def module_level_function(arg1, arg2='default', *args, **kwargs):\n"
#         '    """This function is declared in the module."""\n'
#         '    local_variable = arg1 * 2\n'
#         '    return local_variable\n'
#         '\n'
#         '\n'
#         'class A(object):\n'
#         '    """The A class."""\n'
#         '\n'
#         '    def __init__(self, name):\n'
#         '        self.name = name\n'
#         '\n'
#         '    def get_name(self):\n'
#         '        "Returns the name of the instance."\n'
#         '        return self.name\n'
#         '\n'
#         '\n'
#         "instance_of_a = A('sample_instance')\n"
#         '\n'
#         '\n'
#         'class B(A):\n'
#         '    """This is the B class.\n'
#         '    It is derived from A.\n'
#         '    """\n'
#         '\n'
#         '    # This method is not part of A.\n'
#         '    def do_something(self):\n'
#         '        """Does some work"""\n'
#         '\n'
#         '    def get_name(self):\n'
#         '        "Overrides version from A"\n'
#         "        return 'B(' + self.name + ')'\n"
#         '"""',
#         "src_code = '''\n"
#         '# filename: example.py\n'
#         '\n'
#         '# This comment appears first\n'
#         '# and spans 2 lines.\n'
#         '\n'
#         '# This comment does not show up in the output of getcomments().\n'
#         '\n'
#         '"""Sample file to serve as the basis for inspect examples.\n'
#         '"""\n'
#         '\n'
#         '\n'
#         "def module_level_function(arg1, arg2='default', *args, **kwargs):\n"
#         '    """This function is declared in the module."""\n'
#         '    local_variable = arg1 * 2\n'
#         '    return local_variable\n'
#         '\n'
#         '\n'
#         'class A(object):\n'
#         '    """The A class."""\n'
#         '\n'
#         '    def __init__(self, name):\n'
#         '        self.name = name\n'
#         '\n'
#         '    def get_name(self):\n'
#         '        "Returns the name of the instance."\n'
#         '        return self.name\n'
#         '\n'
#         '\n'
#         "instance_of_a = A('sample_instance')\n"
#         '\n'
#         '\n'
#         'class B(A):\n'
#         '    """This is the B class.\n'
#         '    It is derived from A.\n'
#         '    """\n'
#         '\n'
#         '    # This method is not part of A.\n'
#         '    def do_something(self):\n'
#         '        """Does some work"""\n'
#         '\n'
#         '    def get_name(self):\n'
#         '        "Overrides version from A"\n'
#         "        return 'B(' + self.name + ')'\n"
#         "'''",
#         'src_code',
#         "filename = src_code.split('\\n')[1]",
#         'filename',
#         "filename = src_code.split('\\n')[1].replace('#', '')",
#         'filename',
#         "filename = src_code.split('\\n')[1].replace('#', '').split(':')",
#         'filename',
#         "filename = src_code.split('\\n')[1].replace('#', "
#         "'').split(':')[1].strip()",
#         'filename',
#         "with open(filename, 'w') as f:\n    f.write(src_code)",
#         "get_ipython().system('ls')",
#         'import inspect\n'
#         '\n'
#         'import example\n'
#         '\n'
#         'for name, data in inspect.getmembers(example):\n'
#         "    if not name.startswith('__'):\n"
#         "        print('{} : {!r}'.format(name, data))",
#         'import inspect\n'
#         '\n'
#         'import example\n'
#         '\n'
#         'for name, data in inspect.getmembers(example):\n'
#         "    if not name.startswith('__'):\n"
#         "        print('{} : {!r}'.format(name, data))\n"
#         '        # {!r} calls __repr__()',
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         'for name, data in inspect.getmembers(example, inspect.isclass):\n'
#         "    if not name.startswith('__'):\n"
#         "        print('{} : {!r}'.format(name, data))\n"
#         '        # {!r} calls __repr__()',
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         '# predicate argument can be used to filter the types of objects '
#         'returned\n'
#         'for name, data in inspect.getmembers(example, inspect.isclass):\n'
#         "    if not name.startswith('__'):\n"
#         "        print('{} : {!r}'.format(name, data))\n"
#         '        # {!r} calls __repr__()',
#         'import inspect\n'
#         'from pprint import pprint\n'
#         '\n'
#         'import example\n'
#         '\n'
#         'pprint(inspect.getmembers(example.A))  # , width=65)',
#         'import inspect\n'
#         'from pprint import pprint\n'
#         '\n'
#         'import example\n'
#         '\n'
#         'pprint(inspect.getmembers(example.A), inspect.isfunction))',
#         'import inspect\n'
#         'from pprint import pprint\n'
#         '\n'
#         'import example\n'
#         '\n'
#         'pprint(inspect.getmembers(example.A, inspect.isfunction))',
#         'import inspect\n'
#         'from pprint import pprint\n'
#         '\n'
#         'import example\n'
#         '\n'
#         'pprint(inspect.getmembers(example.A, inspect.isfunction))\n'
#         '\n'
#         'pprint(inspect.getmembers(example.A, inspect.ismethod))',
#         'import inspect\n'
#         'from pprint import pprint\n'
#         '\n'
#         'import example\n'
#         '\n'
#         'pprint(inspect.getmembers(example.A, inspect.isfunction))\n'
#         '\n'
#         'pprint(inspect.getmembers(example.A, inspect.ismethod))\n'
#         '\n'
#         'pprint(inspect.getmembers(example.B, inspect.isfunction))',
#         'import inspect\n'
#         'from pprint import pprint\n'
#         '\n'
#         'import example\n'
#         '\n'
#         "a = example.A(name='inspect_getmembers')\n"
#         'pprint(inspect.getmembers(a, inspect.isfunction))\n'
#         'pprint(inspect.getmembers(a, inspect.ismethod))',
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         "print('B.__doc__:')\n"
#         'print(example.B.__doc__)\n'
#         'print()\n'
#         "print('getdoc(B):')\n"
#         'print(inspect.getdoc(example.B))',
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         "print('B.__doc__:')\n"
#         'print(example.B.__doc__)\n'
#         'print()\n'
#         "print('getdoc(B):')\n"
#         'print(inspect.getdoc(example.B))\n'
#         '\n'
#         'print(inspect.getcomments(example.B.do_something))',
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         "print('B.__doc__:')\n"
#         'print(example.B.__doc__)\n'
#         'print()\n'
#         "print('getdoc(B):')\n"
#         'print(inspect.getdoc(example.B))\n'
#         '\n'
#         "print('get method comment:')\n"
#         'print(inspect.getcomments(example.B.do_something))',
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         "print('B.__doc__:')\n"
#         'print(example.B.__doc__)\n'
#         '\n'
#         "print('\\ngetdoc(B):')\n"
#         'print(inspect.getdoc(example.B))\n'
#         '\n'
#         "print('\\nget method comment:')\n"
#         'print(inspect.getcomments(example.B.do_something))',
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         "print('B.__doc__:')\n"
#         'print(example.B.__doc__)\n'
#         '\n'
#         "print('\\ngetdoc(B):')\n"
#         'print(inspect.getdoc(example.B))\n'
#         '\n'
#         "print('\\nget method comment:')\n"
#         'print(inspect.getcomments(example.B.do_something))\n'
#         '\n'
#         "print('\\nget all comments:')\n"
#         'print(inspect.getcomments(example))',
#         "src_code = '''\n"
#         '# filename: example.py\n'
#         '# This comment appears first\n'
#         '# and spans 2 lines.\n'
#         '\n'
#         '# This comment does not show up in the output of getcomments().\n'
#         '\n'
#         '"""Sample file to serve as the basis for inspect examples.\n'
#         '"""\n'
#         '\n'
#         '\n'
#         "def module_level_function(arg1, arg2='default', *args, **kwargs):\n"
#         '    """This function is declared in the module."""\n'
#         '    local_variable = arg1 * 2\n'
#         '    return local_variable\n'
#         '\n'
#         '\n'
#         'class A(object):\n'
#         '    """The A class."""\n'
#         '\n'
#         '    def __init__(self, name):\n'
#         '        self.name = name\n'
#         '\n'
#         '    def get_name(self):\n'
#         '        "Returns the name of the instance."\n'
#         '        return self.name\n'
#         '\n'
#         '\n'
#         "instance_of_a = A('sample_instance')\n"
#         '\n'
#         '\n'
#         'class B(A):\n'
#         '    """This is the B class.\n'
#         '    It is derived from A.\n'
#         '    """\n'
#         '\n'
#         '    # This method is not part of A.\n'
#         '    def do_something(self):\n'
#         '        """Does some work"""\n'
#         '\n'
#         '    def get_name(self):\n'
#         '        "Overrides version from A"\n'
#         "        return 'B(' + self.name + ')'\n"
#         "'''",
#         "filename = src_code.split('\\n')[1].replace('#', "
#         "'').split(':')[1].strip()",
#         "with open(filename, 'w') as f:\n    f.write(src_code)",
#         "get_ipython().system('ls')",
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         'for name, data in inspect.getmembers(example):\n'
#         "    if not name.startswith('__'):\n"
#         "        print('{} : {!r}'.format(name, data))\n"
#         '        # {!r} calls __repr__()',
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         '# predicate argument can be used to filter the types of objects '
#         'returned\n'
#         'for name, data in inspect.getmembers(example, inspect.isclass):\n'
#         "    if not name.startswith('__'):\n"
#         "        print('{} : {!r}'.format(name, data))\n"
#         '        # {!r} calls __repr__()',
#         'import inspect\n'
#         'from pprint import pprint\n'
#         '\n'
#         'import example\n'
#         '\n'
#         'pprint(inspect.getmembers(example.A))  # , width=65)',
#         'import inspect\n'
#         'from pprint import pprint\n'
#         '\n'
#         'import example\n'
#         '\n'
#         'pprint(inspect.getmembers(example.A, inspect.isfunction))\n'
#         '\n'
#         'pprint(inspect.getmembers(example.A, inspect.ismethod))\n'
#         '\n'
#         'pprint(inspect.getmembers(example.B, inspect.isfunction))',
#         'import inspect\n'
#         'from pprint import pprint\n'
#         '\n'
#         'import example\n'
#         '\n'
#         "a = example.A(name='inspect_getmembers')\n"
#         'pprint(inspect.getmembers(a, inspect.isfunction))\n'
#         'pprint(inspect.getmembers(a, inspect.ismethod))',
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         "print('B.__doc__:')\n"
#         'print(example.B.__doc__)\n'
#         '\n'
#         "print('\\ngetdoc(B):')\n"
#         'print(inspect.getdoc(example.B))\n'
#         '\n'
#         "print('\\nget method comment:')\n"
#         'print(inspect.getcomments(example.B.do_something))\n'
#         '\n'
#         "print('\\nget all comments:')\n"
#         'print(inspect.getcomments(example))',
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         "print('B.__doc__:')\n"
#         'print(example.B.__doc__)\n'
#         '\n'
#         "print('\\ngetdoc(B):')\n"
#         'print(inspect.getdoc(example.B))\n'
#         '\n'
#         "print('\\nget method comment:')\n"
#         'print(inspect.getcomments(example.B.do_something))\n'
#         '\n'
#         "print('\\nget module comments:')\n"
#         'print(inspect.getcomments(example))',
#         'import inspect\nimport example\n\nprint(inspect.getsource(example.A))',
#         'print(inspect.getsource(example))',
#         'print(inspect.getsource(example.A.get_name))',
#         'print(inspect.getsourcelines(example.A.get_name))',
#         'print(inspect.getsourcelines(example.A.get_name)[0])',
#         'pprint(inspect.getsourcelines(example.A.get_name)[0])',
#         'import inspect\n'
#         'import example\n'
#         '\n'
#         'sig = inspect.signature(example.module_level_function)\n'
#         "print('module_level_function{}'.format(sig))\n"
#         '\n'
#         "print('\\nParameter details:')\n"
#         'for name, param in sig.parameters.items():\n'
#         '    if param.kind == inspect.Parameter.POSITIONAL_ONLY:\n'
#         "        print('  {} (positional-only)'.format(name))\n"
#         '    elif param.kind == inspect.Parameter.POSITIONAL_OR_KEYWORD:\n'
#         '        if param.default != inspect.Parameter.empty:\n'
#         "            print('  {}={!r}'.format(name, param.default))\n"
#         '        else:\n'
#         "            print('  {}'.format(name))\n"
#         '    elif param.kind == inspect.Parameter.VAR_POSITIONAL:\n'
#         "        print('  *{}'.format(name))\n"
#         '    elif param.kind == inspect.Parameter.KEYWORD_ONLY:\n'
#         '        if param.default != inspect.Parameter.empty:\n'
#         "            print('  {}={!r} (keyword-only)'.format(\n"
#         '                name, param.default))\n'
#         '        else:\n'
#         "            print('  {} (keyword-only)'.format(name))\n"
#         '    elif param.kind == inspect.Parameter.VAR_KEYWORD:\n'
#         "        print('  **{}'.format(name))",
#         'In addition to introspection of code objects, inspect includes '
#         'functions for inspecting the runtime environment while a program is '
#         'being executed.\n'
#         '\n'
#         'currentframe() returns the frame at the top of the stack (for the '
#         'current function).',
#         'import inspect\n'
#         'import pprint\n'
#         '\n'
#         '\n'
#         "def recurse(limit, keyword='default', *, kwonly='must be named'):\n"
#         "    local_variable = '.' * limit\n"
#         "    keyword = 'changed value of argument'\n"
#         '    frame = inspect.currentframe()\n'
#         "    print('line {} of {}'.format(frame.f_lineno,\n"
#         '                                 frame.f_code.co_filename))\n'
#         "    print('locals:')\n"
#         '    pprint.pprint(frame.f_locals)\n'
#         '    print()\n'
#         '    if limit <= 0:\n'
#         '        return\n'
#         '    recurse(limit - 1)\n'
#         '    return local_variable\n'
#         '\n'
#         "if __name__ == '__main__':\n"
#         '    recurse(2)',
#         'import inspect\n'
#         'import pprint\n'
#         '\n'
#         '\n'
#         "def recurse(limit, keyword='default', *, kwonly='must be named'):\n"
#         "    local_variable = '.' * limit\n"
#         "    keyword = 'changed value of argument'\n"
#         '    frame = inspect.currentframe()\n'
#         "    print('line {} of {}'.format(frame.f_lineno,\n"
#         '                                 frame.f_code.co_filename))\n'
#         "    print('locals:')\n"
#         '    pprint.pprint(frame.f_locals)\n'
#         '    print()\n'
#         '    if limit <= 0:\n'
#         '        return\n'
#         '    recurse(limit - 1)\n'
#         '    return local_variable\n'
#         '\n'
#         "if __name__ == '__main__':\n"
#         '    recurse(2)',
#         'import inspect\n'
#         'import pprint\n'
#         '\n'
#         '\n'
#         "def recurse(limit, keyword='default', *, kwonly='must be named'):\n"
#         "    local_variable = '.' * limit\n"
#         "    keyword = 'changed value of argument'\n"
#         '    frame = inspect.currentframe()\n'
#         "    print('line {} of {}'.format(frame.f_lineno,\n"
#         '                                 frame.f_code.co_filename))\n'
#         "    print('locals:')\n"
#         '    pprint.pprint(frame.f_locals)\n'
#         '    print()\n'
#         '    if limit <= 0:\n'
#         '        return\n'
#         '    recurse(limit - 1)\n'
#         '    return local_variable\n'
#         '\n'
#         "if __name__ == '__main__':\n"
#         '    recurse(1)',
#         'import inspect\n'
#         'import pprint\n'
#         '\n'
#         '\n'
#         "def recurse(limit, keyword='default', *, kwonly='must be named'):\n"
#         "    local_variable = '.' * limit\n"
#         "    keyword = 'changed value of argument'\n"
#         '    frame = inspect.currentframe()\n'
#         "    print('line {} of {}'.format(frame.f_lineno,\n"
#         '                                 frame.f_code.co_filename))\n'
#         "    print('locals:')\n"
#         '    pprint.pprint(frame.f_locals)\n'
#         '    print()\n'
#         '    if limit <= 0:\n'
#         '        return\n'
#         '    recurse(limit - 1)\n'
#         '    return local_variable\n'
#         '\n'
#         "if __name__ == '__main__':\n"
#         '    recurse(2)',
#         'import inspect\n'
#         'import pprint\n'
#         '\n'
#         '\n'
#         'def show_stack():\n'
#         '    for level in inspect.stack():\n'
#         "        print('{}[{}]\\n  -> {}'.format(\n"
#         '            level.frame.f_code.co_filename,\n'
#         '            level.lineno,\n'
#         '            level.code_context[level.index].strip(),\n'
#         '        ))\n'
#         '        pprint.pprint(level.frame.f_locals)\n'
#         '        print()\n'
#         '\n'
#         '\n'
#         'def recurse(limit):\n'
#         "    local_variable = '.' * limit\n"
#         '    if limit <= 0:\n'
#         '        show_stack()\n'
#         '        return\n'
#         '    recurse(limit - 1)\n'
#         '    return local_variable\n'
#         '\n'
#         '\n'
#         "if __name__ == '__main__':\n"
#         '    recurse(2)',
#         'import inspect\n'
#         'import pprint\n'
#         '\n'
#         '\n'
#         'def show_stack():\n'
#         '    for level in inspect.stack():\n'
#         "        print('{}[{}]\\n  -> {}'.format(\n"
#         '            level.frame.f_code.co_filename,\n'
#         '            level.lineno,\n'
#         '            level.code_context[level.index].strip(),\n'
#         '        ))\n'
#         '        pprint.pprint(level.frame.f_locals)\n'
#         '        print()\n'
#         '\n'
#         '\n'
#         'def recurse(limit):\n'
#         "    local_variable = '.' * limit\n"
#         '    if limit <= 0:\n'
#         '        show_stack()\n'
#         '        return\n'
#         '    recurse(limit - 1)\n'
#         '    return local_variable\n'
#         '\n'
#         '\n'
#         "if __name__ == '__main__':\n"
#         '    recurse(1)'],
#  'Out': {4: '\n'
#             '# filename: example.py\n'
#             '\n'
#             '# This comment appears first\n'
#             '# and spans 2 lines.\n'
#             '\n'
#             '# This comment does not show up in the output of getcomments().\n'
#             '\n'
#             '"""Sample file to serve as the basis for inspect examples.\n'
#             '"""\n'
#             '\n'
#             '\n'
#             "def module_level_function(arg1, arg2='default', *args, "
#             '**kwargs):\n'
#             '    """This function is declared in the module."""\n'
#             '    local_variable = arg1 * 2\n'
#             '    return local_variable\n'
#             '\n'
#             '\n'
#             'class A(object):\n'
#             '    """The A class."""\n'
#             '\n'
#             '    def __init__(self, name):\n'
#             '        self.name = name\n'
#             '\n'
#             '    def get_name(self):\n'
#             '        "Returns the name of the instance."\n'
#             '        return self.name\n'
#             '\n'
#             '\n'
#             "instance_of_a = A('sample_instance')\n"
#             '\n'
#             '\n'
#             'class B(A):\n'
#             '    """This is the B class.\n'
#             '    It is derived from A.\n'
#             '    """\n'
#             '\n'
#             '    # This method is not part of A.\n'
#             '    def do_something(self):\n'
#             '        """Does some work"""\n'
#             '\n'
#             '    def get_name(self):\n'
#             '        "Overrides version from A"\n'
#             "        return 'B(' + self.name + ')'\n",
#          6: '# filename: example.py',
#          8: ' filename: example.py',
#          10: [' filename', ' example.py'],
#          12: 'example.py'},
#  '_': 'example.py',
#  '_10': [' filename', ' example.py'],
#  '_12': 'example.py',
#  '_4': '\n'
#        '# filename: example.py\n'
#        '\n'
#        '# This comment appears first\n'
#        '# and spans 2 lines.\n'
#        '\n'
#        '# This comment does not show up in the output of getcomments().\n'
#        '\n'
#        '"""Sample file to serve as the basis for inspect examples.\n'
#        '"""\n'
#        '\n'
#        '\n'
#        "def module_level_function(arg1, arg2='default', *args, **kwargs):\n"
#        '    """This function is declared in the module."""\n'
#        '    local_variable = arg1 * 2\n'
#        '    return local_variable\n'
#        '\n'
#        '\n'
#        'class A(object):\n'
#        '    """The A class."""\n'
#        '\n'
#        '    def __init__(self, name):\n'
#        '        self.name = name\n'
#        '\n'
#        '    def get_name(self):\n'
#        '        "Returns the name of the instance."\n'
#        '        return self.name\n'
#        '\n'
#        '\n'
#        "instance_of_a = A('sample_instance')\n"
#        '\n'
#        '\n'
#        'class B(A):\n'
#        '    """This is the B class.\n'
#        '    It is derived from A.\n'
#        '    """\n'
#        '\n'
#        '    # This method is not part of A.\n'
#        '    def do_something(self):\n'
#        '        """Does some work"""\n'
#        '\n'
#        '    def get_name(self):\n'
#        '        "Overrides version from A"\n'
#        "        return 'B(' + self.name + ')'\n",
#  '_6': '# filename: example.py',
#  '_8': ' filename: example.py',
#  '__': [' filename', ' example.py'],
#  '___': ' filename: example.py',
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__spec__': None,
#  '_dh': ['/home/devopsgong/projects/py4kids/lesson-10-inspect'],
#  '_exit_code': 0,
#  '_i': 'import inspect\n'
#        'import pprint\n'
#        '\n'
#        '\n'
#        'def show_stack():\n'
#        '    for level in inspect.stack():\n'
#        "        print('{}[{}]\\n  -> {}'.format(\n"
#        '            level.frame.f_code.co_filename,\n'
#        '            level.lineno,\n'
#        '            level.code_context[level.index].strip(),\n'
#        '        ))\n'
#        '        pprint.pprint(level.frame.f_locals)\n'
#        '        print()\n'
#        '\n'
#        '\n'
#        'def recurse(limit):\n'
#        "    local_variable = '.' * limit\n"
#        '    if limit <= 0:\n'
#        '        show_stack()\n'
#        '        return\n'
#        '    recurse(limit - 1)\n'
#        '    return local_variable\n'
#        '\n'
#        '\n'
#        "if __name__ == '__main__':\n"
#        '    recurse(2)',
#  '_i1': '!ls',
#  '_i10': 'filename',
#  '_i11': "filename = src_code.split('\\n')[1].replace('#', "
#          "'').split(':')[1].strip()",
#  '_i12': 'filename',
#  '_i13': "with open(filename, 'w') as f:\n    f.write(src_code)",
#  '_i14': '!ls',
#  '_i15': 'import inspect\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'for name, data in inspect.getmembers(example):\n'
#          "    if not name.startswith('__'):\n"
#          "        print('{} : {!r}'.format(name, data))",
#  '_i16': 'import inspect\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'for name, data in inspect.getmembers(example):\n'
#          "    if not name.startswith('__'):\n"
#          "        print('{} : {!r}'.format(name, data))\n"
#          '        # {!r} calls __repr__()',
#  '_i17': 'import inspect\n'
#          'import example\n'
#          '\n'
#          'for name, data in inspect.getmembers(example, inspect.isclass):\n'
#          "    if not name.startswith('__'):\n"
#          "        print('{} : {!r}'.format(name, data))\n"
#          '        # {!r} calls __repr__()',
#  '_i18': 'import inspect\n'
#          'import example\n'
#          '\n'
#          '# predicate argument can be used to filter the types of objects '
#          'returned\n'
#          'for name, data in inspect.getmembers(example, inspect.isclass):\n'
#          "    if not name.startswith('__'):\n"
#          "        print('{} : {!r}'.format(name, data))\n"
#          '        # {!r} calls __repr__()',
#  '_i19': 'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A))  # , width=65)',
#  '_i2': 'src_code = """\n'
#         '# filename: example.py\n'
#         '\n'
#         '# This comment appears first\n'
#         '# and spans 2 lines.\n'
#         '\n'
#         '# This comment does not show up in the output of getcomments().\n'
#         '\n'
#         '"""Sample file to serve as the basis for inspect examples.\n'
#         '"""\n'
#         '\n'
#         '\n'
#         "def module_level_function(arg1, arg2='default', *args, **kwargs):\n"
#         '    """This function is declared in the module."""\n'
#         '    local_variable = arg1 * 2\n'
#         '    return local_variable\n'
#         '\n'
#         '\n'
#         'class A(object):\n'
#         '    """The A class."""\n'
#         '\n'
#         '    def __init__(self, name):\n'
#         '        self.name = name\n'
#         '\n'
#         '    def get_name(self):\n'
#         '        "Returns the name of the instance."\n'
#         '        return self.name\n'
#         '\n'
#         '\n'
#         "instance_of_a = A('sample_instance')\n"
#         '\n'
#         '\n'
#         'class B(A):\n'
#         '    """This is the B class.\n'
#         '    It is derived from A.\n'
#         '    """\n'
#         '\n'
#         '    # This method is not part of A.\n'
#         '    def do_something(self):\n'
#         '        """Does some work"""\n'
#         '\n'
#         '    def get_name(self):\n'
#         '        "Overrides version from A"\n'
#         "        return 'B(' + self.name + ')'\n"
#         '"""',
#  '_i20': 'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A), inspect.isfunction))',
#  '_i21': 'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A, inspect.isfunction))',
#  '_i22': 'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A, inspect.isfunction))\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A, inspect.ismethod))',
#  '_i23': 'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A, inspect.isfunction))\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A, inspect.ismethod))\n'
#          '\n'
#          'pprint(inspect.getmembers(example.B, inspect.isfunction))',
#  '_i24': 'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          "a = example.A(name='inspect_getmembers')\n"
#          'pprint(inspect.getmembers(a, inspect.isfunction))\n'
#          'pprint(inspect.getmembers(a, inspect.ismethod))',
#  '_i25': 'import inspect\n'
#          'import example\n'
#          '\n'
#          "print('B.__doc__:')\n"
#          'print(example.B.__doc__)\n'
#          'print()\n'
#          "print('getdoc(B):')\n"
#          'print(inspect.getdoc(example.B))',
#  '_i26': 'import inspect\n'
#          'import example\n'
#          '\n'
#          "print('B.__doc__:')\n"
#          'print(example.B.__doc__)\n'
#          'print()\n'
#          "print('getdoc(B):')\n"
#          'print(inspect.getdoc(example.B))\n'
#          '\n'
#          'print(inspect.getcomments(example.B.do_something))',
#  '_i27': 'import inspect\n'
#          'import example\n'
#          '\n'
#          "print('B.__doc__:')\n"
#          'print(example.B.__doc__)\n'
#          'print()\n'
#          "print('getdoc(B):')\n"
#          'print(inspect.getdoc(example.B))\n'
#          '\n'
#          "print('get method comment:')\n"
#          'print(inspect.getcomments(example.B.do_something))',
#  '_i28': 'import inspect\n'
#          'import example\n'
#          '\n'
#          "print('B.__doc__:')\n"
#          'print(example.B.__doc__)\n'
#          '\n'
#          "print('\\ngetdoc(B):')\n"
#          'print(inspect.getdoc(example.B))\n'
#          '\n'
#          "print('\\nget method comment:')\n"
#          'print(inspect.getcomments(example.B.do_something))',
#  '_i29': 'import inspect\n'
#          'import example\n'
#          '\n'
#          "print('B.__doc__:')\n"
#          'print(example.B.__doc__)\n'
#          '\n'
#          "print('\\ngetdoc(B):')\n"
#          'print(inspect.getdoc(example.B))\n'
#          '\n'
#          "print('\\nget method comment:')\n"
#          'print(inspect.getcomments(example.B.do_something))\n'
#          '\n'
#          "print('\\nget all comments:')\n"
#          'print(inspect.getcomments(example))',
#  '_i3': "src_code = '''\n"
#         '# filename: example.py\n'
#         '\n'
#         '# This comment appears first\n'
#         '# and spans 2 lines.\n'
#         '\n'
#         '# This comment does not show up in the output of getcomments().\n'
#         '\n'
#         '"""Sample file to serve as the basis for inspect examples.\n'
#         '"""\n'
#         '\n'
#         '\n'
#         "def module_level_function(arg1, arg2='default', *args, **kwargs):\n"
#         '    """This function is declared in the module."""\n'
#         '    local_variable = arg1 * 2\n'
#         '    return local_variable\n'
#         '\n'
#         '\n'
#         'class A(object):\n'
#         '    """The A class."""\n'
#         '\n'
#         '    def __init__(self, name):\n'
#         '        self.name = name\n'
#         '\n'
#         '    def get_name(self):\n'
#         '        "Returns the name of the instance."\n'
#         '        return self.name\n'
#         '\n'
#         '\n'
#         "instance_of_a = A('sample_instance')\n"
#         '\n'
#         '\n'
#         'class B(A):\n'
#         '    """This is the B class.\n'
#         '    It is derived from A.\n'
#         '    """\n'
#         '\n'
#         '    # This method is not part of A.\n'
#         '    def do_something(self):\n'
#         '        """Does some work"""\n'
#         '\n'
#         '    def get_name(self):\n'
#         '        "Overrides version from A"\n'
#         "        return 'B(' + self.name + ')'\n"
#         "'''",
#  '_i30': "src_code = '''\n"
#          '# filename: example.py\n'
#          '# This comment appears first\n'
#          '# and spans 2 lines.\n'
#          '\n'
#          '# This comment does not show up in the output of getcomments().\n'
#          '\n'
#          '"""Sample file to serve as the basis for inspect examples.\n'
#          '"""\n'
#          '\n'
#          '\n'
#          "def module_level_function(arg1, arg2='default', *args, **kwargs):\n"
#          '    """This function is declared in the module."""\n'
#          '    local_variable = arg1 * 2\n'
#          '    return local_variable\n'
#          '\n'
#          '\n'
#          'class A(object):\n'
#          '    """The A class."""\n'
#          '\n'
#          '    def __init__(self, name):\n'
#          '        self.name = name\n'
#          '\n'
#          '    def get_name(self):\n'
#          '        "Returns the name of the instance."\n'
#          '        return self.name\n'
#          '\n'
#          '\n'
#          "instance_of_a = A('sample_instance')\n"
#          '\n'
#          '\n'
#          'class B(A):\n'
#          '    """This is the B class.\n'
#          '    It is derived from A.\n'
#          '    """\n'
#          '\n'
#          '    # This method is not part of A.\n'
#          '    def do_something(self):\n'
#          '        """Does some work"""\n'
#          '\n'
#          '    def get_name(self):\n'
#          '        "Overrides version from A"\n'
#          "        return 'B(' + self.name + ')'\n"
#          "'''",
#  '_i31': "filename = src_code.split('\\n')[1].replace('#', "
#          "'').split(':')[1].strip()",
#  '_i32': "with open(filename, 'w') as f:\n    f.write(src_code)",
#  '_i33': '!ls',
#  '_i34': 'import inspect\n'
#          'import example\n'
#          '\n'
#          'for name, data in inspect.getmembers(example):\n'
#          "    if not name.startswith('__'):\n"
#          "        print('{} : {!r}'.format(name, data))\n"
#          '        # {!r} calls __repr__()',
#  '_i35': 'import inspect\n'
#          'import example\n'
#          '\n'
#          '# predicate argument can be used to filter the types of objects '
#          'returned\n'
#          'for name, data in inspect.getmembers(example, inspect.isclass):\n'
#          "    if not name.startswith('__'):\n"
#          "        print('{} : {!r}'.format(name, data))\n"
#          '        # {!r} calls __repr__()',
#  '_i36': 'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A))  # , width=65)',
#  '_i37': 'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A, inspect.isfunction))\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A, inspect.ismethod))\n'
#          '\n'
#          'pprint(inspect.getmembers(example.B, inspect.isfunction))',
#  '_i38': 'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          "a = example.A(name='inspect_getmembers')\n"
#          'pprint(inspect.getmembers(a, inspect.isfunction))\n'
#          'pprint(inspect.getmembers(a, inspect.ismethod))',
#  '_i39': 'import inspect\n'
#          'import example\n'
#          '\n'
#          "print('B.__doc__:')\n"
#          'print(example.B.__doc__)\n'
#          '\n'
#          "print('\\ngetdoc(B):')\n"
#          'print(inspect.getdoc(example.B))\n'
#          '\n'
#          "print('\\nget method comment:')\n"
#          'print(inspect.getcomments(example.B.do_something))\n'
#          '\n'
#          "print('\\nget all comments:')\n"
#          'print(inspect.getcomments(example))',
#  '_i4': 'src_code',
#  '_i40': 'import inspect\n'
#          'import example\n'
#          '\n'
#          "print('B.__doc__:')\n"
#          'print(example.B.__doc__)\n'
#          '\n'
#          "print('\\ngetdoc(B):')\n"
#          'print(inspect.getdoc(example.B))\n'
#          '\n'
#          "print('\\nget method comment:')\n"
#          'print(inspect.getcomments(example.B.do_something))\n'
#          '\n'
#          "print('\\nget module comments:')\n"
#          'print(inspect.getcomments(example))',
#  '_i41': 'import inspect\n'
#          'import example\n'
#          '\n'
#          'print(inspect.getsource(example.A))',
#  '_i42': 'print(inspect.getsource(example))',
#  '_i43': 'print(inspect.getsource(example.A.get_name))',
#  '_i44': 'print(inspect.getsourcelines(example.A.get_name))',
#  '_i45': 'print(inspect.getsourcelines(example.A.get_name)[0])',
#  '_i46': 'pprint(inspect.getsourcelines(example.A.get_name)[0])',
#  '_i47': 'import inspect\n'
#          'import example\n'
#          '\n'
#          'sig = inspect.signature(example.module_level_function)\n'
#          "print('module_level_function{}'.format(sig))\n"
#          '\n'
#          "print('\\nParameter details:')\n"
#          'for name, param in sig.parameters.items():\n'
#          '    if param.kind == inspect.Parameter.POSITIONAL_ONLY:\n'
#          "        print('  {} (positional-only)'.format(name))\n"
#          '    elif param.kind == inspect.Parameter.POSITIONAL_OR_KEYWORD:\n'
#          '        if param.default != inspect.Parameter.empty:\n'
#          "            print('  {}={!r}'.format(name, param.default))\n"
#          '        else:\n'
#          "            print('  {}'.format(name))\n"
#          '    elif param.kind == inspect.Parameter.VAR_POSITIONAL:\n'
#          "        print('  *{}'.format(name))\n"
#          '    elif param.kind == inspect.Parameter.KEYWORD_ONLY:\n'
#          '        if param.default != inspect.Parameter.empty:\n'
#          "            print('  {}={!r} (keyword-only)'.format(\n"
#          '                name, param.default))\n'
#          '        else:\n'
#          "            print('  {} (keyword-only)'.format(name))\n"
#          '    elif param.kind == inspect.Parameter.VAR_KEYWORD:\n'
#          "        print('  **{}'.format(name))",
#  '_i48': 'In addition to introspection of code objects, inspect includes '
#          'functions for inspecting the runtime environment while a program is '
#          'being executed.\n'
#          '\n'
#          'currentframe() returns the frame at the top of the stack (for the '
#          'current function).',
#  '_i49': 'import inspect\n'
#          'import pprint\n'
#          '\n'
#          '\n'
#          "def recurse(limit, keyword='default', *, kwonly='must be named'):\n"
#          "    local_variable = '.' * limit\n"
#          "    keyword = 'changed value of argument'\n"
#          '    frame = inspect.currentframe()\n'
#          "    print('line {} of {}'.format(frame.f_lineno,\n"
#          '                                 frame.f_code.co_filename))\n'
#          "    print('locals:')\n"
#          '    pprint.pprint(frame.f_locals)\n'
#          '    print()\n'
#          '    if limit <= 0:\n'
#          '        return\n'
#          '    recurse(limit - 1)\n'
#          '    return local_variable\n'
#          '\n'
#          "if __name__ == '__main__':\n"
#          '    recurse(2)',
#  '_i5': "filename = src_code.split('\\n')[1]",
#  '_i50': 'import inspect\n'
#          'import pprint\n'
#          '\n'
#          '\n'
#          "def recurse(limit, keyword='default', *, kwonly='must be named'):\n"
#          "    local_variable = '.' * limit\n"
#          "    keyword = 'changed value of argument'\n"
#          '    frame = inspect.currentframe()\n'
#          "    print('line {} of {}'.format(frame.f_lineno,\n"
#          '                                 frame.f_code.co_filename))\n'
#          "    print('locals:')\n"
#          '    pprint.pprint(frame.f_locals)\n'
#          '    print()\n'
#          '    if limit <= 0:\n'
#          '        return\n'
#          '    recurse(limit - 1)\n'
#          '    return local_variable\n'
#          '\n'
#          "if __name__ == '__main__':\n"
#          '    recurse(2)',
#  '_i51': 'import inspect\n'
#          'import pprint\n'
#          '\n'
#          '\n'
#          "def recurse(limit, keyword='default', *, kwonly='must be named'):\n"
#          "    local_variable = '.' * limit\n"
#          "    keyword = 'changed value of argument'\n"
#          '    frame = inspect.currentframe()\n'
#          "    print('line {} of {}'.format(frame.f_lineno,\n"
#          '                                 frame.f_code.co_filename))\n'
#          "    print('locals:')\n"
#          '    pprint.pprint(frame.f_locals)\n'
#          '    print()\n'
#          '    if limit <= 0:\n'
#          '        return\n'
#          '    recurse(limit - 1)\n'
#          '    return local_variable\n'
#          '\n'
#          "if __name__ == '__main__':\n"
#          '    recurse(1)',
#  '_i52': 'import inspect\n'
#          'import pprint\n'
#          '\n'
#          '\n'
#          "def recurse(limit, keyword='default', *, kwonly='must be named'):\n"
#          "    local_variable = '.' * limit\n"
#          "    keyword = 'changed value of argument'\n"
#          '    frame = inspect.currentframe()\n'
#          "    print('line {} of {}'.format(frame.f_lineno,\n"
#          '                                 frame.f_code.co_filename))\n'
#          "    print('locals:')\n"
#          '    pprint.pprint(frame.f_locals)\n'
#          '    print()\n'
#          '    if limit <= 0:\n'
#          '        return\n'
#          '    recurse(limit - 1)\n'
#          '    return local_variable\n'
#          '\n'
#          "if __name__ == '__main__':\n"
#          '    recurse(2)',
#  '_i53': 'import inspect\n'
#          'import pprint\n'
#          '\n'
#          '\n'
#          'def show_stack():\n'
#          '    for level in inspect.stack():\n'
#          "        print('{}[{}]\\n  -> {}'.format(\n"
#          '            level.frame.f_code.co_filename,\n'
#          '            level.lineno,\n'
#          '            level.code_context[level.index].strip(),\n'
#          '        ))\n'
#          '        pprint.pprint(level.frame.f_locals)\n'
#          '        print()\n'
#          '\n'
#          '\n'
#          'def recurse(limit):\n'
#          "    local_variable = '.' * limit\n"
#          '    if limit <= 0:\n'
#          '        show_stack()\n'
#          '        return\n'
#          '    recurse(limit - 1)\n'
#          '    return local_variable\n'
#          '\n'
#          '\n'
#          "if __name__ == '__main__':\n"
#          '    recurse(2)',
#  '_i54': 'import inspect\n'
#          'import pprint\n'
#          '\n'
#          '\n'
#          'def show_stack():\n'
#          '    for level in inspect.stack():\n'
#          "        print('{}[{}]\\n  -> {}'.format(\n"
#          '            level.frame.f_code.co_filename,\n'
#          '            level.lineno,\n'
#          '            level.code_context[level.index].strip(),\n'
#          '        ))\n'
#          '        pprint.pprint(level.frame.f_locals)\n'
#          '        print()\n'
#          '\n'
#          '\n'
#          'def recurse(limit):\n'
#          "    local_variable = '.' * limit\n"
#          '    if limit <= 0:\n'
#          '        show_stack()\n'
#          '        return\n'
#          '    recurse(limit - 1)\n'
#          '    return local_variable\n'
#          '\n'
#          '\n'
#          "if __name__ == '__main__':\n"
#          '    recurse(1)',
#  '_i6': 'filename',
#  '_i7': "filename = src_code.split('\\n')[1].replace('#', '')",
#  '_i8': 'filename',
#  '_i9': "filename = src_code.split('\\n')[1].replace('#', '').split(':')",
#  '_ih': ['',
#          "get_ipython().system('ls')",
#          'src_code = """\n'
#          '# filename: example.py\n'
#          '\n'
#          '# This comment appears first\n'
#          '# and spans 2 lines.\n'
#          '\n'
#          '# This comment does not show up in the output of getcomments().\n'
#          '\n'
#          '"""Sample file to serve as the basis for inspect examples.\n'
#          '"""\n'
#          '\n'
#          '\n'
#          "def module_level_function(arg1, arg2='default', *args, **kwargs):\n"
#          '    """This function is declared in the module."""\n'
#          '    local_variable = arg1 * 2\n'
#          '    return local_variable\n'
#          '\n'
#          '\n'
#          'class A(object):\n'
#          '    """The A class."""\n'
#          '\n'
#          '    def __init__(self, name):\n'
#          '        self.name = name\n'
#          '\n'
#          '    def get_name(self):\n'
#          '        "Returns the name of the instance."\n'
#          '        return self.name\n'
#          '\n'
#          '\n'
#          "instance_of_a = A('sample_instance')\n"
#          '\n'
#          '\n'
#          'class B(A):\n'
#          '    """This is the B class.\n'
#          '    It is derived from A.\n'
#          '    """\n'
#          '\n'
#          '    # This method is not part of A.\n'
#          '    def do_something(self):\n'
#          '        """Does some work"""\n'
#          '\n'
#          '    def get_name(self):\n'
#          '        "Overrides version from A"\n'
#          "        return 'B(' + self.name + ')'\n"
#          '"""',
#          "src_code = '''\n"
#          '# filename: example.py\n'
#          '\n'
#          '# This comment appears first\n'
#          '# and spans 2 lines.\n'
#          '\n'
#          '# This comment does not show up in the output of getcomments().\n'
#          '\n'
#          '"""Sample file to serve as the basis for inspect examples.\n'
#          '"""\n'
#          '\n'
#          '\n'
#          "def module_level_function(arg1, arg2='default', *args, **kwargs):\n"
#          '    """This function is declared in the module."""\n'
#          '    local_variable = arg1 * 2\n'
#          '    return local_variable\n'
#          '\n'
#          '\n'
#          'class A(object):\n'
#          '    """The A class."""\n'
#          '\n'
#          '    def __init__(self, name):\n'
#          '        self.name = name\n'
#          '\n'
#          '    def get_name(self):\n'
#          '        "Returns the name of the instance."\n'
#          '        return self.name\n'
#          '\n'
#          '\n'
#          "instance_of_a = A('sample_instance')\n"
#          '\n'
#          '\n'
#          'class B(A):\n'
#          '    """This is the B class.\n'
#          '    It is derived from A.\n'
#          '    """\n'
#          '\n'
#          '    # This method is not part of A.\n'
#          '    def do_something(self):\n'
#          '        """Does some work"""\n'
#          '\n'
#          '    def get_name(self):\n'
#          '        "Overrides version from A"\n'
#          "        return 'B(' + self.name + ')'\n"
#          "'''",
#          'src_code',
#          "filename = src_code.split('\\n')[1]",
#          'filename',
#          "filename = src_code.split('\\n')[1].replace('#', '')",
#          'filename',
#          "filename = src_code.split('\\n')[1].replace('#', '').split(':')",
#          'filename',
#          "filename = src_code.split('\\n')[1].replace('#', "
#          "'').split(':')[1].strip()",
#          'filename',
#          "with open(filename, 'w') as f:\n    f.write(src_code)",
#          "get_ipython().system('ls')",
#          'import inspect\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'for name, data in inspect.getmembers(example):\n'
#          "    if not name.startswith('__'):\n"
#          "        print('{} : {!r}'.format(name, data))",
#          'import inspect\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'for name, data in inspect.getmembers(example):\n'
#          "    if not name.startswith('__'):\n"
#          "        print('{} : {!r}'.format(name, data))\n"
#          '        # {!r} calls __repr__()',
#          'import inspect\n'
#          'import example\n'
#          '\n'
#          'for name, data in inspect.getmembers(example, inspect.isclass):\n'
#          "    if not name.startswith('__'):\n"
#          "        print('{} : {!r}'.format(name, data))\n"
#          '        # {!r} calls __repr__()',
#          'import inspect\n'
#          'import example\n'
#          '\n'
#          '# predicate argument can be used to filter the types of objects '
#          'returned\n'
#          'for name, data in inspect.getmembers(example, inspect.isclass):\n'
#          "    if not name.startswith('__'):\n"
#          "        print('{} : {!r}'.format(name, data))\n"
#          '        # {!r} calls __repr__()',
#          'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A))  # , width=65)',
#          'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A), inspect.isfunction))',
#          'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A, inspect.isfunction))',
#          'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A, inspect.isfunction))\n'
#          '\n'
#          'pprint(inspect.getmembers(example.A, inspect.ismethod))',
#          'import inspect\n'
#          'from pprint import pprint\n'
#          '\n'
#          'import example\n'
#          '\n'
# ...
#            'content': {'allow_stdin': True,
#                        'code': 'import inspect\n'
#                                'import pprint\n'
#                                '\n'
#                                '\n'
#                                'def show_stack():\n'
#                                '    for level in inspect.stack():\n'
#                                "        print('{}[{}]\\n  -> {}'.format(\n"
#                                '            level.frame.f_code.co_filename,\n'
#                                '            level.lineno,\n'
#                                '            '
#                                'level.code_context[level.index].strip(),\n'
#                                '        ))\n'
#                                '        pprint.pprint(level.frame.f_locals)\n'
#                                '        print()\n'
#                                '\n'
#                                '\n'
#                                'def recurse(limit):\n'
#                                "    local_variable = '.' * limit\n"
#                                '    if limit <= 0:\n'
#                                '        show_stack()\n'
#                                '        return\n'
#                                '    recurse(limit - 1)\n'
#                                '    return local_variable\n'
#                                '\n'
#                                '\n'
#                                "if __name__ == '__main__':\n"
#                                '    recurse(1)',
#                        'silent': False,
#                        'stop_on_error': True,
#                        'store_history': True,
#                        'user_expressions': {}},
#            'header': {'date': datetime.datetime(2020, 3, 29, 1, 21, 32, 29681, tzinfo=tzutc()),
#                       'msg_id': 'f2ea7cd072944bb28e4ae5d2394f6dd6',
#                       'msg_type': 'execute_request',
#                       'session': 'd17c236ef5d343fb8a5a58ce5c9312a4',
#                       'username': 'username',
#                       'version': '5.2'},
#            'metadata': {},
#            'msg_id': 'f2ea7cd072944bb28e4ae5d2394f6dd6',
#            'msg_type': 'execute_request',
#            'parent_header': {}}),
#  'func': <function Kernel.execute_request at 0x7f68fd3c78c8>,
#  'future': <Future pending>,
#  'kwargs': {},
#  'result': <generator object Kernel.execute_request at 0x7f68deacfed0>}
#
# /home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py[272]
#   -> yield gen.maybe_future(handler(stream, idents, msg))
# {'handler': <bound method Kernel.execute_request of <ipykernel.ipkernel.IPythonKernel object at 0x7f68fd37c908>>,
#  'idents': [b'd17c236ef5d343fb8a5a58ce5c9312a4'],
#  'msg': {'buffers': [],
#          'content': {'allow_stdin': True,
#                      'code': 'import inspect\n'
#                              'import pprint\n'
#                              '\n'
#                              '\n'
#                              'def show_stack():\n'
#                              '    for level in inspect.stack():\n'
#                              "        print('{}[{}]\\n  -> {}'.format(\n"
#                              '            level.frame.f_code.co_filename,\n'
#                              '            level.lineno,\n'
#                              '            '
#                              'level.code_context[level.index].strip(),\n'
#                              '        ))\n'
#                              '        pprint.pprint(level.frame.f_locals)\n'
#                              '        print()\n'
#                              '\n'
#                              '\n'
#                              'def recurse(limit):\n'
#                              "    local_variable = '.' * limit\n"
#                              '    if limit <= 0:\n'
#                              '        show_stack()\n'
#                              '        return\n'
#                              '    recurse(limit - 1)\n'
#                              '    return local_variable\n'
#                              '\n'
#                              '\n'
#                              "if __name__ == '__main__':\n"
#                              '    recurse(1)',
#                      'silent': False,
#                      'stop_on_error': True,
#                      'store_history': True,
#                      'user_expressions': {}},
#          'header': {'date': datetime.datetime(2020, 3, 29, 1, 21, 32, 29681, tzinfo=tzutc()),
#                     'msg_id': 'f2ea7cd072944bb28e4ae5d2394f6dd6',
#                     'msg_type': 'execute_request',
#                     'session': 'd17c236ef5d343fb8a5a58ce5c9312a4',
#                     'username': 'username',
#                     'version': '5.2'},
#          'metadata': {},
#          'msg_id': 'f2ea7cd072944bb28e4ae5d2394f6dd6',
#          'msg_type': 'execute_request',
#          'parent_header': {}},
#  'msg_type': 'execute_request',
#  'self': <ipykernel.ipkernel.IPythonKernel object at 0x7f68fd37c908>,
#  'stream': <zmq.eventloop.zmqstream.ZMQStream object at 0x7f68fd3771d0>}
#
# /home/devopsgong/anaconda3/lib/python3.7/site-packages/tornado/gen.py[209]
#   -> yielded = next(result)
# {'args': (<ipykernel.ipkernel.IPythonKernel object at 0x7f68fd37c908>,
#           <zmq.eventloop.zmqstream.ZMQStream object at 0x7f68fd3771d0>,
#           [<zmq.sugar.frame.Frame object at 0x7f68fc2b78e8>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b79a0>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b7a58>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b7b10>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b7bc8>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b7c80>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b7d38>]),
#  'func': <function Kernel.dispatch_shell at 0x7f68fd3bad08>,
#  'future': <Future pending>,
#  'kwargs': {},
#  'result': <generator object Kernel.dispatch_shell at 0x7f68deacfb10>}
#
# /home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py[365]
#   -> yield gen.maybe_future(dispatch(*args))
# {'args': (<zmq.eventloop.zmqstream.ZMQStream object at 0x7f68fd3771d0>,
#           [<zmq.sugar.frame.Frame object at 0x7f68fc2b78e8>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b79a0>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b7a58>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b7b10>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b7bc8>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b7c80>,
#            <zmq.sugar.frame.Frame object at 0x7f68fc2b7d38>]),
#  'dispatch': <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f68fd37c908>>,
#  'priority': 10,
#  'self': <ipykernel.ipkernel.IPythonKernel object at 0x7f68fd37c908>,
#  't': 60,
#  'wait': True}
#
# /home/devopsgong/anaconda3/lib/python3.7/site-packages/tornado/gen.py[748]
#   -> yielded = self.gen.send(value)
# {'exc_info': None,
#  'future': None,
#  'self': <tornado.gen.Runner object at 0x7f68fc30e550>,
#  'value': (10,
#            60,
#            <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f68fd37c908>>,
#            (<zmq.eventloop.zmqstream.ZMQStream object at 0x7f68fd3771d0>,
#             [<zmq.sugar.frame.Frame object at 0x7f68fc2b78e8>,
#              <zmq.sugar.frame.Frame object at 0x7f68fc2b79a0>,
#              <zmq.sugar.frame.Frame object at 0x7f68fc2b7a58>,
#              <zmq.sugar.frame.Frame object at 0x7f68fc2b7b10>,
#              <zmq.sugar.frame.Frame object at 0x7f68fc2b7bc8>,
#              <zmq.sugar.frame.Frame object at 0x7f68fc2b7c80>,
#              <zmq.sugar.frame.Frame object at 0x7f68fc2b7d38>]))}
#
# /home/devopsgong/anaconda3/lib/python3.7/site-packages/tornado/gen.py[787]
#   -> self.run()
# {'f': None, 'self': <tornado.gen.Runner object at 0x7f68fc30e550>}
#
# /home/devopsgong/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py[743]
#   -> ret = callback()
# {'callback': functools.partial(<function Runner.handle_yield.<locals>.inner at 0x7f68de900d90>, <Future finished result=(10, 60, <bound method...7f68fd37c908>>, (<zmq.eventloo...x7f68fd3771d0>, [<zmq.sugar.fr...x7f68fc2b78e8>, <zmq.sugar.fr...x7f68fc2b79a0>, <zmq.sugar.fr...x7f68fc2b7a58>, <zmq.sugar.fr...x7f68fc2b7b10>, <zmq.sugar.fr...x7f68fc2b7bc8>, <zmq.sugar.fr...x7f68fc2b7c80>, ...]))>),
#  'self': <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f68fd3e17b8>}
#
# /home/devopsgong/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py[690]
#   -> lambda f: self._run_callback(functools.partial(callback, future))
# {'callback': <function Runner.handle_yield.<locals>.inner at 0x7f68de900d90>,
#  'f': <Future finished result=(10, 60, <bound method...7f68fd37c908>>, (<zmq.eventloo...x7f68fd3771d0>, [<zmq.sugar.fr...x7f68fc2b78e8>, <zmq.sugar.fr...x7f68fc2b79a0>, <zmq.sugar.fr...x7f68fc2b7a58>, <zmq.sugar.fr...x7f68fc2b7b10>, <zmq.sugar.fr...x7f68fc2b7bc8>, <zmq.sugar.fr...x7f68fc2b7c80>, ...]))>,
#  'future': <Future finished result=(10, 60, <bound method...7f68fd37c908>>, (<zmq.eventloo...x7f68fd3771d0>, [<zmq.sugar.fr...x7f68fc2b78e8>, <zmq.sugar.fr...x7f68fc2b79a0>, <zmq.sugar.fr...x7f68fc2b7a58>, <zmq.sugar.fr...x7f68fc2b7b10>, <zmq.sugar.fr...x7f68fc2b7bc8>, <zmq.sugar.fr...x7f68fc2b7c80>, ...]))>,
#  'self': <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f68fd3e17b8>}
#
# /home/devopsgong/anaconda3/lib/python3.7/asyncio/events.py[88]
#   -> self._context.run(self._callback, *self._args)
# {'self': <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...7c80>, ...]))>) at /home/devopsgong/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py:690>}
#
# /home/devopsgong/anaconda3/lib/python3.7/asyncio/base_events.py[1764]
#   -> handle._run()
# {'end_time': 37081.540557128996,
#  'event_list': [],
#  'handle': <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...7c80>, ...]))>) at /home/devopsgong/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py:690>,
#  'i': 0,
#  'ntodo': 2,
#  'sched_count': 0,
#  'self': <_UnixSelectorEventLoop running=True closed=False debug=False>,
#  'timeout': 0}
#
# /home/devopsgong/anaconda3/lib/python3.7/asyncio/base_events.py[528]
#   -> self._run_once()
# {'old_agen_hooks': asyncgen_hooks(firstiter=None, finalizer=None),
#  'self': <_UnixSelectorEventLoop running=True closed=False debug=False>}
#
# /home/devopsgong/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py[148]
#   -> self.asyncio_loop.run_forever()
# {'old_loop': <_UnixSelectorEventLoop running=True closed=False debug=False>,
#  'self': <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f68fd3e17b8>}
#
# /home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py[505]
#   -> self.io_loop.start()
# {'self': <ipykernel.kernelapp.IPKernelApp object at 0x7f690132b6a0>}
#
# /home/devopsgong/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py[658]
#   -> app.start()
# {'app': <ipykernel.kernelapp.IPKernelApp object at 0x7f690132b6a0>,
#  'argv': None,
#  'cls': <class 'ipykernel.kernelapp.IPKernelApp'>,
#  'kwargs': {}}
#
# /home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py[16]
#   -> app.launch_new_instance()
# {'__annotations__': {},
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__cached__': '/home/devopsgong/anaconda3/lib/python3.7/site-packages/__pycache__/ipykernel_launcher.cpython-37.pyc',
#  '__doc__': 'Entry point for launching an IPython kernel.\n'
#             '\n'
#             'This is separate from the ipykernel package so we can avoid doing '
#             'imports until\n'
#             'after removing the cwd from sys.path.\n',
#  '__file__': '/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader object at 0x7f690126b550>,
#  '__name__': '__main__',
#  '__package__': '',
#  '__spec__': ModuleSpec(name='ipykernel_launcher', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f690126b550>, origin='/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py'),
#  'app': <module 'ipykernel.kernelapp' from '/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py'>,
#  'sys': <module 'sys' (built-in)>}
#
# /home/devopsgong/anaconda3/lib/python3.7/runpy.py[85]
#   -> exec(code, run_globals)
# {'cached': '/home/devopsgong/anaconda3/lib/python3.7/site-packages/__pycache__/ipykernel_launcher.cpython-37.pyc',
#  'code': <code object <module> at 0x7f690120c1e0, file "/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py", line 5>,
#  'fname': '/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py',
#  'init_globals': None,
#  'loader': <_frozen_importlib_external.SourceFileLoader object at 0x7f690126b550>,
#  'mod_name': '__main__',
#  'mod_spec': ModuleSpec(name='ipykernel_launcher', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f690126b550>, origin='/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py'),
#  'pkg_name': '',
#  'run_globals': {'__annotations__': {},
#                  '__builtins__': <module 'builtins' (built-in)>,
#                  '__cached__': '/home/devopsgong/anaconda3/lib/python3.7/site-packages/__pycache__/ipykernel_launcher.cpython-37.pyc',
#                  '__doc__': 'Entry point for launching an IPython kernel.\n'
#                             '\n'
#                             'This is separate from the ipykernel package so we '
#                             'can avoid doing imports until\n'
#                             'after removing the cwd from sys.path.\n',
#                  '__file__': '/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py',
#                  '__loader__': <_frozen_importlib_external.SourceFileLoader object at 0x7f690126b550>,
#                  '__name__': '__main__',
#                  '__package__': '',
#                  '__spec__': ModuleSpec(name='ipykernel_launcher', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f690126b550>, origin='/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py'),
#                  'app': <module 'ipykernel.kernelapp' from '/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py'>,
#                  'sys': <module 'sys' (built-in)>},
#  'script_name': None}
#
# /home/devopsgong/anaconda3/lib/python3.7/runpy.py[193]
#   -> "__main__", mod_spec)
# {'alter_argv': 1,
#  'code': <code object <module> at 0x7f690120c1e0, file "/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py", line 5>,
#  'main_globals': {'__annotations__': {},
#                   '__builtins__': <module 'builtins' (built-in)>,
#                   '__cached__': '/home/devopsgong/anaconda3/lib/python3.7/site-packages/__pycache__/ipykernel_launcher.cpython-37.pyc',
#                   '__doc__': 'Entry point for launching an IPython kernel.\n'
#                              '\n'
#                              'This is separate from the ipykernel package so '
#                              'we can avoid doing imports until\n'
#                              'after removing the cwd from sys.path.\n',
#                   '__file__': '/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py',
#                   '__loader__': <_frozen_importlib_external.SourceFileLoader object at 0x7f690126b550>,
#                   '__name__': '__main__',
#                   '__package__': '',
#                   '__spec__': ModuleSpec(name='ipykernel_launcher', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f690126b550>, origin='/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py'),
#                   'app': <module 'ipykernel.kernelapp' from '/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py'>,
#                   'sys': <module 'sys' (built-in)>},
#  'mod_name': 'ipykernel_launcher',
#  'mod_spec': ModuleSpec(name='ipykernel_launcher', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f690126b550>, origin='/home/devopsgong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py')}

# %% [markdown]
# ## Command Line Interface

# %%
# !python -m inspect -d example
# Out:
# Target: example
# Origin: /home/devopsgong/projects/py4kids/lesson-10-inspect/example.py
# Cached: /home/devopsgong/projects/py4kids/lesson-10-inspect/__pycache__/example.cpython-37.pyc
# Loader: <_frozen_importlib_external.SourceFileLoader object at 0x7f0a3a2b1748>

# %%
# !python -m inspect example:A.get_name
# Out:
#     def get_name(self):
#         "Returns the name of the instance."
#         return self.name
