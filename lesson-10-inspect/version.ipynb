# %% [markdown]
# https://stackoverflow.com/questions/458550/standard-way-to-embed-version-into-python-package

# %%
# !pip install importlib-metadata

# %%
# !pip list | grep metadata
# Out:
# importlib-metadata                 1.5.0

# %%
## This one is a new built-in as of Python 3.8.0 should become the standard
# from importlib-metadata import version
from importlib_metadata import version
pkg = "pandas"

# %%
# %%timeit
v0 = version(pkg)
print('v0 {}'.format(v0))
# 1.22 ms ± 22.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Out:
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# v0 1.0.1
# ...

# %%
## I don't like this one because the version method is hidden
import pkg_resources  # part of setuptools
pkg = "pandas"

# %%
# %%timeit
v1 = pkg_resources.require(pkg)[0].version
print('v1 {}'.format(v1))
# 500 µs ± 17.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Out:
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# v1 1.0.1
# ...

# %%
# Probably best for pre v3.8.0 - the output without .version is just a longer string with
# both the package name, a space, and the version string
import pkg_resources  # part of setuptools
pkg = "pandas"

# %%
# %%timeit
v2 = pkg_resources.get_distribution(pkg).version
print('v2 {}'.format(v2))
# 256 µs ± 2.68 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Out:
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# v2 1.0.1
# ...

# %%
# !pip install pbr
# Out:
# ...
#      |████████████████████████████████| 106 kB 938 kB/s eta 0:00:01
# ...

# %%
## This one seems to be slower, and with pyinstaller makes the exe a lot bigger
from pbr.version import VersionInfo
pkg = "pandas"

# %%
# %%timeit
v3 = VersionInfo(pkg).release_string()
print('v3 {}'.format(v3))
# 272 µs ± 9.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Out:
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# v3 1.0.1
# ...

# %% [markdown]
# ```
# You can put one of these directly in your __init__.py for the package to extract the version info as follows, similar to some other answers:
#
# __all__ = (
#     '__version__',
#     'my_package_name'
# )
#
# import pkg_resources  # part of setuptools
#
# __version__ = pkg_resources.get_distribution("mypackage").version
#
# ```
