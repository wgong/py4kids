# %% [markdown]
# ## US CS Faculty Dataset
# - [CS Faculty Composition and Hiring Trends (Blog)](https://jeffhuang.com/computer-science-open-data/#cs-faculty-composition-and-hiring-trends)
# - [2200 Computer Science Professors in 50 top US Graduate Programs](https://cs.brown.edu/people/apapouts/faculty_dataset.html)
# - [CS Professors (Data Explorer)](https://drafty.cs.brown.edu/csprofessors?src=csopendata)
# - [Drafty Project](https://drafty.cs.brown.edu/)

# %% [markdown]
# Use beautiful_soup to scrap CS Faculty info

# %%
from scrap_cs_faculty import *

# %%
SCHOOL = "MIT-CS"
URL = SCHOOL_DICT[SCHOOL]["url"]  #  "https://www.eecs.mit.edu/role/faculty-aid/"
print(URL)
# Out:
# https://www.eecs.mit.edu/role/faculty-cs/

# %%
page = requests.get(URL, headers=BROWSER_HEADERS)

# %% [raw]
# page

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %% [raw]
# soup

# %% [raw]
# results = soup.find("span", class_="people-entry small-12 medium-6 large-4 larger-3 cell ")
# print(results.prettify())

# %% [markdown]
# ## Find Elements by HTML Class Name

# %% [raw]
# cs_persons = soup.findAll("div", {"data-name":"people_index"})

# %%
cs_persons = soup.find_all("div", class_="people-entry small-12 medium-6 large-4 larger-3 cell")

# %%
len(cs_persons) , cs_persons[0]
# Out:
# (78,
#  <div class="people-entry small-12 medium-6 large-4 larger-3 cell">
#  <a aria-hidden="true" class="people-index-image" href="https://www.eecs.mit.edu/people/hal-abelson/" rel="bookmark" tabindex="-1" title="Hal Abelson">
#  <img alt="Hal Abelson" class="attachment-people-thumb size-people-thumb wp-post-image" decoding="async" height="228" loading="lazy" sizes="(max-width: 228px) 100vw, 228px" src="https://www.eecs.mit.edu/wp-content/uploads/2021/06/halab.png" srcset="https://www.eecs.mit.edu/wp-content/uploads/2021/06/halab.png 228w, https://www.eecs.mit.edu/wp-content/uploads/2021/06/halab-125x125.png 125w" width="228"/> </a>
#  <h5><a href="https://www.eecs.mit.edu/people/hal-abelson/" rel="bookmark">Hal Abelson</a></h5>
#  <p>Class of 1992 Professor , [CS and AI+D]</p>
#  <ul>
#  <li><a href="mailto:hal@mit.edu">hal@mit.edu</a></li>
#  <li>(617) 253-5856</li>
#  <li>Office: 32-G516</li>
#  </ul>
#  <div class="people-research">
#  <p><a href="?fwp_research=ai-and-society">AI and Society</a></p><p><a href="?fwp_research=artificial-intelligence-decision-making">Artificial Intelligence + Decision making</a></p><p><a href="?fwp_research=artificial-intelligence-machine-learning">Artificial Intelligence + Machine Learning</a></p> </div>
#  </div>)

# %% [markdown]
# ### Extract Text From HTML Elements
#
# You can add .text to a Beautiful Soup object to return only the text content of the HTML elements that the object contains:

# %%
DEBUG =  False # True # 

school, dept = map_school_dept(SCHOOL)
data = []
all_research_dict = {}
for n, person in enumerate(cs_persons):
    try:
        data_dict = {"school": school, "department": dept} # default
        if DEBUG and n > 0: break  # debug
        
        # get name/url
        x = person.find("h5")
        name_x = x.find("a")
        data_dict['name'] = name_x.text.strip()
        data_dict['url'] = name_x["href"]
        
        # get img
        x = person.find("img")
        if x:
            data_dict['img_url'] = x["src"]
            if "http" not in data_dict['img_url']:
                y = person.find("a")
                data_dict['img_url'] = y["href"]
                if not data_dict['img_url']:
                    data_dict['img_url'] = data_dict['url']

        research_area_dict = {}
        for x in person.find_all("p"):
            if (is_job_title(x.text.lower())) and "[" in x.text:
                # get title and dept
                x_tmp = x.text.split("[")
                if len(x_tmp) > 0:
                    title = x_tmp[0].strip()
                    data_dict['job_title'] = title[:-1] if title.endswith(",") else title
                if len(x_tmp) > 1:
                    depts = [i.strip() for i in x_tmp[1].replace("]", "").split("and") if i.strip()]
                    if DEBUG: print(f"depts = {depts}")
                    depts = [DEPT_MAP.get(d, "") for d in depts]
                    data_dict['department'] = "; ".join(depts)
            else:
                # get research
                y = x.find("a")
                if y:
                    research_name = y.text.strip()
                    if research_name:
                        research_area_dict[research_name] = f"{URL}{y['href']}"
                        if research_name not in all_research_dict:
                            all_research_dict[research_name] = research_area_dict[research_name]
        researchs = research_area_dict.keys()
        if researchs:
            data_dict['research_area'] = ", ".join(researchs)
                
        # get email, phone, office
        for x in person.find_all("li"):
            if "Office" in x.text.strip():
                data_dict['office_address'] = x.text.strip()
            else:
                y = x.find("a")
                if y and "@" in y.text:
                    data_dict['email'] = y.text.strip()
                else:
                    data_dict['phone'] = x.text.strip()
                
        if DEBUG:
            print(f"n={n}\t=============")
            print(f"name= {data_dict.get('name','')}")
            print(f"job_title= {data_dict.get('job_title','')}")
            print(f"phone= {data_dict.get('phone','')}")
            print(f"office= {data_dict.get('office_address','')}")
            print(f"email= {data_dict.get('email','')}")
            print(f"url= {data_dict.get('url','')}")
            print(f"img_url= {data_dict.get('img_url','')}")
            print(f"research_area= {data_dict.get('research_area','')}")
            print(f"department= {data_dict.get('department','')}")
        
        if data_dict:
            row_data = []
            for c in COLUMNS:
                cell = data_dict.get(c,"")
                row_data.append(cell)
            data.append(row_data)
    except Exception as e:
        print(f"[Error] {str(e)}\n{person.prettify()}")

# %%
len(data)#
# Out:
# 78

# %%
df = pd.DataFrame(data, columns=COLUMNS)

# %%
print(f"Number of faculties at {SCHOOL}: {df.shape[0]}")
# Out:
# Number of faculties at MIT-CS: 78

# %%
df
# Out:
#                              name  \
# 0                     Hal Abelson
# 1                   Anant Agarwal
# 2                  Pulkit Agrawal
# 3               Mohammad Alizadeh
# 4               Saman Amarasinghe
# ..                            ...
# 73                  Ryan Williams
# 74  Virginia Vassilevska Williams
# 75                    Mengjia Yan
# 76             Nickolai Zeldovich
# 77                     Victor Zue
#
#                                             job_title phd_univ phd_year  \
# 0                            Class of 1992 Professor
# 1                        CEO, edX; Professor of EECS;
# 2   Steven and Renee Finn Career Development Profe...
# 3                                 Associate Professor
# 4                     Professor of CS and Engineering
# ..                                                ...      ...      ...
# 73                                  Professor of EECS
# 74                                          Professor
# 75  Homer A. Burnell Career Development Professor,...
# 76                                  Professor of EECS
# 77  Delta Electronics Professor of EECS (Post-Tenure)
#
#                                         research_area research_concentration  \
# 0   AI and Society, Artificial Intelligence + Deci...
# 1   Computer Architecture, Multicore Processors & ...
# 2   Artificial Intelligence + Machine Learning, Gr...
# 3   Multicore Processors & Cloud Computing, Securi...
# 4   Artificial Intelligence + Machine Learning, Co...
# ..                                                ...                    ...
# 73                              Theory of Computation
# 74                              Theory of Computation
# 75   Computer Architecture, Security and Cryptography
# 76  Programming Languages and Software Engineering...
# 77  Educational Technology, Human-Computer Interac...
#
#    research_focus                                                url  \
# 0                       https://www.eecs.mit.edu/people/hal-abelson/
# 1                     https://www.eecs.mit.edu/people/anant-agarwal/
# 2                    https://www.eecs.mit.edu/people/pulkit-agrawal/
# 3                  https://www.eecs.mit.edu/people/mohammad-aliza...
# 4                  https://www.eecs.mit.edu/people/saman-amarasin...
# ..            ...                                                ...
# 73                    https://www.eecs.mit.edu/people/ryan-williams/
# 74                 https://www.eecs.mit.edu/people/virginia-willi...
# 75                      https://www.eecs.mit.edu/people/mengjia-yan/
# 76                 https://www.eecs.mit.edu/people/nickolai-zeldo...
# 77                       https://www.eecs.mit.edu/people/victor-zue/
#
#                                               img_url           phone  \
# 0   https://www.eecs.mit.edu/wp-content/uploads/20...  (617) 253-5856
# 1      https://www.eecs.mit.edu/people/anant-agarwal/  (617) 253-1448
# 2     https://www.eecs.mit.edu/people/pulkit-agrawal/  (617) 253-5851
# 3   https://www.eecs.mit.edu/people/mohammad-aliza...  (617) 253-6042
# 4   https://www.eecs.mit.edu/people/saman-amarasin...  (617) 253-8879
# ..                                                ...             ...
# 73     https://www.eecs.mit.edu/people/ryan-williams/    617-253-5851
# 74  https://www.eecs.mit.edu/wp-content/uploads/20...    617-253-5851
# 75       https://www.eecs.mit.edu/people/mengjia-yan/    617-258-0719
# 76  https://www.eecs.mit.edu/people/nickolai-zeldo...  (617) 253-6005
# 77        https://www.eecs.mit.edu/people/victor-zue/  (617) 253-8513
#
#                      email cell_phone    office_address  \
# 0              hal@mit.edu              Office: 32-G516
# 1          agarwal@mit.edu             Office: NE55-900
# 2         pulkitag@mit.edu               Office: 32-342
# 3         alizadeh@mit.edu              Office: 32-G920
# 4      saman@csail.mit.edu               Office: 38-427
# ..                     ...        ...               ...
# 73             rrw@mit.edu              Office: 32-G638
# 74           virgi@mit.edu              Office: 32-G640
# 75        mengjiay@mit.edu              Office: 32G-840
# 76  nickolai@csail.mit.edu              Office: 32-G994
# 77       zue@csail.mit.edu              Office: 32-G470
#
#                                   department  \
# 0     Computer Science; AI & Decision-making
# 1   Computer Science; Electrical Engineering
# 2     AI & Decision-making; Computer Science
# 3                         Computer Science;
# 4                           Computer Science
# ..                                       ...
# 73    Computer Science; AI & Decision-making
# 74    Computer Science; AI & Decision-making
# 75                          Computer Science
# 76                          Computer Science
# 77    AI & Decision-making; Computer Science
#
#                                 school
# 0   Massachusetts Institute Technology
# 1   Massachusetts Institute Technology
# 2   Massachusetts Institute Technology
# 3   Massachusetts Institute Technology
# 4   Massachusetts Institute Technology
# ..                                 ...
# 73  Massachusetts Institute Technology
# 74  Massachusetts Institute Technology
# 75  Massachusetts Institute Technology
# 76  Massachusetts Institute Technology
# 77  Massachusetts Institute Technology
#
# [78 rows x 15 columns]

# %%
# prepare research group dataframe
cols = ["research_group", "url"]
data = []
for i in all_research_dict.keys():
    data.append([i, all_research_dict.get(i,'')])
    print(f"{i}:\t {all_research_dict.get(i,'')}")
# Out:
# AI and Society:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=ai-and-society
# Artificial Intelligence + Decision making:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=artificial-intelligence-decision-making
# Artificial Intelligence + Machine Learning:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=artificial-intelligence-machine-learning
# Computer Architecture:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=computer-architecture
# Multicore Processors & Cloud Computing:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=multicore-processors-cloud-computing
# Programming Languages and Software Engineering:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=programming-languages-and-software-engineering
# Graphics and Vision:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=graphics-and-vision
# Human-Computer Interaction:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=human-computer-interaction
# Security and Cryptography:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=security-cryptography
# Systems and Networking:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=systems-and-networking
# Wireless Networks & Mobile Computing:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=wireless-networks-mobile-computing
# AI for Healthcare and Life Sciences:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=ai-for-healthcare-and-life-sciences
# Natural Language and Speech Processing:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=natural-language-and-speech-processing
# Energy:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=energy
# Communications Systems:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=communications-systems
# Electronic, Magnetic, Optical and Quantum Materials and Devices:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=electronic-magnetic-optical-quantum-materials
# Information Science and Systems:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=information-science-and-systems
# Nanoscale Materials, Devices, and Systems:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=nanoscale-materials-devices-and-systems
# Optimization and Game Theory:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=optimization-and-game-theory
# Computer Science and Artificial Intelligence Laboratory (CSAIL):	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=computer-science-and-artificial-intelligence-laboratory-csail
# Cybersecurity:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=cybersecurity
# Theory of Computation:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=theory-of-computation
# Integrated Circuits and Systems:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=integrated-circuits-and-systems
# Educational Technology:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=educational-technology
# Biological and Medical Devices and Systems:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=biological-and-medical-devices-and-systems
# Computational Fabrication and Manufacturing:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=computational-fabrication-and-manufacturing
# Robotics:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=robotics
# Quantum Computing, Communication, and Sensing:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=quantum-computing-communication-and-sensing
# Signal Processing:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=signal-processing
# Systems Theory, Control, and Autonomy:	 https://www.eecs.mit.edu/role/faculty-cs/?fwp_research=systems-theory-control-and-autonomy

# %%
df_research = pd.DataFrame(data, columns=cols)

# %%
df_research
# Out:
#                                        research_group  \
# 0                                      AI and Society
# 1           Artificial Intelligence + Decision making
# 2          Artificial Intelligence + Machine Learning
# 3                               Computer Architecture
# 4              Multicore Processors & Cloud Computing
# 5      Programming Languages and Software Engineering
# 6                                 Graphics and Vision
# 7                          Human-Computer Interaction
# 8                           Security and Cryptography
# 9                              Systems and Networking
# 10               Wireless Networks & Mobile Computing
# 11                AI for Healthcare and Life Sciences
# 12             Natural Language and Speech Processing
# 13                                             Energy
# 14                             Communications Systems
# 15  Electronic, Magnetic, Optical and Quantum Mate...
# 16                    Information Science and Systems
# 17          Nanoscale Materials, Devices, and Systems
# 18                       Optimization and Game Theory
# 19  Computer Science and Artificial Intelligence L...
# 20                                      Cybersecurity
# 21                              Theory of Computation
# 22                    Integrated Circuits and Systems
# 23                             Educational Technology
# 24         Biological and Medical Devices and Systems
# 25        Computational Fabrication and Manufacturing
# 26                                           Robotics
# 27      Quantum Computing, Communication, and Sensing
# 28                                  Signal Processing
# 29              Systems Theory, Control, and Autonomy
#
#                                                   url
# 0   https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 1   https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 2   https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 3   https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 4   https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 5   https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 6   https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 7   https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 8   https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 9   https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 10  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 11  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 12  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 13  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 14  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 15  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 16  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 17  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 18  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 19  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 20  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 21  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 22  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 23  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 24  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 25  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 26  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 27  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 28  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...
# 29  https://www.eecs.mit.edu/role/faculty-cs/?fwp_...

# %%
df.to_csv(f"faculty-{SCHOOL}.csv", index=False)

# %%
# import xlsxwriter
file_xlsx = f"faculty-{SCHOOL}.xlsx"
writer = pd.ExcelWriter(file_xlsx, engine='xlsxwriter')
df.to_excel(writer, sheet_name = "CS Faculty-MIT", index=False)
df_research.to_excel(writer, sheet_name = "Research Groups", index=False)
writer.save()
