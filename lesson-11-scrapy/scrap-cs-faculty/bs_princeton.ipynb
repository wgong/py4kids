# %%
from IPython.display import display, Markdown, Latex
from scrap_cs_faculty import *

with open("readme.md") as f:
    readme_md = f.read()

display(Markdown(readme_md))
# Out:
# ## US CS Faculty Dataset
# - [CS Faculty Composition and Hiring Trends (Blog)](https://jeffhuang.com/computer-science-open-data/#cs-faculty-composition-and-hiring-trends)
# - [2200 Computer Science Professors in 50 top US Graduate Programs](https://cs.brown.edu/people/apapouts/faculty_dataset.html)
# - [CS Professors (Data Explorer)](https://drafty.cs.brown.edu/csprofessors?src=csopendata)
# - [Drafty Project](https://drafty.cs.brown.edu/)
# - [CSRankings.org](https://csrankings.org/#/fromyear/2011/toyear/2023/index?ai&vision&mlmining&nlp&inforet&act&crypt&log&us)
#
#
# ## Top 6 schools
# Stanford, UCB, MIT, CMU, Cornell, UIUC
#
# ## add more schools
#
# - https://www.cs.princeton.edu/people/faculty?type=main
# - https://www.cs.washington.edu/people/faculty
# - https://directory.seas.upenn.edu/computer-and-information-science/
# - https://www.cms.caltech.edu/cms-people/faculty
# - https://www.cs.columbia.edu/people/faculty/
# - https://cse.engin.umich.edu/people/faculty/
# - https://samueli.ucla.edu/search-faculty/#cs
# - https://cse.ucsd.edu/people/faculty-profiles
# - https://seas.harvard.edu/computer-science/people?role[46]=46
# - https://www.cc.gatech.edu/people/faculty?page=24  (page=[0,25))

# %%
SCHOOL = "Princeton-CS"
URL = SCHOOL_DICT[SCHOOL]["url"]  #  "https://www.eecs.mit.edu/role/faculty-aid/"
print(URL)
# Out:
# https://www.cs.princeton.edu/people/faculty?type=main

# %%
base_url = "/".join(URL.split("/")[:3])
base_url
# Out:
# 'https://www.cs.princeton.edu'

# %%
page = requests.get(URL, headers=BROWSER_HEADERS)

# %% [raw]
# page

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %% [raw]
# soup

# %%
results = soup.find("div", class_="people people-facstaff")
print(results.prettify())
# Out:
# <div class="people people-facstaff">
#  <a name="A">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/abtahi">
#     <img alt="Photo of Parastoo Abtahi" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=6671&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/abtahi">
#      Parastoo Abtahi
#     </a>
#    </h2>
#    <div class="person-title">
#     Assistant Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Stanford University, 2022
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~abtahi">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/abtahi">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      abtahi  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-9528
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      419 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Human-Computer Interaction, Augmented Reality, Spatial Computing
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/rpa">
#     <img alt="Photo of Ryan Adams" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=4111&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/rpa">
#      Ryan Adams
#     </a>
#    </h2>
#    <div class="person-title">
#     Professor, Associate Chair
#    </div>
#    <div class="person-degree">
#     Ph.D., University of Cambridge, 2009
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~rpa">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/rpa">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      rpa  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-8682
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      411 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     I am interested in machine learning, artificial intelligence, and computational statistics, with applications across science and engineering. I have broad interests but often work on probabilistic methods and approximate Bayesian inference.
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/appel">
#     <img alt="Photo of Andrew Appel" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=3&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/appel">
#      Andrew Appel
#     </a>
#    </h2>
#    <div class="person-title">
#     Eugene Higgins Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Carnegie-Mellon University, 1985
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~appel">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/appel">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      appel  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-4627
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      209 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Software verification, computer security, programming languages, compilers
#     <br/>
#     <br/>
#     ACM Fellow, 1998; SIGPLAN Distinguished Service Award, 2002
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/arora">
#     <img alt="Photo of Sanjeev Arora" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=4&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/arora">
#      Sanjeev Arora
#     </a>
#    </h2>
#    <div class="person-title">
#     Charles C. Fitzmorris Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., University of California, Berkeley, 1994
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~arora">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/arora">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      arora  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-3869
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      407 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Uses of randomness in complexity theory and algorithms; efficient algorithms for finding approximate solutions to NP-hard problems (or proving that they don't exist); cryptography
#     <br/>
#     <br/>
#     Member, National Academy of Sciences, 2018; Member, American Academy of Arts and Sciences, 2015; Fulkerson Prize, 2012; Gödel Prize, 2010 and 2001; ACM Fellow, 2009
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/august">
#     <img alt="Photo of David August" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=5&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/august">
#      David August
#     </a>
#    </h2>
#    <div class="person-title">
#     Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., University of Illinois, Urbana/Champaign, 2000
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~august">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/august">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      august  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-2085
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      221 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Computer Architecture and Compilers
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <a name="B">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/eberinge">
#     <img alt="Photo of Lennart Beringer" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=907&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/eberinge">
#      Lennart Beringer
#     </a>
#    </h2>
#    <div class="person-title">
#     Research Scholar
#    </div>
#    <div class="person-degree">
#     Ph.D., University of Edinburgh, 2002
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~eberinge">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/eberinge">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      eberinge  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-0451
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      216 Computer Science
#     </span>
#    </div>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/sb2592">
#     <img alt="No photo available" src="/sites/all/modules/custom/cs_people/default.png"/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/sb2592">
#      Suma Bhat
#     </a>
#    </h2>
#    <div class="person-title">
#     Research Scholar
#    </div>
#    <div class="person-degree">
#     Ph.D., University of Illinois, Urbana-Champaign, 2010
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="/people/profile/sb2592">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      sb2592  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      415 Computer Science
#     </span>
#    </div>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/jbrassil">
#     <img alt="Photo of Jack Brassil" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=3181&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/jbrassil">
#      Jack Brassil
#     </a>
#    </h2>
#    <div class="person-title">
#     Senior Research Scholar
#    </div>
#    <div class="person-degree">
#     Ph.D., University of California, San Diego, 1991
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~jbrassil">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/jbrassil">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      jbrassil  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-6253
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      103 221 Nassau Street
#     </span>
#    </div>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/mbraverm">
#     <img alt="Photo of Mark Braverman" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=1314&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/mbraverm">
#      Mark Braverman
#     </a>
#    </h2>
#    <div class="person-title">
#     Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., University of Toronto, 2008
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~mbraverm">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/mbraverm">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      mbraverm  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-8130
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      304 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Complexity theory; algorithms; game theory;  machine learning; applications of computer science in healthcare and medicine
#     <br/>
#     <br/>
#     Abacus Medal, 2022; Presburger Award, 2016; SFCM Stephen Smale Prize, 2014; Packard Fellow, 2013
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <a name="C">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/scaldas">
#     <img alt="No photo available" src="/sites/all/modules/custom/cs_people/default.png"/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/scaldas">
#      Sebastian Caldas
#     </a>
#    </h2>
#    <div class="person-title">
#     Lecturer
#    </div>
#    <div class="person-degree">
#     Ph.D., Carnegie Mellon University, 2023
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="/people/profile/scaldas">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      scaldas  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-8327
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      105 221 Nassau Street
#     </span>
#    </div>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/chazelle">
#     <img alt="Photo of Bernard Chazelle" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=9&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/chazelle">
#      Bernard Chazelle
#     </a>
#    </h2>
#    <div class="person-title">
#     Eugene Higgins Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Yale University, 1980
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~chazelle">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/chazelle">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      chazelle  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-5380
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      404 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Natural Algorithms, Dynamical Systems, Dynamic Networks, Computational Geometry, Discrepancy Theory
#     <br/>
#     <br/>
#     Member, American Academy of Arts and Sciences, 2004; ACM Fellow, 1996
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/danqic">
#     <img alt="Photo of Danqi Chen" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=4884&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/danqic">
#      Danqi Chen
#     </a>
#    </h2>
#    <div class="person-title">
#     Assistant Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Stanford University, 2018
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~danqic">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/danqic">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      danqic  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-8680
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      412 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     My research is in natural language processing (NLP) and machine learning. I am particularly interested in the intersection of text understanding and knowledge representation &amp; reasoning and applications in question answering, information extraction, and conversational systems.
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <a name="D">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/dallagnol">
#     <img alt="Photo of Marcel Dall'Agnol" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=6936&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/dallagnol">
#      Marcel Dall'Agnol
#     </a>
#    </h2>
#    <div class="person-title">
#     Lecturer
#    </div>
#    <div class="person-degree">
#     Ph.D., University of Warwick, 2023
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~dallagnol">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/dallagnol">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      dallagnol  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-3865
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      034 Corwin Hall
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Sublinear algorithms, quantum computation, interactive proof systems, cryptography
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/jiadeng">
#     <img alt="Photo of Jia Deng" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=89&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/jiadeng">
#      Jia Deng
#     </a>
#    </h2>
#    <div class="person-title">
#     Associate Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Princeton University, 2012
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~jiadeng">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/jiadeng">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      jiadeng  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-1203
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      423 Computer Science
#     </span>
#    </div>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/ad6725">
#     <img alt="Photo of Adji Bousso Dieng" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=5772&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/ad6725">
#      Adji Bousso Dieng
#     </a>
#    </h2>
#    <div class="person-title">
#     Assistant Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Columbia University, 2020
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="/people/profile/ad6725">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      ad6725  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-5935
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      406 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Machine learning, Artificial Intelligence for Science (AI4Science)
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/rdondero">
#     <img alt="Photo of Robert Dondero" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=12&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/rdondero">
#      Robert Dondero
#     </a>
#    </h2>
#    <div class="person-title">
#     Senior Lecturer
#    </div>
#    <div class="person-degree">
#     Ph.D., Drexel University, 2008
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~rdondero">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/rdondero">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      rdondero  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-2211
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      038 Corwin Hall
#     </span>
#    </div>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/zdvir">
#     <img alt="Photo of Zeev Dvir" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=1055&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/zdvir">
#      Zeev Dvir
#     </a>
#     <small>
#      (on leave)
#     </small>
#    </h2>
#    <div class="person-title">
#     Professor
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~zdvir">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/zdvir">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      zdvir  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-6469
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      315 Computer Science
#     </span>
#    </div>
#   </div>
#  </div>
#  <hr/>
#  <a name="E">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/eysenbach">
#     <img alt="Photo of Benjamin Eysenbach" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=6937&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/eysenbach">
#      Benjamin Eysenbach
#     </a>
#    </h2>
#    <div class="person-title">
#     Assistant Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Carnegie Mellon University, 2023
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="/people/profile/eysenbach">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      eysenbach  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-8592
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      416 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     reinforcement learning, machine learning
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <a name="F">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/fellbaum">
#     <img alt="Photo of Christiane Fellbaum" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=57&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/fellbaum">
#      Christiane Fellbaum
#     </a>
#    </h2>
#    <div class="person-title">
#     Lecturer with rank of Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Princeton University, 1980
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~fellbaum">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/fellbaum">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      fellbaum  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-2824
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      1-S-14 Green Hall
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Natural Language Processing, Lexical semantics, the syntax-semantics interface, syntactic alternations, computational linguistics, large-scale lexical resources, idioms, ontology
#     <br/>
#     <br/>
#     Humboldt Foundation Wolfgang Paul Award, 2001; LREC Antonio Zampolli Prize, 2006
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/af">
#     <img alt="Photo of Adam Finkelstein" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=14&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/af">
#      Adam Finkelstein
#     </a>
#    </h2>
#    <div class="person-title">
#     Phillip Y. Goldman ’86 Professor in Computer Science
#    </div>
#    <div class="person-degree">
#     Ph.D., University of Washington, 1996
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~af">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/af">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      af  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-5756
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      424 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Computer graphics, animation
#     <br/>
#     <br/>
#     ACM Fellow, 2014
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/rfish">
#     <img alt="Photo of Robert Fish" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=3177&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/rfish">
#      Robert Fish
#     </a>
#    </h2>
#    <div class="person-title">
#     Lecturer
#    </div>
#    <div class="person-degree">
#     Ph.D., Stanford University, 1981
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="/people/profile/rfish">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      rfish  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-0839
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      037 Corwin Hall
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Networking and Telecommunications, Computer-Human Interaction, Online Learning and MOOCs, R&amp;D Innovation Methodologies
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/ruthfong">
#     <img alt="Photo of Ruth Fong" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=6081&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/ruthfong">
#      Ruth Fong
#     </a>
#    </h2>
#    <div class="person-title">
#     Lecturer
#    </div>
#    <div class="person-degree">
#     Ph.D., University of Oxford, 2020
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~ruthfong">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/ruthfong">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      ruthfong  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-9248
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      032 Corwin Hall
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     computer vision, machine learning, deep learning, explainable AI
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/mfreed">
#     <img alt="Photo of Michael Freedman" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=15&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/mfreed">
#      Michael Freedman
#     </a>
#    </h2>
#    <div class="person-title">
#     Robert E. Kahn Professor of Computer Science
#    </div>
#    <div class="person-degree">
#     Ph.D., New York University, 2007
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~mfreed">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/mfreed">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      mfreed  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-9179
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      308 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Distributed systems, security, networking
#     <br/>
#     <br/>
#     ACM Fellow, 2019; ACM Grace Murray Hopper Award, 2018; Presidential Early Career Award (PECASE), 2011; ONR Young Investigator, 2009
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <a name="G">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/dgabai">
#     <img alt="No photo available" src="/sites/all/modules/custom/cs_people/default.png"/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/dgabai">
#      Donna Gabai
#     </a>
#    </h2>
#    <div class="person-title">
#     Lecturer
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~dgabai">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/dgabai">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      dgabai  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-1978
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      039 Corwin Hall
#     </span>
#    </div>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/tomg">
#     <img alt="Photo of Tom Griffiths" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=4404&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/tomg">
#      Tom Griffiths
#     </a>
#    </h2>
#    <div class="person-title">
#     Henry R. Luce Professor of Information Technology, Consciousness and Culture
#    </div>
#    <div class="person-degree">
#     Ph.D., Stanford University, 2005
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="/people/profile/tomg">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      tomg  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-4285
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      417 Computer Science
#     </span>
#    </div>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/aartig">
#     <img alt="Photo of Aarti Gupta" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=2813&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/aartig">
#      Aarti Gupta
#     </a>
#    </h2>
#    <div class="person-title">
#     Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Carnegie Mellon University, 1994
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~aartig">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/aartig">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      aartig  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-8017
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      220 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Formal verification, program analysis, logic decision procedures
#     <br/>
#     <br/>
#     ACM Fellow, 2017
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <a name="H">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/ehazan">
#     <img alt="Photo of Elad Hazan" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=2425&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/ehazan">
#      Elad Hazan
#     </a>
#    </h2>
#    <div class="person-title">
#     Professor, Director of Graduate Studies-Admissions
#    </div>
#    <div class="person-degree">
#     Ph.D., Princeton University, 2006
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~ehazan">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/ehazan">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      ehazan  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-6031
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      409 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Theoretical foundations of machine learning, design and analysis of efficient algorithms for machine learning and mathematical optimization.
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/fheide">
#     <img alt="Photo of Felix Heide" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=4669&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/fheide">
#      Felix Heide
#     </a>
#    </h2>
#    <div class="person-title">
#     Assistant Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., University of British Columbia, 2017
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~fheide">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/fheide">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      fheide  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-0419
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      410 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Computational Imaging, Computer Vision, Computer Graphics, Optics
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <a name="J">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/kylej">
#     <img alt="Photo of Kyle Jamieson" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=3136&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/kylej">
#      Kyle Jamieson
#     </a>
#     <small>
#      (on leave)
#     </small>
#    </h2>
#    <div class="person-title">
#     Professor, Director of Graduate Studies
#    </div>
#    <div class="person-degree">
#     Ph.D., Massachusetts Institute of Technology, 2008
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~kylej">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/kylej">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      kylej  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-7477
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      306 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Networking, Wireless Systems, Internet of Things
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <a name="K">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/ak18">
#     <img alt="Photo of Alan Kaplan" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=2666&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/ak18">
#      Alan Kaplan
#     </a>
#    </h2>
#    <div class="person-title">
#     Senior Lecturer
#    </div>
#    <div class="person-degree">
#     Ph.D., University of Massachusetts, 1996
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~ak18">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/ak18">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      ak18  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-1745
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      106 221 Nassau Street
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Mobile software, middleware and protocols, communication and networking for consumer applications and services, software engineering
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/bwk">
#     <img alt="Photo of Brian Kernighan" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=19&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/bwk">
#      Brian Kernighan
#     </a>
#    </h2>
#    <div class="person-title">
#     William O. Baker *39 Professor in Computer Science, Director of Undergraduate Studies
#    </div>
#    <div class="person-degree">
#     Ph.D., Princeton University, 1969
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~bwk">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/bwk">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      bwk  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-2089
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      311 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Application-specific languages, document preparation, user interfaces, software tools, programming methodology
#     <br/>
#     <br/>
#     Member, American Academy of Arts and Sciences, 2019; Member, National Academy of Engineering, 2002; USENIX Association Lifetime Achievement Award, 1997
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/zkincaid">
#     <img alt="Photo of Zachary Kincaid" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=3338&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/zkincaid">
#      Zachary Kincaid
#     </a>
#    </h2>
#    <div class="person-title">
#     Associate Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., University of Toronto, 2016
#    </div>
#    <div class="person-links">
# ...
#    </h2>
#    <div class="person-title">
#     Evnin Professor in Neuroscience, Professor of Computer Science and Princeton Neurosciences Institute
#    </div>
#    <div class="person-degree">
#     Ph.D., Harvard University, 1990
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~sseung">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/sseung">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      sseung  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-7713
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      153 Princeton Neuroscience Institute
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Machine learning, computational biology
#     <br/>
#     <br/>
#     Ho-Am Prize in Engineering, 2008; McKnight Scholar Award, 2000
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/jps">
#     <img alt="Photo of Jaswinder Singh" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=29&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/jps">
#      Jaswinder Singh
#     </a>
#    </h2>
#    <div class="person-title">
#     Professor of Computer Science, Technology, and Societal Change
#    </div>
#    <div class="person-degree">
#     Ph.D., Stanford University, 1993
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="/people/profile/jps">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      jps  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-5329
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      324 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Parallel computing systems and applications: parallel applications and their implications for software and architectural design; system software and programming environments for multiprocessors
#     <br/>
#     <br/>
#     Presidential Early Career Award (PECASE), 1997
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/mona">
#     <img alt="Photo of Mona Singh" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=30&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/mona">
#      Mona Singh
#     </a>
#    </h2>
#    <div class="person-title">
#     Wang Family Professor in Computer Science
#    </div>
#    <div class="person-degree">
#     Ph.D., Massachusetts Institute of Technology, 1995
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~mona">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/mona">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      mona  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-2087
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      420 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Computational molecular biology, as well as its interface with machine learning and algorithms.
#     <br/>
#     <br/>
#     Presidential Early Career Award (PECASE), 2001; ACM Fellow, 2019; ISCB Fellow, 2018
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <a name="T">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/ret">
#     <img alt="Photo of Robert Tarjan" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=32&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/ret">
#      Robert Tarjan
#     </a>
#    </h2>
#    <div class="person-title">
#     James S. McDonnell Distinguished University Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Stanford University, 1972
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~ret">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/ret">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      ret  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-4797
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      305 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Data structures; graph algorithms; combinatorial optimization; computational complexity; computational geometry; parallel algorithms
#     <br/>
#     <br/>
#     ACM Turing Award, 1986; Fellow, American Academy of Arts &amp; Sciences, 1985;  Member, National Academy of  Sciences, 1987;  Member National Academy of Engineering, 1988; Member American Philosophical Society, 1990; ACM Fellow, 1994; SIAM Fellow, 2009
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/ogt">
#     <img alt="Photo of Olga Troyanskaya" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=33&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/ogt">
#      Olga Troyanskaya
#     </a>
#    </h2>
#    <div class="person-title">
#     Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Stanford University, 2003
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="/people/profile/ogt">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      ogt  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-1749
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      320 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Bioinformatics; analysis of large-scale biological data sets (genomics, gene expression, proteomics, biological networks); algorithms for integration of data from multiple data sources; visualization of biological data; machine learning methods in bioinformatics
#     <br/>
#     <br/>
#     ISCB Overton Prize, 2011; GSA Ira Herskowitz Award, 2014
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <a name="W">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/dpw">
#     <img alt="Photo of David Walker" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=34&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/dpw">
#      David Walker
#     </a>
#    </h2>
#    <div class="person-title">
#     Professor, Director of Undergraduate Studies
#    </div>
#    <div class="person-degree">
#     Ph.D., Cornell University, 2001
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~dpw">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/dpw">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      dpw  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-7654
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      211 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Programming languages, type systems, compilers, domain-specific languages, software-defined networking
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/wayne">
#     <img alt="Photo of Kevin Wayne" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=35&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/wayne">
#      Kevin Wayne
#     </a>
#    </h2>
#    <div class="person-title">
#     Phillip Y. Goldman '86 University Lecturer
#    </div>
#    <div class="person-degree">
#     Ph.D., Cornell University, 1999
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~wayne">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/wayne">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      wayne  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-4455
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      040 Corwin Hall
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Algorithms and data structures; computer science education
#     <br/>
#     <br/>
#     ACM Distinguished Educator, 2014
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/smattw">
#     <img alt="Photo of Matthew Weinberg" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=2667&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/smattw">
#      Matthew Weinberg
#     </a>
#    </h2>
#    <div class="person-title">
#     Associate Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Massachusetts Institute of Technology, 2014
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~smattw">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/smattw">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      smattw  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-0944
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      317 Computer Science
#     </span>
#    </div>
#   </div>
#  </div>
#  <hr/>
#  <a name="Y">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/hy2">
#     <img alt="Photo of Huacheng Yu" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=5209&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/hy2">
#      Huacheng Yu
#     </a>
#    </h2>
#    <div class="person-title">
#     Assistant Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Stanford University, 2017
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~hy2">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/hy2">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      hy2  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-5962
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      310 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Data structures, streaming algorithms, communication complexity
#    </p>
#   </div>
#  </div>
#  <hr/>
#  <a name="Z">
#  </a>
#  <div class="person clearfix">
#   <div class="person-photo">
#    <a href="/people/profile/zhonge">
#     <img alt="Photo of Ellen Zhong" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=6488&amp;thumb="/>
#    </a>
#   </div>
#   <div class="person-details">
#    <h2 class="person-name">
#     <a href="/people/profile/zhonge">
#      Ellen Zhong
#     </a>
#    </h2>
#    <div class="person-title">
#     Assistant Professor
#    </div>
#    <div class="person-degree">
#     Ph.D., Massachusetts Institute of Technology, 2022
#    </div>
#    <div class="person-links">
#     <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~zhonge">
#      <span class="glyphicon glyphicon-globe">
#      </span>
#      Homepage
#     </a>
#     <a class="btn btn-xs btn-default" href="/people/profile/zhonge">
#      <span class="glyphicon glyphicon-arrow-right">
#      </span>
#      Profile
#     </a>
#    </div>
#    <div class="person-address">
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-envelope">
#      </span>
#      zhonge  (@cs.princeton.edu)
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-earphone">
#      </span>
#      (609) 258-9075
#     </span>
#     <span class="person-address-item">
#      <span class="glyphicon glyphicon-briefcase">
#      </span>
#      314 Computer Science
#     </span>
#    </div>
#    <p class="person-research-interests">
#     <span class="person-label">
#      Research Interests:
#     </span>
#     Machine learning, computational and structural biology, 3D computer vision, biological imaging
#    </p>
#   </div>
#  </div>
#  <hr/>
# </div>

# %% [markdown]
# ## Find Elements by HTML Class Name

# %% [raw]
# cs_persons = soup.findAll("div", {"data-name":"people_index"})

# %%
cs_persons = soup.find_all("div", class_="person clearfix")

# %%
len(cs_persons) , cs_persons[0]
# Out:
# (69,
#  <div class="person clearfix">
#  <div class="person-photo">
#  <a href="/people/profile/abtahi"><img alt="Photo of Parastoo Abtahi" src="/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=6671&amp;thumb="/></a>
#  </div>
#  <div class="person-details">
#  <h2 class="person-name">
#  <a href="/people/profile/abtahi">Parastoo Abtahi</a>
#  </h2>
#  <div class="person-title">
#          Assistant Professor      </div>
#  <div class="person-degree">
#          Ph.D., Stanford University, 2022      </div>
#  <div class="person-links">
#  <a class="btn btn-xs btn-default" href="https://www.cs.princeton.edu/~abtahi"><span class="glyphicon glyphicon-globe"></span>Homepage</a>
#  <a class="btn btn-xs btn-default" href="/people/profile/abtahi"><span class="glyphicon glyphicon-arrow-right"></span>Profile</a>
#  </div>
#  <div class="person-address">
#  <span class="person-address-item">
#  <span class="glyphicon glyphicon-envelope"></span> abtahi  (@cs.princeton.edu)
#        </span>
#  <span class="person-address-item">
#  <span class="glyphicon glyphicon-earphone"></span> (609) 258-9528      </span>
#  <span class="person-address-item">
#  <span class="glyphicon glyphicon-briefcase"></span> 419 Computer Science      </span>
#  </div>
#  <p class="person-research-interests">
#  <span class="person-label">Research Interests:</span>
#          Human-Computer Interaction, Augmented Reality, Spatial Computing      </p>
#  </div>
#  </div>)

# %% [markdown]
# ### Extract Text From HTML Elements
#
# You can add .text to a Beautiful Soup object to return only the text content of the HTML elements that the object contains:

# %%
DEBUG =  False # True # 

if DEBUG:
    N_START, N_STOP = 0, 1
else:
    N_START, N_STOP = 0, -1

school, dept = map_school_dept(SCHOOL)
data = []
all_research_dict = {}
for n, person in enumerate(cs_persons[N_START:N_STOP]):
    try:
        data_dict = {"school": school, "department": dept} # default
#         if DEBUG and n > 0: break  # debug
        
        # parse profile and image URL
        url_img = person.find("div", class_="person-photo")
        url = url_img.find("a")["href"]
        img_url = url_img.find("img")["src"]
        data_dict['url_profile'] = f"{base_url}{url}"
        data_dict['img_url'] = f"{base_url}{img_url}"
        
        person_detail = person.find("div", class_="person-details")
        
        # parse name
        name = person_detail.find("h2", class_="person-name")
        if name:
            data_dict['name'] = name.text.strip()
        
        # parse title 
        title = person_detail.find("div", class_="person-title")
        if title:
            data_dict['job_title'] = title.text.strip()

        # parse phd school, year 
        school_year = person_detail.find("div", class_="person-degree")
        if school_year:
            x = [i.strip() for i in school_year.text.strip().split(",") if i.strip()]
            
            if re.match(r"[0-9]{4}", x[-1]):
                data_dict['phd_year'] = x[-1]
                
            if x[0].lower().replace(".", "").strip() == "phd" and 'phd_year' in data_dict:
                data_dict['phd_univ'] = ", ".join(x[1:-1])
                
        # parse homepage/profile url
        links = person_detail.find("div", class_="person-links")
        if links:
            hrefs = links.find_all("a")
            if hrefs:
                data_dict['url'] = hrefs[0]["href"]
            
        # parse contact info
        for item in person_detail.find_all("span", class_="person-address-item"):
            if item.find("span", class_="glyphicon glyphicon-envelope"):
                data_dict['email'] = "".join([i.strip() for i in item.text.strip().replace("(","").replace(")","").split() if i.strip()])
            if item.find("span", class_="glyphicon glyphicon-earphone"):
                data_dict['phone'] = item.text.strip()
            if item.find("span", class_="glyphicon glyphicon-briefcase"):
                data_dict['office_address'] = item.text.strip()
            
        # parse interest
        interest = person_detail.find("p", class_="person-research-interests")
        if interest:
            data_dict['research_area'] = interest.text.replace("Research Interests:", "").strip()          
                                
        if DEBUG:
            print(f"========\t n={n}\t=============")
            print(f"name= {data_dict.get('name','')}")
            print(f"job_title= {data_dict.get('job_title','')}")
            print(f"phone= {data_dict.get('phone','')}")
            print(f"office= {data_dict.get('office_address','')}")
            print(f"email= {data_dict.get('email','')}")
            print(f"url= {data_dict.get('url','')}")
            print(f"img_url= {data_dict.get('img_url','')}")
            print(f"phd_univ= {data_dict.get('phd_univ','')}")
            print(f"phd_year= {data_dict.get('phd_year','')}")
            print(f"research_area= {data_dict.get('research_area','')}")
            print(f"department= {data_dict.get('department','')}")
            print(f"school= {data_dict.get('school','')}")
            print(f"url_profile= {data_dict.get('url_profile','')}")
            
        if data_dict:
            row_data = []
            for c in COLUMNS_v2:
                cell = data_dict.get(c,"")
                row_data.append(cell)
            data.append(row_data)
    except Exception as e:
        print(f"[Error] {str(e)}")
#         print(f"{person.prettify()}")

# %% [raw]
# data

# %% [raw]
# data_dict

# %%
len(data) , data[-1]
# Out:
# (68,
#  ['Huacheng Yu',
#   'Assistant Professor',
#   'Stanford University',
#   '2017',
#   'Data structures, streaming algorithms, communication complexity',
#   '',
#   '',
#   'https://www.cs.princeton.edu/~hy2',
#   'https://www.cs.princeton.edu/sites/all/modules/custom/cs_people/generate_thumbnail.php?id=5209&thumb=',
#   '(609) 258-5962',
#   'hy2@cs.princeton.edu',
#   '',
#   '310 Computer Science',
#   'Computer Science',
#   'Princeton Univ',
#   'https://www.cs.princeton.edu/people/profile/hy2',
#   ''])

# %%
df = pd.DataFrame(data, columns=COLUMNS_v2)

# %%
print(f"Number of faculties at {SCHOOL}: {df.shape[0]}")
# Out:
# Number of faculties at Princeton-CS: 68

# %%
df
# Out:
#                 name                                     job_title  \
# 0    Parastoo Abtahi                           Assistant Professor
# 1         Ryan Adams                    Professor, Associate Chair
# 2       Andrew Appel                      Eugene Higgins Professor
# 3      Sanjeev Arora               Charles C. Fitzmorris Professor
# 4       David August                                     Professor
# ..               ...                                           ...
# 63  Olga Troyanskaya                                     Professor
# 64      David Walker  Professor, Director of Undergraduate Studies
# 65       Kevin Wayne    Phillip Y. Goldman '86 University Lecturer
# 66  Matthew Weinberg                           Associate Professor
# 67       Huacheng Yu                           Assistant Professor
#
#                                     phd_univ phd_year  \
# 0                        Stanford University     2022
# 1                    University of Cambridge     2009
# 2                 Carnegie-Mellon University     1985
# 3         University of California, Berkeley     1994
# 4   University of Illinois, Urbana/Champaign     2000
# ..                                       ...      ...
# 63                       Stanford University     2003
# 64                        Cornell University     2001
# 65                        Cornell University     1999
# 66     Massachusetts Institute of Technology     2014
# 67                       Stanford University     2017
#
#                                         research_area research_concentration  \
# 0   Human-Computer Interaction, Augmented Reality,...
# 1   I am interested in machine learning, artificia...
# 2   Software verification, computer security, prog...
# 3   Uses of randomness in complexity theory and al...
# 4                 Computer Architecture and Compilers
# ..                                                ...                    ...
# 63  Bioinformatics; analysis of large-scale biolog...
# 64  Programming languages, type systems, compilers...
# 65  Algorithms and data structures; computer scien...
# 66
# 67  Data structures, streaming algorithms, communi...
#
#    research_focus                                   url  \
# 0                  https://www.cs.princeton.edu/~abtahi
# 1                     https://www.cs.princeton.edu/~rpa
# 2                   https://www.cs.princeton.edu/~appel
# 3                   https://www.cs.princeton.edu/~arora
# 4                  https://www.cs.princeton.edu/~august
# ..            ...                                   ...
# 63                                  /people/profile/ogt
# 64                    https://www.cs.princeton.edu/~dpw
# 65                  https://www.cs.princeton.edu/~wayne
# 66                 https://www.cs.princeton.edu/~smattw
# 67                    https://www.cs.princeton.edu/~hy2
#
#                                               img_url           phone  \
# 0   https://www.cs.princeton.edu/sites/all/modules...  (609) 258-9528
# 1   https://www.cs.princeton.edu/sites/all/modules...  (609) 258-8682
# 2   https://www.cs.princeton.edu/sites/all/modules...  (609) 258-4627
# 3   https://www.cs.princeton.edu/sites/all/modules...  (609) 258-3869
# 4   https://www.cs.princeton.edu/sites/all/modules...  (609) 258-2085
# ..                                                ...             ...
# 63  https://www.cs.princeton.edu/sites/all/modules...  (609) 258-1749
# 64  https://www.cs.princeton.edu/sites/all/modules...  (609) 258-7654
# 65  https://www.cs.princeton.edu/sites/all/modules...  (609) 258-4455
# 66  https://www.cs.princeton.edu/sites/all/modules...  (609) 258-0944
# 67  https://www.cs.princeton.edu/sites/all/modules...  (609) 258-5962
#
#                       email cell_phone        office_address  \
# 0   abtahi@cs.princeton.edu             419 Computer Science
# 1      rpa@cs.princeton.edu             411 Computer Science
# 2    appel@cs.princeton.edu             209 Computer Science
# 3    arora@cs.princeton.edu             407 Computer Science
# 4   august@cs.princeton.edu             221 Computer Science
# ..                      ...        ...                   ...
# 63     ogt@cs.princeton.edu             320 Computer Science
# 64     dpw@cs.princeton.edu             211 Computer Science
# 65   wayne@cs.princeton.edu                  040 Corwin Hall
# 66  smattw@cs.princeton.edu             317 Computer Science
# 67     hy2@cs.princeton.edu             310 Computer Science
#
#           department          school  \
# 0   Computer Science  Princeton Univ
# 1   Computer Science  Princeton Univ
# 2   Computer Science  Princeton Univ
# 3   Computer Science  Princeton Univ
# 4   Computer Science  Princeton Univ
# ..               ...             ...
# 63  Computer Science  Princeton Univ
# 64  Computer Science  Princeton Univ
# 65  Computer Science  Princeton Univ
# 66  Computer Science  Princeton Univ
# 67  Computer Science  Princeton Univ
#
#                                           url_profile url_author
# 0   https://www.cs.princeton.edu/people/profile/ab...
# 1     https://www.cs.princeton.edu/people/profile/rpa
# 2   https://www.cs.princeton.edu/people/profile/appel
# 3   https://www.cs.princeton.edu/people/profile/arora
# 4   https://www.cs.princeton.edu/people/profile/au...
# ..                                                ...        ...
# 63    https://www.cs.princeton.edu/people/profile/ogt
# 64    https://www.cs.princeton.edu/people/profile/dpw
# 65  https://www.cs.princeton.edu/people/profile/wayne
# 66  https://www.cs.princeton.edu/people/profile/sm...
# 67    https://www.cs.princeton.edu/people/profile/hy2
#
# [68 rows x 17 columns]

# %%
# import xlsxwriter
file_xlsx = f"faculty-{SCHOOL}.xlsx"
print(f"{file_xlsx}")
writer = pd.ExcelWriter(file_xlsx, engine='xlsxwriter')
df.to_excel(writer, sheet_name="Faculty", index=False)
# if not df_research.empty:
#     df_research.to_excel(writer, sheet_name = "Research Groups", index=False)
writer.close()
# Out:
# faculty-Princeton-CS.xlsx
