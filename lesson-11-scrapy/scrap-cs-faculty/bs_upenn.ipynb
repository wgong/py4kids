# %%
from IPython.display import display, Markdown, Latex
from scrap_cs_faculty import *

with open("readme.md") as f:
    readme_md = f.read()

display(Markdown(readme_md))
# Out:
# ## US CS Faculty Dataset
# - [CS Faculty Composition and Hiring Trends (Blog)](https://jeffhuang.com/computer-science-open-data/#cs-faculty-composition-and-hiring-trends)
# - [2200 Computer Science Professors in 50 top US Graduate Programs](https://cs.brown.edu/people/apapouts/faculty_dataset.html)
# - [CS Professors (Data Explorer)](https://drafty.cs.brown.edu/csprofessors?src=csopendata)
# - [Drafty Project](https://drafty.cs.brown.edu/)
# - [CSRankings.org](https://csrankings.org/#/fromyear/2011/toyear/2023/index?ai&vision&mlmining&nlp&inforet&act&crypt&log&us)
#
#
# ## Top 6 schools
# Stanford, UCB, MIT, CMU, Cornell, UIUC
#
# ## add more schools
#
# - https://www.cs.princeton.edu/people/faculty?type=main
# - https://www.cs.washington.edu/people/faculty
# - https://directory.seas.upenn.edu/computer-and-information-science/
# - https://www.cms.caltech.edu/cms-people/faculty
# - https://www.cs.columbia.edu/people/faculty/
# - https://cse.engin.umich.edu/people/faculty/
# - https://samueli.ucla.edu/search-faculty/#cs
# - https://cse.ucsd.edu/people/faculty-profiles
# - https://seas.harvard.edu/computer-science/people?role[46]=46
# - https://www.cc.gatech.edu/people/faculty?page=24  (page=[0,25))

# %% [raw]
# def pick_name_from_profile_url(url):
#     """
#     UPenn profile URL is always present with name
#     used it to recover Name when missing
#     """
#     name = [i.strip() for i in url.split("/") if i.strip()][-1]
#     cap_ed = [i.strip().capitalize() for i in name.split("-") if i.strip()]
#     return " ".join(cap_ed)

# %%
SCHOOL = "UPenn-CS"
URL = SCHOOL_DICT[SCHOOL]["url"]  #  "https://www.eecs.mit.edu/role/faculty-aid/"
print(URL)
# Out:
# https://directory.seas.upenn.edu/computer-and-information-science/

# %%
base_url = "/".join(URL.split("/")[:3])
base_url
# Out:
# 'https://directory.seas.upenn.edu'

# %%
page = requests.get(URL, headers=BROWSER_HEADERS)

# %% [raw]
# page

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %% [raw]
# soup

# %% [markdown]
# We take 2 passes of processing on div classes: StaffListPhoto, StaffListMeta, separately,
#
# build up a dict with url as key

# %% [markdown]
# ## Find Profile with image

# %%
photos = soup.find_all("div", class_="StaffListPhoto")
# print(results.prettify())

# %%
school, dept = map_school_dept(SCHOOL)
school, dept
# Out:
# ('Univ Pennsylvania', 'Computer Science')

# %%
len(photos), photos[1]
# Out:
# (112,
#  <div class="StaffListPhoto">
#  <a href="https://directory.seas.upenn.edu/rajeev-alur/">
#  <img alt="Rajeev Alur" src="https://directory.seas.upenn.edu/wp-content/uploads/2020/03/alur-rajeev.jpg"/>
#  </a>
#  </div>)

# %%
all_data_dict = {}

for n, url_img in enumerate(photos):
    data_dict = {"school": school, "department": dept}

    # parse name, url
    url = url_img.find("a")["href"]
    if not url:
        print(f"[ERROR] {n} missing URL: {url_img.prettify()}")
    
    img = url_img.find("img")
    if img:
        name = img.get("alt", "")
        img_url = img.get("src", "")
        
    data_dict['url'] = url
    data_dict['name'] = name if name else pick_name_from_profile_url(url)
    data_dict['img_url'] = img_url

    all_data_dict.update({url : data_dict})

# %%
all_data_dict
# Out:
# {'https://directory.seas.upenn.edu/shivani-agarwal/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/shivani-agarwal/',
#   'name': 'Shivani Agarwal',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Agarwal-Shivani.jpg'},
#  'https://directory.seas.upenn.edu/rajeev-alur/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/rajeev-alur/',
#   'name': 'Rajeev Alur',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/alur-rajeev.jpg'},
#  'https://directory.seas.upenn.edu/sebastian-angel/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/sebastian-angel/',
#   'name': 'Sebastian Angel',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/angel-sebastian.jpg'},
#  'https://directory.seas.upenn.edu/ryan-baker/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/ryan-baker/',
#   'name': 'Ryan Baker',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Baker-Ryan.jpg'},
#  'https://directory.seas.upenn.edu/yoseph-barash/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/yoseph-barash/',
#   'name': 'Yoseph Barash',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/10/Barash-Yoseph.jpg'},
#  'https://directory.seas.upenn.edu/osbert-bastani/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/osbert-bastani/',
#   'name': 'Osbert Bastani',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Bastani-Osbert.jpg'},
#  'https://directory.seas.upenn.edu/arvind-bhusnurmath/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/arvind-bhusnurmath/',
#   'name': 'Arvind Bhusnurmath',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Bhusnermath-Arvind.jpg'},
#  'https://directory.seas.upenn.edu/chris-callison-burch/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/chris-callison-burch/',
#   'name': 'Chris Callison-Burch',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/callison-burch-chris.jpg'},
#  'https://directory.seas.upenn.edu/damon-centola/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/damon-centola/',
#   'name': 'Damon Centola',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2021/10/Damon_Centola.png'},
#  'https://directory.seas.upenn.edu/pratik-chaudhari/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/pratik-chaudhari/',
#   'name': 'Pratik Chaudhari',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/chaudhari-pratik.jpg'},
#  'https://directory.seas.upenn.edu/konstantinos-daniilidis/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/konstantinos-daniilidis/',
#   'name': 'Konstantinos Daniilidis',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/daniilidis-kostas.jpg'},
#  'https://directory.seas.upenn.edu/susan-b-davidson/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/susan-b-davidson/',
#   'name': 'Susan B. Davidson',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/davidson-susan.jpg'},
#  'https://directory.seas.upenn.edu/anindya-de/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/anindya-de/',
#   'name': 'Anindya De',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/de-anindya.jpg'},
#  'https://directory.seas.upenn.edu/andre-dehon/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/andre-dehon/',
#   'name': 'Andre DeHon',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/dehon-andre.jpg'},
#  'https://directory.seas.upenn.edu/joseph-devietti/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/joseph-devietti/',
#   'name': 'Joseph Devietti',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/devietti-joe.jpg'},
#  'https://directory.seas.upenn.edu/eric-eaton/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/eric-eaton/',
#   'name': 'Eric Eaton',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/eaton-eric.jpg'},
#  'https://directory.seas.upenn.edu/thomas-farmer/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/thomas-farmer/',
#   'name': 'Thomas Farmer',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/farmer-tom.jpg'},
#  'https://directory.seas.upenn.edu/nadia-figueroa/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/nadia-figueroa/',
#   'name': 'Nadia Figueroa',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2022/04/Figueroa_Nadia-e1648836410476.jpeg'},
#  'https://directory.seas.upenn.edu/eric-fouh/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/eric-fouh/',
#   'name': 'Eric Fouh',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Fouh-Eric.jpg'},
#  'https://directory.seas.upenn.edu/jean-h-gallier/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/jean-h-gallier/',
#   'name': 'Jean H. Gallier',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/gallier-jean.jpg'},
#  'https://directory.seas.upenn.edu/rajiv-gandhi/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/rajiv-gandhi/',
#   'name': 'Rajiv Gandhi',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Ghandi-Rajiv.jpg'},
#  'https://directory.seas.upenn.edu/jacob-gardner/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/jacob-gardner/',
#   'name': 'Jacob Gardner',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/07/gardner-jacob.jpg'},
#  'https://directory.seas.upenn.edu/james-gee/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/james-gee/',
#   'name': 'James Gee',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Gee-James.jpg'},
#  'https://directory.seas.upenn.edu/surbhi-goel/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/surbhi-goel/',
#   'name': 'Surbhi Goel',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2023/03/Surbhi-Goel_01.27.23-Surbhi-Goel-3-copy-e1678984066190.jpeg'},
#  'https://directory.seas.upenn.edu/sharath-chandra-guntuku/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/sharath-chandra-guntuku/',
#   'name': 'Sharath Chandra Guntuku',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/05/guntuku-sharath-chandra.jpg'},
#  'https://directory.seas.upenn.edu/andreas-haeberlen/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/andreas-haeberlen/',
#   'name': 'Andreas Haeberlen',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/haeberlen-andreas.jpg'},
#  'https://directory.seas.upenn.edu/hamed-hassani/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/hamed-hassani/',
#   'name': 'Hamed Hassani',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/hassani-hamed.jpg'},
#  'https://directory.seas.upenn.edu/andrew-head/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/andrew-head/',
#   'name': 'Andrew Head',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2022/06/Head_Andrew-Penn-square-400-x-400.jpeg'},
#  'https://directory.seas.upenn.edu/brett-hemenway/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/brett-hemenway/',
#   'name': 'Brett Hemenway',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/hemenway-brett.jpg'},
#  'https://directory.seas.upenn.edu/m-ani-hsieh/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/m-ani-hsieh/',
#   'name': 'M. Ani Hsieh',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/hsieh-ani.jpg'},
#  'https://directory.seas.upenn.edu/zachary-ives/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/zachary-ives/',
#   'name': 'Zachary Ives',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/ives-zack.jpg'},
#  'https://directory.seas.upenn.edu/dinesh-jayaraman/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/dinesh-jayaraman/',
#   'name': 'Dinesh Jayaraman',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Jayaraman-Dinesh-2.jpg'},
#  'https://directory.seas.upenn.edu/kevin-b-johnson/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/kevin-b-johnson/',
#   'name': 'Kevin B. Johnson',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2021/12/Johnson-Kevin-directory.jpg'},
#  'https://directory.seas.upenn.edu/yasmin-kafai/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/yasmin-kafai/',
#   'name': 'Yasmin Kafai',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Kafai-Yasmin.jpg'},
#  'https://directory.seas.upenn.edu/sampath-k-kannan/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/sampath-k-kannan/',
#   'name': 'Sampath K. Kannan',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/kannan-sampath.jpg'},
#  'https://directory.seas.upenn.edu/michael-kearns/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/michael-kearns/',
#   'name': 'Michael Kearns',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/kearns-michael.jpg'},
#  'https://directory.seas.upenn.edu/sanjeev-khanna/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/sanjeev-khanna/',
#   'name': 'Sanjeev Khanna',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/khanna-sanjeev.jpg'},
#  'https://directory.seas.upenn.edu/bongho-kim/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/bongho-kim/',
#   'name': 'Bongho Kim',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2021/08/B_Kim_sq-1-e1630336861778.jpeg'},
#  'https://directory.seas.upenn.edu/junhyong-kim/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/junhyong-kim/',
#   'name': 'Junhyong Kim',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Kim-Junhyong.jpg'},
#  'https://directory.seas.upenn.edu/daniel-e-koditschek/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/daniel-e-koditschek/',
#   'name': 'Daniel E. Koditschek',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/koditschek-dan-e1688674841157.jpg'},
#  'https://directory.seas.upenn.edu/konrad-paul-kording/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/konrad-paul-kording/',
#   'name': 'Konrad Paul Kording',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/kording-konrad.jpg'},
#  'https://directory.seas.upenn.edu/brandon-krakowsky/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/brandon-krakowsky/',
#   'name': 'Brandon Krakowsky',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Krakowsky-Brandon.jpg'},
#  'https://directory.seas.upenn.edu/vijay-kumar/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/vijay-kumar/',
#   'name': 'Vijay Kumar',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/kumar-vijay.jpg'},
#  'https://directory.seas.upenn.edu/stephen-lane/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/stephen-lane/',
#   'name': 'Stephen Lane',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/lane-stephen.jpg'},
#  'https://directory.seas.upenn.edu/benjamin-c-lee/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/benjamin-c-lee/',
#   'name': 'Benjamin C. Lee',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/08/lee-benjamin-c.jpg'},
#  'https://directory.seas.upenn.edu/insup-lee/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/insup-lee/',
#   'name': 'Insup Lee',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/lee-insup.jpg'},
#  'https://directory.seas.upenn.edu/jing-jane-li/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/jing-jane-li/',
#   'name': 'Jing (Jane) Li',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Li-Jing.jpg'},
#  'https://directory.seas.upenn.edu/gushu-li/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/gushu-li/',
#   'name': 'Gushu Li',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2023/01/Li_Gushu-e1673539750122.jpg'},
#  'https://directory.seas.upenn.edu/mark-y-liberman/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/mark-y-liberman/',
#   'name': 'Mark Y. Liberman',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Liberman-Mark.jpg'},
#  'https://directory.seas.upenn.edu/vincent-liu/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/vincent-liu/',
#   'name': 'Vincent Liu',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Liu-Vincent.jpg'},
#  'https://directory.seas.upenn.edu/lingjie-liu/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/lingjie-liu/',
#   'name': 'Lingjie Liu',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2023/02/Liu_Lingjie-e1676915333131.jpg'},
#  'https://directory.seas.upenn.edu/qi-long/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/qi-long/',
#   'name': 'Qi Long',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2022/09/Qi-Long-1-scaled-e1662750839649.jpg'},
#  'https://directory.seas.upenn.edu/boon-thau-loo/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/boon-thau-loo/',
#   'name': 'Boon Thau Loo',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/loo-boon-thau.jpg'},
#  'https://directory.seas.upenn.edu/jeremie-o-lumbroso/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/jeremie-o-lumbroso/',
#   'name': 'Jérémie O. Lumbroso',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2023/08/lumbroso_400x400-Jeremie-Lumbroso.png'},
#  'https://directory.seas.upenn.edu/adam-david-mally/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/adam-david-mally/',
#   'name': 'Adam David Mally',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/mally-adam.jpg'},
#  'https://directory.seas.upenn.edu/rahul-mangharam/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/rahul-mangharam/',
#   'name': 'Rahul Mangharam',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/mangharam-rahul.jpg'},
#  'https://directory.seas.upenn.edu/ryan-marcus/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/ryan-marcus/',
#   'name': 'Ryan Marcus',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2023/08/Marcus_Ryan-e1691764763588.jpg'},
#  'https://directory.seas.upenn.edu/nikolai-matni/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/nikolai-matni/',
#   'name': 'Nikolai Matni',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/matni-nikolai.jpg'},
#  'https://directory.seas.upenn.edu/travis-q-mcgaha/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/travis-q-mcgaha/',
#   'name': 'Travis Q. McGaha',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2021/08/T_McGaha_sq-1-e1628545840568.jpeg'},
#  'https://directory.seas.upenn.edu/danae-metaxa/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/danae-metaxa/',
#   'name': 'Danaë Metaxa',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2022/10/Metaxa_Danae_Photo-e1666974399191.jpg'},
#  'https://directory.seas.upenn.edu/pratyush-mishra/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/pratyush-mishra/',
#   'name': 'Pratyush Mishra',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/06/directory-placeholder.jpg'},
#  'https://directory.seas.upenn.edu/mayur-naik/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/mayur-naik/',
#   'name': 'Mayur Naik',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/naik-mayur.jpg'},
#  'https://directory.seas.upenn.edu/george-j-pappas/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/george-j-pappas/',
#   'name': 'George J. Pappas',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/pappas-george.jpg'},
#  'https://directory.seas.upenn.edu/robin-pemantle/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/robin-pemantle/',
#   'name': 'Robin Pemantle',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/06/directory-placeholder.jpg'},
#  'https://directory.seas.upenn.edu/linh-thi-xuan-phan/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/linh-thi-xuan-phan/',
#   'name': 'Linh Thi Xuan Phan',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/phan-linh.jpg'},
#  'https://directory.seas.upenn.edu/benjamin-c-pierce/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/benjamin-c-pierce/',
#   'name': 'Benjamin C. Pierce',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/pierce-benjamin.jpg'},
#  'https://directory.seas.upenn.edu/joshua-b-plotkin/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/joshua-b-plotkin/',
#   'name': 'Joshua B. Plotkin',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Plotkin-Josh.jpg'},
#  'https://directory.seas.upenn.edu/michael-posa/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/michael-posa/',
#   'name': 'Michael Posa',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/posa-michael.jpg'},
#  'https://directory.seas.upenn.edu/victor-m-preciado/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/victor-m-preciado/',
#   'name': 'Victor M. Preciado',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/preciado-victor.jpg'},
#  'https://directory.seas.upenn.edu/tal-rabin/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/tal-rabin/',
#   'name': 'Tal Rabin',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/09/Rabin-Tal.jpg'},
#  'https://directory.seas.upenn.edu/alejandro-ribeiro/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/alejandro-ribeiro/',
#   'name': 'Alejandro Ribeiro',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/ribeiro-alejandro.jpg'},
#  'https://directory.seas.upenn.edu/dan-roth/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/dan-roth/',
#   'name': 'Dan Roth',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Roth-Dan.jpg'},
#  'https://directory.seas.upenn.edu/aaron-roth/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/aaron-roth/',
#   'name': 'Aaron Roth',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Roth-Aaron.jpg'},
#  'https://directory.seas.upenn.edu/harvey-rubin/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/harvey-rubin/',
#   'name': 'Harvey Rubin',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/06/directory-placeholder.jpg'},
#  'https://directory.seas.upenn.edu/shirin-saeedi-bidokhti/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/shirin-saeedi-bidokhti/',
#   'name': 'Shirin Saeedi Bidokhti',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/saeedi-bidokhti-shirin.jpg'},
#  'https://directory.seas.upenn.edu/andre-scedrov/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/andre-scedrov/',
#   'name': 'Andre Scedrov',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/06/directory-placeholder.jpg'},
#  'https://directory.seas.upenn.edu/swapneel-sheth/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/swapneel-sheth/',
#   'name': 'Swapneel Sheth',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/sheth-swapneel.jpg'},
#  'https://directory.seas.upenn.edu/jianbo-shi/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/jianbo-shi/',
#   'name': 'Jianbo Shi',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/shi-jianbo.jpg'},
#  'https://directory.seas.upenn.edu/harry-smith/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/harry-smith/',
#   'name': 'Harry Smith',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/07/smith-harry.jpg'},
#  'https://directory.seas.upenn.edu/jonathan-m-smith/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/jonathan-m-smith/',
#   'name': 'Jonathan M. Smith',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/smith-jonathan.jpg'},
#  'https://directory.seas.upenn.edu/oleg-sokolsky/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/oleg-sokolsky/',
#   'name': 'Oleg Sokolsky',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/sokolosky-oleg.jpg'},
#  'https://directory.seas.upenn.edu/weijie-su/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/weijie-su/',
#   'name': 'Weijie Su',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/11/su-weijie.jpg'},
#  'https://directory.seas.upenn.edu/cynthia-sung/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/cynthia-sung/',
#   'name': 'Cynthia Sung',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/sung-cynthia.jpg'},
#  'https://directory.seas.upenn.edu/val-b-tannen/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/val-b-tannen/',
#   'name': 'Val B. Tannen',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/tannen-val.jpg'},
#  'https://directory.seas.upenn.edu/camillo-jose-taylor/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/camillo-jose-taylor/',
#   'name': 'Camillo Jose Taylor',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/taylor-camillo-jose.jpg'},
#  'https://directory.seas.upenn.edu/lyle-h-ungar/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/lyle-h-ungar/',
#   'name': 'Lyle H. Ungar',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/ungar-lyle.jpg'},
#  'https://directory.seas.upenn.edu/rene-vidal/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/rene-vidal/',
#   'name': 'René Vidal',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2022/10/Vidal_Rene_Photo-e1666973953718.jpg'},
#  'https://directory.seas.upenn.edu/rakesh-v-vohra/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/rakesh-v-vohra/',
#   'name': 'Rakesh V. Vohra',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/vohra-rakesh.jpg'},
#  'https://directory.seas.upenn.edu/erik-waingarten/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/erik-waingarten/',
#   'name': 'Erik Waingarten',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2023/01/Waingarten_Erik.jpeg'},
#  'https://directory.seas.upenn.edu/li-san-wang/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/li-san-wang/',
#   'name': 'Li-San Wang',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2021/11/LSW-cropped-e1638307877588.jpg'},
#  'https://directory.seas.upenn.edu/duncan-j-watts/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/duncan-j-watts/',
#   'name': 'Duncan J. Watts',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Watts-Duncan.jpg'},
#  'https://directory.seas.upenn.edu/scott-weinstein/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/scott-weinstein/',
#   'name': 'Scott Weinstein',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Weinstein-Scott.jpg'},
#  'https://directory.seas.upenn.edu/stephanie-weirich/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/stephanie-weirich/',
#   'name': 'Stephanie Weirich',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/weirich-stephanie.jpg'},
#  'https://directory.seas.upenn.edu/eric-wong/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/eric-wong/',
#   'name': 'Eric Wong',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2022/10/wong-eric-web.jpg'},
#  'https://directory.seas.upenn.edu/charles-yang/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/charles-yang/',
#   'name': 'Charles Yang',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/06/directory-placeholder.jpg'},
#  'https://directory.seas.upenn.edu/mark-yatskar/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/mark-yatskar/',
#   'name': 'Mark Yatskar',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2021/12/Yatskar-Mark-directory.jpg'},
#  'https://directory.seas.upenn.edu/mark-yim/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/mark-yim/',
#   'name': 'Mark Yim',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/yim-mark-e1631888206507.jpg'},
#  'https://directory.seas.upenn.edu/christopher-s-yoo/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/christopher-s-yoo/',
#   'name': 'Christopher S Yoo',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/06/directory-placeholder.jpg'},
#  'https://directory.seas.upenn.edu/stephan-a-zdancewic/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/stephan-a-zdancewic/',
#   'name': 'Stephan A Zdancewic',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/06/directory-placeholder.jpg'},
#  'https://directory.seas.upenn.edu/mingmin-zhao/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/mingmin-zhao/',
#   'name': 'Mingmin Zhao',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/06/directory-placeholder.jpg'},
#  'https://directory.seas.upenn.edu/norman-i-badler/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/norman-i-badler/',
#   'name': 'Norman I. Badler',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/badler-norm.jpg'},
#  'https://directory.seas.upenn.edu/ruzena-bajcsy/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/ruzena-bajcsy/',
#   'name': 'Ruzena Bajcsy',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Bajcsy-Ruzena.jpg'},
#  'https://directory.seas.upenn.edu/peter-buneman-2/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/peter-buneman-2/',
#   'name': 'Peter Buneman',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2023/04/brunos-Peter-Buneman.jpg'},
#  'https://directory.seas.upenn.edu/david-j-farber/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/david-j-farber/',
#   'name': 'David J. Farber',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Farber-David.jpg'},
#  'https://directory.seas.upenn.edu/justin-gottschlich/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/justin-gottschlich/',
#   'name': 'Justin Gottschlich',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Gottschlich-Justin.jpg'},
#  'https://directory.seas.upenn.edu/mitch-marcus/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/mitch-marcus/',
#   'name': 'Mitch Marcus',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/marcus-mitch.jpg'},
#  'https://directory.seas.upenn.edu/ani-nenkova/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/ani-nenkova/',
#   'name': 'Ani Nenkova',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/nenkova-ani.jpg'},
#  'https://directory.seas.upenn.edu/richard-paul/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/richard-paul/',
#   'name': 'Richard Paul',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/06/directory-placeholder.jpg'},
#  'https://directory.seas.upenn.edu/mark-steedman/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/mark-steedman/',
#   'name': 'Mark Steedman',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Steedman-Mark.jpg'},
#  'https://directory.seas.upenn.edu/bonnie-webber/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/bonnie-webber/',
#   'name': 'Bonnie Webber',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/06/directory-placeholder.jpg'},
#  'https://directory.seas.upenn.edu/james-weimer/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/james-weimer/',
#   'name': 'James Weimer',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/weimer-james.jpg'},
#  'https://directory.seas.upenn.edu/stella-yu/': {'school': 'Univ Pennsylvania',
#   'department': 'Computer Science',
#   'url': 'https://directory.seas.upenn.edu/stella-yu/',
#   'name': 'Stella Yu',
#   'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Yu-Stella.jpg'}}

# %% [markdown]
# ## Find Person Detail

# %%
metas = soup.find_all("div", class_="StaffListMeta")
# print(results.prettify())

# %%
len(metas), metas[1]
# Out:
# (112,
#  <div class="StaffListMeta">
#  <div class="StaffListName">
#  <a href="https://directory.seas.upenn.edu/rajeev-alur/">
#  	 			Rajeev Alur	 		</a>
#  </div>
#  <div class="StaffListTitles">
#  <div class="d-none">
#  						Professor					</div>
#  <div>
#  							Zisman Family Professor						</div>
#  <div>
#  																Computer and Information Science										</div>
#  </div>
#  <div class="StaffListSpecialTitle">
#  <div>
#  		 		 	Founding Director, ASSET Center		 		</div>
#  </div>
#  <div class="StaffListSocial">
#  <ul>
#  <li><a href="mailto:ALUR@CIS.UPENN.EDU"><i class="sls-icon email"></i></a></li> <li><a href="https://scholar.google.com/citations?user=ZvLa1RIAAAAJ&amp;hl=en" target="_blank"><i class="sls-icon gschool"></i></a></li> <li><a href="https://twitter.com/RajeevAlur" target="_blank"><i class="sls-icon twitter"></i></a></li> </ul>
#  </div>
#  </div>)

# %% [raw]
# person_detail = metas[1]

# %%
all_data_dict2 = {}
for m, person_detail in enumerate(metas):
    data_dict = {"school": school, "department": dept}
    job_titles = []

    # parse name
    name = person_detail.find("div", class_="StaffListName")
    if name:
        x = name.find("a")
        url = x["href"]
        data_dict["url"] = url
        data_dict["name"] = x.text.strip()

    # parse title
    titles = person_detail.find("div", class_="StaffListTitles")
    if titles:
        job_titles += [x.text.strip() for x in titles.find_all("div") if x.text.strip()]

    titles = person_detail.find("div", class_="StaffListSpecialTitle")
    if titles:
        job_titles += [x.text.strip() for x in titles.find_all("div") if x.text.strip()]

    if job_titles:
        data_dict["job_title"] = ", ".join(job_titles)

    # parse social
    social = person_detail.find("div", class_="StaffListSocial")
    if social:
        items = social.find_all("li")
        num_lis = len(items)
        n = 0
        for li in items:
            href = li.find("a")["href"]
            if "mailto:" in href:
                data_dict["email"] = href.replace("mailto:", "")
                n += 1
            elif "scholar.google." in href:
                data_dict["url_author"] = href
                n += 1
            elif "twitter." in href:
                data_dict["url_twitter"] = href
                n += 1
            elif "tel:" in href:
                data_dict["phone"] = href.replace("tel:", "")
                n += 1

        if n != num_lis:
            print(f"[ERROR] {m} : {url} has new social tag:\n {social.prettify()}")

    if data_dict.get("url", ""):
        all_data_dict2.update({data_dict["url"] : data_dict})
# Out:
# [ERROR] 32 : https://directory.seas.upenn.edu/kevin-b-johnson/ has new social tag:
#  <div class="StaffListSocial">
#  <ul>
#   <li>
#    <a href="mailto:Kevin.Johnson1@Pennmedicine.upenn.edu">
#     <i class="sls-icon email">
#     </i>
#    </a>
#   </li>
#   <li>
#    <a href="https://scholar.google.com/citations?user=RFcbxjoAAAAJ&amp;hl=en&amp;oi=ao" target="_blank">
#     <i class="sls-icon gschool">
#     </i>
#    </a>
#   </li>
#   <li>
#    <a href="@kbjohnsonmd" target="_blank">
#     <i class="sls-icon twitter">
#     </i>
#    </a>
#   </li>
#  </ul>
# </div>

# %% [markdown]
# ## Merge two dicts

# %%
all_data_dict["https://directory.seas.upenn.edu/kevin-b-johnson/"]
# Out:
# {'school': 'Univ Pennsylvania',
#  'department': 'Computer Science',
#  'url': 'https://directory.seas.upenn.edu/kevin-b-johnson/',
#  'name': 'Kevin B. Johnson',
#  'img_url': 'https://directory.seas.upenn.edu/wp-content/uploads/2021/12/Johnson-Kevin-directory.jpg'}

# %%
all_data_dict2["https://directory.seas.upenn.edu/kevin-b-johnson/"]
# Out:
# {'school': 'Univ Pennsylvania',
#  'department': 'Computer Science',
#  'url': 'https://directory.seas.upenn.edu/kevin-b-johnson/',
#  'name': 'Kevin B. Johnson',
#  'job_title': 'Professor, David L. Cohen University Professor, Annenberg School for Communication, Bioengineering, Biostatistics, Epidemiology and Informatics, Computer and Information Science, Pediatrics, Vice President for Applied Informatics, University of Pennsylvania Health System',
#  'email': 'Kevin.Johnson1@Pennmedicine.upenn.edu',
#  'url_author': 'https://scholar.google.com/citations?user=RFcbxjoAAAAJ&hl=en&oi=ao'}

# %% [markdown]
# ## Prepare dataframe

# %%
DEBUG = True

# %%
data = []
for n, k in enumerate(all_data_dict2.keys()):
    data_dict = all_data_dict2[k]
    if "img_url" not in data_dict and k in all_data_dict:
        data_dict.update({"img_url": all_data_dict[k]["img_url"]})
        
    print(f"========\t n={n}\t=============")
    if DEBUG and n < 3:
        print(f"name= {data_dict.get('name','')}")
        print(f"job_title= {data_dict.get('job_title','')}")
        print(f"phone= {data_dict.get('phone','')}")
        print(f"office= {data_dict.get('office_address','')}")
        print(f"email= {data_dict.get('email','')}")
        print(f"url= {data_dict.get('url','')}")
        print(f"img_url= {data_dict.get('img_url','')}")
        print(f"phd_univ= {data_dict.get('phd_univ','')}")
        print(f"phd_year= {data_dict.get('phd_year','')}")
        print(f"research_area= {data_dict.get('research_area','')}")
        print(f"department= {data_dict.get('department','')}")
        print(f"school= {data_dict.get('school','')}")
        print(f"url_profile= {data_dict.get('url_profile','')}")
        print(f"url_author= {data_dict.get('url_author','')}")

    row_data = []
    for c in COLUMNS_v2:
        cell = data_dict.get(c,"")
        row_data.append(cell)
    data.append(row_data)
# Out:
# ========	 n=0	=============
# name= Shivani Agarwal
# job_title= Associate Professor, Rachleff Family Associate Professor, Computer and Information Science
# phone=
# office=
# email= ashivani@cis.upenn.edu
# url= https://directory.seas.upenn.edu/shivani-agarwal/
# img_url= https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Agarwal-Shivani.jpg
# phd_univ=
# phd_year=
# research_area=
# department= Computer Science
# school= Univ Pennsylvania
# url_profile=
# url_author=
# ========	 n=1	=============
# name= Rajeev Alur
# job_title= Professor, Zisman Family Professor, Computer and Information Science, Founding Director, ASSET Center
# phone=
# office=
# email= ALUR@CIS.UPENN.EDU
# url= https://directory.seas.upenn.edu/rajeev-alur/
# img_url= https://directory.seas.upenn.edu/wp-content/uploads/2020/03/alur-rajeev.jpg
# phd_univ=
# phd_year=
# research_area=
# department= Computer Science
# school= Univ Pennsylvania
# url_profile=
# url_author= https://scholar.google.com/citations?user=ZvLa1RIAAAAJ&hl=en
# ========	 n=2	=============
# name= Sebastian Angel
# job_title= Assistant Professor, Raj and Neera Singh Term Assistant Professor, Computer and Information Science
# phone=
# office=
# email= sga001@cis.upenn.edu
# url= https://directory.seas.upenn.edu/sebastian-angel/
# img_url= https://directory.seas.upenn.edu/wp-content/uploads/2020/03/angel-sebastian.jpg
# phd_univ=
# phd_year=
# research_area=
# department= Computer Science
# school= Univ Pennsylvania
# url_profile=
# url_author=
# ========	 n=3	=============
# ========	 n=4	=============
# ========	 n=5	=============
# ========	 n=6	=============
# ========	 n=7	=============
# ========	 n=8	=============
# ========	 n=9	=============
# ========	 n=10	=============
# ========	 n=11	=============
# ========	 n=12	=============
# ========	 n=13	=============
# ========	 n=14	=============
# ========	 n=15	=============
# ========	 n=16	=============
# ========	 n=17	=============
# ========	 n=18	=============
# ========	 n=19	=============
# ========	 n=20	=============
# ========	 n=21	=============
# ========	 n=22	=============
# ========	 n=23	=============
# ========	 n=24	=============
# ========	 n=25	=============
# ========	 n=26	=============
# ========	 n=27	=============
# ========	 n=28	=============
# ========	 n=29	=============
# ========	 n=30	=============
# ========	 n=31	=============
# ========	 n=32	=============
# ========	 n=33	=============
# ========	 n=34	=============
# ========	 n=35	=============
# ========	 n=36	=============
# ========	 n=37	=============
# ========	 n=38	=============
# ========	 n=39	=============
# ========	 n=40	=============
# ========	 n=41	=============
# ========	 n=42	=============
# ========	 n=43	=============
# ========	 n=44	=============
# ========	 n=45	=============
# ========	 n=46	=============
# ========	 n=47	=============
# ========	 n=48	=============
# ========	 n=49	=============
# ========	 n=50	=============
# ========	 n=51	=============
# ========	 n=52	=============
# ========	 n=53	=============
# ========	 n=54	=============
# ========	 n=55	=============
# ========	 n=56	=============
# ========	 n=57	=============
# ========	 n=58	=============
# ========	 n=59	=============
# ========	 n=60	=============
# ========	 n=61	=============
# ========	 n=62	=============
# ========	 n=63	=============
# ========	 n=64	=============
# ========	 n=65	=============
# ========	 n=66	=============
# ========	 n=67	=============
# ========	 n=68	=============
# ========	 n=69	=============
# ========	 n=70	=============
# ========	 n=71	=============
# ========	 n=72	=============
# ========	 n=73	=============
# ========	 n=74	=============
# ========	 n=75	=============
# ========	 n=76	=============
# ========	 n=77	=============
# ========	 n=78	=============
# ========	 n=79	=============
# ========	 n=80	=============
# ========	 n=81	=============
# ========	 n=82	=============
# ========	 n=83	=============
# ========	 n=84	=============
# ========	 n=85	=============
# ========	 n=86	=============
# ========	 n=87	=============
# ========	 n=88	=============
# ========	 n=89	=============
# ========	 n=90	=============
# ========	 n=91	=============
# ========	 n=92	=============
# ========	 n=93	=============
# ========	 n=94	=============
# ========	 n=95	=============
# ========	 n=96	=============
# ========	 n=97	=============
# ========	 n=98	=============
# ========	 n=99	=============
# ========	 n=100	=============
# ========	 n=101	=============
# ========	 n=102	=============
# ========	 n=103	=============
# ========	 n=104	=============
# ========	 n=105	=============
# ========	 n=106	=============
# ========	 n=107	=============
# ========	 n=108	=============
# ========	 n=109	=============
# ========	 n=110	=============
# ========	 n=111	=============

# %%
len(data) , data[-1]
# Out:
# (112,
#  ['Stella Yu',
#   'Adjunct Assistant Professor, Computer and Information Science',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'https://directory.seas.upenn.edu/stella-yu/',
#   'https://directory.seas.upenn.edu/wp-content/uploads/2020/03/Yu-Stella.jpg',
#   '510-666-2900',
#   'stellayu@berkeley.edu',
#   '',
#   '',
#   'Computer Science',
#   'Univ Pennsylvania',
#   '',
#   ''])

# %%
df = pd.DataFrame(data, columns=COLUMNS_v2)

# %%
print(f"Number of faculties at {SCHOOL}: {df.shape[0]}")
# Out:
# Number of faculties at UPenn-CS: 112

# %%
df
# Out:
#                 name                                          job_title  \
# 0    Shivani Agarwal  Associate Professor, Rachleff Family Associate...
# 1        Rajeev Alur  Professor, Zisman Family Professor, Computer a...
# 2    Sebastian Angel  Assistant Professor, Raj and Neera Singh Term ...
# 3         Ryan Baker  Associate Professor, Computer and Information ...
# 4      Yoseph Barash  Associate Professor, Computer and Information ...
# ..               ...                                                ...
# 107     Richard Paul  Professor Emeritus, Computer and Information S...
# 108    Mark Steedman  Adjunct Professor, Computer and Information Sc...
# 109    Bonnie Webber  Adjunct Professor, Computer and Information Sc...
# 110     James Weimer  Adjunct Assistant Professor, Computer and Info...
# 111        Stella Yu  Adjunct Assistant Professor, Computer and Info...
#
#     phd_univ phd_year research_area research_concentration research_focus  \
# 0
# 1
# 2
# 3
# 4
# ..       ...      ...           ...                    ...            ...
# 107
# 108
# 109
# 110
# 111
#
#                                                    url  \
# 0    https://directory.seas.upenn.edu/shivani-agarwal/
# 1        https://directory.seas.upenn.edu/rajeev-alur/
# 2    https://directory.seas.upenn.edu/sebastian-angel/
# 3         https://directory.seas.upenn.edu/ryan-baker/
# 4      https://directory.seas.upenn.edu/yoseph-barash/
# ..                                                 ...
# 107     https://directory.seas.upenn.edu/richard-paul/
# 108    https://directory.seas.upenn.edu/mark-steedman/
# 109    https://directory.seas.upenn.edu/bonnie-webber/
# 110     https://directory.seas.upenn.edu/james-weimer/
# 111        https://directory.seas.upenn.edu/stella-yu/
#
#                                                img_url           phone  \
# 0    https://directory.seas.upenn.edu/wp-content/up...
# 1    https://directory.seas.upenn.edu/wp-content/up...
# 2    https://directory.seas.upenn.edu/wp-content/up...
# 3    https://directory.seas.upenn.edu/wp-content/up...
# 4    https://directory.seas.upenn.edu/wp-content/up...  (215) 746-8683
# ..                                                 ...             ...
# 107  https://directory.seas.upenn.edu/wp-content/up...
# 108  https://directory.seas.upenn.edu/wp-content/up...
# 109  https://directory.seas.upenn.edu/wp-content/up...
# 110  https://directory.seas.upenn.edu/wp-content/up...
# 111  https://directory.seas.upenn.edu/wp-content/up...    510-666-2900
#
#                        email cell_phone office_address        department  \
# 0     ashivani@cis.upenn.edu                            Computer Science
# 1         ALUR@CIS.UPENN.EDU                            Computer Science
# 2       sga001@cis.upenn.edu                            Computer Science
# 3          rybaker@upenn.edu                            Computer Science
# 4     yosephb@seas.upenn.edu                            Computer Science
# ..                       ...        ...            ...               ...
# 107       lou@seas.upenn.edu                            Computer Science
# 108  steedman@seas.upenn.edu                            Computer Science
# 109    bonnie@seas.upenn.edu                            Computer Science
# 110   weimerj@seas.upenn.edu                            Computer Science
# 111    stellayu@berkeley.edu                            Computer Science
#
#                 school url_profile  \
# 0    Univ Pennsylvania
# 1    Univ Pennsylvania
# 2    Univ Pennsylvania
# 3    Univ Pennsylvania
# 4    Univ Pennsylvania
# ..                 ...         ...
# 107  Univ Pennsylvania
# 108  Univ Pennsylvania
# 109  Univ Pennsylvania
# 110  Univ Pennsylvania
# 111  Univ Pennsylvania
#
#                                             url_author
# 0
# 1    https://scholar.google.com/citations?user=ZvLa...
# 2
# 3
# 4
# ..                                                 ...
# 107
# 108
# 109
# 110  https://scholar.google.com/citations?user=IeuL...
# 111
#
# [112 rows x 17 columns]

# %%
# import xlsxwriter
file_xlsx = f"faculty-{SCHOOL}.xlsx"
print(f"{file_xlsx}")
writer = pd.ExcelWriter(file_xlsx, engine='xlsxwriter')
df.to_excel(writer, sheet_name="Faculty", index=False)
# if not df_research.empty:
#     df_research.to_excel(writer, sheet_name = "Research Groups", index=False)
writer.close()
# Out:
# faculty-UPenn-CS.xlsx
