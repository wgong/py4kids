# %% [markdown]
# This notebook uses `scholarly` API (https://github.com/scholarly-python-package/scholarly) to enrich CS faculty info

# %%
from scrap_cs_faculty import *

# %%
org_list = ["CMU-CS","Cornell-CS","MIT-AID","MIT-CS","Stanford-CS","UCB-CS","UIUC-CS",]
idx_org = org_list.index("CMU-CS")
org = org_list[idx_org]
org2 = org.split("-")[0]

# %% [markdown]
# ## read CS faculty info scraped previously

# %%
file_xlsx = f"faculty-{org}.xlsx"
xlsxf = pd.ExcelFile(file_xlsx)

# %%
xlsxf.sheet_names
# Out:
# ['Faculty']

# %%
df = xlsxf.parse('Faculty')

# %%
df
# Out:
#                     name                                         job_title  \
# 0             Acar, Umut                               Associate Professor
# 1              Ada, Anil                      Associate Teaching Professor
# 2          Akoglu, Leman           Associate Professor, Affiliated Faculty
# 3      Aldrich, Jonathan                     Professor, Affiliated Faculty
# 4    Amvrosiadis, George  Assistant Research Professor, Affiliated Faculty
# ..                   ...                                               ...
# 115      Wing, Jeannette                                   Adjunct Faculty
# 116      Woodruff, David                                         Professor
# 117    Xhakaj, Franceska                      Assistant Teaching Professor
# 118           Zhang, Hui                              Consulting Professor
# 119       Zheng, Wenting                               Assistant Professor
#
#      phd_univ  phd_year  research_area  research_concentration  \
# 0         NaN       NaN            NaN                     NaN
# 1         NaN       NaN            NaN                     NaN
# 2         NaN       NaN            NaN                     NaN
# 3         NaN       NaN            NaN                     NaN
# 4         NaN       NaN            NaN                     NaN
# ..        ...       ...            ...                     ...
# 115       NaN       NaN            NaN                     NaN
# 116       NaN       NaN            NaN                     NaN
# 117       NaN       NaN            NaN                     NaN
# 118       NaN       NaN            NaN                     NaN
# 119       NaN       NaN            NaN                     NaN
#
#      research_focus                                                url  \
# 0               NaN       https://csd.cmu.edu/people/faculty/umut-acar
# 1               NaN        https://csd.cmu.edu/people/faculty/anil-ada
# 2               NaN    https://csd.cmu.edu/people/faculty/leman-akoglu
# 3               NaN  https://csd.cmu.edu/people/faculty/jonathan-al...
# 4               NaN  https://csd.cmu.edu/people/faculty/george-amvr...
# ..              ...                                                ...
# 115             NaN  https://csd.cmu.edu/people/faculty/jeannette-wing
# 116             NaN  https://csd.cmu.edu/people/faculty/david-woodr...
# 117             NaN  https://csd.cmu.edu/people/faculty/franceska-x...
# 118             NaN     https://csd.cmu.edu/people/faculty/hui-zhang-0
# 119             NaN   https://csd.cmu.edu/people/faculty/wenting-zheng
#
#      img_url           phone                    email  cell_phone  \
# 0        NaN  (412) 268-6791     uacar@andrew.cmu.edu         NaN
# 1        NaN  (412) 268-3835      aada@andrew.cmu.edu         NaN
# 2        NaN  (412) 268-3043   lakoglu@andrew.cmu.edu         NaN
# 3        NaN  (412) 268-7278       aldrich@cs.cmu.edu         NaN
# 4        NaN             NaN  gamvrosi@andrew.cmu.edu         NaN
# ..       ...             ...                      ...         ...
# 115      NaN  (412) 268-2000      jw35@andrew.cmu.edu         NaN
# 116      NaN             NaN  dwoodruf@andrew.cmu.edu         NaN
# 117      NaN             NaN  francesx@andrew.cmu.edu         NaN
# 118      NaN             NaN     huiz1@andrew.cmu.edu         NaN
# 119      NaN             NaN   wzheng2@andrew.cmu.edu         NaN
#
#                                      office_address        department  \
# 0                    9101 Gates and Hillman Centers  Computer Science
# 1                    6215 Gates and Hillman Centers  Computer Science
# 2                                2118C Hamburg Hall  Computer Science
# 3                                      422 TCS Hall  Computer Science
# 4    2311 Mehrabian Collaborative Innovation Center  Computer Science
# ..                                              ...               ...
# 115                                             NaN  Computer Science
# 116                  7217 Gates and Hillman Centers  Computer Science
# 117                  4003 Gates and Hillman Centers  Computer Science
# 118                                             NaN  Computer Science
# 119                  9015 Gates and Hillman Centers  Computer Science
#
#                    school
# 0    Carnegie Mellon Univ
# 1    Carnegie Mellon Univ
# 2    Carnegie Mellon Univ
# 3    Carnegie Mellon Univ
# 4    Carnegie Mellon Univ
# ..                    ...
# 115  Carnegie Mellon Univ
# 116  Carnegie Mellon Univ
# 117  Carnegie Mellon Univ
# 118  Carnegie Mellon Univ
# 119  Carnegie Mellon Univ
#
# [120 rows x 15 columns]

# %%
names = df["name"].to_list()

# %%
len(names), names
# Out:
# (120,
#  ['Acar, Umut',
#   'Ada, Anil',
#   'Akoglu, Leman',
#   'Aldrich, Jonathan',
#   'Amvrosiadis, George',
#   'Andersen, David',
#   'Balcan, Maria',
#   'Balzer, Stephanie',
#   'Beckmann, Nathan',
#   'Berger, Daniel',
#   'Blelloch, Guy',
#   'Blum, Manuel',
#   'Bogart, Christopher',
#   'Brookes, Stephen',
#   'Brumley, David',
#   'Bryant, Randal',
#   'Carrasquel, Jacobo',
#   'Cervesato, Iliano',
#   'Chen, Tianqi',
#   'Chrysanthis, Panos',
#   'Conitzer, Vincent',
#   'Cortina, Thomas',
#   'Crane, Keenan',
#   'Crary, Karl',
#   'Dannenberg, Roger',
#   'DeYoung, Henry',
#   'Donahue, Chris',
#   'Eckhardt, Dave',
#   'Erdmann, Michael',
#   'Faloutsos, Christos',
#   'Fanti, Giulia',
#   'Fatahalian, Kayvon',
#   'Fredrikson, Matt',
#   'Frieze, Alan',
#   'Ganger, Gregory',
#   'Garlan, David',
#   'Gibbons, Phillip',
#   'Gibson, Garth',
#   'Gligor, Virgil',
#   'Goldstein, Seth',
#   'Goyal, Vipul',
#   'Gupta, Anupam',
#   'Guruswami, Venkatesan',
#   'Haeupler, Bernhard',
#   'Harchol-Balter, Mor',
#   'Harper, Robert',
#   'Heule, Marijn',
#   'Hodgins, Jessica',
#   'Hoffmann, Jan',
#   'Jahanian, Farnam',
#   'Jain, Aayush',
#   'Jia, Limin',
#   'Jia, Zhihao',
#   'Kaminsky, Michael',
#   'Kanade, Takeo',
#   'Kaynar, Zeliha Dilsun',
#   'Kilinc-Karzan, Fatma',
#   'Kohlbrenner, Anne',
#   'Kolter, Zico',
#   'Kosbie, David',
#   'Kothari, Pravesh',
#   'Kumar, Swarun',
#   'Labrinidis, Alexandros',
#   'Lee, Tai-Sing',
#   'Levin, Golan',
#   'Lucia, Brandon',
#   'Mackey, John',
#   'Martins, Ruben',
#   'Miller, Gary',
#   'Mitchell, Tom',
#   'Mitsch, Stefan',
#   'Mowry, Todd',
#   'Needham, Kit',
#   "O'Donnell, Ryan",
#   "O'Hallaron, David",
#   "O'Toole, Matthew",
#   'Parno, Bryan',
#   'Pavlo, Andrew',
#   'Pfenning, Frank',
#   'Pollard, Nancy',
#   'Procaccia, Ariel',
#   'Raghunathan, Aditi',
#   'Railing, Brian',
#   'Ravi, R.',
#   'Reddy, Raj',
#   'Rivers, Kelly',
#   'Rosenthal, Stephanie',
#   'Rudich, Steven',
#   'Saad, Feras',
#   'Sakr, Majd',
#   'Sanders, William',
#   'Sandholm, Tuomas',
#   'Satyanarayanan, Mahadev',
#   'Savelka, Jaromir',
#   'Schwartz, Russell',
#   'Scott, Dana',
#   'Sekar, Vyas',
#   'Seshan, Srini',
#   'Shah, Nihar',
#   'Shaw, Mary',
#   'Sherry, Justine',
#   'Shi, Elaine',
#   'Simmons, Reid',
#   'Skarlatos, Dimitrios',
#   'Sleator, Daniel',
#   'Sriraman, Akshitha',
#   'Steenkiste, Peter',
#   'Stehlik, Mark',
#   'Sutner, Klaus',
#   'Taylor, Michael',
#   'Touretzky, David',
#   'Vinayak, Rashmi Korlakai',
#   'Virtue, Patrick',
#   'Wang, Weina',
#   'Weinberg, Zack',
#   'Wing, Jeannette',
#   'Woodruff, David',
#   'Xhakaj, Franceska',
#   'Zhang, Hui',
#   'Zheng, Wenting'])

# %% [markdown]
# ## fetch google scholar data for all CS faculty

# %%
ntest = -1  #  2 #

# %%
pub_data = []
for n, name in enumerate(names[:ntest]):
#     if n < 5: continue 
    print(f"n, name = {n}, {name} ...")
    
    author_org = f"{name} {org2}"
    norm_auth_org = normalize_str(author_org)
    file_author = f"data/GScholar_{norm_auth_org}.json"

    try:
        search_query = scholarly.search_author(author_org)
        init_result = next(search_query)
    except Exception as ex:
        print(str(ex))
        init_result = None 
        
    if init_result is None:
        print(f"Failed search_author()")
        continue

    scholar_id = init_result.get("scholar_id", "")
    if not scholar_id:
        print(f"Missing scholar_id")
        continue        
    
    # fetch data
    author = scholarly.fill(init_result)
    
    author_dict = {}
    # fill data cell
    author_dict["name"] = name 
    author_dict["file_author"] = file_author 
    author_dict["scholar_id"] = scholar_id 
    author_dict["affiliation"] = author.get("affiliation", "")
    author_dict["interests"] = "; ".join(author.get("interests", []))
    author_dict["url_author"] = get_scholar_page(scholar_id)
    author_dict["url_picture"] = author.get("url_picture", "")
    author_dict["url_homepage"] = author.get("homepage", "")
    author_dict["citedby"] = author.get("citedby", 0)
    author_dict["citedby5y"] = author.get("citedby5y", 0)
    author_dict["hindex"] = author.get("hindex", 0)
    author_dict["hindex5y"] = author.get("hindex5y", 0)
    author_dict["i10index"] = author.get("i10index", 0)
    author_dict["i10index5y"] = author.get("i10index5y", 0)
    author_dict["num_papers"] = len(author.get("publications", []))
    author_dict["num_coauthors"] = len(author.get("coauthors", []))
      
    # fill row 
    author_data = []
    for c in SCHOLAR_HEADER:
        author_data.append(author_dict.get(c))
        
    # accumulate row
    pub_data.append(author_data)
    
    # persist author data
    with open(Path(file_author), "w", encoding="utf-8") as f:
        f.write(json.dumps(author))
    
    delay = randint(1,5)
    sleep(delay)
# Out:
# n, name = 0, Acar, Umut ...
# n, name = 1, Ada, Anil ...
#
# Failed search_author()
# n, name = 2, Akoglu, Leman ...
# n, name = 3, Aldrich, Jonathan ...
# n, name = 4, Amvrosiadis, George ...
# n, name = 5, Andersen, David ...
# n, name = 6, Balcan, Maria ...
# n, name = 7, Balzer, Stephanie ...
# n, name = 8, Beckmann, Nathan ...
# n, name = 9, Berger, Daniel ...
#
# Failed search_author()
# n, name = 10, Blelloch, Guy ...
# n, name = 11, Blum, Manuel ...
#
# Failed search_author()
# n, name = 12, Bogart, Christopher ...
# n, name = 13, Brookes, Stephen ...
#
# Failed search_author()
# n, name = 14, Brumley, David ...
# n, name = 15, Bryant, Randal ...
# n, name = 16, Carrasquel, Jacobo ...
# n, name = 17, Cervesato, Iliano ...
# n, name = 18, Chen, Tianqi ...
# n, name = 19, Chrysanthis, Panos ...
#
# Failed search_author()
# n, name = 20, Conitzer, Vincent ...
# n, name = 21, Cortina, Thomas ...
# n, name = 22, Crane, Keenan ...
# n, name = 23, Crary, Karl ...
# n, name = 24, Dannenberg, Roger ...
# n, name = 25, DeYoung, Henry ...
#
# Failed search_author()
# n, name = 26, Donahue, Chris ...
#
# Failed search_author()
# n, name = 27, Eckhardt, Dave ...
#
# Failed search_author()
# n, name = 28, Erdmann, Michael ...
#
# Failed search_author()
# n, name = 29, Faloutsos, Christos ...
# n, name = 30, Fanti, Giulia ...
# n, name = 31, Fatahalian, Kayvon ...
#
# Failed search_author()
# n, name = 32, Fredrikson, Matt ...
# n, name = 33, Frieze, Alan ...
# n, name = 34, Ganger, Gregory ...
# n, name = 35, Garlan, David ...
# n, name = 36, Gibbons, Phillip ...
# n, name = 37, Gibson, Garth ...
# n, name = 38, Gligor, Virgil ...
#
# Failed search_author()
# n, name = 39, Goldstein, Seth ...
# n, name = 40, Goyal, Vipul ...
# n, name = 41, Gupta, Anupam ...
# n, name = 42, Guruswami, Venkatesan ...
#
# Failed search_author()
# n, name = 43, Haeupler, Bernhard ...
# n, name = 44, Harchol-Balter, Mor ...
# n, name = 45, Harper, Robert ...
# n, name = 46, Heule, Marijn ...
# n, name = 47, Hodgins, Jessica ...
# n, name = 48, Hoffmann, Jan ...
# n, name = 49, Jahanian, Farnam ...
#
# Failed search_author()
# n, name = 50, Jain, Aayush ...
# n, name = 51, Jia, Limin ...
# n, name = 52, Jia, Zhihao ...
# n, name = 53, Kaminsky, Michael ...
# n, name = 54, Kanade, Takeo ...
# n, name = 55, Kaynar, Zeliha Dilsun ...
#
# Failed search_author()
# n, name = 56, Kilinc-Karzan, Fatma ...
# n, name = 57, Kohlbrenner, Anne ...
#
# Failed search_author()
# n, name = 58, Kolter, Zico ...
# n, name = 59, Kosbie, David ...
#
# Failed search_author()
# n, name = 60, Kothari, Pravesh ...
# n, name = 61, Kumar, Swarun ...
# n, name = 62, Labrinidis, Alexandros ...
#
# Failed search_author()
# n, name = 63, Lee, Tai-Sing ...
# n, name = 64, Levin, Golan ...
# n, name = 65, Lucia, Brandon ...
# n, name = 66, Mackey, John ...
# n, name = 67, Martins, Ruben ...
# n, name = 68, Miller, Gary ...
# n, name = 69, Mitchell, Tom ...
# n, name = 70, Mitsch, Stefan ...
# n, name = 71, Mowry, Todd ...
# n, name = 72, Needham, Kit ...
#
# Failed search_author()
# n, name = 73, O'Donnell, Ryan ...
# n, name = 74, O'Hallaron, David ...
# n, name = 75, O'Toole, Matthew ...
# n, name = 76, Parno, Bryan ...
# n, name = 77, Pavlo, Andrew ...
# n, name = 78, Pfenning, Frank ...
# n, name = 79, Pollard, Nancy ...
# n, name = 80, Procaccia, Ariel ...
#
# Failed search_author()
# n, name = 81, Raghunathan, Aditi ...
# n, name = 82, Railing, Brian ...
# n, name = 83, Ravi, R. ...
# n, name = 84, Reddy, Raj ...
# n, name = 85, Rivers, Kelly ...
# n, name = 86, Rosenthal, Stephanie ...
# n, name = 87, Rudich, Steven ...
# n, name = 88, Saad, Feras ...
# n, name = 89, Sakr, Majd ...
# n, name = 90, Sanders, William ...
# n, name = 91, Sandholm, Tuomas ...
# n, name = 92, Satyanarayanan, Mahadev ...
# n, name = 93, Savelka, Jaromir ...
# n, name = 94, Schwartz, Russell ...
# n, name = 95, Scott, Dana ...
# n, name = 96, Sekar, Vyas ...
# n, name = 97, Seshan, Srini ...
# n, name = 98, Shah, Nihar ...
# n, name = 99, Shaw, Mary ...
# n, name = 100, Sherry, Justine ...
#
# Failed search_author()
# n, name = 101, Shi, Elaine ...
# n, name = 102, Simmons, Reid ...
# n, name = 103, Skarlatos, Dimitrios ...
# n, name = 104, Sleator, Daniel ...
# n, name = 105, Sriraman, Akshitha ...
# n, name = 106, Steenkiste, Peter ...
# n, name = 107, Stehlik, Mark ...
# n, name = 108, Sutner, Klaus ...
# n, name = 109, Taylor, Michael ...
# n, name = 110, Touretzky, David ...
# n, name = 111, Vinayak, Rashmi Korlakai ...
#
# Failed search_author()
# n, name = 112, Virtue, Patrick ...
# n, name = 113, Wang, Weina ...
# n, name = 114, Weinberg, Zack ...
# n, name = 115, Wing, Jeannette ...
#
# Failed search_author()
# n, name = 116, Woodruff, David ...
# n, name = 117, Xhakaj, Franceska ...
# n, name = 118, Zhang, Hui ...

# %% [raw]
# author

# %%
len(pub_data)
# Out:
# 97

# %% [markdown]
# ## write out xlsx

# %%
df_out = pd.DataFrame(pub_data, columns=SCHOLAR_HEADER)

# %%
df_out.head()
# Out:
#                   name                                        affiliation  \
# 0           Acar, Umut  Carnegie Mellon University, Department of Comp...
# 1        Akoglu, Leman    Associate Professor, Carnegie Mellon University
# 2    Aldrich, Jonathan  Professor of Computer Science, Carnegie Mellon...
# 3  Amvrosiadis, George    Carnegie Mellon University, Amazon Web Services
# 4      Andersen, David  Professor of Computer Science, Carnegie Mellon...
#
#                                            interests  num_papers  \
# 0                                                            144
# 1  AI/ML; Unsupervised Learning; Anomaly/Fraud/Ev...         188
# 2        Programming Languages; Software Engineering         282
# 3  Computer Systems; Operating Systems; Distribut...          46
# 4  Distributed systems; networks; operating syste...         221
#
#    num_coauthors  citedby  hindex  i10index  citedby5y  hindex5y  i10index5y  \
# 0             36     4104      34        74       1459        20          47
# 1             45    10997      49        87       8295        41          78
# 2             17     6254      38        93       1557        24          46
# 3             20      997      13        18        782        13          18
# 4             55    25327      70       133      11668        49          96
#
#      scholar_id                                         url_author  \
# 0  wJ4NywgAAAAJ  https://scholar.google.com/citations?user=wJ4N...
# 1  4ITkr_kAAAAJ  https://scholar.google.com/citations?user=4ITk...
# 2  AzHmOtcAAAAJ  https://scholar.google.com/citations?user=AzHm...
# 3  ygiY7C8AAAAJ  https://scholar.google.com/citations?user=ygiY...
# 4  wUArfPgAAAAJ  https://scholar.google.com/citations?user=wUAr...
#
#                                          url_picture  \
# 0  https://scholar.google.com/citations?view_op=m...
# 1  https://scholar.google.com/citations?view_op=m...
# 2  https://scholar.google.com/citations?view_op=m...
# 3  https://scholar.google.com/citations?view_op=m...
# 4  https://scholar.google.com/citations?view_op=m...
#
#                        url_homepage                                file_author
# 0         http://www.umut-acar.org/           data/GScholar_acar_umut_cmu.json
# 1  https://www.cs.cmu.edu/~lakoglu/        data/GScholar_akoglu_leman_cmu.json
# 2   http://www.cs.cmu.edu/~aldrich/    data/GScholar_aldrich_jonathan_cmu.json
# 3       http://www.amvrosiadis.com/  data/GScholar_amvrosiadis_george_cmu.json
# 4       http://www.cs.cmu.edu/~dga/      data/GScholar_andersen_david_cmu.json

# %%
# import xlsxwriter
file_xlsx = f"data/cs-faculty-gscholar-{org2}-{n}.xlsx"
writer = pd.ExcelWriter(Path(file_xlsx), engine='xlsxwriter')
df_out.to_excel(writer, sheet_name=org2, index=False)
writer.save()
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_5908\3066051369.py:5: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
