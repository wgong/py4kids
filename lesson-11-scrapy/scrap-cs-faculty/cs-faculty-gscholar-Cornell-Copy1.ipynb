# %% [markdown]
# This notebook uses `scholarly` API (https://github.com/scholarly-python-package/scholarly) to enrich CS faculty info

# %%
from scrap_cs_faculty import *

# %%
org_list = ["CMU-CS","Cornell-CS","MIT-AID","MIT-CS","Stanford-CS","UCB-CS","UIUC-CS",]
idx_org = org_list.index("Cornell-CS")
org = org_list[idx_org]
org2 = org.split("-")[0]

# %% [markdown]
# ## read CS faculty info scraped previously

# %%
file_xlsx = f"faculty-{org}.xlsx"
xlsxf = pd.ExcelFile(file_xlsx)

# %%
xlsxf.sheet_names
# Out:
# ['Faculty', 'Research Groups']

# %%
df = xlsxf.parse('Faculty')

# %%
df
# Out:
#                     name             job_title  \
# 0    Mohamed Abdelfattah   Assistant Professor
# 1        Jayadev Acharya   Assistant Professor
# 2         Rachit Agarwal  Associate Professor
# 3         David Albonesi             Professor
# 4         Lorenzo Alvisi             Professor
# ..                   ...                   ...
# 117     Christina Lee Yu   Assistant Professor
# 118           Haiyuan Yu             Professor
# 119          Ramin Zabih             Professor
# 120          Cheng Zhang   Assistant Professor
# 121          Zhiru Zhang   Assistant Professor
#
#                            phd_univ  phd_year  \
# 0                      Univ Toronto    2016.0
# 1         Univ California San Diego    2014.0
# 2    Univ Illinois Urbana-Champaign    2013.0
# 3                 Univ Mass Amherst    1996.0
# 4                      Cornell Univ    1996.0
# ..                              ...       ...
# 117                             MIT       NaN
# 118                            Yale    2005.0
# 119                   Stanford Univ    1994.0
# 120    Georgia Institute Technology    2018.0
# 121              Univ California LA    2007.0
#
#                                          research_area  \
# 0            Artificial Intelligence, Machine Learning
# 1         Artificial Intelligence, Theory of Computing
# 2          Systems and Networking, Theory of Computing
# 3    Computer Architecture & VLSI, Systems and Netw...
# 4                               Systems and Networking
# ..                                                 ...
# 117                                Theory of Computing
# 118                              Computational Biology
# 119                          Human Interaction, Vision
# 120                            Artificial Intelligence
# 121                             Systems and Networking
#
#                              research_concentration  \
# 0                           Artificial Intelligence
# 1    Artificial Intelligence, Theory of Computation
# 2                    Systems, Theory of Computation
# 3                                           Systems
# 4                                           Systems
# ..                                              ...
# 117                           Theory of Computation
# 118           Scientific Computing and Applications
# 119  Artificial Intelligence, Theory of Computation
# 120                                         Systems
# 121                                         Systems
#
#                                         research_focus  \
# 0                                                  NaN
# 1    Information theory, machine learning, and algo...
# 2    Distributed systems, systems for big data anal...
# 3    Adaptive and reconfigurable multi-core and pro...
# 4    Theory and practice of dependable distributed ...
# ..                                                 ...
# 117  Theory of Computing, Artificial Intelligence (...
# 118  Biomedical systems biology, machine learning, ...
# 119  Computer vision and its applications, especial...
# 120  Ubiquitous Computing, Wearable Computing, Huma...
# 121  Computer-aided design methodologies, optimizat...
#
#                                          url  \
# 0                   https://www.mohsaied.com
# 1    https://people.ece.cornell.edu/acharya/
# 2       http://www.cs.cornell.edu/~ragarwal/
# 3      http://www.csl.cornell.edu/~albonesi/
# 4         http://www.cs.cornell.edu/lorenzo/
# ..                                       ...
# 117  https://people.orie.cornell.edu/cleeyu/
# 118                    https://www.yulab.org
# 119           http://www.cs.cornell.edu/~rdz
# 120                   http://www.czhang.org/
# 121      http://www.csl.cornell.edu/~zhiruz/
#
#                                                img_url  phone  email  \
# 0    https://www.cs.cornell.edu/sites/default/files...    NaN    NaN
# 1    https://www.cs.cornell.edu/sites/default/files...    NaN    NaN
# 2    https://www.cs.cornell.edu/sites/default/files...    NaN    NaN
# 3    https://www.cs.cornell.edu/sites/default/files...    NaN    NaN
# 4    https://www.cs.cornell.edu/sites/default/files...    NaN    NaN
# ..                                                 ...    ...    ...
# 117  https://www.cs.cornell.edu/sites/default/files...    NaN    NaN
# 118  https://www.cs.cornell.edu/sites/default/files...    NaN    NaN
# 119  https://www.cs.cornell.edu/sites/default/files...    NaN    NaN
# 120  https://www.cs.cornell.edu/sites/default/files...    NaN    NaN
# 121  https://www.cs.cornell.edu/sites/default/files...    NaN    NaN
#
#      cell_phone  office_address  \
# 0           NaN             NaN
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
# ..          ...             ...
# 117         NaN             NaN
# 118         NaN             NaN
# 119         NaN             NaN
# 120         NaN             NaN
# 121         NaN             NaN
#
#                                             department  school
# 0    Electrical and Computer Engineering, Cornell T...     NaN
# 1    Electrical and Computer Engineering, CS Field ...     NaN
# 2                    Computer Science, CS Field Member     NaN
# 3    Electrical and Computer Engineering, CS Field ...     NaN
# 4    Computer Science, CS Field Member, Tisch Unive...     NaN
# ..                                                 ...     ...
# 117                              ORIE, CS Field Member     NaN
# 118  Biological Statistics & Computational Biology,...     NaN
# 119    Computer Science, Cornell Tech, CS Field Member     NaN
# 120               Information Science, CS Field Member     NaN
# 121  Electrical and Computer Engineering, CS Field ...     NaN
#
# [122 rows x 15 columns]

# %%
names = df["name"].to_list()

# %%
len(names), names
# Out:
# (122,
#  ['Mohamed Abdelfattah',
#   'Jayadev Acharya',
#   'Rachit Agarwal',
#   'David Albonesi',
#   'Lorenzo Alvisi',
#   'Yoav Artzi',
#   'Shiri Azenkot',
#   'Kavita Bala',
#   'Siddhartha  Banerjee',
#   'Christopher Batten',
#   'Tapomayukh Bhattacharjee',
#   'David Bindel',
#   'Ken Birman',
#   'Ronald Brachman',
#   'Anne Bracy',
#   'Florentina Bunea',
#   'Mark Campbell',
#   'Claire Cardie',
#   'Eshan Chattopadhyay',
#   'Sanjiban Choudhury',
#   'Tanzeem Choudhury',
#   'Michael Clarkson',
#   'Robert Constable',
#   'Anil Damle',
#   'Cristian Danescu-Niculescu-Mizil',
#   'Abe Davis',
#   'Christopher De Sa',
#   'Sarah Dean',
#   'Nicola Dell',
#   'Alan Demers',
#   'Shimon Edelman',
#   'Ahmed El Alaoui',
#   'Kevin Ellis',
#   'Deborah Estrin',
#   'K-Y. Daisy Fan',
#   'Silvia Ferrari',
#   'Nate Foster',
#   'Nikhil Garg',
#   'Ziv Goldfeld',
#   'Carla Gomes',
#   'Donald Greenberg',
#   'David Gries',
#   'Giulia Guidi',
#   'Francois Guimbretiere',
#   'Joseph Halpern',
#   'Bharath Hariharan',
#   'Haym Hirsh',
#   'Guy Hoffman',
#   'John Hopcroft',
#   'Justin Hsu',
#   'Thorsten Joachims',
#   'Wendy Ju',
#   'Ari Juels',
#   'Malte Jung',
#   'Nathan Kallus',
#   'Jon Kleinberg',
#   'Robert Kleinberg',
#   'Dexter Kozen',
#   'Hadas Kress-Gazit',
#   'Volodymyr Kuleshov',
#   'Daniel Lee',
#   'Lillian Lee',
#   'Owolabi Legunsen',
#   'Steve Marschner',
#   'Jose Martinez',
#   'David Matteson',
#   'David Mimno',
#   'Greg Morrisett',
#   'Curran Muhlberger',
#   'Andrew Myers',
#   'Mor Naaman',
#   'Rajalakshmi Nandakumar',
#   'Anil Nerode',
#   'Tapan Parikh',
#   'Francesca Parise',
#   'Rafael Pass',
#   'Kirstin Petersen',
#   'Emma Pierson',
#   'Martha E. Pollack',
#   'Tom Ristenpart',
#   'Thijs Roumen',
#   'Alexander "Sasha" Rush',
#   'Mert Sabuncu',
#   'Adrian Sampson',
#   'Katya Scheinberg',
#   'Fred Schneider',
#   'Bart Selman',
#   'Phoebe Sengers',
#   'Vitaly Shmatikov',
#   'David Shmoys',
#   'Alexandra Silva',
#   'Rachee Singh',
#   'Noah Snavely',
#   'Karthik Sridharan',
#   'Noah Stephens-Davidowitz',
#   'G. Edward Suh',
#   'Wen Sun',
#   'A. Kevin Tang',
#   'Eva Tardos',
#   'Angelique Taylor',
#   'Tim Teitelbaum',
#   'Alex  Townsend',
#   'Immanuel Trummer',
#   'Charles Van Loan',
#   'Robbert van Renesse',
#   'Marten van Schijndel',
#   'Anke van Zuylen',
#   'Aaron Wagner',
#   'Fei Wang',
#   'Hakim Weatherspoon',
#   'Kilian Weinberger',
#   'Walker White',
#   'Stephen Wicker',
#   'Mark Wilde',
#   'David Williamson',
#   'Qian Yang',
#   'Fengqi You',
#   'Christina Lee Yu',
#   'Haiyuan Yu',
#   'Ramin Zabih',
#   'Cheng Zhang',
#   'Zhiru Zhang'])

# %% [markdown]
# ## fetch google scholar data for all CS faculty

# %%
ntest = -1  #  2 #

# %%
pub_data = []
for n, name in enumerate(names[:ntest]):
#     if n < 5: continue 
    print(f"n, name = {n}, {name} ...")
    
    author_org = f"{name} {org2}"
    norm_auth_org = normalize_str(author_org)
    file_author = f"data/GScholar_{norm_auth_org}.json"

    try:
        search_query = scholarly.search_author(author_org)
        init_result = next(search_query)
    except Exception as ex:
        print(str(ex))
        init_result = None 
        
    if init_result is None:
        print(f"Failed search_author()")
        continue

    scholar_id = init_result.get("scholar_id", "")
    if not scholar_id:
        print(f"Missing scholar_id")
        continue        
    
    # fetch data
    author = scholarly.fill(init_result)
    
    author_dict = {}
    # fill data cell
    author_dict["name"] = name 
    author_dict["file_author"] = file_author 
    author_dict["scholar_id"] = scholar_id 
    author_dict["affiliation"] = author.get("affiliation", "")
    author_dict["interests"] = "; ".join(author.get("interests", []))
    author_dict["url_author"] = get_scholar_page(scholar_id)
    author_dict["url_picture"] = author.get("url_picture", "")
    author_dict["url_homepage"] = author.get("homepage", "")
    author_dict["citedby"] = author.get("citedby", 0)
    author_dict["citedby5y"] = author.get("citedby5y", 0)
    author_dict["hindex"] = author.get("hindex", 0)
    author_dict["hindex5y"] = author.get("hindex5y", 0)
    author_dict["i10index"] = author.get("i10index", 0)
    author_dict["i10index5y"] = author.get("i10index5y", 0)
    author_dict["num_papers"] = len(author.get("publications", []))
    author_dict["num_coauthors"] = len(author.get("coauthors", []))
      
    # fill row 
    author_data = []
    for c in SCHOLAR_HEADER:
        author_data.append(author_dict.get(c))
        
    # accumulate row
    pub_data.append(author_data)
    
    # persist author data
    with open(Path(file_author), "w", encoding="utf-8") as f:
        f.write(json.dumps(author))
    
    delay = randint(1,5)
    sleep(delay)
# Out:
# n, name = 0, Mohamed Abdelfattah ...
# n, name = 1, Jayadev Acharya ...
# n, name = 2, Rachit Agarwal ...
# n, name = 3, David Albonesi ...
#
# Failed search_author()
# n, name = 4, Lorenzo Alvisi ...
# n, name = 5, Yoav Artzi ...
# n, name = 6, Shiri Azenkot ...
# n, name = 7, Kavita Bala ...
# n, name = 8, Siddhartha  Banerjee ...
# n, name = 9, Christopher Batten ...
# n, name = 10, Tapomayukh Bhattacharjee ...
# n, name = 11, David Bindel ...
# n, name = 12, Ken Birman ...
# n, name = 13, Ronald Brachman ...
# n, name = 14, Anne Bracy ...
#
# Failed search_author()
# n, name = 15, Florentina Bunea ...
# n, name = 16, Mark Campbell ...
# n, name = 17, Claire Cardie ...
# n, name = 18, Eshan Chattopadhyay ...
# n, name = 19, Sanjiban Choudhury ...
# n, name = 20, Tanzeem Choudhury ...
# n, name = 21, Michael Clarkson ...
# n, name = 22, Robert Constable ...
#
# Failed search_author()
# n, name = 23, Anil Damle ...
# n, name = 24, Cristian Danescu-Niculescu-Mizil ...
# n, name = 25, Abe Davis ...
# n, name = 26, Christopher De Sa ...
# n, name = 27, Sarah Dean ...
# n, name = 28, Nicola Dell ...
# n, name = 29, Alan Demers ...
#
# Failed search_author()
# n, name = 30, Shimon Edelman ...
# n, name = 31, Ahmed El Alaoui ...
# n, name = 32, Kevin Ellis ...
# n, name = 33, Deborah Estrin ...
# n, name = 34, K-Y. Daisy Fan ...
#
# Failed search_author()
# n, name = 35, Silvia Ferrari ...
# n, name = 36, Nate Foster ...
# n, name = 37, Nikhil Garg ...
# n, name = 38, Ziv Goldfeld ...
# n, name = 39, Carla Gomes ...
#
# Failed search_author()
# n, name = 40, Donald Greenberg ...
#
# Failed search_author()
# n, name = 41, David Gries ...
# n, name = 42, Giulia Guidi ...
# n, name = 43, Francois Guimbretiere ...
# n, name = 44, Joseph Halpern ...
# n, name = 45, Bharath Hariharan ...
# n, name = 46, Haym Hirsh ...
# n, name = 47, Guy Hoffman ...
# n, name = 48, John Hopcroft ...
# n, name = 49, Justin Hsu ...
# n, name = 50, Thorsten Joachims ...
# n, name = 51, Wendy Ju ...
# n, name = 52, Ari Juels ...
# n, name = 53, Malte Jung ...
# n, name = 54, Nathan Kallus ...
# n, name = 55, Jon Kleinberg ...
# n, name = 56, Robert Kleinberg ...
# n, name = 57, Dexter Kozen ...
# n, name = 58, Hadas Kress-Gazit ...
# n, name = 59, Volodymyr Kuleshov ...
# n, name = 60, Daniel Lee ...
# n, name = 61, Lillian Lee ...
# n, name = 62, Owolabi Legunsen ...
# n, name = 63, Steve Marschner ...
# n, name = 64, Jose Martinez ...
# n, name = 65, David Matteson ...
# n, name = 66, David Mimno ...
# n, name = 67, Greg Morrisett ...
# n, name = 68, Curran Muhlberger ...
#
# Failed search_author()
# n, name = 69, Andrew Myers ...
# n, name = 70, Mor Naaman ...
# n, name = 71, Rajalakshmi Nandakumar ...
# n, name = 72, Anil Nerode ...
# n, name = 73, Tapan Parikh ...
# n, name = 74, Francesca Parise ...
# n, name = 75, Rafael Pass ...
# n, name = 76, Kirstin Petersen ...
# n, name = 77, Emma Pierson ...
# n, name = 78, Martha E. Pollack ...
#
# Failed search_author()
# n, name = 79, Tom Ristenpart ...
# n, name = 80, Thijs Roumen ...
# n, name = 81, Alexander "Sasha" Rush ...
#
# Failed search_author()
# n, name = 82, Mert Sabuncu ...
# n, name = 83, Adrian Sampson ...
# n, name = 84, Katya Scheinberg ...
# n, name = 85, Fred Schneider ...
# n, name = 86, Bart Selman ...
# n, name = 87, Phoebe Sengers ...
# n, name = 88, Vitaly Shmatikov ...
# n, name = 89, David Shmoys ...
# n, name = 90, Alexandra Silva ...
# n, name = 91, Rachee Singh ...
# n, name = 92, Noah Snavely ...
# n, name = 93, Karthik Sridharan ...
# n, name = 94, Noah Stephens-Davidowitz ...
# n, name = 95, G. Edward Suh ...
#
# Failed search_author()
# n, name = 96, Wen Sun ...
# n, name = 97, A. Kevin Tang ...
#
# Failed search_author()
# n, name = 98, Eva Tardos ...
# n, name = 99, Angelique Taylor ...
# n, name = 100, Tim Teitelbaum ...
#
# Failed search_author()
# n, name = 101, Alex  Townsend ...
# n, name = 102, Immanuel Trummer ...
# n, name = 103, Charles Van Loan ...
# n, name = 104, Robbert van Renesse ...
# n, name = 105, Marten van Schijndel ...
# n, name = 106, Anke van Zuylen ...
# n, name = 107, Aaron Wagner ...
# n, name = 108, Fei Wang ...
# n, name = 109, Hakim Weatherspoon ...
# n, name = 110, Kilian Weinberger ...
# n, name = 111, Walker White ...
#
# Failed search_author()
# n, name = 112, Stephen Wicker ...
# n, name = 113, Mark Wilde ...
# n, name = 114, David Williamson ...
# n, name = 115, Qian Yang ...
# n, name = 116, Fengqi You ...
# n, name = 117, Christina Lee Yu ...
# n, name = 118, Haiyuan Yu ...
# n, name = 119, Ramin Zabih ...
# n, name = 120, Cheng Zhang ...

# %% [raw]
# author

# %%
len(pub_data)
# Out:
# 107

# %% [markdown]
# ## write out xlsx

# %%
df_out = pd.DataFrame(pub_data, columns=SCHOLAR_HEADER)

# %%
df_out.head()
# Out:
#                   name                                        affiliation  \
# 0  Mohamed Abdelfattah                                 Cornell University
# 1      Jayadev Acharya            Assistant Professor, Cornell University
# 2       Rachit Agarwal                                 Cornell University
# 3       Lorenzo Alvisi  Tisch University Professor of Computer Science...
# 4           Yoav Artzi                          Cornell University; ASAPP
#
#                                            interests  num_papers  \
# 0  Machine Learning; FPGAs; Reconfigurable Computing          57
# 1  Learning theory; information theory; statistic...          89
# 2           Systems; Networking; Distributed systems          48
# 3                              Distributed Computing         199
# 4      Natural Language Processing; Machine Learning          71
#
#    num_coauthors  citedby  hindex  i10index  citedby5y  hindex5y  i10index5y  \
# 0             28     1220      17        22        999        15          18
# 1             44     2684      28        52       2044        26          46
# 2             57     2861      26        34       2144        20          25
# 3             13    15019      56        96       4021        29          51
# 4             80     8456      33        46       7505        31          44
#
#      scholar_id                                         url_author  \
# 0  q4wBpWAAAAAJ  https://scholar.google.com/citations?user=q4wB...
# 1  70vJVxcAAAAJ  https://scholar.google.com/citations?user=70vJ...
# 2  71IXR1QAAAAJ  https://scholar.google.com/citations?user=71IX...
# 3  TIGS4c8AAAAJ  https://scholar.google.com/citations?user=TIGS...
# 4  XuQW7ogAAAAJ  https://scholar.google.com/citations?user=XuQW...
#
#                                          url_picture  \
# 0  https://scholar.google.com/citations?view_op=m...
# 1  https://scholar.google.com/citations?view_op=m...
# 2  https://scholar.google.com/citations?view_op=m...
# 3  https://scholar.google.com/citations?view_op=m...
# 4  https://scholar.google.com/citations?view_op=m...
#
#                               url_homepage  \
# 0                     http://mohsaied.com/
# 1  https://people.ece.cornell.edu/acharya/
# 2     http://www.cs.cornell.edu/~ragarwal/
# 3       http://www.cs.cornell.edu/lorenzo/
# 4                    http://yoavartzi.com/
#
#                                       file_author
# 0  data/GScholar_mohamed_abdelfattah_cornell.json
# 1      data/GScholar_jayadev_acharya_cornell.json
# 2       data/GScholar_rachit_agarwal_cornell.json
# 3       data/GScholar_lorenzo_alvisi_cornell.json
# 4           data/GScholar_yoav_artzi_cornell.json

# %%
# import xlsxwriter
file_xlsx = f"data/cs-faculty-gscholar-{org2}-{n}.xlsx"
writer = pd.ExcelWriter(Path(file_xlsx), engine='xlsxwriter')
df_out.to_excel(writer, sheet_name=org2, index=False)
writer.save()
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_9856\3066051369.py:5: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
file_xlsx
# Out:
# 'data/cs-faculty-gscholar-Cornell-120.xlsx'
