# %% [markdown]
# This notebook uses `scholarly` API (https://github.com/scholarly-python-package/scholarly) to enrich CS faculty info

# %%
from scrap_cs_faculty import *

# %%
org_list = ["CMU-CS","Cornell-CS","MIT-AID","MIT-CS","Stanford-CS","UCB-CS","UIUC-CS",]
idx_org = org_list.index("MIT-AID")
org = org_list[idx_org]
org2 = org.split("-")[0]

# %% [markdown]
# ## read CS faculty info scraped previously

# %%
file_xlsx = f"faculty-{org}.xlsx"
xlsxf = pd.ExcelFile(file_xlsx)

# %%
xlsxf.sheet_names
# Out:
# ['Faculty', 'Research Groups']

# %%
df = xlsxf.parse('Faculty')

# %%
df
# Out:
#                    name                                          job_title  \
# 0           Hal Abelson                           Class of 1992 Professor
# 1   Elfar Adalsteinsson  Education Officer for Electrical Engineering, ...
# 2        Pulkit Agrawal  Steven and Renee Finn Career Development Profe...
# 3     Mohammad Alizadeh                                Associate Professor
# 4         Jacob Andreas  X-Window Consortium Professor, Assistant Profe...
# ..                  ...                                                ...
# 87         Ashia Wilson  Lister Brothers (Gordon K. ’30 and Donald K. ’...
# 88      Gregory Wornell  Sumitomo Electric Industries Professor in Engi...
# 89  Guangyu Robert Yang    Assistant Professor / Shared appointment in BCS
# 90        Lizhong Zheng                                    Professor of EE
# 91           Victor Zue  Delta Electronics Professor of EECS (Post-Tenure)
#
#     phd_univ  phd_year                                      research_area  \
# 0        NaN       NaN  AI and Society, Artificial Intelligence + Deci...
# 1        NaN       NaN  AI for Healthcare and Life Sciences, Biologica...
# 2        NaN       NaN  Artificial Intelligence + Machine Learning, Gr...
# 3        NaN       NaN  Multicore Processors & Cloud Computing, Securi...
# 4        NaN       NaN  Artificial Intelligence + Machine Learning, Na...
# ..       ...       ...                                                ...
# 87       NaN       NaN  AI and Society, Artificial Intelligence + Mach...
# 88       NaN       NaN  Artificial Intelligence + Machine Learning, Co...
# 89       NaN       NaN          Artificial Intelligence + Decision making
# 90       NaN       NaN  Communications Systems, Information Science an...
# 91       NaN       NaN  Educational Technology, Human-Computer Interac...
#
#     research_concentration  research_focus  \
# 0                      NaN             NaN
# 1                      NaN             NaN
# 2                      NaN             NaN
# 3                      NaN             NaN
# 4                      NaN             NaN
# ..                     ...             ...
# 87                     NaN             NaN
# 88                     NaN             NaN
# 89                     NaN             NaN
# 90                     NaN             NaN
# 91                     NaN             NaN
#
#                                                   url  \
# 0        https://www.eecs.mit.edu/people/hal-abelson/
# 1   https://www.eecs.mit.edu/people/elfar-adalstei...
# 2     https://www.eecs.mit.edu/people/pulkit-agrawal/
# 3   https://www.eecs.mit.edu/people/mohammad-aliza...
# 4      https://www.eecs.mit.edu/people/jacob-andreas/
# ..                                                ...
# 87      https://www.eecs.mit.edu/people/ashia-wilson/
# 88   https://www.eecs.mit.edu/people/gregory-wornell/
# 89  https://www.eecs.mit.edu/people/guangyu-robert...
# 90     https://www.eecs.mit.edu/people/lizhong-zheng/
# 91        https://www.eecs.mit.edu/people/victor-zue/
#
#                                               img_url           phone  \
# 0   https://www.eecs.mit.edu/wp-content/uploads/20...  (617) 253-5856
# 1   https://www.eecs.mit.edu/people/elfar-adalstei...  (617) 324-3597
# 2     https://www.eecs.mit.edu/people/pulkit-agrawal/  (617) 253-5851
# 3   https://www.eecs.mit.edu/people/mohammad-aliza...  (617) 253-6042
# 4      https://www.eecs.mit.edu/people/jacob-andreas/    617-253-0352
# ..                                                ...             ...
# 87  https://www.eecs.mit.edu/wp-content/uploads/20...             NaN
# 88   https://www.eecs.mit.edu/people/gregory-wornell/  (617) 253-3513
# 89  https://www.eecs.mit.edu/wp-content/uploads/20...  (475) 201-7714
# 90     https://www.eecs.mit.edu/people/lizhong-zheng/  (617) 452-2941
# 91        https://www.eecs.mit.edu/people/victor-zue/  (617) 253-8513
#
#                 email  cell_phone   office_address  \
# 0         hal@mit.edu         NaN  Office: 32-G516
# 1       elfar@mit.edu         NaN   Office: 36-766
# 2    pulkitag@mit.edu         NaN   Office: 32-342
# 3    alizadeh@mit.edu         NaN  Office: 32-G920
# 4         jda@mit.edu         NaN  Office: 32-386H
# ..                ...         ...              ...
# 87    ashia07@mit.edu         NaN  Office: 32-D660
# 88        gww@mit.edu         NaN   Office: 36-677
# 89     yanggr@mit.edu         NaN       Office: 46
# 90    lizhong@mit.edu         NaN   Office: 36-660
# 91  zue@csail.mit.edu         NaN  Office: 32-G470
#
#                                       department  \
# 0         Computer Science; AI & Decision-making
# 1   Electrical Engineering; AI & Decision-making
# 2         AI & Decision-making; Computer Science
# 3                             Computer Science;
# 4                           AI & Decision-making
# ..                                           ...
# 87                          AI & Decision-making
# 88                          AI & Decision-making
# 89                          AI & Decision-making
# 90  AI & Decision-making; Electrical Engineering
# 91        AI & Decision-making; Computer Science
#
#                                 school
# 0   Massachusetts Institute Technology
# 1   Massachusetts Institute Technology
# 2   Massachusetts Institute Technology
# 3   Massachusetts Institute Technology
# 4   Massachusetts Institute Technology
# ..                                 ...
# 87  Massachusetts Institute Technology
# 88  Massachusetts Institute Technology
# 89  Massachusetts Institute Technology
# 90  Massachusetts Institute Technology
# 91  Massachusetts Institute Technology
#
# [92 rows x 15 columns]

# %%
names = df["name"].to_list()

# %%
len(names), names
# Out:
# (92,
#  ['Hal Abelson',
#   'Elfar Adalsteinsson',
#   'Pulkit Agrawal',
#   'Mohammad Alizadeh',
#   'Jacob Andreas',
#   'Hari Balakrishnan',
#   'Regina Barzilay',
#   'Robert Berwick',
#   'Sangeeta Bhatia',
#   'Duane Boning',
#   'Guy Bresler',
#   'Tamara Broderick',
#   'Michael Carbin',
#   'Vincent Chan',
#   'YuFeng (Kevin)  Chen',
#   'Isaac Chuang',
#   'Connor Wilson Coley',
#   'Munther Dahleh',
#   'Luca Daniel',
#   'Constantinos Daskalakis',
#   'Randall Davis',
#   'Frederic Durand',
#   'Dirk Englund',
#   'Dennis Freeman',
#   'William Freeman',
#   'Marzyeh Ghassemi',
#   'David Gifford',
#   'Polina Golland',
#   'W. Eric L Grimson',
#   'Dylan Hadfield-Menell',
#   'Thomas Heldt',
#   'Sam Hopkins',
#   'Berthold Horn',
#   'Daniel Huttenlocher',
#   'Piotr Indyk',
#   'Phillip Isola',
#   'Tommi Jaakkola',
#   'Patrick Jaillet',
#   'Stefanie Jegelka',
#   'Leslie Kaelbling',
#   'Dina Katabi',
#   'Manolis Kellis',
#   'Yoon Kim',
#   'Mina Konakovic Lukovic',
#   'Jing Kong',
#   'Tim Kraska',
#   'Jae Lim',
#   'Tomás Lozano-Pérez',
#   'Samuel Madden',
#   'Aleksander Mądry',
#   'Wojciech Matusik',
#   'Muriel Médard',
#   'Alexandre Megretski',
#   'Sanjoy Mitter',
#   'William D. Oliver',
#   'Alan Oppenheim',
#   'Asu Ozdaglar',
#   'Pablo Parrilo',
#   'Yury Polyanskiy',
#   'Jonathan Ragan-Kelley',
#   'Rajeev Ram',
#   'Martin Rinard',
#   'Ronitt Rubinfeld',
#   'Daniela Rus',
#   'Nidhi Seethapathi',
#   'Devavrat Shah',
#   'Jeffrey Shapiro',
#   'Armando Solar-Lezama',
#   'Justin Solomon',
#   'David Sontag',
#   'Suvrit Sra',
#   'Collin Stultz',
#   'Gerald Sussman',
#   'Vivienne Sze',
#   'Peter Szolovits',
#   'Christopher Tanner',
#   'Russell Tedrake',
#   'Bruce Tidor',
#   'Antonio Torralba',
#   'John Tsitsiklis',
#   'Caroline Uhler',
#   'Vinod Vaikuntanathan',
#   'George Verghese',
#   'Jacob White',
#   'Ryan Williams',
#   'Virginia Vassilevska Williams',
#   'Alan Willsky',
#   'Ashia Wilson',
#   'Gregory Wornell',
#   'Guangyu Robert Yang',
#   'Lizhong Zheng',
#   'Victor Zue'])

# %% [markdown]
# ## fetch google scholar data for all CS faculty

# %%
ntest = -1  #  2 #

# %%
pub_data = []
for n, name in enumerate(names[:ntest]):
#     if n < 5: continue 
    print(f"n, name = {n}, {name} ...")
    
    author_org = f"{name} {org2}"
    norm_auth_org = normalize_str(author_org)
    file_author = f"data/GScholar_{norm_auth_org}.json"

    try:
        search_query = scholarly.search_author(author_org)
        init_result = next(search_query)
    except Exception as ex:
        print(str(ex))
        init_result = None 
        
    if init_result is None:
        print(f"Failed search_author()")
        continue

    scholar_id = init_result.get("scholar_id", "")
    if not scholar_id:
        print(f"Missing scholar_id")
        continue        
    
    # fetch data
    author = scholarly.fill(init_result)
    
    author_dict = {}
    # fill data cell
    author_dict["name"] = name 
    author_dict["file_author"] = file_author 
    author_dict["scholar_id"] = scholar_id 
    author_dict["affiliation"] = author.get("affiliation", "")
    author_dict["interests"] = "; ".join(author.get("interests", []))
    author_dict["url_author"] = get_scholar_page(scholar_id)
    author_dict["url_picture"] = author.get("url_picture", "")
    author_dict["url_homepage"] = author.get("homepage", "")
    author_dict["citedby"] = author.get("citedby", 0)
    author_dict["citedby5y"] = author.get("citedby5y", 0)
    author_dict["hindex"] = author.get("hindex", 0)
    author_dict["hindex5y"] = author.get("hindex5y", 0)
    author_dict["i10index"] = author.get("i10index", 0)
    author_dict["i10index5y"] = author.get("i10index5y", 0)
    author_dict["num_papers"] = len(author.get("publications", []))
    author_dict["num_coauthors"] = len(author.get("coauthors", []))
      
    # fill row 
    author_data = []
    for c in SCHOLAR_HEADER:
        author_data.append(author_dict.get(c))
        
    # accumulate row
    pub_data.append(author_data)
    
    # persist author data
    with open(Path(file_author), "w", encoding="utf-8") as f:
        f.write(json.dumps(author))
    
    delay = randint(1,5)
    sleep(delay)
# Out:
# n, name = 0, Hal Abelson ...
#
# Failed search_author()
# n, name = 1, Elfar Adalsteinsson ...
#
# Failed search_author()
# n, name = 2, Pulkit Agrawal ...
# n, name = 3, Mohammad Alizadeh ...
# n, name = 4, Jacob Andreas ...
# n, name = 5, Hari Balakrishnan ...
# n, name = 6, Regina Barzilay ...
#
# Failed search_author()
# n, name = 7, Robert Berwick ...
# n, name = 8, Sangeeta Bhatia ...
# n, name = 9, Duane Boning ...
# n, name = 10, Guy Bresler ...
# n, name = 11, Tamara Broderick ...
# n, name = 12, Michael Carbin ...
# n, name = 13, Vincent Chan ...
# n, name = 14, YuFeng (Kevin)  Chen ...
#
# Failed search_author()
# n, name = 15, Isaac Chuang ...
#
# Failed search_author()
# n, name = 16, Connor Wilson Coley ...
#
# Failed search_author()
# n, name = 17, Munther Dahleh ...
# n, name = 18, Luca Daniel ...
#
# Failed search_author()
# n, name = 19, Constantinos Daskalakis ...
# n, name = 20, Randall Davis ...
# n, name = 21, Frederic Durand ...
#
# Failed search_author()
# n, name = 22, Dirk Englund ...
# n, name = 23, Dennis Freeman ...
#
# Failed search_author()
# n, name = 24, William Freeman ...
# n, name = 25, Marzyeh Ghassemi ...
# n, name = 26, David Gifford ...
#
# Failed search_author()
# n, name = 27, Polina Golland ...
# n, name = 28, W. Eric L Grimson ...
#
# Failed search_author()
# n, name = 29, Dylan Hadfield-Menell ...
# n, name = 30, Thomas Heldt ...
# n, name = 31, Sam Hopkins ...
# n, name = 32, Berthold Horn ...
# n, name = 33, Daniel Huttenlocher ...
# n, name = 34, Piotr Indyk ...
# n, name = 35, Phillip Isola ...
# n, name = 36, Tommi Jaakkola ...
# n, name = 37, Patrick Jaillet ...
# n, name = 38, Stefanie Jegelka ...
# n, name = 39, Leslie Kaelbling ...
# n, name = 40, Dina Katabi ...
# n, name = 41, Manolis Kellis ...
# n, name = 42, Yoon Kim ...
# n, name = 43, Mina Konakovic Lukovic ...
# n, name = 44, Jing Kong ...
# n, name = 45, Tim Kraska ...
# n, name = 46, Jae Lim ...
# n, name = 47, Tomás Lozano-Pérez ...
#
# Failed search_author()
# n, name = 48, Samuel Madden ...
# n, name = 49, Aleksander Mądry ...
# n, name = 50, Wojciech Matusik ...
# n, name = 51, Muriel Médard ...
# n, name = 52, Alexandre Megretski ...
# n, name = 53, Sanjoy Mitter ...
# n, name = 54, William D. Oliver ...
# n, name = 55, Alan Oppenheim ...
#
# Failed search_author()
# n, name = 56, Asu Ozdaglar ...
#
# Failed search_author()
# n, name = 57, Pablo Parrilo ...
# n, name = 58, Yury Polyanskiy ...
#
# Failed search_author()
# n, name = 59, Jonathan Ragan-Kelley ...
# n, name = 60, Rajeev Ram ...
# n, name = 61, Martin Rinard ...
# n, name = 62, Ronitt Rubinfeld ...
# n, name = 63, Daniela Rus ...
# n, name = 64, Nidhi Seethapathi ...
# n, name = 65, Devavrat Shah ...
# n, name = 66, Jeffrey Shapiro ...
#
# Failed search_author()
# n, name = 67, Armando Solar-Lezama ...
# n, name = 68, Justin Solomon ...
# n, name = 69, David Sontag ...
# n, name = 70, Suvrit Sra ...
# n, name = 71, Collin Stultz ...
#
# Failed search_author()
# n, name = 72, Gerald Sussman ...
#
# Failed search_author()
# n, name = 73, Vivienne Sze ...
# n, name = 74, Peter Szolovits ...
# n, name = 75, Christopher Tanner ...
#
# Failed search_author()
# n, name = 76, Russell Tedrake ...
# n, name = 77, Bruce Tidor ...
# n, name = 78, Antonio Torralba ...
# n, name = 79, John Tsitsiklis ...
# n, name = 80, Caroline Uhler ...
# n, name = 81, Vinod Vaikuntanathan ...
# n, name = 82, George Verghese ...
# n, name = 83, Jacob White ...
#
# Failed search_author()
# n, name = 84, Ryan Williams ...
# n, name = 85, Virginia Vassilevska Williams ...
# n, name = 86, Alan Willsky ...
# n, name = 87, Ashia Wilson ...
# n, name = 88, Gregory Wornell ...
# n, name = 89, Guangyu Robert Yang ...
# n, name = 90, Lizhong Zheng ...
#
# Failed search_author()

# %% [raw]
# author

# %%
len(pub_data)
# Out:
# 70

# %% [markdown]
# ## write out xlsx

# %%
df_out = pd.DataFrame(pub_data, columns=SCHOLAR_HEADER)

# %%
df_out.head()
# Out:
#                 name                                       affiliation  \
# 0     Pulkit Agrawal             Massachusetts Institute of Technology
# 1  Mohammad Alizadeh      Associate Professor of Computer Science, MIT
# 2      Jacob Andreas                                               MIT
# 3  Hari Balakrishnan                                               MIT
# 4     Robert Berwick  Professor, Massachusetts Institute of Technology
#
#                                            interests  num_papers  \
# 0  Robotics; Computer Vision; Artificial Intellig...          97
# 1       Computer networks; Systems; Machine learning         164
# 2                                            NLP; ML         106
# 3  Networked computer systems; wireless networks;...         451
# 4       computational linguistics; cognitive science         283
#
#    num_coauthors  citedby  hindex  i10index  citedby5y  hindex5y  i10index5y  \
# 0             39     8748      30        44       7923        30          43
# 1            180    16853      59       103      13727        54         100
# 2             75     7672      39        62       6847        36          58
# 3             34   145090     128       247      29652        62         170
# 4              0    13935      51       103       4423        28          56
#
#      scholar_id                                         url_author  \
# 0  UpZmJI0AAAAJ  https://scholar.google.com/citations?user=UpZm...
# 1  6_cxCKQAAAAJ  https://scholar.google.com/citations?user=6_cx...
# 2  dnZ8udEAAAAJ  https://scholar.google.com/citations?user=dnZ8...
# 3  Qf4bw4UAAAAJ  https://scholar.google.com/citations?user=Qf4b...
# 4  7xH1C7IAAAAJ  https://scholar.google.com/citations?user=7xH1...
#
#                                          url_picture  \
# 0  https://scholar.google.com/citations?view_op=m...
# 1  https://scholar.google.com/citations?view_op=m...
# 2  https://scholar.google.com/citations?view_op=m...
# 3  https://scholar.google.com/citations?view_op=m...
# 4  https://scholar.google.com/citations?view_op=m...
#
#                              url_homepage  \
# 0  https://people.csail.mit.edu/pulkitag/
# 1    http://people.csail.mit.edu/alizadeh
# 2              http://web.mit.edu/jda/www
# 3          http://nms.csail.mit.edu/~hari
# 4
#
#                                 file_author
# 0     data/GScholar_pulkit_agrawal_mit.json
# 1  data/GScholar_mohammad_alizadeh_mit.json
# 2      data/GScholar_jacob_andreas_mit.json
# 3  data/GScholar_hari_balakrishnan_mit.json
# 4     data/GScholar_robert_berwick_mit.json

# %%
# import xlsxwriter
file_xlsx = f"data/cs-faculty-gscholar-{org2}-{n}.xlsx"
writer = pd.ExcelWriter(Path(file_xlsx), engine='xlsxwriter')
df_out.to_excel(writer, sheet_name=org2, index=False)
writer.save()
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_5324\3066051369.py:5: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
