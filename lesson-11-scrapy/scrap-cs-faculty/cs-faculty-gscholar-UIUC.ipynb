# %% [markdown]
# This notebook uses `scholarly` API (https://github.com/scholarly-python-package/scholarly) to enrich CS faculty info

# %%
from scrap_cs_faculty import *

# %%
org_list = ["CMU-CS","Cornell-CS","MIT-AID","MIT-CS","Stanford-CS","UCB-CS","UIUC-CS",]
idx_org = org_list.index("UIUC-CS")
org = org_list[idx_org]
org2 = org.split("-")[0]

# %% [markdown]
# ## read CS faculty info scraped previously

# %%
file_xlsx = f"faculty-{org}.xlsx"
xlsxf = pd.ExcelFile(file_xlsx)

# %%
xlsxf.sheet_names
# Out:
# ['Faculty']

# %%
df = xlsxf.parse('Faculty')

# %%
df
# Out:
#                   name                                          job_title  \
# 0    Tarek  Abdelzaher  Sohaib and Sara Abbasi Professor and Willett F...
# 1       Sarita V. Adve                         Richard T. Cheng Professor
# 2          Vikram Adve    Donald B. Gillies Professor in Computer Science
# 3          Gul A. Agha          Research Professor and Professor Emeritus
# 4        Ram Alagappan                                Assistant Professor
# ..                 ...                                                ...
# 116       Wenzhen Yuan             Assistant Professor starting Fall 2023
# 117    ChengXiang Zhai     Donald Biggar Willett Professor in Engineering
# 118    Lingming  Zhang                                Associate Professor
# 119           Han Zhao                                Assistant Professor
# 120       Craig Zilles              Professor and Severns Faculty Scholar
#
#      phd_univ  phd_year  research_area  research_concentration  \
# 0         NaN       NaN            NaN                     NaN
# 1         NaN       NaN            NaN                     NaN
# 2         NaN       NaN            NaN                     NaN
# 3         NaN       NaN            NaN                     NaN
# 4         NaN       NaN            NaN                     NaN
# ..        ...       ...            ...                     ...
# 116       NaN       NaN            NaN                     NaN
# 117       NaN       NaN            NaN                     NaN
# 118       NaN       NaN            NaN                     NaN
# 119       NaN       NaN            NaN                     NaN
# 120       NaN       NaN            NaN                     NaN
#
#      research_focus                                                url  \
# 0               NaN  https://cs.illinois.edu/about/people/departmen...
# 1               NaN  https://cs.illinois.edu/about/people/departmen...
# 2               NaN  https://cs.illinois.edu/about/people/departmen...
# 3               NaN  https://cs.illinois.edu/about/people/departmen...
# 4               NaN  https://cs.illinois.edu/about/people/departmen...
# ..              ...                                                ...
# 116             NaN  https://cs.illinois.edu/about/people/departmen...
# 117             NaN  https://cs.illinois.edu/about/people/departmen...
# 118             NaN  https://cs.illinois.edu/about/people/departmen...
# 119             NaN  https://cs.illinois.edu/about/people/departmen...
# 120             NaN  https://cs.illinois.edu/about/people/departmen...
#
#                                                img_url           phone  \
# 0    https://ws.engr.illinois.edu/directory/viewpho...  (217) 265-6793
# 1    https://ws.engr.illinois.edu/directory/viewpho...  (217) 333-8461
# 2    https://ws.engr.illinois.edu/directory/viewpho...  (217) 244-2016
# 3    https://ws.engr.illinois.edu/directory/viewpho...  (217) 244-3087
# 4    https://ws.engr.illinois.edu/directory/viewpho...             NaN
# ..                                                 ...             ...
# 116  https://ws.engr.illinois.edu/directory/viewpho...             NaN
# 117  https://ws.engr.illinois.edu/directory/viewpho...  (217) 244-4943
# 118  https://ws.engr.illinois.edu/directory/viewpho...  (217) 244-8921
# 119  https://ws.engr.illinois.edu/directory/viewpho...             NaN
# 120  https://ws.engr.illinois.edu/directory/viewpho...  (217) 244-0553
#
#                      email  cell_phone  office_address        department  \
# 0       zaher@illinois.edu         NaN             NaN  Computer Science
# 1       sadve@illinois.edu         NaN             NaN  Computer Science
# 2       vadve@illinois.edu         NaN             NaN  Computer Science
# 3        agha@illinois.edu         NaN             NaN  Computer Science
# 4        ramn@illinois.edu         NaN             NaN  Computer Science
# ..                     ...         ...             ...               ...
# 116    yuanwz@illinois.edu         NaN             NaN  Computer Science
# 117     czhai@illinois.edu         NaN             NaN  Computer Science
# 118  lingming@illinois.edu         NaN             NaN  Computer Science
# 119   hanzhao@illinois.edu         NaN             NaN  Computer Science
# 120    zilles@illinois.edu         NaN             NaN  Computer Science
#
#                              school
# 0    Univ Illinois Urbana-Champaign
# 1    Univ Illinois Urbana-Champaign
# 2    Univ Illinois Urbana-Champaign
# 3    Univ Illinois Urbana-Champaign
# 4    Univ Illinois Urbana-Champaign
# ..                              ...
# 116  Univ Illinois Urbana-Champaign
# 117  Univ Illinois Urbana-Champaign
# 118  Univ Illinois Urbana-Champaign
# 119  Univ Illinois Urbana-Champaign
# 120  Univ Illinois Urbana-Champaign
#
# [121 rows x 15 columns]

# %%
names = df["name"].to_list()

# %%
len(names), names
# Out:
# (121,
#  ['Tarek  Abdelzaher',
#   'Sarita V. Adve',
#   'Vikram Adve',
#   'Gul A. Agha',
#   'Ram Alagappan',
#   'Abdussalam Alawini',
#   'Nancy M. Amato',
#   'Lawrence Angrave',
#   'Brian P. Bailey',
#   'Arindam  Banerjee',
#   'Adam Bates',
#   'Mattox Alan Beckman',
#   'Matthew Caesar',
#   'George  Chacko',
#   'Geoffrey Werner Challen',
#   'Timothy Moon-Yew Chan',
#   'Eshwar  Chandrasekharan',
#   'Kevin Chenchuan Chang',
#   'Chandra Sekhar Chekuri',
#   'Girish  Chowdhary',
#   'Camille Cobb',
#   'Benjamin Cosman',
#   'Katie Cunningham',
#   'Ryan Matthew Cunningham',
#   'Neal E. Davis',
#   'Payam  Delgosha',
#   'Mohammed  El-Kebir',
#   'Jeff Erickson',
#   'Carl Evans',
#   'Wade A. Fagen-Ulmschneider',
#   'Paul  Fischer',
#   'Margaret M. Fleck',
#   'Christopher Wardlaw Fletcher',
#   'Michael A. Forbes',
#   'David Forsyth',
#   'Aishwarya Ganesan',
#   'Yael  Gertner',
#   'Saugata  Ghose',
#   'Brighten Godfrey',
#   'William D. Gropp',
#   'Liangyan  Gui',
#   'Carl  Gunter',
#   'Elsa  Gunter',
#   'Indranil  Gupta',
#   'Jiawei  Han',
#   'Sariel  Har-Peled',
#   'John C. Hart',
#   'Kris K. Hauser',
#   'David Heath',
#   'Geoffrey Lindsay Herman',
#   'Julia Hockenmaier',
#   'Derek W. Hoiem',
#   'Reyhaneh  Jabbarvand',
#   'Sheldon Howard Jacobson',
#   'Heng  Ji',
#   'Nan  Jiang',
#   'Laxmikant V. Kale',
#   'Daniel  Kang',
#   'Karrie Karahalios',
#   'Dakshita  Khurana',
#   'Andreas Paul Eberhard Kloeckner',
#   'Bill Kramer',
#   'Robin Hillary Kravets',
#   'Ranjitha  Kumar',
#   'Steven M. LaValle',
#   'Svetlana  Lazebnik',
#   'Colleen M. Lewis',
#   'Bo  Li',
#   'Yunzhu Li',
#   'Hongye  Liu',
#   'Darko  Marinov',
#   'Ruta  Mehta',
#   'Charith Mendis',
#   'Jose  Meseguer',
#   'Sasa  Misailovic',
#   'Marco Morales Aguirre',
#   'Klara  Nahrstedt',
#   'Michael Nowak',
#   'Luke  Olson',
#   'Yongjoo  Park',
#   'Madhusudan  Parthasarathy',
#   'Hao Peng',
#   'Jian  Peng',
#   'Lawrence Rauchwerger',
#   'Jim Rehg',
#   'John F. Reid',
#   'Ling  Ren',
#   'Talia Ringer',
#   'Grigore  Rosu',
#   'Lui Sha',
#   'Eric Gene Shaffer',
#   'Mariana  Silva',
#   'Gagandeep Singh',
#   'Makrand SINHA',
#   'Paris  Smaragdis',
#   'Marc  Snir',
#   'Brad R. Solomon',
#   'Edgar Solomonik',
#   'Elahe Soltanaghai',
#   'Sarah Gimbert Sterman',
#   'Jimeng  Sun',
#   'Hari  Sundaram',
#   'Ruby Tahboub',
#   'Matus Jan Telgarsky',
#   'Hanghang  Tong',
#   'Josep  Torrellas',
#   'Luther Tychonievich',
#   'Deepak Vasisht',
#   'Mahesh  Viswanathan',
#   'Gang  Wang',
#   'Shenlong Wang',
#   'Yuxiong  Wang',
#   'Tandy  Warnow',
#   'Tiffani L. Williams',
#   'Michael Joseph Woodley',
#   'Tianyin  Xu',
#   'Wenzhen Yuan',
#   'ChengXiang Zhai',
#   'Lingming  Zhang',
#   'Han Zhao',
#   'Craig Zilles'])

# %% [markdown]
# ## fetch google scholar data for all CS faculty

# %%
ntest = -1  #  2 #

# %%
pub_data = []
for n, name in enumerate(names[:ntest]):
#     if n < 5: continue 
    print(f"n, name = {n}, {name} ...")
    
    author_org = f"{name} {org2}"
    norm_auth_org = normalize_str(author_org)
    file_author = f"data/GScholar_{norm_auth_org}.json"

    try:
        search_query = scholarly.search_author(author_org)
        init_result = next(search_query)
    except Exception as ex:
        print(str(ex))
        init_result = None 
        
    if init_result is None:
        print(f"Failed search_author()")
        continue

    scholar_id = init_result.get("scholar_id", "")
    if not scholar_id:
        print(f"Missing scholar_id")
        continue        
    
    # fetch data
    author = scholarly.fill(init_result)
    
    author_dict = {}
    # fill data cell
    author_dict["name"] = name 
    author_dict["file_author"] = file_author 
    author_dict["scholar_id"] = scholar_id 
    author_dict["affiliation"] = author.get("affiliation", "")
    author_dict["interests"] = "; ".join(author.get("interests", []))
    author_dict["url_author"] = get_scholar_page(scholar_id)
    author_dict["url_picture"] = author.get("url_picture", "")
    author_dict["url_homepage"] = author.get("homepage", "")
    author_dict["citedby"] = author.get("citedby", 0)
    author_dict["citedby5y"] = author.get("citedby5y", 0)
    author_dict["hindex"] = author.get("hindex", 0)
    author_dict["hindex5y"] = author.get("hindex5y", 0)
    author_dict["i10index"] = author.get("i10index", 0)
    author_dict["i10index5y"] = author.get("i10index5y", 0)
    author_dict["num_papers"] = len(author.get("publications", []))
    author_dict["num_coauthors"] = len(author.get("coauthors", []))
      
    # fill row 
    author_data = []
    for c in SCHOLAR_HEADER:
        author_data.append(author_dict.get(c))
        
    # accumulate row
    pub_data.append(author_data)
    
    # persist author data
    with open(Path(file_author), "w", encoding="utf-8") as f:
        f.write(json.dumps(author))
    
    delay = randint(1,5)
    sleep(delay)
# Out:
# n, name = 0, Tarek  Abdelzaher ...
# n, name = 1, Sarita V. Adve ...
#
# Failed search_author()
# n, name = 2, Vikram Adve ...
# n, name = 3, Gul A. Agha ...
#
# Failed search_author()
# n, name = 4, Ram Alagappan ...
#
# Failed search_author()
# n, name = 5, Abdussalam Alawini ...
# n, name = 6, Nancy M. Amato ...
# n, name = 7, Lawrence Angrave ...
# n, name = 8, Brian P. Bailey ...
# n, name = 9, Arindam  Banerjee ...
# n, name = 10, Adam Bates ...
# n, name = 11, Mattox Alan Beckman ...
#
# Failed search_author()
# n, name = 12, Matthew Caesar ...
# n, name = 13, George  Chacko ...
# n, name = 14, Geoffrey Werner Challen ...
#
# Failed search_author()
# n, name = 15, Timothy Moon-Yew Chan ...
#
# Failed search_author()
# n, name = 16, Eshwar  Chandrasekharan ...
# n, name = 17, Kevin Chenchuan Chang ...
# n, name = 18, Chandra Sekhar Chekuri ...
#
# Failed search_author()
# n, name = 19, Girish  Chowdhary ...
# n, name = 20, Camille Cobb ...
# n, name = 21, Benjamin Cosman ...
# n, name = 22, Katie Cunningham ...
# n, name = 23, Ryan Matthew Cunningham ...
#
# Failed search_author()
# n, name = 24, Neal E. Davis ...
#
# Failed search_author()
# n, name = 25, Payam  Delgosha ...
# n, name = 26, Mohammed  El-Kebir ...
# n, name = 27, Jeff Erickson ...
# n, name = 28, Carl Evans ...
#
# Failed search_author()
# n, name = 29, Wade A. Fagen-Ulmschneider ...
#
# Failed search_author()
# n, name = 30, Paul  Fischer ...
# n, name = 31, Margaret M. Fleck ...
# n, name = 32, Christopher Wardlaw Fletcher ...
#
# Failed search_author()
# n, name = 33, Michael A. Forbes ...
#
# Failed search_author()
# n, name = 34, David Forsyth ...
# n, name = 35, Aishwarya Ganesan ...
# n, name = 36, Yael  Gertner ...
# n, name = 37, Saugata  Ghose ...
# n, name = 38, Brighten Godfrey ...
# n, name = 39, William D. Gropp ...
#
# Failed search_author()
# n, name = 40, Liangyan  Gui ...
# n, name = 41, Carl  Gunter ...
# n, name = 42, Elsa  Gunter ...
# n, name = 43, Indranil  Gupta ...
# n, name = 44, Jiawei  Han ...
# n, name = 45, Sariel  Har-Peled ...
# n, name = 46, John C. Hart ...
# n, name = 47, Kris K. Hauser ...
# n, name = 48, David Heath ...
# n, name = 49, Geoffrey Lindsay Herman ...
#
# Failed search_author()
# n, name = 50, Julia Hockenmaier ...
# n, name = 51, Derek W. Hoiem ...
#
# Failed search_author()
# n, name = 52, Reyhaneh  Jabbarvand ...
# n, name = 53, Sheldon Howard Jacobson ...
#
# Failed search_author()
# n, name = 54, Heng  Ji ...
# n, name = 55, Nan  Jiang ...
# n, name = 56, Laxmikant V. Kale ...
# n, name = 57, Daniel  Kang ...
#
# Failed search_author()
# n, name = 58, Karrie Karahalios ...
# n, name = 59, Dakshita  Khurana ...
# n, name = 60, Andreas Paul Eberhard Kloeckner ...
#
# Failed search_author()
# n, name = 61, Bill Kramer ...
# n, name = 62, Robin Hillary Kravets ...
#
# Failed search_author()
# n, name = 63, Ranjitha  Kumar ...
# n, name = 64, Steven M. LaValle ...
#
# Failed search_author()
# n, name = 65, Svetlana  Lazebnik ...
# n, name = 66, Colleen M. Lewis ...
# n, name = 67, Bo  Li ...
# n, name = 68, Yunzhu Li ...
# n, name = 69, Hongye  Liu ...
#
# Failed search_author()
# n, name = 70, Darko  Marinov ...
# n, name = 71, Ruta  Mehta ...
# n, name = 72, Charith Mendis ...
# n, name = 73, Jose  Meseguer ...
# n, name = 74, Sasa  Misailovic ...
# n, name = 75, Marco Morales Aguirre ...
#
# Failed search_author()
# n, name = 76, Klara  Nahrstedt ...
# n, name = 77, Michael Nowak ...
# n, name = 78, Luke  Olson ...
# n, name = 79, Yongjoo  Park ...
# n, name = 80, Madhusudan  Parthasarathy ...
# n, name = 81, Hao Peng ...
#
# Failed search_author()
# n, name = 82, Jian  Peng ...
#
# Failed search_author()
# n, name = 83, Lawrence Rauchwerger ...
# n, name = 84, Jim Rehg ...
# n, name = 85, John F. Reid ...
#
# Failed search_author()
# n, name = 86, Ling  Ren ...
# n, name = 87, Talia Ringer ...
# n, name = 88, Grigore  Rosu ...
# n, name = 89, Lui Sha ...
# n, name = 90, Eric Gene Shaffer ...
#
# Failed search_author()
# n, name = 91, Mariana  Silva ...
#
# Failed search_author()
# n, name = 92, Gagandeep Singh ...
# n, name = 93, Makrand SINHA ...
#
# Failed search_author()
# n, name = 94, Paris  Smaragdis ...
# n, name = 95, Marc  Snir ...
# n, name = 96, Brad R. Solomon ...
#
# Failed search_author()
# n, name = 97, Edgar Solomonik ...
# n, name = 98, Elahe Soltanaghai ...
# n, name = 99, Sarah Gimbert Sterman ...
#
# Failed search_author()
# n, name = 100, Jimeng  Sun ...
# n, name = 101, Hari  Sundaram ...
# n, name = 102, Ruby Tahboub ...
# n, name = 103, Matus Jan Telgarsky ...
#
# Failed search_author()
# n, name = 104, Hanghang  Tong ...
# n, name = 105, Josep  Torrellas ...
# n, name = 106, Luther Tychonievich ...
#
# Failed search_author()
# n, name = 107, Deepak Vasisht ...
# n, name = 108, Mahesh  Viswanathan ...
# n, name = 109, Gang  Wang ...
# n, name = 110, Shenlong Wang ...
# n, name = 111, Yuxiong  Wang ...
# n, name = 112, Tandy  Warnow ...
# n, name = 113, Tiffani L. Williams ...
#
# Failed search_author()
# n, name = 114, Michael Joseph Woodley ...
#
# Failed search_author()
# n, name = 115, Tianyin  Xu ...
# n, name = 116, Wenzhen Yuan ...
# n, name = 117, ChengXiang Zhai ...
# n, name = 118, Lingming  Zhang ...
# n, name = 119, Han Zhao ...

# %% [raw]
# author

# %%
len(pub_data)
# Out:
# 85

# %% [markdown]
# ## write out xlsx

# %%
df_out = pd.DataFrame(pub_data, columns=SCHOLAR_HEADER)

# %%
df_out.head()
# Out:
#                  name                                        affiliation  \
# 0   Tarek  Abdelzaher                             University of Illinois
# 1         Vikram Adve         University of Illinois at Urbana-Champaign
# 2  Abdussalam Alawini  Teaching Assistant Professor, University of Il...
# 3      Nancy M. Amato  Abel Bliss Professor and Head, Computer Scienc...
# 4    Lawrence Angrave  Teaching Professor of Computer Science, Univer...
#
#                                            interests  num_papers  \
# 0  Real-time Systems; wireless sensor networks; c...         751
# 1  Compilers; Programming Languages; Parallel Com...         171
# 2  Database Systems; Data Science; Data Provenanc...          38
# 3  motion planning; robotics; computational biolo...         471
# 4                                                             46
#
#    num_coauthors  citedby  hindex  i10index  citedby5y  hindex5y  i10index5y  \
# 0              0    42269      96       330       9888        48         202
# 1             36    15388      50        85       5618        27          47
# 2             12      178       9         8        168         8           6
# 3              7    12485      60       180       3253        28          91
# 4              9      288       8         8        205         6           5
#
#      scholar_id                                         url_author  \
# 0  cA28Zs0AAAAJ  https://scholar.google.com/citations?user=cA28...
# 1  VbruE20AAAAJ  https://scholar.google.com/citations?user=Vbru...
# 2  lyoVis4AAAAJ  https://scholar.google.com/citations?user=lyoV...
# 3  AmaB9c4AAAAJ  https://scholar.google.com/citations?user=AmaB...
# 4  KEl_ggoAAAAJ  https://scholar.google.com/citations?user=KEl_...
#
#                                          url_picture  \
# 0  https://scholar.google.com/citations?view_op=m...
# 1  https://scholar.google.com/citations?view_op=m...
# 2  https://scholar.google.com/citations?view_op=m...
# 3  https://scholar.google.com/citations?view_op=m...
# 4  https://scholar.google.com/citations?view_op=m...
#
#                                         url_homepage  \
# 0
# 1                     http://vikram.cs.illinois.edu/
# 2  https://cs.illinois.edu/about/people/faculty/a...
# 3   https://cs.illinois.edu/directory/profile/namato
# 4
#
#                                   file_author
# 0    data/GScholar_tarek_abdelzaher_uiuc.json
# 1         data/GScholar_vikram_adve_uiuc.json
# 2  data/GScholar_abdussalam_alawini_uiuc.json
# 3       data/GScholar_nancy_m_amato_uiuc.json
# 4    data/GScholar_lawrence_angrave_uiuc.json

# %%
# import xlsxwriter
file_xlsx = f"data/cs-faculty-gscholar-{org2}-{n}.xlsx"
writer = pd.ExcelWriter(Path(file_xlsx), engine='xlsxwriter')
df_out.to_excel(writer, sheet_name=org2, index=False)
writer.save()
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_3268\3066051369.py:5: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
