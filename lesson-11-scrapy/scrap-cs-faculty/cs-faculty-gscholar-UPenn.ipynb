# %% [markdown]
# This notebook uses `scholarly` API (https://github.com/scholarly-python-package/scholarly) to enrich CS faculty info

# %%
from scrap_cs_faculty import *

# %%
org_list = ["Princeton-CS","UWash-CS", "UPenn-CS"]
idx_org = org_list.index("UPenn-CS")
org = org_list[idx_org]
org2 = org.split("-")[0]

# %% [markdown]
# ## read CS faculty info scraped previously

# %%
file_xlsx = f"faculty-{org}.xlsx"
xlsxf = pd.ExcelFile(file_xlsx)

# %%
xlsxf.sheet_names
# Out:
# ['Faculty']

# %%
df = xlsxf.parse('Faculty')

# %%
df
# Out:
#                 name                                          job_title  \
# 0    Shivani Agarwal  Associate Professor, Rachleff Family Associate...
# 1        Rajeev Alur  Professor, Zisman Family Professor, Computer a...
# 2    Sebastian Angel  Assistant Professor, Raj and Neera Singh Term ...
# 3         Ryan Baker  Associate Professor, Computer and Information ...
# 4      Yoseph Barash  Associate Professor, Computer and Information ...
# ..               ...                                                ...
# 107     Richard Paul  Professor Emeritus, Computer and Information S...
# 108    Mark Steedman  Adjunct Professor, Computer and Information Sc...
# 109    Bonnie Webber  Adjunct Professor, Computer and Information Sc...
# 110     James Weimer  Adjunct Assistant Professor, Computer and Info...
# 111        Stella Yu  Adjunct Assistant Professor, Computer and Info...
#
#      phd_univ  phd_year  research_area  research_concentration  \
# 0         NaN       NaN            NaN                     NaN
# 1         NaN       NaN            NaN                     NaN
# 2         NaN       NaN            NaN                     NaN
# 3         NaN       NaN            NaN                     NaN
# 4         NaN       NaN            NaN                     NaN
# ..        ...       ...            ...                     ...
# 107       NaN       NaN            NaN                     NaN
# 108       NaN       NaN            NaN                     NaN
# 109       NaN       NaN            NaN                     NaN
# 110       NaN       NaN            NaN                     NaN
# 111       NaN       NaN            NaN                     NaN
#
#      research_focus                                                url  \
# 0               NaN  https://directory.seas.upenn.edu/shivani-agarwal/
# 1               NaN      https://directory.seas.upenn.edu/rajeev-alur/
# 2               NaN  https://directory.seas.upenn.edu/sebastian-angel/
# 3               NaN       https://directory.seas.upenn.edu/ryan-baker/
# 4               NaN    https://directory.seas.upenn.edu/yoseph-barash/
# ..              ...                                                ...
# 107             NaN     https://directory.seas.upenn.edu/richard-paul/
# 108             NaN    https://directory.seas.upenn.edu/mark-steedman/
# 109             NaN    https://directory.seas.upenn.edu/bonnie-webber/
# 110             NaN     https://directory.seas.upenn.edu/james-weimer/
# 111             NaN        https://directory.seas.upenn.edu/stella-yu/
#
#                                                img_url           phone  \
# 0    https://directory.seas.upenn.edu/wp-content/up...             NaN
# 1    https://directory.seas.upenn.edu/wp-content/up...             NaN
# 2    https://directory.seas.upenn.edu/wp-content/up...             NaN
# 3    https://directory.seas.upenn.edu/wp-content/up...             NaN
# 4    https://directory.seas.upenn.edu/wp-content/up...  (215) 746-8683
# ..                                                 ...             ...
# 107  https://directory.seas.upenn.edu/wp-content/up...             NaN
# 108  https://directory.seas.upenn.edu/wp-content/up...             NaN
# 109  https://directory.seas.upenn.edu/wp-content/up...             NaN
# 110  https://directory.seas.upenn.edu/wp-content/up...             NaN
# 111  https://directory.seas.upenn.edu/wp-content/up...    510-666-2900
#
#                        email  cell_phone  office_address        department  \
# 0     ashivani@cis.upenn.edu         NaN             NaN  Computer Science
# 1         ALUR@CIS.UPENN.EDU         NaN             NaN  Computer Science
# 2       sga001@cis.upenn.edu         NaN             NaN  Computer Science
# 3          rybaker@upenn.edu         NaN             NaN  Computer Science
# 4     yosephb@seas.upenn.edu         NaN             NaN  Computer Science
# ..                       ...         ...             ...               ...
# 107       lou@seas.upenn.edu         NaN             NaN  Computer Science
# 108  steedman@seas.upenn.edu         NaN             NaN  Computer Science
# 109    bonnie@seas.upenn.edu         NaN             NaN  Computer Science
# 110   weimerj@seas.upenn.edu         NaN             NaN  Computer Science
# 111    stellayu@berkeley.edu         NaN             NaN  Computer Science
#
#                 school  url_profile  \
# 0    Univ Pennsylvania          NaN
# 1    Univ Pennsylvania          NaN
# 2    Univ Pennsylvania          NaN
# 3    Univ Pennsylvania          NaN
# 4    Univ Pennsylvania          NaN
# ..                 ...          ...
# 107  Univ Pennsylvania          NaN
# 108  Univ Pennsylvania          NaN
# 109  Univ Pennsylvania          NaN
# 110  Univ Pennsylvania          NaN
# 111  Univ Pennsylvania          NaN
#
#                                             url_author
# 0                                                  NaN
# 1    https://scholar.google.com/citations?user=ZvLa...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110  https://scholar.google.com/citations?user=IeuL...
# 111                                                NaN
#
# [112 rows x 17 columns]

# %%
names = df["name"].to_list()

# %%
len(names), names
# Out:
# (112,
#  ['Shivani Agarwal',
#   'Rajeev Alur',
#   'Sebastian Angel',
#   'Ryan Baker',
#   'Yoseph Barash',
#   'Osbert Bastani',
#   'Arvind Bhusnurmath',
#   'Chris Callison-Burch',
#   'Damon Centola',
#   'Pratik Chaudhari',
#   'Konstantinos Daniilidis',
#   'Susan B. Davidson',
#   'Anindya De',
#   'Andre DeHon',
#   'Joseph Devietti',
#   'Eric Eaton',
#   'Thomas Farmer',
#   'Nadia Figueroa',
#   'Eric Fouh',
#   'Jean H. Gallier',
#   'Rajiv Gandhi',
#   'Jacob Gardner',
#   'James Gee',
#   'Surbhi Goel',
#   'Sharath Chandra Guntuku',
#   'Andreas Haeberlen',
#   'Hamed Hassani',
#   'Andrew Head',
#   'Brett Hemenway',
#   'M. Ani Hsieh',
#   'Zachary Ives',
#   'Dinesh Jayaraman',
#   'Kevin B. Johnson',
#   'Yasmin Kafai',
#   'Sampath K. Kannan',
#   'Michael Kearns',
#   'Sanjeev Khanna',
#   'Bongho Kim',
#   'Junhyong Kim',
#   'Daniel E. Koditschek',
#   'Konrad Paul Kording',
#   'Brandon Krakowsky',
#   'Vijay Kumar',
#   'Stephen Lane',
#   'Benjamin C. Lee',
#   'Insup Lee',
#   'Jing (Jane) Li',
#   'Gushu Li',
#   'Mark Y. Liberman',
#   'Vincent Liu',
#   'Lingjie Liu',
#   'Qi Long',
#   'Boon Thau Loo',
#   'Jérémie O. Lumbroso',
#   'Adam David Mally',
#   'Rahul Mangharam',
#   'Ryan Marcus',
#   'Nikolai Matni',
#   'Travis Q. McGaha',
#   'Danaë Metaxa',
#   'Pratyush Mishra',
#   'Mayur Naik',
#   'George J. Pappas',
#   'Robin Pemantle',
#   'Linh Thi Xuan Phan',
#   'Benjamin C. Pierce',
#   'Joshua B. Plotkin',
#   'Michael Posa',
#   'Victor M. Preciado',
#   'Tal Rabin',
#   'Alejandro Ribeiro',
#   'Dan Roth',
#   'Aaron Roth',
#   'Harvey Rubin',
#   'Shirin Saeedi Bidokhti',
#   'Andre Scedrov',
#   'Swapneel Sheth',
#   'Jianbo Shi',
#   'Harry Smith',
#   'Jonathan M. Smith',
#   'Oleg Sokolsky',
#   'Weijie Su',
#   'Cynthia Sung',
#   'Val B. Tannen',
#   'Camillo Jose Taylor',
#   'Lyle H. Ungar',
#   'René Vidal',
#   'Rakesh V. Vohra',
#   'Erik Waingarten',
#   'Li-San Wang',
#   'Duncan J. Watts',
#   'Scott Weinstein',
#   'Stephanie Weirich',
#   'Eric Wong',
#   'Charles Yang',
#   'Mark Yatskar',
#   'Mark Yim',
#   'Christopher S. Yoo',
#   'Stephan A. Zdancewic',
#   'Mingmin Zhao',
#   'Norman I. Badler',
#   'Ruzena Bajcsy',
#   'Peter Buneman',
#   'David J. Farber',
#   'Justin Gottschlich',
#   'Mitch Marcus',
#   'Ani Nenkova',
#   'Richard Paul',
#   'Mark Steedman',
#   'Bonnie Webber',
#   'James Weimer',
#   'Stella Yu'])

# %% [markdown]
# ## fetch google scholar data for all CS faculty

# %%
ntest = -1  #  2 #

# %%
pub_data = []
for n, name in enumerate(names[:ntest]):
#     if n < 5: continue 
    print(f"n, name = {n}, {name} ...")
    
    author_org = f"{name} {org2}"
    norm_auth_org = normalize_str(author_org)
    file_author = f"data/GScholar_{norm_auth_org}.json"

    try:
        search_query = scholarly.search_author(author_org)
        init_result = next(search_query)
    except Exception as ex:
        print(str(ex))
        init_result = None 
        
    if init_result is None:
        print(f"Failed search_author()")
        continue

    scholar_id = init_result.get("scholar_id", "")
    if not scholar_id:
        print(f"Missing scholar_id")
        continue        
    
    # fetch data
    author = scholarly.fill(init_result)
    
    author_dict = {}
    # fill data cell
    author_dict["name"] = name 
    author_dict["file_author"] = file_author 
    author_dict["scholar_id"] = scholar_id 
    author_dict["affiliation"] = author.get("affiliation", "")
    author_dict["interests"] = "; ".join(author.get("interests", []))
    author_dict["url_author"] = get_scholar_page(scholar_id)
    author_dict["url_picture"] = author.get("url_picture", "")
    author_dict["url_homepage"] = author.get("homepage", "")
    author_dict["citedby"] = author.get("citedby", 0)
    author_dict["citedby5y"] = author.get("citedby5y", 0)
    author_dict["hindex"] = author.get("hindex", 0)
    author_dict["hindex5y"] = author.get("hindex5y", 0)
    author_dict["i10index"] = author.get("i10index", 0)
    author_dict["i10index5y"] = author.get("i10index5y", 0)
    author_dict["num_papers"] = len(author.get("publications", []))
    author_dict["num_coauthors"] = len(author.get("coauthors", []))
      
    # fill row 
    author_data = []
    for c in SCHOLAR_HEADER:
        author_data.append(author_dict.get(c))
        
    # accumulate row
    pub_data.append(author_data)
    
    # persist author data
    with open(Path(file_author), "w", encoding="utf-8") as f:
        f.write(json.dumps(author))
    
    delay = randint(1,5)
    sleep(delay)
# Out:
# n, name = 0, Shivani Agarwal ...
# n, name = 1, Rajeev Alur ...
# n, name = 2, Sebastian Angel ...
# n, name = 3, Ryan Baker ...
# n, name = 4, Yoseph Barash ...
# n, name = 5, Osbert Bastani ...
# n, name = 6, Arvind Bhusnurmath ...
#
# Failed search_author()
# n, name = 7, Chris Callison-Burch ...
# n, name = 8, Damon Centola ...
# n, name = 9, Pratik Chaudhari ...
# n, name = 10, Konstantinos Daniilidis ...
# n, name = 11, Susan B. Davidson ...
#
# Failed search_author()
# n, name = 12, Anindya De ...
# n, name = 13, Andre DeHon ...
# n, name = 14, Joseph Devietti ...
# n, name = 15, Eric Eaton ...
# n, name = 16, Thomas Farmer ...
# n, name = 17, Nadia Figueroa ...
# n, name = 18, Eric Fouh ...
# n, name = 19, Jean H. Gallier ...
#
# Failed search_author()
# n, name = 20, Rajiv Gandhi ...
#
# Failed search_author()
# n, name = 21, Jacob Gardner ...
# n, name = 22, James Gee ...
# n, name = 23, Surbhi Goel ...
# n, name = 24, Sharath Chandra Guntuku ...
# n, name = 25, Andreas Haeberlen ...
# n, name = 26, Hamed Hassani ...
# n, name = 27, Andrew Head ...
# n, name = 28, Brett Hemenway ...
# n, name = 29, M. Ani Hsieh ...
# n, name = 30, Zachary Ives ...
# n, name = 31, Dinesh Jayaraman ...
# n, name = 32, Kevin B. Johnson ...
#
# Failed search_author()
# n, name = 33, Yasmin Kafai ...
# n, name = 34, Sampath K. Kannan ...
#
# Failed search_author()
# n, name = 35, Michael Kearns ...
# n, name = 36, Sanjeev Khanna ...
# n, name = 37, Bongho Kim ...
#
# Failed search_author()
# n, name = 38, Junhyong Kim ...
# n, name = 39, Daniel E. Koditschek ...
#
# Failed search_author()
# n, name = 40, Konrad Paul Kording ...
# n, name = 41, Brandon Krakowsky ...
#
# Failed search_author()
# n, name = 42, Vijay Kumar ...
# n, name = 43, Stephen Lane ...
# n, name = 44, Benjamin C. Lee ...
# n, name = 45, Insup Lee ...
# n, name = 46, Jing (Jane) Li ...
#
# Failed search_author()
# n, name = 47, Gushu Li ...
# n, name = 48, Mark Y. Liberman ...
#
# Failed search_author()
# n, name = 49, Vincent Liu ...
# n, name = 50, Lingjie Liu ...
# n, name = 51, Qi Long ...
# n, name = 52, Boon Thau Loo ...
# n, name = 53, Jérémie O. Lumbroso ...
#
# Failed search_author()
# n, name = 54, Adam David Mally ...
#
# Failed search_author()
# n, name = 55, Rahul Mangharam ...
# n, name = 56, Ryan Marcus ...
# n, name = 57, Nikolai Matni ...
# n, name = 58, Travis Q. McGaha ...
#
# Failed search_author()
# n, name = 59, Danaë Metaxa ...
# n, name = 60, Pratyush Mishra ...
# n, name = 61, Mayur Naik ...
# n, name = 62, George J. Pappas ...
# n, name = 63, Robin Pemantle ...
#
# Failed search_author()
# n, name = 64, Linh Thi Xuan Phan ...
# n, name = 65, Benjamin C. Pierce ...
# n, name = 66, Joshua B. Plotkin ...
# n, name = 67, Michael Posa ...
# n, name = 68, Victor M. Preciado ...
#
# Failed search_author()
# n, name = 69, Tal Rabin ...
# n, name = 70, Alejandro Ribeiro ...
# n, name = 71, Dan Roth ...
# n, name = 72, Aaron Roth ...
# n, name = 73, Harvey Rubin ...
#
# Failed search_author()
# n, name = 74, Shirin Saeedi Bidokhti ...
# n, name = 75, Andre Scedrov ...
# n, name = 76, Swapneel Sheth ...
# n, name = 77, Jianbo Shi ...
# n, name = 78, Harry Smith ...
#
# Failed search_author()
# n, name = 79, Jonathan M. Smith ...
#
# Failed search_author()
# n, name = 80, Oleg Sokolsky ...
# n, name = 81, Weijie Su ...
# n, name = 82, Cynthia Sung ...
# n, name = 83, Val B. Tannen ...
#
# Failed search_author()
# n, name = 84, Camillo Jose Taylor ...
# n, name = 85, Lyle H. Ungar ...
#
# Failed search_author()
# n, name = 86, René Vidal ...
# n, name = 87, Rakesh V. Vohra ...
#
# Failed search_author()
# n, name = 88, Erik Waingarten ...
# n, name = 89, Li-San Wang ...
# n, name = 90, Duncan J. Watts ...
# n, name = 91, Scott Weinstein ...
#
# Failed search_author()
# n, name = 92, Stephanie Weirich ...
# n, name = 93, Eric Wong ...
# n, name = 94, Charles Yang ...
#
# Failed search_author()
# n, name = 95, Mark Yatskar ...
# n, name = 96, Mark Yim ...
# n, name = 97, Christopher S. Yoo ...
#
# Failed search_author()
# n, name = 98, Stephan A. Zdancewic ...
#
# Failed search_author()
# n, name = 99, Mingmin Zhao ...
# n, name = 100, Norman I. Badler ...
#
# Failed search_author()
# n, name = 101, Ruzena Bajcsy ...
#
# Failed search_author()
# n, name = 102, Peter Buneman ...
#
# Failed search_author()
# n, name = 103, David J. Farber ...
#
# Failed search_author()
# n, name = 104, Justin Gottschlich ...
#
# Failed search_author()
# n, name = 105, Mitch Marcus ...
# n, name = 106, Ani Nenkova ...
#
# Failed search_author()
# n, name = 107, Richard Paul ...
#
# Failed search_author()
# n, name = 108, Mark Steedman ...
#
# Failed search_author()
# n, name = 109, Bonnie Webber ...
#
# Failed search_author()
# n, name = 110, James Weimer ...
#
# Failed search_author()

# %% [raw]
# author

# %%
len(pub_data)
# Out:
# 75

# %% [markdown]
# ## write out xlsx

# %%
df_out = pd.DataFrame(pub_data, columns=SCHOLAR_HEADER)

# %%
df_out.head()
# Out:
#               name                                        affiliation  \
# 0  Shivani Agarwal                         University of Pennsylvania
# 1      Rajeev Alur  Zisman Family Professor of Computer and Inform...
# 2  Sebastian Angel  University of Pennsylvania  &  Microsoft Research
# 3       Ryan Baker                         University of Pennsylvania
# 4    Yoseph Barash  Associate Professor of Genetics and Computer &...
#
#                                            interests  num_papers  \
# 0                  Machine Learning; Learning Theory          80
# 1  Formal methods; Trustworthy AI; Cyber-physical...         484
# 2  Operating Systems; Distributed Systems; Networ...          37
# 3  Educational Data Mining; Learning Analytics; L...         530
# 4  Computational RNA Biology; Machine learning; G...          92
#
#    num_coauthors  citedby  hindex  i10index  citedby5y  hindex5y  i10index5y  \
# 0              0     5337      33        55       2082        25          42
# 1             52    51973      94       239      11184        49         147
# 2             10     1546      13        16       1155        13          16
# 3            182    27442      74       299      16072        59         256
# 4              0     6760      32        46       4057        24          41
#
#      scholar_id                                         url_author  \
# 0  Q4ErnU4AAAAJ  https://scholar.google.com/citations?user=Q4Er...
# 1  ZvLa1RIAAAAJ  https://scholar.google.com/citations?user=ZvLa...
# 2  pNaNj8EAAAAJ  https://scholar.google.com/citations?user=pNaN...
# 3  hvs8PEoAAAAJ  https://scholar.google.com/citations?user=hvs8...
# 4  U5G4TJAAAAAJ  https://scholar.google.com/citations?user=U5G4...
#
#                                          url_picture  \
# 0  https://scholar.google.com/citations?view_op=m...
# 1  https://scholar.google.com/citations?view_op=m...
# 2  https://scholar.google.com/citations?view_op=m...
# 3  https://scholar.google.com/citations?view_op=m...
# 4  https://scholar.google.com/citations?view_op=m...
#
#                                         url_homepage  \
# 0                   https://www.shivani-agarwal.net/
# 1                    http://www.cis.upenn.edu/~alur/
# 2                      https://cis.upenn.edu/~sga001
# 3  http://www.upenn.edu/learninganalytics/ryanbaker/
# 4                         http://www.biociphers.org/
#
#                                 file_author
# 0  data/GScholar_shivani_agarwal_upenn.json
# 1      data/GScholar_rajeev_alur_upenn.json
# 2  data/GScholar_sebastian_angel_upenn.json
# 3       data/GScholar_ryan_baker_upenn.json
# 4    data/GScholar_yoseph_barash_upenn.json

# %%
# import xlsxwriter
file_xlsx = f"data/cs-faculty-gscholar-{org2}-{n}.xlsx"
writer = pd.ExcelWriter(Path(file_xlsx), engine='xlsxwriter')
df_out.to_excel(writer, sheet_name=org2, index=False)
writer.save()
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_13880\3066051369.py:5: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
file_xlsx
# Out:
# 'data/cs-faculty-gscholar-UPenn-110.xlsx'
