# %% [markdown]
# This notebook uses `scholarly` API (https://github.com/scholarly-python-package/scholarly) to enrich CS faculty info

# %%
from scrap_cs_faculty import *

# %%
org_list = ["Princeton-CS","UWash-CS", "UPenn-CS"]
idx_org = org_list.index("UWash-CS")
org = org_list[idx_org]
org2 = org.split("-")[0]

# %% [markdown]
# ## read CS faculty info scraped previously

# %%
file_xlsx = f"faculty-{org}.xlsx"
xlsxf = pd.ExcelFile(file_xlsx)

# %%
xlsxf.sheet_names
# Out:
# ['Faculty']

# %%
df = xlsxf.parse('Faculty')

# %%
df
# Out:
#                     name  job_title  phd_univ  phd_year  \
# 0            Tim Althoff        NaN       NaN       NaN
# 1       Richard Anderson        NaN       NaN       NaN
# 2       Ruth E. Anderson        NaN       NaN       NaN
# 3           Tom Anderson        NaN       NaN       NaN
# 4   Magdalena Balazinska        NaN       NaN       NaN
# ..                   ...        ...       ...       ...
# 93               Xi Wang        NaN       NaN       NaN
# 94          Robbie Weber        NaN       NaN       NaN
# 95        James R Wilcox        NaN       NaN       NaN
# 96        Brett Wortzman        NaN       NaN       NaN
# 97      Luke Zettlemoyer        NaN       NaN       NaN
#
#                                         research_area  research_concentration  \
# 0   Data Science, Data Mining, Social Network Anal...                     NaN
# 1   Computing for the developing world, health inf...                     NaN
# 2   Computer science education, educational techno...                     NaN
# 3   Distributed systems, networks, operating syste...                     NaN
# 4   Databases, cloud computing, big-data analytics...                     NaN
# ..                                                ...                     ...
# 93  Computer systems, security, and programming la...                     NaN
# 94                                                NaN                     NaN
# 95  Computer science education, programming langua...                     NaN
# 96  Computer science education; Computer science t...                     NaN
# 97                                                NaN                     NaN
#
#     research_focus                                                url  \
# 0              NaN          https://homes.cs.washington.edu/~althoff/
# 1              NaN  https://www.cs.washington.edu/people/faculty/a...
# 2              NaN                http://homes.cs.washington.edu/~rea
# 3              NaN   http://www.cs.washington.edu/people/faculty/tom/
# 4              NaN  http://www.cs.washington.edu/people/faculty/ma...
# ..             ...                                                ...
# 93             NaN                                 /people/faculty/xi
# 94             NaN                            http://weberrobbie.com/
# 95             NaN             http://homes.cs.washington.edu/~jrw12/
# 96             NaN          https://homes.cs.washington.edu/~brettwo/
# 97             NaN   http://www.cs.washington.edu/people/faculty/lsz/
#
#                                               img_url  phone  \
# 0   https://s3-us-west-2.amazonaws.com/www-cse-pub...    NaN
# 1   https://s3-us-west-2.amazonaws.com/www-cse-pub...    NaN
# 2   https://s3-us-west-2.amazonaws.com/www-cse-pub...    NaN
# 3   https://s3-us-west-2.amazonaws.com/www-cse-pub...    NaN
# 4   https://s3-us-west-2.amazonaws.com/www-cse-pub...    NaN
# ..                                                ...    ...
# 93  https://s3-us-west-2.amazonaws.com/www-cse-pub...    NaN
# 94  https://s3-us-west-2.amazonaws.com/www-cse-pub...    NaN
# 95  https://s3-us-west-2.amazonaws.com/www-cse-pub...    NaN
# 96  https://s3-us-west-2.amazonaws.com/www-cse-pub...    NaN
# 97  https://s3-us-west-2.amazonaws.com/www-cse-pub...    NaN
#
#                          email  cell_phone office_address        department  \
# 0    althoff@cs.washington.edu         NaN       CSE2 313  Computer Science
# 1   anderson@cs.washington.edu         NaN       CSE2 344  Computer Science
# 2        rea@cs.washington.edu         NaN        CSE 558  Computer Science
# 3        tom@cs.washington.edu         NaN        CSE 646  Computer Science
# 4      magda@cs.washington.edu         NaN        CSE 584  Computer Science
# ..                         ...         ...            ...               ...
# 93        xi@cs.washington.edu         NaN        CSE 580  Computer Science
# 94  rtweber2@cs.washington.edu         NaN            NaN  Computer Science
# 95     jrw12@cs.washington.edu         NaN            NaN  Computer Science
# 96   brettwo@cs.washington.edu         NaN        CSE 542  Computer Science
# 97       lsz@cs.washington.edu         NaN        CSE 534  Computer Science
#
#              school  url_profile  url_author
# 0   Univ Washington          NaN         NaN
# 1   Univ Washington          NaN         NaN
# 2   Univ Washington          NaN         NaN
# 3   Univ Washington          NaN         NaN
# 4   Univ Washington          NaN         NaN
# ..              ...          ...         ...
# 93  Univ Washington          NaN         NaN
# 94  Univ Washington          NaN         NaN
# 95  Univ Washington          NaN         NaN
# 96  Univ Washington          NaN         NaN
# 97  Univ Washington          NaN         NaN
#
# [98 rows x 17 columns]

# %%
names = df["name"].to_list()

# %%
len(names), names
# Out:
# (98,
#  ['Tim Althoff',
#   'Richard Anderson',
#   'Ruth E. Anderson',
#   'Tom Anderson',
#   'Magdalena Balazinska',
#   'Leilani Battle',
#   'Paul Beame',
#   'Gilbert Bernstein',
#   'Rastislav Bodik',
#   'Byron Boots',
#   'Lauren Bricker',
#   'Maya Cakmak',
#   'Luis Ceze',
#   'Yejin Choi',
#   'Andrea Coladangelo',
#   'Brian Curless',
#   'Simon Du',
#   'Michael Ernst',
#   'Ali Farhadi',
#   'James Fogarty',
#   'Dieter Fox',
#   'Jon E. Froehlich',
#   'Elba Garza',
#   'Shyam Gollakota',
#   'Matthew Golub',
#   'Dan Grossman',
#   'Abhishek Gupta',
#   'Hannaneh Hajishirzi',
#   'Jeffrey Heer',
#   'Kurtis Heimerl',
#   'Justin Hsia',
#   'Scott Sumio Ichikawa',
#   'Vikram Iyer',
#   'Kevin Jamieson',
#   'Natasha Jaques',
#   'René Just',
#   'Anna Karlin',
#   'Baris Kasikci',
#   'Ira Kemelmacher-Shlizerman',
#   'Pang Wei Koh',
#   'David Kohlbrenner',
#   'Tadayoshi Kohno',
#   'Ranjay Krishna',
#   'Arvind Krishnamurthy',
#   'Ed Lazowska',
#   'James R. Lee',
#   'Su-In Lee',
#   'Yin Tat Lee',
#   'Hank Levy',
#   'Huijia (Rachel) Lin',
#   'Kevin Lin',
#   'Ryan Maas',
#   'Ratul Mahajan',
#   'Jennifer Mankoff',
#   'Barbara Mones',
#   'Jamie Morgenstern',
#   'Sara Mostafavi',
#   'Miya Natsuhara',
#   'Chinmay Nirkhe',
#   'Jeff Nivala',
#   'Sewoong Oh',
#   'Mark Oskin',
#   'Shayan Oveis Gharan',
#   'Shwetak Patel',
#   'Hal Perkins',
#   'Simon Peter',
#   'Zoran Popović',
#   'Anup Rao',
#   'Rajesh P. N. Rao',
#   'Stuart Reges',
#   'Katharina Reinecke',
#   'Franziska Roesner',
#   'Thomas Rothvoss',
#   'Hunter Schafer',
#   'Ludwig Schmidt',
#   'Adriana Schulz',
#   'Georg Seelig',
#   'Steven Seitz',
#   'Ben Shapiro',
#   'Linda Shapiro',
#   'Joshua R. Smith',
#   'Noah Smith',
#   'Siddhartha (Sidd) Srinivasa',
#   'Dan Suciu',
#   'Steve Tanimoto',
#   'Zachary Tatlock',
#   'Michael Taylor',
#   'Stefano Tessaro',
#   'Christopher Thachuk',
#   'Emina Torlak',
#   'Yulia Tsvetkov',
#   'Matthew Wang',
#   'Sheng Wang',
#   'Xi Wang',
#   'Robbie Weber',
#   'James R Wilcox',
#   'Brett Wortzman',
#   'Luke Zettlemoyer'])

# %% [markdown]
# ## fetch google scholar data for all CS faculty

# %%
ntest = -1  #  2 #

# %%
pub_data = []
for n, name in enumerate(names[:ntest]):
#     if n < 5: continue 
    print(f"n, name = {n}, {name} ...")
    
    author_org = f"{name} {org2}"
    norm_auth_org = normalize_str(author_org)
    file_author = f"data/GScholar_{norm_auth_org}.json"

    try:
        search_query = scholarly.search_author(author_org)
        init_result = next(search_query)
    except Exception as ex:
        print(str(ex))
        init_result = None 
        
    if init_result is None:
        print(f"Failed search_author()")
        continue

    scholar_id = init_result.get("scholar_id", "")
    if not scholar_id:
        print(f"Missing scholar_id")
        continue        
    
    # fetch data
    author = scholarly.fill(init_result)
    
    author_dict = {}
    # fill data cell
    author_dict["name"] = name 
    author_dict["file_author"] = file_author 
    author_dict["scholar_id"] = scholar_id 
    author_dict["affiliation"] = author.get("affiliation", "")
    author_dict["interests"] = "; ".join(author.get("interests", []))
    author_dict["url_author"] = get_scholar_page(scholar_id)
    author_dict["url_picture"] = author.get("url_picture", "")
    author_dict["url_homepage"] = author.get("homepage", "")
    author_dict["citedby"] = author.get("citedby", 0)
    author_dict["citedby5y"] = author.get("citedby5y", 0)
    author_dict["hindex"] = author.get("hindex", 0)
    author_dict["hindex5y"] = author.get("hindex5y", 0)
    author_dict["i10index"] = author.get("i10index", 0)
    author_dict["i10index5y"] = author.get("i10index5y", 0)
    author_dict["num_papers"] = len(author.get("publications", []))
    author_dict["num_coauthors"] = len(author.get("coauthors", []))
      
    # fill row 
    author_data = []
    for c in SCHOLAR_HEADER:
        author_data.append(author_dict.get(c))
        
    # accumulate row
    pub_data.append(author_data)
    
    # persist author data
    with open(Path(file_author), "w", encoding="utf-8") as f:
        f.write(json.dumps(author))
    
    delay = randint(1,5)
    sleep(delay)
# Out:
# n, name = 0, Tim Althoff ...
# n, name = 1, Richard Anderson ...
# n, name = 2, Ruth E. Anderson ...
# n, name = 3, Tom Anderson ...
# n, name = 4, Magdalena Balazinska ...
# n, name = 5, Leilani Battle ...
# n, name = 6, Paul Beame ...
# n, name = 7, Gilbert Bernstein ...
#
# Failed search_author()
# n, name = 8, Rastislav Bodik ...
# n, name = 9, Byron Boots ...
# n, name = 10, Lauren Bricker ...
#
# Failed search_author()
# n, name = 11, Maya Cakmak ...
# n, name = 12, Luis Ceze ...
# n, name = 13, Yejin Choi ...
# n, name = 14, Andrea Coladangelo ...
#
# Failed search_author()
# n, name = 15, Brian Curless ...
# n, name = 16, Simon Du ...
# n, name = 17, Michael Ernst ...
# n, name = 18, Ali Farhadi ...
# n, name = 19, James Fogarty ...
# n, name = 20, Dieter Fox ...
# n, name = 21, Jon E. Froehlich ...
# n, name = 22, Elba Garza ...
#
# Failed search_author()
# n, name = 23, Shyam Gollakota ...
# n, name = 24, Matthew Golub ...
#
# Failed search_author()
# n, name = 25, Dan Grossman ...
# n, name = 26, Abhishek Gupta ...
# n, name = 27, Hannaneh Hajishirzi ...
# n, name = 28, Jeffrey Heer ...
# n, name = 29, Kurtis Heimerl ...
# n, name = 30, Justin Hsia ...
#
# Failed search_author()
# n, name = 31, Scott Sumio Ichikawa ...
#
# Failed search_author()
# n, name = 32, Vikram Iyer ...
# n, name = 33, Kevin Jamieson ...
# n, name = 34, Natasha Jaques ...
#
# Failed search_author()
# n, name = 35, René Just ...
# n, name = 36, Anna Karlin ...
#
# Failed search_author()
# n, name = 37, Baris Kasikci ...
# n, name = 38, Ira Kemelmacher-Shlizerman ...
#
# Failed search_author()
# n, name = 39, Pang Wei Koh ...
# n, name = 40, David Kohlbrenner ...
# n, name = 41, Tadayoshi Kohno ...
# n, name = 42, Ranjay Krishna ...
# n, name = 43, Arvind Krishnamurthy ...
#
# Failed search_author()
# n, name = 44, Ed Lazowska ...
# n, name = 45, James R. Lee ...
# n, name = 46, Su-In Lee ...
# n, name = 47, Yin Tat Lee ...
# n, name = 48, Hank Levy ...
#
# Failed search_author()
# n, name = 49, Huijia (Rachel) Lin ...
# n, name = 50, Kevin Lin ...
#
# Failed search_author()
# n, name = 51, Ryan Maas ...
#
# Failed search_author()
# n, name = 52, Ratul Mahajan ...
# n, name = 53, Jennifer Mankoff ...
# n, name = 54, Barbara Mones ...
#
# Failed search_author()
# n, name = 55, Jamie Morgenstern ...
# n, name = 56, Sara Mostafavi ...
# n, name = 57, Miya Natsuhara ...
#
# Failed search_author()
# n, name = 58, Chinmay Nirkhe ...
#
# Failed search_author()
# n, name = 59, Jeff Nivala ...
# n, name = 60, Sewoong Oh ...
# n, name = 61, Mark Oskin ...
# n, name = 62, Shayan Oveis Gharan ...
# n, name = 63, Shwetak Patel ...
# n, name = 64, Hal Perkins ...
#
# Failed search_author()
# n, name = 65, Simon Peter ...
# n, name = 66, Zoran Popović ...
# n, name = 67, Anup Rao ...
# n, name = 68, Rajesh P. N. Rao ...
# n, name = 69, Stuart Reges ...
# n, name = 70, Katharina Reinecke ...
# n, name = 71, Franziska Roesner ...
#
# Failed search_author()
# n, name = 72, Thomas Rothvoss ...
# n, name = 73, Hunter Schafer ...
#
# Failed search_author()
# n, name = 74, Ludwig Schmidt ...
# n, name = 75, Adriana Schulz ...
# n, name = 76, Georg Seelig ...
# n, name = 77, Steven Seitz ...
# n, name = 78, Ben Shapiro ...
# n, name = 79, Linda Shapiro ...
# n, name = 80, Joshua R. Smith ...
# n, name = 81, Noah Smith ...
# n, name = 82, Siddhartha (Sidd) Srinivasa ...
#
# Failed search_author()
# n, name = 83, Dan Suciu ...
# n, name = 84, Steve Tanimoto ...
# n, name = 85, Zachary Tatlock ...
# n, name = 86, Michael Taylor ...
# n, name = 87, Stefano Tessaro ...
# n, name = 88, Christopher Thachuk ...
# n, name = 89, Emina Torlak ...
# n, name = 90, Yulia Tsvetkov ...
# n, name = 91, Matthew Wang ...
#
# Failed search_author()
# n, name = 92, Sheng Wang ...
# n, name = 93, Xi Wang ...
# n, name = 94, Robbie Weber ...
#
# Failed search_author()
# n, name = 95, James R Wilcox ...
# n, name = 96, Brett Wortzman ...
#
# Failed search_author()

# %% [raw]
# author

# %%
len(pub_data)
# Out:
# 73

# %% [markdown]
# ## write out xlsx

# %%
df_out = pd.DataFrame(pub_data, columns=SCHOLAR_HEADER)

# %%
df_out.head()
# Out:
#                    name                                        affiliation  \
# 0           Tim Althoff  Assistant Professor of Computer Science, Unive...
# 1      Richard Anderson  Professor of Computer Science and Engineering,...
# 2      Ruth E. Anderson                           University of Washington
# 3          Tom Anderson  Warren Francis and Wilma Kolm Bradley Chair, C...
# 4  Magdalena Balazinska                           University of Washington
#
#                                            interests  num_papers  \
# 0  data science; data mining; natural language pr...          98
# 1  Information and Computing Technologies for Dev...        1103
# 2                                                             61
# 3  Distributed Systems; Networking; Operating Sys...         310
# 4  Databases; data science; cloud computing; para...         226
#
#    num_coauthors  citedby  hindex  i10index  citedby5y  hindex5y  i10index5y  \
# 0             26     4104      29        42       3617        27          42
# 1              0    13823      61       228       3576        28          95
# 2              0     2435      24        33        596        13          16
# 3             56    59071      98       183      13284        50         109
# 4              0    17167      63       117       5458        39          88
#
#      scholar_id                                         url_author  \
# 0  yc4nBNgAAAAJ  https://scholar.google.com/citations?user=yc4n...
# 1  uLsDDUMAAAAJ  https://scholar.google.com/citations?user=uLsD...
# 2  X3x2Pi0AAAAJ  https://scholar.google.com/citations?user=X3x2...
# 3  MYqlcPgAAAAJ  https://scholar.google.com/citations?user=MYql...
# 4  DDxFvcIAAAAJ  https://scholar.google.com/citations?user=DDxF...
#
#                                          url_picture  \
# 0  https://scholar.google.com/citations?view_op=m...
# 1  https://scholar.google.com/citations?view_op=m...
# 2  https://scholar.google.com/citations?view_op=m...
# 3  https://scholar.google.com/citations?view_op=m...
# 4  https://scholar.google.com/citations?view_op=m...
#
#                                         url_homepage  \
# 0                         http://www.timalthoff.com/
# 1  http://www.cs.washington.edu/people/faculty/an...
# 2
# 3             http://www.cs.washington.edu/homes/tom
# 4  http://www.cs.washington.edu/people/faculty/magda
#
#                                      file_author
# 0           data/GScholar_tim_althoff_uwash.json
# 1      data/GScholar_richard_anderson_uwash.json
# 2       data/GScholar_ruth_e_anderson_uwash.json
# 3          data/GScholar_tom_anderson_uwash.json
# 4  data/GScholar_magdalena_balazinska_uwash.json

# %%
# import xlsxwriter
file_xlsx = f"data/cs-faculty-gscholar-{org2}-{n}.xlsx"
writer = pd.ExcelWriter(Path(file_xlsx), engine='xlsxwriter')
df_out.to_excel(writer, sheet_name=org2, index=False)
writer.save()
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_3784\3066051369.py:5: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
file_xlsx
# Out:
# 'data/cs-faculty-gscholar-UWash-96.xlsx'
