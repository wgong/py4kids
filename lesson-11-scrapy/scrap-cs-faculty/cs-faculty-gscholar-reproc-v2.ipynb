# %% [markdown]
# This notebook uses `scholarly` API (https://github.com/scholarly-python-package/scholarly) to enrich CS faculty info

# %% [markdown]
# When searching google scholar using `scholarly`, don't include org, e.g.
# - `Stuart J. Russell berkeley` returns no result,
#     - but `Stuart J. Russell` does

# %%
from scrap_cs_faculty import *

# %% [markdown]
# ## read CS faculty to be reprocessed

# %% [raw]
# file_xlsx = f"faculty-{org}.xlsx"
# xlsxf = pd.ExcelFile(file_xlsx)
# # xlsxf.sheet_names
# df = xlsxf.parse('Faculty')

# %%
file_csv = "cs-faculty-no_scholar_id-0910.csv"  # "cs-faculty-no_scholar_id.csv"
df = pd.read_csv(file_csv)

# %%
df
# Out:
#                     name                  name_school
# 0         DeYoung, Henry           DeYoung, Henry CMU
# 1         Eckhardt, Dave           Eckhardt, Dave CMU
# 2         Gligor, Virgil           Gligor, Virgil CMU
# 3       Jahanian, Farnam         Jahanian, Farnam CMU
# 4      Kohlbrenner, Anne        Kohlbrenner, Anne CMU
# ..                   ...                          ...
# 113  Matus Jan Telgarsky     Matus Jan Telgarsky UIUC
# 114        Serge Plotkin       Serge Plotkin Stanford
# 115    Michael J. Clancy   Michael J. Clancy Berkeley
# 116   David A. Patterson  David A. Patterson Berkeley
# 117      David A. Wagner     David A. Wagner Berkeley
#
# [118 rows x 2 columns]

# %%
names = df.values

# %%
len(names), names
# Out:
# (118,
#  array([['DeYoung, Henry', 'DeYoung, Henry CMU'],
#         ['Eckhardt, Dave', 'Eckhardt, Dave CMU'],
#         ['Gligor, Virgil', 'Gligor, Virgil CMU'],
#         ['Jahanian, Farnam', 'Jahanian, Farnam CMU'],
#         ['Kohlbrenner, Anne', 'Kohlbrenner, Anne CMU'],
#         ['Kosbie, David', 'Kosbie, David CMU'],
#         ['Needham, Kit', 'Needham, Kit CMU'],
#         ['Sherry, Justine', 'Sherry, Justine CMU'],
#         ['Vinayak, Rashmi Korlakai', 'Vinayak, Rashmi Korlakai CMU'],
#         ['David Albonesi', 'David Albonesi nan'],
#         ['Anne Bracy', 'Anne Bracy nan'],
#         ['Robert Constable', 'Robert Constable nan'],
#         ['Alan Demers', 'Alan Demers nan'],
#         ['K-Y. Daisy Fan', 'K-Y. Daisy Fan nan'],
#         ['Donald Greenberg', 'Donald Greenberg nan'],
#         ['Curran Muhlberger', 'Curran Muhlberger nan'],
#         ['Alexander "Sasha" Rush', 'Alexander "Sasha" Rush nan'],
#         ['G. Edward Suh', 'G. Edward Suh nan'],
#         ['Tim Teitelbaum', 'Tim Teitelbaum nan'],
#         ['Hal Abelson', 'Hal Abelson MIT'],
#         ['Elfar Adalsteinsson', 'Elfar Adalsteinsson MIT'],
#         ['Regina Barzilay', 'Regina Barzilay MIT'],
#         ['YuFeng (Kevin)  Chen', 'YuFeng (Kevin)  Chen MIT'],
#         ['Isaac Chuang', 'Isaac Chuang MIT'],
#         ['Connor Wilson Coley', 'Connor Wilson Coley MIT'],
#         ['Dennis Freeman', 'Dennis Freeman MIT'],
#         ['David Gifford', 'David Gifford MIT'],
#         ['W. Eric L Grimson', 'W. Eric L Grimson MIT'],
#         ['Tomás Lozano-Pérez', 'Tomás Lozano-Pérez MIT'],
#         ['Alan Oppenheim', 'Alan Oppenheim MIT'],
#         ['Asu Ozdaglar', 'Asu Ozdaglar MIT'],
#         ['Collin Stultz', 'Collin Stultz MIT'],
#         ['Brynmor Chapman', 'Brynmor Chapman MIT'],
#         ['Shafrira Goldwasser', 'Shafrira Goldwasser MIT'],
#         ['M. Frans Kaashoek', 'M. Frans Kaashoek MIT'],
#         ['Steven Leeb', 'Steven Leeb MIT'],
#         ['Barbara Liskov', 'Barbara Liskov MIT'],
#         ['Silvio Micali', 'Silvio Micali MIT'],
#         ['Gill Bejerano', 'Gill Bejerano Stanford'],
#         ['Ron Fedkiw', 'Ron Fedkiw Stanford'],
#         ['Fred Kjolstad', 'Fred Kjolstad Stanford'],
#         ['Mendel Rosenblum', 'Mendel Rosenblum Stanford'],
#         ['Nick Parlante', 'Nick Parlante Stanford'],
#         ['Keith Schwarz', 'Keith Schwarz Stanford'],
#         ['Nick Troccoli', 'Nick Troccoli Stanford'],
#         ['Christina Wodtke', 'Christina Wodtke Stanford'],
#         ['Julie Zelenski', 'Julie Zelenski Stanford'],
#         ['Tom Dienstbier', 'Tom Dienstbier Stanford'],
#         ['Edward Feigenbaum', 'Edward Feigenbaum Stanford'],
#         ['Richard Fikes', 'Richard Fikes Stanford'],
#         ['Teresa Meng', 'Teresa Meng Stanford'],
#         ['Vaughan Pratt', 'Vaughan Pratt Stanford'],
#         ['Terry Winograd', 'Terry Winograd Stanford'],
#         ['Camille Utterback', 'Camille Utterback Stanford'],
#         ['Juan Carlos Niebles Duque',
#          'Juan Carlos Niebles Duque Stanford'],
#         ['Sebastian Thrun', 'Sebastian Thrun Stanford'],
#         ['Babak Ayazifar', 'Babak Ayazifar Berkeley'],
#         ['John F. Canny', 'John F. Canny Berkeley'],
#         ['David E. Culler', 'David E. Culler Berkeley'],
#         ['Prabal Dutta', 'Prabal Dutta Berkeley'],
#         ['Alexei (Alyosha) Efros', 'Alexei (Alyosha) Efros Berkeley'],
#         ['Richard J. Fateman', 'Richard J. Fateman Berkeley'],
#         ['Jerome A. Feldman', 'Jerome A. Feldman Berkeley'],
#         ['Shafi Goldwasser', 'Shafi Goldwasser Berkeley'],
#         ['Joseph M. Hellerstein', 'Joseph M. Hellerstein Berkeley'],
#         ['Joshua Hug', 'Joshua Hug Berkeley'],
#         ['Christopher Hunn', 'Christopher Hunn Berkeley'],
#         ['Peyrin Kao', 'Peyrin Kao Berkeley'],
#         ['John D. Kubiatowicz', 'John D. Kubiatowicz Berkeley'],
#         ['Beresford N. Parlett', 'Beresford N. Parlett Berkeley'],
#         ['Stuart J. Russell', 'Stuart J. Russell Berkeley'],
#         ['Carlo H. Séquin', 'Carlo H. Séquin Berkeley'],
#         ['Costas J. Spanos', 'Costas J. Spanos Berkeley'],
#         ['Michael Stonebraker', 'Michael Stonebraker Berkeley'],
#         ['Umesh Vazirani', 'Umesh Vazirani Berkeley'],
#         ['Lisa Yan', 'Lisa Yan Berkeley'],
#         ['Katherine A. Yelick', 'Katherine A. Yelick Berkeley'],
#         ['Justin Yokota', 'Justin Yokota Berkeley'],
#         ['Sarita V. Adve', 'Sarita V. Adve UIUC'],
#         ['Mattox Alan Beckman', 'Mattox Alan Beckman UIUC'],
#         ['Geoffrey Werner Challen', 'Geoffrey Werner Challen UIUC'],
#         ['Ryan Matthew Cunningham', 'Ryan Matthew Cunningham UIUC'],
#         ['Carl Evans', 'Carl Evans UIUC'],
#         ['Wade A. Fagen-Ulmschneider', 'Wade A. Fagen-Ulmschneider UIUC'],
#         ['Christopher Wardlaw Fletcher',
#          'Christopher Wardlaw Fletcher UIUC'],
#         ['William D. Gropp', 'William D. Gropp UIUC'],
#         ['Geoffrey Lindsay Herman', 'Geoffrey Lindsay Herman UIUC'],
#         ['Derek W. Hoiem', 'Derek W. Hoiem UIUC'],
#         ['Andreas Paul Eberhard Kloeckner',
#          'Andreas Paul Eberhard Kloeckner UIUC'],
#         ['Marco Morales Aguirre', 'Marco Morales Aguirre UIUC'],
#         ['John F. Reid', 'John F. Reid UIUC'],
#         ['Eric Gene Shaffer', 'Eric Gene Shaffer UIUC'],
#         ['Makrand SINHA', 'Makrand SINHA UIUC'],
#         ['Brad R. Solomon', 'Brad R. Solomon UIUC'],
#         ['Sarah Gimbert Sterman', 'Sarah Gimbert Sterman UIUC'],
#         ['Michael Joseph Woodley', 'Michael Joseph Woodley UIUC'],
#         ['Kaynar, Zeliha Dilsun', 'Kaynar, Zeliha Dilsun CMU'],
#         ['Yury Polyanskiy', 'Yury Polyanskiy MIT'],
#         ['Michael Stonebraker', 'Michael Stonebraker MIT'],
#         ['Fred Kjoelstad', 'Fred Kjoelstad Stanford'],
#         ['Aviad Rubinstein', 'Aviad Rubinstein Stanford'],
#         ['Jean-Claude Latombe', 'Jean-Claude Latombe Stanford'],
#         ['Domenico Ferrari', 'Domenico Ferrari Berkeley'],
#         ['Paul N. Hilfinger', 'Paul N. Hilfinger Berkeley'],
#         ['Timothy Moon-Yew Chan', 'Timothy Moon-Yew Chan UIUC'],
#         ['Chandra Sekhar Chekuri', 'Chandra Sekhar Chekuri UIUC'],
#         ['Michael A. Forbes', 'Michael A. Forbes UIUC'],
#         ['Sheldon Howard Jacobson', 'Sheldon Howard Jacobson UIUC'],
#         ['Robin Hillary Kravets', 'Robin Hillary Kravets UIUC'],
#         ['Luther Tychonievich', 'Luther Tychonievich UIUC'],
#         ['Victor Zue', 'Victor Zue MIT'],
#         ['Anand V Natarajan', 'Anand V Natarajan MIT'],
#         ['Randy H. Katz', 'Randy H. Katz Berkeley'],
#         ['Matus Jan Telgarsky', 'Matus Jan Telgarsky UIUC'],
#         ['Serge Plotkin', 'Serge Plotkin Stanford'],
#         ['Michael J. Clancy', 'Michael J. Clancy Berkeley'],
#         ['David A. Patterson', 'David A. Patterson Berkeley'],
#         ['David A. Wagner', 'David A. Wagner Berkeley']], dtype=object))

# %% [markdown]
# ## fetch google scholar data for all CS faculty

# %%
def search_gscholar(name, author_org=""):
    init_result = None
    
    if author_org:
        try:
            search_query = scholarly.search_author(author_org)
            init_result = next(search_query)
            return init_result
        except Exception as ex:
            print(str(ex))
             
    if not author_org or init_result is None:
        try:
            x = name.split()
            if len(x) > 2:
                name = x[0] + " " + x[-1]
            search_query = scholarly.search_author(name)
            init_result = next(search_query)
            return init_result
        except Exception as ex:
            print(str(ex))
            init_result = None 
        
    if init_result is None:
        print(f"Failed to search google scholar: {name}, {author_org}")
        return None

# %%
ntest = -1  #  5 #

# %%
pub_data = []
pub_error = []
for n, r in enumerate(names[:ntest]):
#     if n < 5: continue 
    name, author_org = r
    print(f"\n n, name = {n}, {name} ...")
    
    norm_auth_org = normalize_str(author_org)
    file_author = f"data/GScholar_{norm_auth_org}.json"

    init_result = search_gscholar(name, author_org)
    if init_result is None:
        pub_error.append(r)
        continue

    scholar_id = init_result.get("scholar_id", "")
    if not scholar_id:
        print(f"Missing scholar_id")
        continue        
    
    # fetch data
    author = scholarly.fill(init_result)
    
    author_dict = {}
    # fill data cell
    author_dict["name"] = name 
    author_dict["file_author"] = file_author 
    author_dict["scholar_id"] = scholar_id 
    author_dict["affiliation"] = author.get("affiliation", "")
    author_dict["interests"] = "; ".join(author.get("interests", []))
    author_dict["url_author"] = get_scholar_page(scholar_id)
    author_dict["url_picture"] = author.get("url_picture", "")
    author_dict["url_homepage"] = author.get("homepage", "")
    author_dict["citedby"] = author.get("citedby", 0)
    author_dict["citedby5y"] = author.get("citedby5y", 0)
    author_dict["hindex"] = author.get("hindex", 0)
    author_dict["hindex5y"] = author.get("hindex5y", 0)
    author_dict["i10index"] = author.get("i10index", 0)
    author_dict["i10index5y"] = author.get("i10index5y", 0)
    author_dict["num_papers"] = len(author.get("publications", []))
    author_dict["num_coauthors"] = len(author.get("coauthors", []))
      
    # fill row 
    author_data = []
    for c in SCHOLAR_HEADER:
        author_data.append(author_dict.get(c))
        
    # accumulate row
    pub_data.append(author_data)
    
    # persist author data
    with open(Path(file_author), "w", encoding="utf-8") as f:
        f.write(json.dumps(author))
    
    delay = randint(1,5)
    sleep(delay)
# Out:
#  n, name = 0, DeYoung, Henry ...
#
#
# Failed to search google scholar: DeYoung, Henry, DeYoung, Henry CMU
#
#  n, name = 1, Eckhardt, Dave ...
#
#
# Failed to search google scholar: Eckhardt, Dave, Eckhardt, Dave CMU
#
#  n, name = 2, Gligor, Virgil ...
#
#
# Failed to search google scholar: Gligor, Virgil, Gligor, Virgil CMU
#
#  n, name = 3, Jahanian, Farnam ...
#
#
# Failed to search google scholar: Jahanian, Farnam, Jahanian, Farnam CMU
#
#  n, name = 4, Kohlbrenner, Anne ...
#
#
# Failed to search google scholar: Kohlbrenner, Anne, Kohlbrenner, Anne CMU
#
#  n, name = 5, Kosbie, David ...
#
#
# Failed to search google scholar: Kosbie, David, Kosbie, David CMU
#
#  n, name = 6, Needham, Kit ...
#
#
# Failed to search google scholar: Needham, Kit, Needham, Kit CMU
#
#  n, name = 7, Sherry, Justine ...
#
#
# Failed to search google scholar: Sherry, Justine, Sherry, Justine CMU
#
#  n, name = 8, Vinayak, Rashmi Korlakai ...
#
#
#  n, name = 9, David Albonesi ...
#
#
# Failed to search google scholar: David Albonesi, David Albonesi nan
#
#  n, name = 10, Anne Bracy ...
#
#
# Failed to search google scholar: Anne Bracy, Anne Bracy nan
#
#  n, name = 11, Robert Constable ...
#
#
# Failed to search google scholar: Robert Constable, Robert Constable nan
#
#  n, name = 12, Alan Demers ...
#
#
# Failed to search google scholar: Alan Demers, Alan Demers nan
#
#  n, name = 13, K-Y. Daisy Fan ...
#
#
#  n, name = 14, Donald Greenberg ...
#
#
# Failed to search google scholar: Donald Greenberg, Donald Greenberg nan
#
#  n, name = 15, Curran Muhlberger ...
#
#
# Failed to search google scholar: Curran Muhlberger, Curran Muhlberger nan
#
#  n, name = 16, Alexander "Sasha" Rush ...
#
#
#  n, name = 17, G. Edward Suh ...
#
#
#  n, name = 18, Tim Teitelbaum ...
#
#
# Failed to search google scholar: Tim Teitelbaum, Tim Teitelbaum nan
#
#  n, name = 19, Hal Abelson ...
#
#
# Failed to search google scholar: Hal Abelson, Hal Abelson MIT
#
#  n, name = 20, Elfar Adalsteinsson ...
#
#
# Failed to search google scholar: Elfar Adalsteinsson, Elfar Adalsteinsson MIT
#
#  n, name = 21, Regina Barzilay ...
#
#
# Failed to search google scholar: Regina Barzilay, Regina Barzilay MIT
#
#  n, name = 22, YuFeng (Kevin)  Chen ...
#
#
#  n, name = 23, Isaac Chuang ...
#
#
# Failed to search google scholar: Isaac Chuang, Isaac Chuang MIT
#
#  n, name = 24, Connor Wilson Coley ...
#
#
#  n, name = 25, Dennis Freeman ...
#
#
# Failed to search google scholar: Dennis Freeman, Dennis Freeman MIT
#
#  n, name = 26, David Gifford ...
#
#
# Failed to search google scholar: David Gifford, David Gifford MIT
#
#  n, name = 27, W. Eric L Grimson ...
#
#
#  n, name = 28, Tomás Lozano-Pérez ...
#
#
# Failed to search google scholar: Tomás Lozano-Pérez, Tomás Lozano-Pérez MIT
#
#  n, name = 29, Alan Oppenheim ...
#
#
# Failed to search google scholar: Alan Oppenheim, Alan Oppenheim MIT
#
#  n, name = 30, Asu Ozdaglar ...
#
#
# Failed to search google scholar: Asu Ozdaglar, Asu Ozdaglar MIT
#
#  n, name = 31, Collin Stultz ...
#
#
# Failed to search google scholar: Collin Stultz, Collin Stultz MIT
#
#  n, name = 32, Brynmor Chapman ...
#
#
# Failed to search google scholar: Brynmor Chapman, Brynmor Chapman MIT
#
#  n, name = 33, Shafrira Goldwasser ...
#
#
# Failed to search google scholar: Shafrira Goldwasser, Shafrira Goldwasser MIT
#
#  n, name = 34, M. Frans Kaashoek ...
#
#
# Failed to search google scholar: M. Kaashoek, M. Frans Kaashoek MIT
#
#  n, name = 35, Steven Leeb ...
#
#
# Failed to search google scholar: Steven Leeb, Steven Leeb MIT
#
#  n, name = 36, Barbara Liskov ...
#
#
# Failed to search google scholar: Barbara Liskov, Barbara Liskov MIT
#
#  n, name = 37, Silvio Micali ...
#
#
# Failed to search google scholar: Silvio Micali, Silvio Micali MIT
#
#  n, name = 38, Gill Bejerano ...
#
#
# Failed to search google scholar: Gill Bejerano, Gill Bejerano Stanford
#
#  n, name = 39, Ron Fedkiw ...
#
#
# Failed to search google scholar: Ron Fedkiw, Ron Fedkiw Stanford
#
#  n, name = 40, Fred Kjolstad ...
#
#
# Failed to search google scholar: Fred Kjolstad, Fred Kjolstad Stanford
#
#  n, name = 41, Mendel Rosenblum ...
#
#
# Failed to search google scholar: Mendel Rosenblum, Mendel Rosenblum Stanford
#
#  n, name = 42, Nick Parlante ...
#
#
# Failed to search google scholar: Nick Parlante, Nick Parlante Stanford
#
#  n, name = 43, Keith Schwarz ...
#
#
# Failed to search google scholar: Keith Schwarz, Keith Schwarz Stanford
#
#  n, name = 44, Nick Troccoli ...
#
#
# Failed to search google scholar: Nick Troccoli, Nick Troccoli Stanford
#
#  n, name = 45, Christina Wodtke ...
#
#
# Failed to search google scholar: Christina Wodtke, Christina Wodtke Stanford
#
#  n, name = 46, Julie Zelenski ...
#
#
# Failed to search google scholar: Julie Zelenski, Julie Zelenski Stanford
#
#  n, name = 47, Tom Dienstbier ...
#
#
# Failed to search google scholar: Tom Dienstbier, Tom Dienstbier Stanford
#
#  n, name = 48, Edward Feigenbaum ...
#
#
# Failed to search google scholar: Edward Feigenbaum, Edward Feigenbaum Stanford
#
#  n, name = 49, Richard Fikes ...
#
#
# Failed to search google scholar: Richard Fikes, Richard Fikes Stanford
#
#  n, name = 50, Teresa Meng ...
#
#
# Failed to search google scholar: Teresa Meng, Teresa Meng Stanford
#
#  n, name = 51, Vaughan Pratt ...
#
#
# Failed to search google scholar: Vaughan Pratt, Vaughan Pratt Stanford
#
#  n, name = 52, Terry Winograd ...
#
#
# Failed to search google scholar: Terry Winograd, Terry Winograd Stanford
#
#  n, name = 53, Camille Utterback ...
#
#
# Failed to search google scholar: Camille Utterback, Camille Utterback Stanford
#
#  n, name = 54, Juan Carlos Niebles Duque ...
#
#
#  n, name = 55, Sebastian Thrun ...
#
#
# Failed to search google scholar: Sebastian Thrun, Sebastian Thrun Stanford
#
#  n, name = 56, Babak Ayazifar ...
#
#
# Failed to search google scholar: Babak Ayazifar, Babak Ayazifar Berkeley
#
#  n, name = 57, John F. Canny ...
#
#
#  n, name = 58, David E. Culler ...
#
#
#  n, name = 59, Prabal Dutta ...
#
#
# Failed to search google scholar: Prabal Dutta, Prabal Dutta Berkeley
#
#  n, name = 60, Alexei (Alyosha) Efros ...
#
#
#  n, name = 61, Richard J. Fateman ...
#
#
#  n, name = 62, Jerome A. Feldman ...
#
#
#  n, name = 63, Shafi Goldwasser ...
#
#
# Failed to search google scholar: Shafi Goldwasser, Shafi Goldwasser Berkeley
#
#  n, name = 64, Joseph M. Hellerstein ...
#
#
#  n, name = 65, Joshua Hug ...
#
#
# Failed to search google scholar: Joshua Hug, Joshua Hug Berkeley
#
#  n, name = 66, Christopher Hunn ...
#
#
# Failed to search google scholar: Christopher Hunn, Christopher Hunn Berkeley
#
#  n, name = 67, Peyrin Kao ...
#
#
# Failed to search google scholar: Peyrin Kao, Peyrin Kao Berkeley
#
#  n, name = 68, John D. Kubiatowicz ...
#
#
#  n, name = 69, Beresford N. Parlett ...
#
#
# Failed to search google scholar: Beresford Parlett, Beresford N. Parlett Berkeley
#
#  n, name = 70, Stuart J. Russell ...
#
#
#  n, name = 71, Carlo H. Séquin ...
#
#
# Failed to search google scholar: Carlo Séquin, Carlo H. Séquin Berkeley
#
#  n, name = 72, Costas J. Spanos ...
#
#
#  n, name = 73, Michael Stonebraker ...
#
#
# Failed to search google scholar: Michael Stonebraker, Michael Stonebraker Berkeley
#
#  n, name = 74, Umesh Vazirani ...
#
#
# Failed to search google scholar: Umesh Vazirani, Umesh Vazirani Berkeley
#
#  n, name = 75, Lisa Yan ...
#
#
# Failed to search google scholar: Lisa Yan, Lisa Yan Berkeley
#
#  n, name = 76, Katherine A. Yelick ...
#
#
#  n, name = 77, Justin Yokota ...
#
#
# Failed to search google scholar: Justin Yokota, Justin Yokota Berkeley
#
#  n, name = 78, Sarita V. Adve ...
#
#
#  n, name = 79, Mattox Alan Beckman ...
#
#
#  n, name = 80, Geoffrey Werner Challen ...
#
#
#  n, name = 81, Ryan Matthew Cunningham ...
#
#
#  n, name = 82, Carl Evans ...
#
#
# Failed to search google scholar: Carl Evans, Carl Evans UIUC
#
#  n, name = 83, Wade A. Fagen-Ulmschneider ...
#
#
#  n, name = 84, Christopher Wardlaw Fletcher ...
#
#
#  n, name = 85, William D. Gropp ...
#
#
#  n, name = 86, Geoffrey Lindsay Herman ...
#
#
#  n, name = 87, Derek W. Hoiem ...
#
#
#  n, name = 88, Andreas Paul Eberhard Kloeckner ...
#
#
#  n, name = 89, Marco Morales Aguirre ...
#
#
#  n, name = 90, John F. Reid ...
#
#
#  n, name = 91, Eric Gene Shaffer ...
#
#
#  n, name = 92, Makrand SINHA ...
#
#
# Failed to search google scholar: Makrand SINHA, Makrand SINHA UIUC
#
#  n, name = 93, Brad R. Solomon ...
#
#
#  n, name = 94, Sarah Gimbert Sterman ...
#
#
#  n, name = 95, Michael Joseph Woodley ...
#
#
#  n, name = 96, Kaynar, Zeliha Dilsun ...
#
#
#  n, name = 97, Yury Polyanskiy ...
#
#
# Failed to search google scholar: Yury Polyanskiy, Yury Polyanskiy MIT
#
#  n, name = 98, Michael Stonebraker ...
# Failed to search google scholar: Michael Stonebraker, Michael Stonebraker MIT
#
#  n, name = 99, Fred Kjoelstad ...
#
#
# Failed to search google scholar: Fred Kjoelstad, Fred Kjoelstad Stanford
#
#  n, name = 100, Aviad Rubinstein ...
#
#
# Failed to search google scholar: Aviad Rubinstein, Aviad Rubinstein Stanford
#
#  n, name = 101, Jean-Claude Latombe ...
#
#
# Failed to search google scholar: Jean-Claude Latombe, Jean-Claude Latombe Stanford
#
#  n, name = 102, Domenico Ferrari ...
#
#
# Failed to search google scholar: Domenico Ferrari, Domenico Ferrari Berkeley
#
#  n, name = 103, Paul N. Hilfinger ...
#
#
# Failed to search google scholar: Paul Hilfinger, Paul N. Hilfinger Berkeley
#
#  n, name = 104, Timothy Moon-Yew Chan ...
#
#
#  n, name = 105, Chandra Sekhar Chekuri ...
#
#
#  n, name = 106, Michael A. Forbes ...
#
#
#  n, name = 107, Sheldon Howard Jacobson ...
#
#
#  n, name = 108, Robin Hillary Kravets ...
#
#
#  n, name = 109, Luther Tychonievich ...
#
#
# Failed to search google scholar: Luther Tychonievich, Luther Tychonievich UIUC
#
#  n, name = 110, Victor Zue ...
#
#
# Failed to search google scholar: Victor Zue, Victor Zue MIT
#
#  n, name = 111, Anand V Natarajan ...
#
#
#  n, name = 112, Randy H. Katz ...
#
#
#  n, name = 113, Matus Jan Telgarsky ...
#
#
#  n, name = 114, Serge Plotkin ...
#
#
# Failed to search google scholar: Serge Plotkin, Serge Plotkin Stanford
#
#  n, name = 115, Michael J. Clancy ...
#
#
#  n, name = 116, David A. Patterson ...

# %% [raw]
# author

# %%
len(pub_data), len(pub_error)
# Out:
# (45, 72)

# %%
if len(pub_data) == len(pub_error):
    raise Exception("All searches failed!")

# %% [markdown]
# ## write out xlsx

# %%
df_out = pd.DataFrame(pub_data, columns=SCHOLAR_HEADER)

# %%
df_out
# Out:
#                                name  \
# 0          Vinayak, Rashmi Korlakai
# 1                    K-Y. Daisy Fan
# 2            Alexander "Sasha" Rush
# 3                     G. Edward Suh
# 4              YuFeng (Kevin)  Chen
# 5               Connor Wilson Coley
# 6                 W. Eric L Grimson
# 7         Juan Carlos Niebles Duque
# 8                     John F. Canny
# 9                   David E. Culler
# 10           Alexei (Alyosha) Efros
# 11               Richard J. Fateman
# 12                Jerome A. Feldman
# 13            Joseph M. Hellerstein
# 14              John D. Kubiatowicz
# 15                Stuart J. Russell
# 16                 Costas J. Spanos
# 17              Katherine A. Yelick
# 18                   Sarita V. Adve
# 19              Mattox Alan Beckman
# 20          Geoffrey Werner Challen
# 21          Ryan Matthew Cunningham
# 22       Wade A. Fagen-Ulmschneider
# 23     Christopher Wardlaw Fletcher
# 24                 William D. Gropp
# 25          Geoffrey Lindsay Herman
# 26                   Derek W. Hoiem
# 27  Andreas Paul Eberhard Kloeckner
# 28            Marco Morales Aguirre
# 29                     John F. Reid
# 30                Eric Gene Shaffer
# 31                  Brad R. Solomon
# 32            Sarah Gimbert Sterman
# 33           Michael Joseph Woodley
# 34            Kaynar, Zeliha Dilsun
# 35            Timothy Moon-Yew Chan
# 36           Chandra Sekhar Chekuri
# 37                Michael A. Forbes
# 38          Sheldon Howard Jacobson
# 39            Robin Hillary Kravets
# 40                Anand V Natarajan
# 41                    Randy H. Katz
# 42              Matus Jan Telgarsky
# 43                Michael J. Clancy
# 44               David A. Patterson
#
#                                           affiliation  \
# 0                     Assistant Professor, UW-Madison
# 1                              University of Kentucky
# 2             Associate Professor, Cornell University
# 3                                                KBRI
# 4                                 Unknown affiliation
# 5             Department of Chemical Engineering, MIT
# 6                           The University of Alabama
# 7                        Professor Emeritus, Duke-NUS
# 8                  University of California, Berkeley
# 9                  University of California, Berkeley
# 10                                        UC Berkeley
# 11  Emeritus Professor of Computer Science, Univer...
# 12         Professor of Computer Science, UC Berkeley
# 13  Jim Gray Professor of Computer Science, UC Ber...
# 14               University of California at Berkeley
# 15  Professor of Computer Science, University of C...
# 16  Professor of Electrical Engineering and Comput...
# 17  Associate Laboratory Director of Computing Sci...
# 18  Professor of Computer Science, University of I...
# 19  Teaching Assistant Professor, Computer Science...
# 20                             University of Illinois
# 21  Centre for Advanced Computational Science, Man...
# 22         University of Illinois at Urbana-Champaign
# 23  Assistant Professor, University of Illinois Ur...
# 24  Professor of Computer Science, University of I...
# 25                             University of Maryland
# 26  Professor of Computer Science, University of I...
# 27         University of Illinois at Urbana-Champaign
# 28  profesor de Química, Universidad Nacional Mayo...
# 29  John Curtin Distinguished Professor, Curtin & ...
# 30  Professor of Cellular Nanoscience, University ...
# 31            University of Illinois Urbana-Champaign
# 32                 Assistant Research Professor, UIUC
# 33  Independent (please note that the email accoun...
# 34  Associate Teaching Professor, Carnegie Mellon ...
# 35                                   Cleveland Clinic
# 36  Professor of Computer Science, University of I...
# 37   Associate Professor, Washington State University
# 38          University of Illinois @ Urbana-Champaign
# 39                             University of Illinois
# 40                     Assistant Professor, EECS, MIT
# 41                 University of California, Berkeley
# 42           University of Illinois, Urbana-Champaign
# 43      Professor of Politics, University of Hartford
# 44         Professor of Computer Science, UC Berkeley
#
#                                             interests  num_papers  \
# 0   Machine Learning; Statistical Inference; Crowd...          22
# 1                                Systems biochemistry         327
# 2       Natural Language Processing; Machine Learning         166
# 3                                                             893
# 4                                                             114
# 5   drug discovery; machine learning; automation; ...         129
# 6                                                              19
# 7                                          Psychiatry        1333
# 8   HCI; Ubicomp; ICTD; Data Mining; Health Techno...         435
# 9   Systems; Networks; Embedded Computing; Archite...         635
# 10  computer vision; machine learning; computer gr...         235
# 11  computer algebra; programming languages; Lisp;...         204
# 12                            Artificial Intelligence         282
# 13                     Databases; Distributed Systems         382
# 14  Computer Architecture; Operating Systems; Peer...         235
# 15                            Artificial Intelligence         573
# 16     Semiconductor Manufacturing; Energy Efficiency         463
# 17  Parallel Computing; Programming Languages; Com...         473
# 18  Computer architecture; parallel computing; com...         237
# 19                CS Education; Programming Languages          14
# 20                            Computers and Education          73
# 21  Artificial Intelligence; Machine Leraning; Neu...          30
# 22                                 Data Visualization          18
# 23  Systems; Architecture; Security; Machine Learning          99
# 24  High performance computing; HPC; Parallel comp...         826
# 25                                                            284
# 26                                                            150
# 27  Numerical Methods for PDEs; High Performance C...          50
# 28  Analítica e instrumental  en productos natural...          37
# 29          Cardiovascular disease; Outcomes Research        1590
# 30  Biophysics; optical tweezers; molecular motors...         129
# 31                                                              7
# 32  human computer interaction; creativity support...          11
# 33  Community Ecology; Behavioral Ecology; Life Hi...         165
# 34  Formal methods; Foundations of Security; Progr...          85
# 35  medicine; oncology; immunology; genomics; biology         504
# 36  Design and Analysis of Algorithms; Combinatori...         200
# 37  Theoretical Nuclear Astrophysics; Neutron Star...         102
# 38  Aviation Security; Public Policy & Public Heal...         311
# 39           Mobile Computing and Wireless Networking         197
# 40                                  Quantum computing          20
# 41  Computer Systems; Communications Networks; Dis...         687
# 42      deep learning theory; machine learning theory          54
# 43  political economy; tourism; Ireland; Mexico; s...          37
# 44                                   computer systems         974
#
#     num_coauthors  citedby  hindex  i10index  citedby5y  hindex5y  i10index5y  \
# 0               7      199       7         5        160         7           5
# 1               0    18872      60       141      10343        43         100
# 2              18    26964      56       105      24208        52          98
# 3               0    23541      81       311       6194        39         167
# 4               0     2462      28        49       1426        22          44
# 5              12     8249      39        68       8174        39          68
# 6               1      743       9         9        406         6           6
# 7               0   136306     175       772      37908        89         481
# 8               0    72850      88       230      19161        45         136
# 9              49   112366     132       347      14747        58         193
# 10            182   114954     102       152      88765        84         140
# 11             10     2097      24        45        253         7           4
# 12              0    18462      48       104       2261        13          25
# 13             94    53091     101       236      12393        56         142
# 14              0    28819      60       113       3113        24          53
# 15              0   107576      88       261      43170        56         167
# 16             51    12483      60       215       7467        47         125
# 17             26    25129      66       186       5787        37          85
# 18              0    17482      67       120       3576        30          71
# 19              0       17       3         0          9         2           0
# 20             41     7952      22        28       1293        16          22
# 21             17      265       9         9        237         9           9
# 22              0       87       4         3         54         2           1
# 23            135     5561      35        57       4224        32          50
# 24             52    54387      86       343      13823        45         140
# 25              0     5104      32        92       1657        18          33
# 26              0    25935      54        89      14591        38          75
# 27              6     2175      16        21       1134        12          13
# 28              0      211       7         5        119         5           4
# 29              8    28570      75       423      16138        53         332
# 30             73     7796      40        62       2767        29          51
# 31              0      386       6         5        351         5           5
# 32             10      213       6         6        206         6           6
# 33             37     3106      34        72       1581        21          51
# 34             23     1713      19        30        375        11          13
# 35              6    94494     125       250      72571       110         236
# 36             75    13190      57       127       4532        32          91
# 37              0     2164      27        29        947        19          28
# 38             11     9175      44       140       3268        25          68
# 39              0     9282      42        86       1166        19          29
# 40             11      583      11        11        534        11          11
# 41              0    94359     127       340      16845        49         140
# 42             21     5075      21        28       4350        19          27
# 43              0     1584      16        19        523        12          13
# 44              0   123635     121       423      34068        67         185
#
#       scholar_id                                         url_author  \
# 0   -dDKMgoAAAAJ  https://scholar.google.com/citations?user=-dDK...
# 1   2a_t2xwAAAAJ  https://scholar.google.com/citations?user=2a_t...
# 2   LIjnUGgAAAAJ  https://scholar.google.com/citations?user=LIjn...
# 3   ih5KsPkAAAAJ  https://scholar.google.com/citations?user=ih5K...
# 4   UQwjO6UAAAAJ  https://scholar.google.com/citations?user=UQwj...
# 5   l015S80AAAAJ  https://scholar.google.com/citations?user=l015...
# 6   vunn5csAAAAJ  https://scholar.google.com/citations?user=vunn...
# 7   gFBjcfMAAAAJ  https://scholar.google.com/citations?user=gFBj...
# 8   LAv0HTEAAAAJ  https://scholar.google.com/citations?user=LAv0...
# 9   urTiL7QAAAAJ  https://scholar.google.com/citations?user=urTi...
# 10  d97bGd8AAAAJ  https://scholar.google.com/citations?user=d97b...
# 11  MKANuc0AAAAJ  https://scholar.google.com/citations?user=MKAN...
# 12  30Lf1CYAAAAJ  https://scholar.google.com/citations?user=30Lf...
# 13  uFJi3IUAAAAJ  https://scholar.google.com/citations?user=uFJi...
# 14  00M1AqQAAAAJ  https://scholar.google.com/citations?user=00M1...
# 15  2oy3OXYAAAAJ  https://scholar.google.com/citations?user=2oy3...
# 16  90TaOdoAAAAJ  https://scholar.google.com/citations?user=90Ta...
# 17  93yNuV0AAAAJ  https://scholar.google.com/citations?user=93yN...
# 18  5m-oAesAAAAJ  https://scholar.google.com/citations?user=5m-o...
# 19  n9W52r0AAAAJ  https://scholar.google.com/citations?user=n9W5...
# 20  VS9wzBsAAAAJ  https://scholar.google.com/citations?user=VS9w...
# 21  dYrQtaEAAAAJ  https://scholar.google.com/citations?user=dYrQ...
# 22  v74pajgAAAAJ  https://scholar.google.com/citations?user=v74p...
# 23  QRw9-IYAAAAJ  https://scholar.google.com/citations?user=QRw9...
# 24  vB96fX8AAAAJ  https://scholar.google.com/citations?user=vB96...
# 25  VxbU-TQAAAAJ  https://scholar.google.com/citations?user=VxbU...
# 26  8Sfj7q8AAAAJ  https://scholar.google.com/citations?user=8Sfj...
# 27  WYWEZqgAAAAJ  https://scholar.google.com/citations?user=WYWE...
# 28  tDCwtgwAAAAJ  https://scholar.google.com/citations?user=tDCw...
# 29  n8XKDhIAAAAJ  https://scholar.google.com/citations?user=n8XK...
# 30  _tZ1naAAAAAJ  https://scholar.google.com/citations?user=_tZ1...
# 31  jAKeS10AAAAJ  https://scholar.google.com/citations?user=jAKe...
# 32  dXJyqiEAAAAJ  https://scholar.google.com/citations?user=dXJy...
# 33  mmoY0-kAAAAJ  https://scholar.google.com/citations?user=mmoY...
# 34  JYTiG5kAAAAJ  https://scholar.google.com/citations?user=JYTi...
# 35  0W87xxYAAAAJ  https://scholar.google.com/citations?user=0W87...
# 36  7j3itaMAAAAJ  https://scholar.google.com/citations?user=7j3i...
# 37  wPpyBHEAAAAJ  https://scholar.google.com/citations?user=wPpy...
# 38  ZLTSUtsAAAAJ  https://scholar.google.com/citations?user=ZLTS...
# 39  dACRUjgAAAAJ  https://scholar.google.com/citations?user=dACR...
# 40  7Y4nM-oAAAAJ  https://scholar.google.com/citations?user=7Y4n...
# 41  PkfChMgAAAAJ  https://scholar.google.com/citations?user=PkfC...
# 42  Fc-5yRIAAAAJ  https://scholar.google.com/citations?user=Fc-5...
# 43  q-lFwSEAAAAJ  https://scholar.google.com/citations?user=q-lF...
# 44  Wj4ZBFIAAAAJ  https://scholar.google.com/citations?user=Wj4Z...
#
#                                           url_picture  \
# 0   https://scholar.google.com/citations?view_op=m...
# 1   https://scholar.google.com/citations?view_op=m...
# 2   https://scholar.google.com/citations?view_op=m...
# 3   https://scholar.google.com/citations?view_op=m...
# 4   https://scholar.google.com/citations?view_op=m...
# 5   https://scholar.google.com/citations?view_op=m...
# 6   https://scholar.google.com/citations?view_op=m...
# 7   https://scholar.google.com/citations?view_op=m...
# 8   https://scholar.google.com/citations?view_op=m...
# 9   https://scholar.google.com/citations?view_op=m...
# 10  https://scholar.google.com/citations?view_op=m...
# 11  https://scholar.google.com/citations?view_op=m...
# 12  https://scholar.google.com/citations?view_op=m...
# 13  https://scholar.google.com/citations?view_op=m...
# 14  https://scholar.google.com/citations?view_op=m...
# 15  https://scholar.google.com/citations?view_op=m...
# 16  https://scholar.google.com/citations?view_op=m...
# 17  https://scholar.google.com/citations?view_op=m...
# 18  https://scholar.google.com/citations?view_op=m...
# 19  https://scholar.google.com/citations?view_op=m...
# 20  https://scholar.google.com/citations?view_op=m...
# 21  https://scholar.google.com/citations?view_op=m...
# 22  https://scholar.google.com/citations?view_op=m...
# 23  https://scholar.google.com/citations?view_op=m...
# 24  https://scholar.google.com/citations?view_op=m...
# 25  https://scholar.google.com/citations?view_op=m...
# 26  https://scholar.google.com/citations?view_op=m...
# 27  https://scholar.google.com/citations?view_op=m...
# 28  https://scholar.google.com/citations?view_op=m...
# 29  https://scholar.google.com/citations?view_op=m...
# 30  https://scholar.google.com/citations?view_op=m...
# 31  https://scholar.google.com/citations?view_op=m...
# 32  https://scholar.google.com/citations?view_op=m...
# 33  https://scholar.google.com/citations?view_op=m...
# 34  https://scholar.google.com/citations?view_op=m...
# 35  https://scholar.google.com/citations?view_op=m...
# 36  https://scholar.google.com/citations?view_op=m...
# 37  https://scholar.google.com/citations?view_op=m...
# 38  https://scholar.google.com/citations?view_op=m...
# 39  https://scholar.google.com/citations?view_op=m...
# 40  https://scholar.google.com/citations?view_op=m...
# 41  https://scholar.google.com/citations?view_op=m...
# 42  https://scholar.google.com/citations?view_op=m...
# 43  https://scholar.google.com/citations?view_op=m...
# 44  https://scholar.google.com/citations?view_op=m...
#
#                                          url_homepage  \
# 0                          https://ramyakv.github.io/
# 1   http://bioinformatics.cesb.uky.edu/bin/view/RC...
# 2                        http://nlp.seas.harvard.edu/
# 3
# 4
# 5                               http://coley.mit.edu/
# 6
# 7
# 8
# 9
# 10                http://www.eecs.berkeley.edu/~efros
# 11                http://www.cs.berkeley.edu/~fateman
# 12
# 13                        http://dsf.berkeley.edu/jmh
# 14               http://www.cs.berkeley.edu/~kubitron
# 15                http://www.cs.berkeley.edu/~russell
# 16
# 17
# 18
# 19
# 20                     https://cs125.cs.illinois.edu/
# 21                       https://twitter.com/ryanc_ai
# 22                       https://waf.cs.illinois.edu/
# 23                             http://cwfletcher.net/
# 24                     http://wgropp.cs.illinois.edu/
# 25             http://www.isr.umd.edu/~jwh2/jwh2.html
# 26                     http://dhoiem.cs.illinois.edu/
# 27            http://andreask.cs.illinois.edu/aboutme
# 28
# 29
# 30          http://www.zmbp.uni-tuebingen.de/res/nano
# 31
# 32
# 33               https://michaelwoodleyofmenie.co.uk/
# 34                      http://www.cs.cmu.edu/~dilsun
# 35              https://www.lerner.ccf.org/citi/chan/
# 36          http://www.cs.illinois.edu/homes/chekuri/
# 37                        https://labs.wsu.edu/forbes
# 38                        http://shj.cs.illinois.edu/
# 39                     http://mobius.cs.illinois.edu/
# 40                     http://web.mit.edu/anandn/www/
# 41                  http://www.cs.berkeley.edu/~randy
# 42                        http://mjt.cs.illinois.edu/
# 43                 http://uhaweb.hartford.edu/clancy/
# 44
#
#                                           file_author
# 0      data/GScholar_vinayak_rashmi_korlakai_cmu.json
# 1                data/GScholar_k_y_daisy_fan_nan.json
# 2         data/GScholar_alexander_sasha_rush_nan.json
# 3                 data/GScholar_g_edward_suh_nan.json
# 4            data/GScholar_yufeng_kevin_chen_mit.json
# 5          data/GScholar_connor_wilson_coley_mit.json
# 6             data/GScholar_w_eric_l_grimson_mit.json
# 7   data/GScholar_juan_carlos_niebles_duque_stanfo...
# 8            data/GScholar_john_f_canny_berkeley.json
# 9          data/GScholar_david_e_culler_berkeley.json
# 10   data/GScholar_alexei_alyosha_efros_berkeley.json
# 11      data/GScholar_richard_j_fateman_berkeley.json
# 12       data/GScholar_jerome_a_feldman_berkeley.json
# 13   data/GScholar_joseph_m_hellerstein_berkeley.json
# 14     data/GScholar_john_d_kubiatowicz_berkeley.json
# 15       data/GScholar_stuart_j_russell_berkeley.json
# 16        data/GScholar_costas_j_spanos_berkeley.json
# 17     data/GScholar_katherine_a_yelick_berkeley.json
# 18              data/GScholar_sarita_v_adve_uiuc.json
# 19        data/GScholar_mattox_alan_beckman_uiuc.json
# 20    data/GScholar_geoffrey_werner_challen_uiuc.json
# 21    data/GScholar_ryan_matthew_cunningham_uiuc.json
# 22  data/GScholar_wade_a_fagen_ulmschneider_uiuc.json
# 23  data/GScholar_christopher_wardlaw_fletcher_uiu...
# 24            data/GScholar_william_d_gropp_uiuc.json
# 25    data/GScholar_geoffrey_lindsay_herman_uiuc.json
# 26              data/GScholar_derek_w_hoiem_uiuc.json
# 27  data/GScholar_andreas_paul_eberhard_kloeckner_...
# 28      data/GScholar_marco_morales_aguirre_uiuc.json
# 29                data/GScholar_john_f_reid_uiuc.json
# 30          data/GScholar_eric_gene_shaffer_uiuc.json
# 31             data/GScholar_brad_r_solomon_uiuc.json
# 32      data/GScholar_sarah_gimbert_sterman_uiuc.json
# 33     data/GScholar_michael_joseph_woodley_uiuc.json
# 34        data/GScholar_kaynar_zeliha_dilsun_cmu.json
# 35      data/GScholar_timothy_moon_yew_chan_uiuc.json
# 36     data/GScholar_chandra_sekhar_chekuri_uiuc.json
# 37           data/GScholar_michael_a_forbes_uiuc.json
# 38    data/GScholar_sheldon_howard_jacobson_uiuc.json
# 39      data/GScholar_robin_hillary_kravets_uiuc.json
# 40           data/GScholar_anand_v_natarajan_mit.json
# 41           data/GScholar_randy_h_katz_berkeley.json
# 42        data/GScholar_matus_jan_telgarsky_uiuc.json
# 43       data/GScholar_michael_j_clancy_berkeley.json
# 44      data/GScholar_david_a_patterson_berkeley.json

# %%
# import xlsxwriter
org = "extra3" # "extra2"
file_xlsx = f"data/cs-faculty-gscholar-{org}.xlsx"
print(file_xlsx)
writer = pd.ExcelWriter(Path(file_xlsx), engine='xlsxwriter')
df_out.to_excel(writer, sheet_name=org, index=False)
writer.close()
# Out:
# data/cs-faculty-gscholar-extra3.xlsx

# %%
len(pub_error), pub_error[:10]
# Out:
# (72,
#  [array(['DeYoung, Henry', 'DeYoung, Henry CMU'], dtype=object),
#   array(['Eckhardt, Dave', 'Eckhardt, Dave CMU'], dtype=object),
#   array(['Gligor, Virgil', 'Gligor, Virgil CMU'], dtype=object),
#   array(['Jahanian, Farnam', 'Jahanian, Farnam CMU'], dtype=object),
#   array(['Kohlbrenner, Anne', 'Kohlbrenner, Anne CMU'], dtype=object),
#   array(['Kosbie, David', 'Kosbie, David CMU'], dtype=object),
#   array(['Needham, Kit', 'Needham, Kit CMU'], dtype=object),
#   array(['Sherry, Justine', 'Sherry, Justine CMU'], dtype=object),
#   array(['David Albonesi', 'David Albonesi nan'], dtype=object),
#   array(['Anne Bracy', 'Anne Bracy nan'], dtype=object)])

# %%
df_err = pd.DataFrame(pub_error, columns=["name", "name_org"])
df_err
# Out:
#                    name                    name_org
# 0        DeYoung, Henry          DeYoung, Henry CMU
# 1        Eckhardt, Dave          Eckhardt, Dave CMU
# 2        Gligor, Virgil          Gligor, Virgil CMU
# 3      Jahanian, Farnam        Jahanian, Farnam CMU
# 4     Kohlbrenner, Anne       Kohlbrenner, Anne CMU
# ..                  ...                         ...
# 67     Domenico Ferrari   Domenico Ferrari Berkeley
# 68    Paul N. Hilfinger  Paul N. Hilfinger Berkeley
# 69  Luther Tychonievich    Luther Tychonievich UIUC
# 70           Victor Zue              Victor Zue MIT
# 71        Serge Plotkin      Serge Plotkin Stanford
#
# [72 rows x 2 columns]

# %%
# import xlsxwriter
org = "error" # "extra2"
file_xlsx = f"data/cs-faculty-gscholar-{org}.xlsx"
print(file_xlsx)
writer = pd.ExcelWriter(Path(file_xlsx), engine='xlsxwriter')
df_err.to_excel(writer, sheet_name=org, index=False)
writer.close()
# Out:
# data/cs-faculty-gscholar-error.xlsx
