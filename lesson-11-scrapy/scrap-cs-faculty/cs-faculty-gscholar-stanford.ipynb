# %% [markdown]
# This notebook uses `scholarly` API (https://github.com/scholarly-python-package/scholarly) to enrich CS faculty info

# %%
from scrap_cs_faculty import *

# %% [raw]
# import re
# def normalize_str(text, non_alpha_numeric=r'[^a-z0-9]', sep="_"):
#     # Replace all non-alphanumeric chars with underscores
#     words = re.sub(non_alpha_numeric, sep, text.lower()).split(sep)
#     return sep.join([w for w in words if w])

# %% [raw]
# text = "!This has     many spaces!"
# normalized = normalize_str(text)
# print(normalized)

# %% [raw]
# def get_scholar_page(scholar_id, base_url=SCHOOL_DICT["Google-Scholar"]["url"], lang=LANG):
#     if not scholar_id:
#         return ""
#     return f"{base_url}/citations?user={scholar_id}&hl={lang}&oi=ao"

# %%
org_list = ["CMU-CS","Cornell-CS","MIT-AID","MIT-CS","Stanford-CS","UCB-CS","UIUC-CS",]

# %%
org = org_list[4]  # stanford

# %%
org2 = org.split("-")[0]

# %%
file_xlsx = f"faculty-{org}.xlsx"
xlsxf = pd.ExcelFile(file_xlsx)

# %%
xlsxf.sheet_names
# Out:
# ['Faculty']

# %%
df = xlsxf.parse('Faculty')

# %%
df
# Out:
#                      name                    job_title  phd_univ  phd_year  \
# 0             Sara Achour              Regular Faculty       NaN       NaN
# 1        Maneesh Agrawala              Regular Faculty       NaN       NaN
# 2              Alex Aiken              Regular Faculty       NaN       NaN
# 3              Nima Anari              Regular Faculty       NaN       NaN
# 4           Clark Barrett              Regular Faculty       NaN       NaN
# ..                    ...                          ...       ...       ...
# 141            Chris Hahn  Visiting and Acting Faculty       NaN       NaN
# 142          Hamed Nemati  Visiting and Acting Faculty       NaN       NaN
# 143  Dolière Francis Somé  Visiting and Acting Faculty       NaN       NaN
# 144         Marco Vassena  Visiting and Acting Faculty       NaN       NaN
# 145          Zhikun Zhang  Visiting and Acting Faculty       NaN       NaN
#
#      research_area  research_concentration  research_focus  \
# 0              NaN                     NaN             NaN
# 1              NaN                     NaN             NaN
# 2              NaN                     NaN             NaN
# 3              NaN                     NaN             NaN
# 4              NaN                     NaN             NaN
# ..             ...                     ...             ...
# 141            NaN                     NaN             NaN
# 142            NaN                     NaN             NaN
# 143            NaN                     NaN             NaN
# 144            NaN                     NaN             NaN
# 145            NaN                     NaN             NaN
#
#                                          url  img_url         phone  \
# 0                                        NaN      NaN           NaN
# 1      http://graphics.stanford.edu/~maneesh      NaN           NaN
# 2          http://theory.stanford.edu/~aiken      NaN        5-3359
# 3                      https://nimaanari.com      NaN           NaN
# 4        http://theory.stanford.edu/~barrett      NaN  650-736-0822
# ..                                       ...      ...           ...
# 141            http://www.christopherhahn.io      NaN           NaN
# 142               https://hnemati.github.io/      NaN           NaN
# 143                                      NaN      NaN           NaN
# 144  https://webspace.science.uu.nl/mvassena      NaN           NaN
# 145                     http://zhangzhk.com/      NaN           NaN
#
#                        email  cell_phone office_address        department  \
# 0       sachour@stanford.edu         NaN      Gates 484  Computer Science
# 1              @stanford.edu         NaN      Gates 364  Computer Science
# 2         aiken@stanford.edu         NaN     Gates  490  Computer Science
# 3    nima.anari@stanford.edu         NaN     Gates 168A  Computer Science
# 4       barrett@stanford.edu         NaN      Gates 488  Computer Science
# ..                       ...         ...            ...               ...
# 141        hahn@stanford.edu         NaN      Gates 481  Computer Science
# 142    hnnemati@stanford.edu         NaN      Gates 999  Computer Science
# 143     doliere@stanford.edu         NaN            NaN  Computer Science
# 144     vassena@stanford.edu         NaN      Gates 478  Computer Science
# 145      zhikun@stanford.edu         NaN            NaN  Computer Science
#
#             school
# 0    Stanford Univ
# 1    Stanford Univ
# 2    Stanford Univ
# 3    Stanford Univ
# 4    Stanford Univ
# ..             ...
# 141  Stanford Univ
# 142  Stanford Univ
# 143  Stanford Univ
# 144  Stanford Univ
# 145  Stanford Univ
#
# [146 rows x 15 columns]

# %%
names = df["name"].to_list()

# %%
len(names), names
# Out:
# (146,
#  ['Sara Achour',
#   'Maneesh Agrawala',
#   'Alex Aiken',
#   'Nima Anari',
#   'Clark Barrett',
#   'Gill Bejerano',
#   'Michael Bernstein',
#   'Jeannette Bohg',
#   'Dan Boneh',
#   'Adam Bouland',
#   'Emma Brunskill',
#   'Moses Charikar',
#   'Ron Dror',
#   'Zakir Durumeric',
#   'Dawson Engler',
#   'Stefano Ermon',
#   'Kayvon Fatahalian',
#   'Ron Fedkiw',
#   'Chelsea Finn',
#   'Emily Fox',
#   'Mike Genesereth',
#   'Noah Goodman',
#   'Carlos Guestrin',
#   'Leonidas Guibas',
#   'Patrick Hanrahan',
#   'Tatsu Hashimoto',
#   'John Hennessy',
#   'Mark Horowitz',
#   'Doug James',
#   'Dan Jurafsky',
#   'Sachin Katti',
#   'Oussama Khatib',
#   'Fred Kjoelstad',
#   'Fred Kjolstad',
#   'Sanmi Koyejo',
#   'Christos Kozyrakis',
#   'Anshul Kundaje',
#   'Monica Lam',
#   'James Landay',
#   'Jure Leskovec',
#   'Philip Levis',
#   'Fei-Fei Li',
#   'Percy Liang',
#   'Karen Liu',
#   'Tengyu Ma',
#   'Chris Manning',
#   'David Mazieres',
#   'Nick McKeown',
#   'John Mitchell',
#   'Subhasish Mitra',
#   'Kunle Olukotun',
#   'John Ousterhout',
#   'Chris Piech',
#   'Balaji Prabhakar',
#   'Chris Re',
#   'Omer Reingold',
#   'Mendel Rosenblum',
#   'Aviad Rubinstein',
#   'Dorsa Sadigh',
#   'Mehran Sahami',
#   'Aaron Sidford',
#   'Li-Yang Tan',
#   'Caroline Trippel',
#   'Greg Valiant',
#   'Ellen Vitercik',
#   'Jennifer Widom',
#   'Keith Winstein',
#   'Mary Wootters',
#   'Jiajun Wu',
#   'Daniel Yamins',
#   'Diyi Yang',
#   'Matei Zaharia',
#   'Jay Borenstein',
#   'Jerry Cain',
#   'Michael Chang',
#   'Chris Gregg',
#   'Cynthia Lee',
#   'Nick Parlante',
#   'Keith Schwarz',
#   'Julie Stanford',
#   'Nick Troccoli',
#   'Christina Wodtke',
#   'Patrick Young',
#   'Julie Zelenski',
#   'David Cheriton',
#   'Bill Dally',
#   'Tom Dienstbier',
#   'David Dill',
#   'Edward Feigenbaum',
#   'Richard Fikes',
#   'Don Knuth',
#   'Jean-Claude Latombe',
#   'Marc Levoy',
#   'Teresa Meng',
#   'Serge Plotkin',
#   'Vaughan Pratt',
#   'Eric Roberts',
#   'Kenneth Salisbury',
#   'Yoav Shoham',
#   'Jeff Ullman',
#   'Gio Wiederhold',
#   'Terry Winograd',
#   'Mohammad Akbarpour',
#   'Russ Altman',
#   'Kwabena Boahen',
#   'Sean Follmer',
#   'Jacob Fox',
#   'Surya Ganguli',
#   'Ashish Goel',
#   'Nick Haber',
#   'Patrick Hayden',
#   'Thomas Icard',
#   'Ramesh Johari',
#   'Monroe Kennedy',
#   'Mykel Kochenderfer',
#   'Michael Levitt',
#   'Scott Linderman',
#   'James McClelland',
#   'Stephen Montgomery',
#   'Marco Pavone',
#   'Roy Pea',
#   'Chris Potts',
#   'Priyanka Raina',
#   'Daniel Rubin',
#   'Camille Utterback',
#   'Ge Wang',
#   'Gordon Wetzstein',
#   'Serena Yeung',
#   'James Zou',
#   'Peter Bailis',
#   'Edward Chang',
#   'Karol Hausman',
#   'Changhoon Kim',
#   'Daphne Koller',
#   'Bill MacCartney',
#   'Andrew Ng',
#   'Juan Carlos Niebles Duque',
#   'Silvio Savarese',
#   'Sebastian Thrun',
#   'Shahar Dobzinski',
#   'Aurore Fass',
#   'Chris Hahn',
#   'Hamed Nemati',
#   'Dolière Francis Somé',
#   'Marco Vassena',
#   'Zhikun Zhang'])

# %% [markdown]
# ## fetch google scholar data for all CS faculty

# %%
SCHOLAR_HEADER = [
    'name',
    'affiliation',
    'interests',
    'num_papers',
    'num_coauthors',
    'citedby',
    'hindex',
    'i10index',
    'citedby5y',
    'hindex5y',
    'i10index5y',
    'scholar_id',
    'url_author',
    'url_picture',
    'url_homepage',
    'file_author']

# %%
ntest = -1  #  2 #

# %%
pub_data = []
for n, name in enumerate(names[:ntest]):
    if n < 5: continue 
    print(f"n, name = {n}, {name} ...")
    
    author_org = f"{name} {org2}"
    norm_auth_org = normalize_str(author_org)
    file_author = f"data/GScholar_{norm_auth_org}.json"

    try:
        search_query = scholarly.search_author(author_org)
        init_result = next(search_query)
    except Exception as ex:
        print(str(ex))
        init_result = None 
        
    if init_result is None:
        print(f"Failed search_author()")
        continue

    scholar_id = init_result.get("scholar_id", "")
    if not scholar_id:
        print(f"Missing scholar_id")
        continue        
    
    # fetch data
    author = scholarly.fill(init_result)
    
    author_dict = {}
    # fill data cell
    author_dict["name"] = name 
    author_dict["file_author"] = file_author 
    author_dict["scholar_id"] = scholar_id 
    author_dict["affiliation"] = author.get("affiliation", "")
    author_dict["interests"] = "; ".join(author.get("interests", []))
    author_dict["url_author"] = get_scholar_page(scholar_id)
    author_dict["url_picture"] = author.get("url_picture", "")
    author_dict["url_homepage"] = author.get("homepage", "")
    author_dict["citedby"] = author.get("citedby", 0)
    author_dict["citedby5y"] = author.get("citedby5y", 0)
    author_dict["hindex"] = author.get("hindex", 0)
    author_dict["hindex5y"] = author.get("hindex5y", 0)
    author_dict["i10index"] = author.get("i10index", 0)
    author_dict["i10index5y"] = author.get("i10index5y", 0)
    author_dict["num_papers"] = len(author.get("publications", []))
    author_dict["num_coauthors"] = len(author.get("coauthors", []))
      
    # fill row 
    author_data = []
    for c in SCHOLAR_HEADER:
        author_data.append(author_dict.get(c))
        
    # accumulate row
    pub_data.append(author_data)
    
    # persist author data
    with open(Path(file_author), "w", encoding="utf-8") as f:
        f.write(json.dumps(author))
    
    delay = randint(1,5)
    sleep(delay)
# Out:
# n, name = 5, Gill Bejerano ...
#
# Failed search_author()
# n, name = 6, Michael Bernstein ...
# n, name = 7, Jeannette Bohg ...
# n, name = 8, Dan Boneh ...
# n, name = 9, Adam Bouland ...
# n, name = 10, Emma Brunskill ...
# n, name = 11, Moses Charikar ...
# n, name = 12, Ron Dror ...
# n, name = 13, Zakir Durumeric ...
# n, name = 14, Dawson Engler ...
# n, name = 15, Stefano Ermon ...
# n, name = 16, Kayvon Fatahalian ...
# n, name = 17, Ron Fedkiw ...
#
# Failed search_author()
# n, name = 18, Chelsea Finn ...
# n, name = 19, Emily Fox ...
# n, name = 20, Mike Genesereth ...
# n, name = 21, Noah Goodman ...
# n, name = 22, Carlos Guestrin ...
# n, name = 23, Leonidas Guibas ...
# n, name = 24, Patrick Hanrahan ...
# n, name = 25, Tatsu Hashimoto ...
# n, name = 26, John Hennessy ...
# n, name = 27, Mark Horowitz ...
# n, name = 28, Doug James ...
# n, name = 29, Dan Jurafsky ...
# n, name = 30, Sachin Katti ...
# n, name = 31, Oussama Khatib ...
# n, name = 32, Fred Kjoelstad ...
#
# Failed search_author()
# n, name = 33, Fred Kjolstad ...
#
# Failed search_author()
# n, name = 34, Sanmi Koyejo ...
# n, name = 35, Christos Kozyrakis ...
# n, name = 36, Anshul Kundaje ...
# n, name = 37, Monica Lam ...
# n, name = 38, James Landay ...
# n, name = 39, Jure Leskovec ...
# n, name = 40, Philip Levis ...
# n, name = 41, Fei-Fei Li ...
# n, name = 42, Percy Liang ...
# n, name = 43, Karen Liu ...
#
# Failed search_author()
# n, name = 44, Tengyu Ma ...
# n, name = 45, Chris Manning ...
#
# Failed search_author()
# n, name = 46, David Mazieres ...
# n, name = 47, Nick McKeown ...
# n, name = 48, John Mitchell ...
# n, name = 49, Subhasish Mitra ...
# n, name = 50, Kunle Olukotun ...
# n, name = 51, John Ousterhout ...
# n, name = 52, Chris Piech ...
# n, name = 53, Balaji Prabhakar ...
# n, name = 54, Chris Re ...
# n, name = 55, Omer Reingold ...
# n, name = 56, Mendel Rosenblum ...
#
# Failed search_author()
# n, name = 57, Aviad Rubinstein ...
#
# Failed search_author()
# n, name = 58, Dorsa Sadigh ...
# n, name = 59, Mehran Sahami ...
# n, name = 60, Aaron Sidford ...
# n, name = 61, Li-Yang Tan ...
# n, name = 62, Caroline Trippel ...
# n, name = 63, Greg Valiant ...
# n, name = 64, Ellen Vitercik ...
# n, name = 65, Jennifer Widom ...
# n, name = 66, Keith Winstein ...
# n, name = 67, Mary Wootters ...
# n, name = 68, Jiajun Wu ...
# n, name = 69, Daniel Yamins ...
# n, name = 70, Diyi Yang ...
# n, name = 71, Matei Zaharia ...
#
# Failed search_author()
# n, name = 72, Jay Borenstein ...
#
# Failed search_author()
# n, name = 73, Jerry Cain ...
#
# Failed search_author()
# n, name = 74, Michael Chang ...
#
# Failed search_author()
# n, name = 75, Chris Gregg ...
# n, name = 76, Cynthia Lee ...
# n, name = 77, Nick Parlante ...
#
# Failed search_author()
# n, name = 78, Keith Schwarz ...
#
# Failed search_author()
# n, name = 79, Julie Stanford ...
# n, name = 80, Nick Troccoli ...
#
# Failed search_author()
# n, name = 81, Christina Wodtke ...
#
# Failed search_author()
# n, name = 82, Patrick Young ...
#
# Failed search_author()
# n, name = 83, Julie Zelenski ...
#
# Failed search_author()
# n, name = 84, David Cheriton ...
#
# Failed search_author()
# n, name = 85, Bill Dally ...
# n, name = 86, Tom Dienstbier ...
#
# Failed search_author()
# n, name = 87, David Dill ...
# n, name = 88, Edward Feigenbaum ...
#
# Failed search_author()
# n, name = 89, Richard Fikes ...
#
# Failed search_author()
# n, name = 90, Don Knuth ...
# n, name = 91, Jean-Claude Latombe ...
#
# Failed search_author()
# n, name = 92, Marc Levoy ...
# n, name = 93, Teresa Meng ...
#
# Failed search_author()
# n, name = 94, Serge Plotkin ...
#
# Failed search_author()
# n, name = 95, Vaughan Pratt ...
#
# Failed search_author()
# n, name = 96, Eric Roberts ...
#
# Failed search_author()
# n, name = 97, Kenneth Salisbury ...
# n, name = 98, Yoav Shoham ...
# n, name = 99, Jeff Ullman ...
# n, name = 100, Gio Wiederhold ...
# n, name = 101, Terry Winograd ...
#
# Failed search_author()
# n, name = 102, Mohammad Akbarpour ...
# n, name = 103, Russ Altman ...
# n, name = 104, Kwabena Boahen ...
# n, name = 105, Sean Follmer ...
# n, name = 106, Jacob Fox ...
# n, name = 107, Surya Ganguli ...
# n, name = 108, Ashish Goel ...
# n, name = 109, Nick Haber ...
# n, name = 110, Patrick Hayden ...
# n, name = 111, Thomas Icard ...
# n, name = 112, Ramesh Johari ...
# n, name = 113, Monroe Kennedy ...
# n, name = 114, Mykel Kochenderfer ...
# n, name = 115, Michael Levitt ...
# n, name = 116, Scott Linderman ...
# n, name = 117, James McClelland ...
# n, name = 118, Stephen Montgomery ...
# n, name = 119, Marco Pavone ...
# n, name = 120, Roy Pea ...
# n, name = 121, Chris Potts ...
# n, name = 122, Priyanka Raina ...
# n, name = 123, Daniel Rubin ...
# n, name = 124, Camille Utterback ...
#
# Failed search_author()
# n, name = 125, Ge Wang ...
# n, name = 126, Gordon Wetzstein ...
# n, name = 127, Serena Yeung ...
# n, name = 128, James Zou ...
# n, name = 129, Peter Bailis ...
#
# Failed search_author()
# n, name = 130, Edward Chang ...
# n, name = 131, Karol Hausman ...
# n, name = 132, Changhoon Kim ...
#
# Failed search_author()
# n, name = 133, Daphne Koller ...
#
# Failed search_author()
# n, name = 134, Bill MacCartney ...
# n, name = 135, Andrew Ng ...
# n, name = 136, Juan Carlos Niebles Duque ...
#
# Failed search_author()
# n, name = 137, Silvio Savarese ...
# n, name = 138, Sebastian Thrun ...
#
# Failed search_author()
# n, name = 139, Shahar Dobzinski ...
#
# Failed search_author()
# n, name = 140, Aurore Fass ...
# n, name = 141, Chris Hahn ...
#
# Failed search_author()
# n, name = 142, Hamed Nemati ...
# n, name = 143, Dolière Francis Somé ...
#
# Failed search_author()
# n, name = 144, Marco Vassena ...
#
# Failed search_author()

# %% [raw]
# StopIteration: n = 5 when Google scholar profile not found

# %% [raw]
# author_dict
#
#
# {'name': 'Sara Achour',
#  'file_author': 'GScholar_sara_achour_stanford.json',
#  'scholar_id': 'J-5mJ7AAAAAJ',
#  'affiliation': 'Stanford University',
#  'interests': 'programming languages; compilers; emerging hardware technologies',
#  'url_author': 'https://scholar.google.com/citations?user=J-5mJ7AAAAAJ&hl=en&oi=ao',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=J-5mJ7AAAAAJ',
#  'homepage': 'https://www.sara-achour.me/',
#  'citedby': 769,
#  'citedby5y': 541,
#  'hindex': 5,
#  'hindex5y': 5,
#  'i10index': 5,
#  'i10index5y': 4,
#  'num_coauthors': 5,
#  'num_papers': 12}

# %% [raw]
# author

# %%
len(pub_data)
# Out:
# 102

# %% [markdown]
# ## write out xlsx

# %%
df_out = pd.DataFrame(pub_data, columns=SCHOLAR_HEADER)

# %%
df_out.head()
# Out:
#                 name                                        affiliation  \
# 0  Michael Bernstein           Associate Professor, Stanford University
# 1     Jeannette Bohg           Assistant Professor, Stanford University
# 2          Dan Boneh  Professor of Computer Science, Stanford Univer...
# 3       Adam Bouland                                Stanford University
# 4     Emma Brunskill  Associate Professor of Computer Science, Stanf...
#
#                                            interests  num_papers  \
# 0       Human-computer interaction; social computing         245
# 1  Robotics; Multi-Modal Perception; Machine Lear...         135
# 2  Cryptography; Computer Security; Computer Scie...         475
# 3    Quantum Computing; Theoretical Computer Science          33
# 4  Reinforcement Learning; Machine Learning; Deci...         220
#
#    num_coauthors  citedby  hindex  i10index  citedby5y  hindex5y  i10index5y  \
# 0             73    63473      61       133      51505        53         118
# 1             96     7216      36        76       6149        33          67
# 2             18   101996     132       302      38220        89         249
# 3             44      889      15        18        762        14          17
# 4             19    10839      49       120       8636        43         105
#
#      scholar_id                                         url_author  \
# 0  zkhHirIAAAAJ  https://scholar.google.com/citations?user=zkhH...
# 1  rjnJnEkAAAAJ  https://scholar.google.com/citations?user=rjnJ...
# 2  MwLqCs4AAAAJ  https://scholar.google.com/citations?user=MwLq...
# 3  61uf9p0AAAAJ  https://scholar.google.com/citations?user=61uf...
# 4  HaN8b2YAAAAJ  https://scholar.google.com/citations?user=HaN8...
#
#                                          url_picture  \
# 0  https://scholar.google.com/citations?view_op=m...
# 1  https://scholar.google.com/citations?view_op=m...
# 2  https://scholar.google.com/citations?view_op=m...
# 3  https://scholar.google.com/citations?view_op=m...
# 4  https://scholar.google.com/citations?view_op=m...
#
#                             url_homepage  \
# 0            http://hci.stanford.edu/msb
# 1          http://web.stanford.edu/~bohg
# 2       http://crypto.stanford.edu/~dabo
# 3  http://theory.stanford.edu/~abouland/
# 4   http://cs.stanford.edu/people/ebrun/
#
#                                      file_author
# 0  data/GScholar_michael_bernstein_stanford.json
# 1     data/GScholar_jeannette_bohg_stanford.json
# 2          data/GScholar_dan_boneh_stanford.json
# 3       data/GScholar_adam_bouland_stanford.json
# 4     data/GScholar_emma_brunskill_stanford.json

# %%
# import xlsxwriter
file_xlsx = f"data/cs-faculty-gscholar-{org2}-{n}.xlsx"
writer = pd.ExcelWriter(Path(file_xlsx), engine='xlsxwriter')
df_out.to_excel(writer, sheet_name=org2, index=False)
writer.save()
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_15664\4019838328.py:5: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
