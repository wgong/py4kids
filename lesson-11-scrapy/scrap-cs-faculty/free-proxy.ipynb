# %%
from fp.fp import FreeProxy

# %%
proxy = FreeProxy(
        country_id=['US'],
        rand=True,
#         google=True,
        https=True,        
    ).get()

proxy
# Out:
# 'http://209.79.65.132:8080'
