# %% [markdown]
# https://github.com/scholarly-python-package/scholarly

# %%
from scholarly import scholarly

# %%
author_org = "Karthik Sridharan cornell"
search_query = scholarly.search_author(author_org)

# %%
# Retrieve the author's data, fill-in, and print
# Get an iterator for the author results
# search_query = scholarly.search_author('Steven A Cholewiak')
# Retrieve the first result from the iterator
first_author_result = next(search_query)

# %%
first_author_result
# Out:
# {'container_type': 'Author',
#  'filled': [],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'nX9D5AoAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nX9D5AoAAAAJ',
#  'name': 'Karthik Sridharan',
#  'affiliation': 'Cornell University, University of Pennsylvania, Toyota Technological Institute',
#  'email_domain': '@ttic.edu',
#  'interests': ['Learning Theory',
#   'Machine Learning',
#   'Optimization',
#   'Reinforcement Learning'],
#  'citedby': 7585}

# %%
first_author_result
# Out:
# {'container_type': 'Author',
#  'filled': ['basics',
#   'indices',
#   'counts',
#   'coauthors',
#   'publications',
#   'public_access'],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'nX9D5AoAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nX9D5AoAAAAJ',
#  'name': 'Karthik Sridharan',
#  'affiliation': 'Cornell University, University of Pennsylvania, Toyota Technological Institute',
#  'email_domain': '@ttic.edu',
#  'interests': ['Learning Theory',
#   'Machine Learning',
#   'Optimization',
#   'Reinforcement Learning'],
#  'citedby': 7585,
#  'homepage': 'http://www.cs.cornell.edu/~sridharan/research.html',
#  'citedby5y': 5163,
#  'hindex': 41,
#  'hindex5y': 36,
#  'i10index': 63,
#  'i10index5y': 56,
#  'cites_per_year': {2009: 31,
#   2010: 55,
#   2011: 103,
#   2012: 180,
#   2013: 270,
#   2014: 304,
#   2015: 377,
#   2016: 514,
#   2017: 518,
#   2018: 566,
#   2019: 717,
# ...

# %%
# Retrieve all the details for the author
author = scholarly.fill(first_author_result )

# %%
author
# Out:
# {'container_type': 'Author',
#  'filled': ['basics',
#   'indices',
#   'counts',
#   'coauthors',
#   'publications',
#   'public_access'],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'nX9D5AoAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nX9D5AoAAAAJ',
#  'name': 'Karthik Sridharan',
#  'affiliation': 'Cornell University, University of Pennsylvania, Toyota Technological Institute',
#  'email_domain': '@ttic.edu',
#  'interests': ['Learning Theory',
#   'Machine Learning',
#   'Optimization',
#   'Reinforcement Learning'],
#  'citedby': 7585,
#  'homepage': 'http://www.cs.cornell.edu/~sridharan/research.html',
#  'citedby5y': 5163,
#  'hindex': 41,
#  'hindex5y': 36,
#  'i10index': 63,
#  'i10index5y': 56,
#  'cites_per_year': {2009: 31,
#   2010: 55,
#   2011: 103,
#   2012: 180,
#   2013: 270,
#   2014: 304,
#   2015: 377,
#   2016: 514,
#   2017: 518,
#   2018: 566,
#   2019: 717,
# ...

# %%
author
# Out:
# {'container_type': 'Author',
#  'filled': ['basics',
#   'indices',
#   'counts',
#   'coauthors',
#   'publications',
#   'public_access'],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'nX9D5AoAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nX9D5AoAAAAJ',
#  'name': 'Karthik Sridharan',
#  'affiliation': 'Cornell University, University of Pennsylvania, Toyota Technological Institute',
#  'email_domain': '@ttic.edu',
#  'interests': ['Learning Theory',
#   'Machine Learning',
#   'Optimization',
#   'Reinforcement Learning'],
#  'citedby': 7585,
#  'homepage': 'http://www.cs.cornell.edu/~sridharan/research.html',
#  'citedby5y': 5163,
#  'hindex': 41,
#  'hindex5y': 36,
#  'i10index': 63,
#  'i10index5y': 56,
#  'cites_per_year': {2009: 31,
#   2010: 55,
#   2011: 103,
#   2012: 180,
#   2013: 270,
#   2014: 304,
#   2015: 377,
#   2016: 514,
#   2017: 518,
#   2018: 566,
#   2019: 717,
# ...

# %%
print(f"total number of pubs: {len(author['publications'])}")  # verified
# Out:
# total number of pubs: 94

# %%
# Take a closer look at the first publication
first_publication = author['publications'][0]
first_publication_filled = scholarly.fill(first_publication)

# %%
first_publication_filled
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#  'bib': {'title': 'Multi-view clustering via canonical correlation analysis',
#   'pub_year': 2009,
#   'citation': 'Proceedings of the 26th annual international conference on machine learning …, 2009',
#   'author': 'Kamalika Chaudhuri and Sham M Kakade and Karen Livescu and Karthik Sridharan',
#   'pages': '129-136',
# ...

# %%
# Print the titles of the author's publications
publication_titles = [pub['bib']['title'] for pub in author['publications']]

# %%
print("\n".join(publication_titles))
# Out:
# Multi-view clustering via canonical correlation analysis
# Making gradient descent optimal for strongly convex stochastic optimization
# Learnability, stability and uniform convergence
# On the complexity of linear prediction: Risk bounds, margin bounds, and regularization
# Better mini-batch algorithms via accelerated gradient methods
# Optimization, learning, and games with predictable sequences
# Stochastic Convex Optimization.
# Smoothness, low noise and fast rates
# Online learning with predictable sequences
# Online optimization: Competing with dynamic comparators
# Fast rates for regularized objectives
# On the universality of online mirror descent
# Online learning: Random averages, combinatorial parameters, and learnability
# Optimization with Non-Differentiable Constraints with Applications to Fairness, Recall, Churn, and Other Goals.
# An information theoretic framework for multi-view learning
# Two-player games for efficient non-convex constrained optimization
# ...

# %% [markdown]
# the first paper cited 891 times, takes too long and failed

# %%
# Which papers cited that publication?
citations = [citation['bib']['title'] for citation in scholarly.citedby(first_publication_filled)]
# Out:
# ---------------------------------------------------------------------------
# MaxTriesExceededException                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15616\35465845.py in <module>
#       1 # Which papers cited that publication?
# ----> 2 citations = [citation['bib']['title'] for citation in scholarly.citedby(first_publication_filled)]
#
# ~\AppData\Local\Temp\ipykernel_15616\35465845.py in <listcomp>(.0)
#       1 # Which papers cited that publication?
# ----> 2 citations = [citation['bib']['title'] for citation in scholarly.citedby(first_publication_filled)]
#
# ~\projects\research\scholarly\scholarly\publication_parser.py in __next__(self)
#      88                 class_='gs_ico gs_ico_nav_next').parent['href']
#      89             self._url = url
# ---> 90             self._load_url(url)
#      91             return self.__next__()
#      92         else:
#
# ...

# %%
print(citations)
