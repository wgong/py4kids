# %% [markdown]
# - Documentation
#     - [Getting Started Developing with Python and DynamoDB](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStarted.Python.html)
#     - [Query Data Examples](https://www.fernandomc.com/posts/ten-examples-of-getting-data-from-dynamodb-with-python-and-boto3/);  [CheatSheet](https://dynobase.dev/dynamodb-python-with-boto3/)
#
#
# - [Setting Up DynamoDB Local](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/DynamoDBLocal.html)
#
# ```
# $ cat start_dynamodb
# java -Djava.library.path=~/projects/aws-cert/dynamodb/DynamoDBLocal_lib -jar ~/projects/aws-cert/dynamodb/DynamoDBLocal.jar -sharedDb
#
# export DYNAMO_ENDPOINT="http://localhost:8000"
#
# ```
#
# - [A GUI for Local DynamoDB— dynamodb-admin](https://medium.com/swlh/a-gui-for-local-dynamodb-dynamodb-admin-b16998323f8e)
#
# ```
# $ sudo npm install -g npm
# $ dynamodb-admin
#
# dynamodb-admin listening on http://localhost:8001
# ```

# %%
from __future__ import print_function # Python 2/3 compatibility
import json
import decimal

import boto3
from boto3.dynamodb.conditions import Key,Attr
from botocore.exceptions import ClientError

# Helper class to convert a DynamoDB item to JSON.
class DecimalEncoder(json.JSONEncoder):
    def default(self, o):
        if isinstance(o, decimal.Decimal):
            if abs(o) % 1 > 0:
                return float(o)
            else:
                return int(o)
        return super(DecimalEncoder, self).default(o)

# %% [markdown]
# ### Step 0: List Tables

# %%
DYNAMO_ENDPOINT = "http://localhost:8000"

# Get the service resource.
dynamodb = boto3.resource('dynamodb', endpoint_url=DYNAMO_ENDPOINT)

# %%
table_names = [table.name for table in dynamodb.tables.all()]
table_names
# Out:
# ['Movies', 'UserImages']

# %% [markdown]
# ### [Step 1: Create a Table](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStarted.Python.01.html)

# %%
TABLE_NAME = 'Movies'

# %%
def create_movie_table(table_name, dynamodb=None):
    if not dynamodb:
        dynamodb = boto3.resource('dynamodb', endpoint_url=DYNAMO_ENDPOINT)
        
    try:
        table = dynamodb.Table(table_name)
        status = table.table_status
    except:

        # Error thrown when creating a pre-existing table
        # ResourceInUseException: An error occurred (ResourceInUseException) when calling the CreateTable operation: 
        # Cannot create preexisting table
        table = dynamodb.create_table(
            TableName=table_name,
            KeySchema=[
                {
                    'AttributeName': 'year',
                    'KeyType': 'HASH'  # Partition key
                },
                {
                    'AttributeName': 'title',
                    'KeyType': 'RANGE'  # Sort key
                }
            ],
            AttributeDefinitions=[
                {
                    'AttributeName': 'year',
                    'AttributeType': 'N'
                },
                {
                    'AttributeName': 'title',
                    'AttributeType': 'S'
                },

            ],
            ProvisionedThroughput={
                'ReadCapacityUnits': 5,
                'WriteCapacityUnits': 5
            }
        )
    return table

# %%
def load_movies(movies, table_name='Movies', dynamodb=None):
    if not dynamodb:
        dynamodb = boto3.resource('dynamodb', endpoint_url="http://localhost:8000")

    table = dynamodb.Table(table_name)
    with table.batch_writer() as batch:
        for movie in movies:
            year = int(movie['year'])
            title = movie['title']
            print("Adding movie:", year, title)
            batch.put_item(Item=movie)

# %%
table = create_movie_table(table_name=TABLE_NAME, dynamodb=dynamodb)
print("Table status:", table.table_status)
# Out:
# Table status: ACTIVE

# %% [markdown]
# ### [Step 2: Load Sample Data](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStarted.Python.02.html)

# %%
with open("moviedata.json") as json_file:
    movie_list = json.load(json_file, parse_float=decimal.Decimal)
load_movies(movie_list, table_name=TABLE_NAME)
# Out:
# Adding movie: 2013 Rush
# Adding movie: 2013 Prisoners
# Adding movie: 2013 The Hunger Games: Catching Fire
# Adding movie: 2013 Thor: The Dark World
# Adding movie: 2013 This Is the End
# Adding movie: 2013 Insidious: Chapter 2
# Adding movie: 2013 World War Z
# Adding movie: 2014 X-Men: Days of Future Past
# Adding movie: 2014 Transformers: Age of Extinction
# Adding movie: 2013 Now You See Me
# Adding movie: 2013 Gravity
# Adding movie: 2013 We're the Millers
# Adding movie: 2013 Riddick
# Adding movie: 2013 The Family
# Adding movie: 2013 Star Trek Into Darkness
# Adding movie: 2013 After Earth
# Adding movie: 2013 The Great Gatsby
# Adding movie: 2014 Divergent
# Adding movie: 2013 We Are What We Are
# Adding movie: 2013 Iron Man 3
# Adding movie: 2014 The Amazing Spider-Man 2
# Adding movie: 2013 Curse of Chucky
# Adding movie: 2013 The Conjuring
# Adding movie: 2013 Oldboy
# Adding movie: 2013 Escape Plan
# Adding movie: 2013 Elysium
# Adding movie: 2013 Cloudy with a Chance of Meatballs 2
# Adding movie: 2014 RoboCop
# Adding movie: 2013 Carrie
# Adding movie: 2013 The Mortal Instruments: City of Bones
# Adding movie: 2014 Captain America: The Winter Soldier
# Adding movie: 2014 Need for Speed
# Adding movie: 2013 Runner Runner
# Adding movie: 2013 I Spit on Your Grave 2
# Adding movie: 2013 Battle of the Year
# Adding movie: 2013 Behind the Candelabra
# Adding movie: 2013 No se Aceptan Devoluciones
# Adding movie: 2013 The Bling Ring
# Adding movie: 2013 Furious 6
# Adding movie: 2013 Machete Kills
# Adding movie: 2013 12 Years a Slave
# Adding movie: 2013 The World's End
# Adding movie: 2012 Pitch Perfect
# Adding movie: 2013 Epic
# Adding movie: 2012 The Avengers
# Adding movie: 2013 Metallica Through the Never
# Adding movie: 2013 Oblivion
# Adding movie: 2013 Dom Hemingway
# Adding movie: 2013 The Hangover Part III
# Adding movie: 2013 Despicable Me 2
# Adding movie: 2013 The Butler
# Adding movie: 2014 Dumb and Dumber To
# Adding movie: 2013 Blue Jasmine
# Adding movie: 2013 Ender's Game
# Adding movie: 2013 White House Down
# Adding movie: 2013 Pain & Gain
# Adding movie: 2013 2 Guns
# Adding movie: 2012 The Dark Knight Rises
# Adding movie: 2012 The Place Beyond the Pines
# Adding movie: 2014 Fast & Furious 7
# Adding movie: 2013 jOBS
# Adding movie: 2012 Disconnect
# Adding movie: 2011 Bridesmaids
# Adding movie: 2013 Man of Steel
# Adding movie: 2013 Ghost Team One
# Adding movie: 2010 Insidious
# Adding movie: 2014 Godzilla
# Adding movie: 2012 Wreck-It Ralph
# Adding movie: 2013 The Hobbit: The Desolation of Smaug
# Adding movie: 2013 Frozen
# Adding movie: 2012 Spring Breakers
# Adding movie: 2014 Fifty Shades of Grey
# Adding movie: 2012 Silver Linings Playbook
# Adding movie: 2013 R.I.P.D.
# Adding movie: 1994 The Shawshank Redemption
# Adding movie: 2013 Pacific Rim
# Adding movie: 2012 The Hunger Games
# Adding movie: 2013 The Last Days on Mars
# Adding movie: 2013 Baggage Claim
# Adding movie: 2013 Percy Jackson: Sea of Monsters
# Adding movie: 2012 Byzantium
# Adding movie: 2011 X-Men: First Class
# Adding movie: 1993 Hocus Pocus
# Adding movie: 2013 The East
# Adding movie: 2013 V/H/S/2
# Adding movie: 2013 The Croods
# Adding movie: 2013 Olympus Has Fallen
# Adding movie: 2013 Hummingbird
# Adding movie: 2013 About Time
# Adding movie: 2012 Mud
# Adding movie: 2012 Argo
# Adding movie: 2012 Django Unchained
# Adding movie: 2013 Grown Ups 2
# Adding movie: 2008 The Dark Knight
# Adding movie: 2013 Planes
# Adding movie: 2013 Captain Phillips
# Adding movie: 2012 The Hobbit: An Unexpected Journey
# Adding movie: 2014 Guardians of the Galaxy
# Adding movie: 2012 Les Miserables
# Adding movie: 2013 The Kings of Summer
# Adding movie: 2009 Mr. Nobody
# Adding movie: 2013 The Fifth Estate
# Adding movie: 1997 Titanic
# Adding movie: 2004 The Incredibles
# Adding movie: 2014 Into the Woods
# Adding movie: 1994 Pulp Fiction
# Adding movie: 2013 The Call
# Adding movie: 2013 Side Effects
# Adding movie: 2012 The Iceman
# Adding movie: 1939 The Wizard of Oz
# Adding movie: 2013 Big Sur
# Adding movie: 1985 The Breakfast Club
# Adding movie: 2010 Inception
# Adding movie: 2012 Hitchcock
# Adding movie: 2014 The Expendables 3
# Adding movie: 2013 The Wolverine
# Adding movie: 2013 The Purge
# Adding movie: 2013 Safe Haven
# Adding movie: 2012 The Perks of Being a Wallflower
# Adding movie: 2009 Star Trek
# Adding movie: 2013 One Direction: This Is Us
# Adding movie: 2012 Cloud Atlas
# Adding movie: 2011 Harry Potter and the Deathly Hallows: Part 2
# Adding movie: 2013 Empire State
# Adding movie: 2013 The Frozen Ground
# Adding movie: 2013 The Wolf of Wall Street
# Adding movie: 2011 Thor
# Adding movie: 2010 I Spit on Your Grave
# Adding movie: 2004 The Notebook
# Adding movie: 2012 Looper
# Adding movie: 2013 The Spectacular Now
# Adding movie: 2013 The Heat
# Adding movie: 2009 Inglourious Basterds
# Adding movie: 1972 The Godfather
# Adding movie: 2013 Filth
# Adding movie: 1999 Fight Club
# Adding movie: 2013 Escape from Tomorrow
# Adding movie: 1976 Carrie
# Adding movie: 2013 Enough Said
# Adding movie: 2012 Prometheus
# Adding movie: 2006 The Departed
# Adding movie: 1994 Dumb & Dumber
# Adding movie: 2013 Romeo and Juliet
# Adding movie: 2009 Cloudy with a Chance of Meatballs
# Adding movie: 2013 CBGB
# Adding movie: 2013 The Counselor
# Adding movie: 2013 Kill Your Darlings
# Adding movie: 2013 Only God Forgives
# Adding movie: 2013 Evil Dead
# Adding movie: 2012 Stuck in Love
# Adding movie: 2013 Bad Grandpa
# Adding movie: 2011 You're Next
# Adding movie: 2011 Crazy, Stupid, Love.
# Adding movie: 2006 300
# Adding movie: 2011 Conan the Barbarian
# Adding movie: 2013 Scenic Route
# Adding movie: 2012 Zero Dark Thirty
# Adding movie: 2011 The Awakening
# Adding movie: 2012 The Twilight Saga: Breaking Dawn - Part 2
# Adding movie: 2008 Iron Man
# Adding movie: 2013 Oz the Great and Powerful
# Adding movie: 2010 Despicable Me
# Adding movie: 2013 Movie 43
# Adding movie: 2013 Warm Bodies
# Adding movie: 2012 Flight
# Adding movie: 2014 I, Frankenstein
# Adding movie: 2013 G.I. Joe: Retaliation
# Adding movie: 2014 300: Rise of an Empire
# Adding movie: 2001 The Lord of the Rings: The Fellowship of the Ring
# Adding movie: 2013 Red 2
# Adding movie: 2013 Anchorman 2: The Legend Continues
# Adding movie: 2012 Dredd
# Adding movie: 2013 The Smurfs 2
# Adding movie: 2001 Harry Potter and the Sorcerer's Stone
# Adding movie: 2012 21 Jump Street
# Adding movie: 1980 The Shining
# Adding movie: 2012 The Cabin in the Woods
# Adding movie: 2013 Turbo
# Adding movie: 2013 The Lone Ranger
# Adding movie: 2011 Moneyball
# Adding movie: 2001 Donnie Darko
# Adding movie: 2011 Drive
# Adding movie: 2013 The Internship
# Adding movie: 2012 Skyfall
# Adding movie: 2004 Mean Girls
# Adding movie: 2006 The Prestige
# Adding movie: 2011 Intouchables
# Adding movie: 2013 Nebraska
# Adding movie: 2013 Zero Charisma
# Adding movie: 2013 American Hustle
# Adding movie: 1985 Back to the Future
# Adding movie: 2013 Adore
# Adding movie: 2000 Requiem for a Dream
# Adding movie: 2013 Monsters University
# Adding movie: 2013 Parkland
# Adding movie: 2010 She's Out of My League
# Adding movie: 1999 American Beauty
# Adding movie: 2013 Homefront
# Adding movie: 2012 Magic Mike
# Adding movie: 2009 The Hangover
# Adding movie: 2012 Lawless
# Adding movie: 2014 Teenage Mutant Ninja Turtles
# Adding movie: 2011 Pirates of the Caribbean: On Stranger Tides
# Adding movie: 2013 Trance
# Adding movie: 2013 One Chance
# Adding movie: 2013 The Colony
# Adding movie: 2003 Love Actually
# Adding movie: 2012 Ted
# Adding movie: 2014 Maleficent
# Adding movie: 2008 Twilight
# Adding movie: 2014 The Giver
# Adding movie: 2014 Edge of Tomorrow
# Adding movie: 1977 Star Wars
# Adding movie: 2011 In Time
# Adding movie: 2005 Batman Begins
# Adding movie: 2013 42
# Adding movie: 2013 The Host
# Adding movie: 2014 Neighbors
# Adding movie: 2007 Into the Wild
# Adding movie: 2000 Pitch Black
# Adding movie: 2013 Hansel & Gretel: Witch Hunters
# Adding movie: 2012 The Amazing Spider-Man
# Adding movie: 2005 Sin City
# Adding movie: 2013 The Way Way Back
# Adding movie: 1991 The Silence of the Lambs
# Adding movie: 2003 Pirates of the Caribbean: The Curse of the Black Pearl
# Adding movie: 2013 Generation Iron
# Adding movie: 2011 The Help
# Adding movie: 1993 Schindler's List
# Adding movie: 2011 No Strings Attached
# Adding movie: 2014 The Maze Runner
# Adding movie: 2013 Stoker
# Adding movie: 2013 Lone Survivor
# Adding movie: 1990 Goodfellas
# Adding movie: 2011 Warrior
# Adding movie: 2009 Couples Retreat
# Adding movie: 2011 Captain America: The First Avenger
# Adding movie: 2013 Paranoia
# Adding movie: 2012 Jagten
# Adding movie: 1998 The Big Lebowski
# Adding movie: 2000 Remember the Titans
# Adding movie: 1987 The Princess Bride
# Adding movie: 1982 Blade Runner
# Adding movie: 2013 Austenland
# Adding movie: 1993 Jurassic Park
# Adding movie: 2013 C.O.G.
# Adding movie: 1995 Se7en
# Adding movie: 2010 The Town
# Adding movie: 2013 Gangster Squad
# Adding movie: 2012 Rock of Ages
# Adding movie: 2001 Zoolander
# Adding movie: 2003 Finding Nemo
# Adding movie: 2009 (500) Days of Summer
# Adding movie: 1966 Il buono, il brutto, il cattivo.
# Adding movie: 2012 Life of Pi
# Adding movie: 2013 The Big Wedding
# Adding movie: 1999 The Matrix
# Adding movie: 2014 Vampire Academy
# Adding movie: 2010 Iron Man 2
# Adding movie: 1994 Forrest Gump
# Adding movie: 2013 Parker
# Adding movie: 2004 The Chronicles of Riddick
# Adding movie: 1994 The Lion King
# Adding movie: 2012 Jack Reacher
# Adding movie: 2011 The Girl with the Dragon Tattoo
# Adding movie: 2009 Avatar
# Adding movie: 2012 End of Watch
# Adding movie: 2012 Snow White and the Huntsman
# Adding movie: 2013 Mama
# Adding movie: 2012 This Is 40
# Adding movie: 2007 Superbad
# Adding movie: 2012 Much Ado About Nothing
# Adding movie: 2013 Last Vegas
# Adding movie: 2010 Black Swan
# Adding movie: 2011 Drive Angry
# Adding movie: 2007 Ratatouille
# Adding movie: 2010 Grown Ups
# Adding movie: 2000 Gladiator
# Adding movie: 2012 Hotel Transylvania
# Adding movie: 2009 The Lovely Bones
# Adding movie: 2011 Horrible Bosses
# Adding movie: 2012 The Expendables 2
# Adding movie: 2009 G.I. Joe: The Rise of Cobra
# Adding movie: 1989 The Little Mermaid
# Adding movie: 2013 Before Midnight
# Adding movie: 2012 The Lords of Salem
# Adding movie: 2009 Watchmen
# Adding movie: 1998 Saving Private Ryan
# Adding movie: 2006 X-Men: The Last Stand
# Adding movie: 2012 Lincoln
# Adding movie: 2014 Dawn of the Planet of the Apes
# Adding movie: 1985 Pee-wee's Big Adventure
# Adding movie: 2011 Something Borrowed
# Adding movie: 2002 Cidade de Deus
# Adding movie: 2012 Savages
# Adding movie: 1999 Sleepy Hollow
# Adding movie: 1984 Sixteen Candles
# Adding movie: 2007 There Will Be Blood
# Adding movie: 2012 Rise of the Guardians
# Adding movie: 2012 Sinister
# Adding movie: 1985 The Goonies
# Adding movie: 2013 Beautiful Creatures
# Adding movie: 2003 Oldeuboi
# Adding movie: 2004 Eternal Sunshine of the Spotless Mind
# Adding movie: 1997 Good Will Hunting
# Adding movie: 2010 Alice in Wonderland
# Adding movie: 2004 Troy
# Adding movie: 2007 Shooter
# Adding movie: 2010 Percy Jackson & the Olympians: The Lightning Thief
# Adding movie: 2012 Dark Shadows
# Adding movie: 2010 Scott Pilgrim vs. the World
# Adding movie: 2011 Sucker Punch
# Adding movie: 1975 One Flew Over the Cuckoo's Nest
# Adding movie: 2013 Scary MoVie
# Adding movie: 1998 American History X
# Adding movie: 1995 The Usual Suspects
# Adding movie: 1982 E.T. the Extra-Terrestrial
# Adding movie: 2003 The Lord of the Rings: The Return of the King
# Adding movie: 2014 Sin City: A Dame to Kill For
# Adding movie: 1983 Scarface
# Adding movie: 1971 A Clockwork Orange
# Adding movie: 2013 Grudge Match
# Adding movie: 2013 The Secret Life of Walter Mitty
# Adding movie: 2005 V for Vendetta
# Adding movie: 2013 Drinking Buddies
# Adding movie: 2008 Pineapple Express
# Adding movie: 2013 Jack Ryan: Shadow One
# Adding movie: 2000 Memento
# Adding movie: 2013 Europa Report
# Adding movie: 2013 How I Live Now
# Adding movie: 2008 Cloverfield
# Adding movie: 2010 Easy A
# Adding movie: 2004 The Punisher
# Adding movie: 2012 Lo imposible
# Adding movie: 1994 Leon
# Adding movie: 1989 Dead Poets Society
# Adding movie: 2014 Noah
# Adding movie: 2010 Tangled
# Adding movie: 2010 The Social Network
# Adding movie: 2011 Paul
# Adding movie: 2000 American Psycho
# Adding movie: 2010 Love & Other Drugs
# Adding movie: 2014 About Last Night
# Adding movie: 2000 The Emperor's New Groove
# Adding movie: 2013 Jack the Giant Slayer
# Adding movie: 1982 Star Trek: The Wrath of Khan
# Adding movie: 1995 Heat
# Adding movie: 1999 10 Things I Hate About You
# Adding movie: 2005 Star Wars: Episode III - Revenge of the Sith
# Adding movie: 2007 No Country for Old Men
# Adding movie: 1978 Grease
# Adding movie: 2011 Limitless
# Adding movie: 2009 Zombieland
# Adding movie: 2010 Shutter Island
# Adding movie: 2002 Lilo & Stitch
# Adding movie: 2013 Blue Caprice
# Adding movie: 2011 50/50
# Adding movie: 2004 Anchorman: The Legend of Ron Burgundy
# Adding movie: 2010 How to Train Your Dragon
# Adding movie: 2013 Killing Season
# Adding movie: 2012 Moonrise Kingdom
# Adding movie: 2016 Pirates of the Caribbean: Dead Men Tell No Tales
# Adding movie: 2013 Identity Thief
# Adding movie: 2005 Harry Potter and the Goblet of Fire
# Adding movie: 1987 RoboCop
# Adding movie: 2014 The Fault in Our Stars
# Adding movie: 2006 Inside Man
# Adding movie: 1983 The Outsiders
# Adding movie: 2013 47 Ronin
# Adding movie: 2010 Burlesque
# Adding movie: 2012 John Carter
# Adding movie: 2013 All Is Lost
# Adding movie: 1957 12 Angry Men
# Adding movie: 2012 V/H/S
# Adding movie: 2009 X-Men Origins: Wolverine
# Adding movie: 2000 Snatch.
# Adding movie: 1996 Independence Day
# Adding movie: 2013 +1
# Adding movie: 1996 Romeo + Juliet
# Adding movie: 1975 The Rocky Horror Picture Show
# Adding movie: 2013 Getaway
# Adding movie: 2005 Hooligans
# Adding movie: 2012 Total Recall
# Adding movie: 2007 28 Weeks Later
# Adding movie: 1992 Reservoir Dogs
# Adding movie: 1993 Dazed and Confused
# Adding movie: 2002 Spider-Man
# Adding movie: 2006 The Covenant
# Adding movie: 2012 Battleship
# Adding movie: 2001 Ocean's Eleven
# Adding movie: 2001 Sen to Chihiro no kamikakushi
# Adding movie: 2011 The Inbetweeners Movie
# Adding movie: 2001 The Fast and the Furious
# Adding movie: 2012 Ruby Sparks
# Adding movie: 1986 Top Gun
# Adding movie: 2014 Foxcatcher
# Adding movie: 1991 Terminator 2: Judgment Day
# Adding movie: 2004 Man on Fire
# Adding movie: 2005 Brokeback Mountain
# Adding movie: 1986 Stand by Me
# Adding movie: 2011 Midnight in Paris
# Adding movie: 2012 The Vow
# Adding movie: 2013 Snitch
# Adding movie: 2013 Broken City
# Adding movie: 2011 Fast Five
# Adding movie: 1979 Alien
# Adding movie: 2011 Abduction
# Adding movie: 2009 The Blind Side
# Adding movie: 2013 21 & Over
# Adding movie: 2005 Pride & Prejudice
# Adding movie: 2007 Transformers
# Adding movie: 2005 The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# Adding movie: 2013 Dark Skies
# Adding movie: 2012 That's My Boy
# Adding movie: 2012 Seven Psychopaths
# Adding movie: 2011 I Am Number Four
# Adding movie: 1990 Teenage Mutant Ninja Turtles
# Adding movie: 2004 Million Dollar Baby
# Adding movie: 1979 Apocalypse Now
# Adding movie: 2012 Men in Black 3
# Adding movie: 1996 Trainspotting
# Adding movie: 2009 Fast & Furious
# Adding movie: 2007 Knocked Up
# Adding movie: 2012 The Company You Keep
# Adding movie: 2005 War of the Worlds
# Adding movie: 2001 A Beautiful Mind
# Adding movie: 2004 King Arthur
# Adding movie: 2012 Red Dawn
# Adding movie: 2010 Red
# Adding movie: 1974 The Godfather: Part II
# Adding movie: 2011 Melancholia
# Adding movie: 2011 Transformers: Dark of the Moon
# Adding movie: 2011 Immortals
# Adding movie: 2007 Zodiac
# Adding movie: 2013 The Incredible Burt Wonderstone
# Adding movie: 2008 Taken
# Adding movie: 2013 The Book Thief
# Adding movie: 2013 Dallas Buyers Club
# Adding movie: 2013 All Is Bright
# Adding movie: 2012 The Master
# Adding movie: 2011 One Day
# Adding movie: 2013 Phata Poster Nikhla Hero
# Adding movie: 2007 Enchanted
# Adding movie: 1999 Star Wars: Episode I - The Phantom Menace
# Adding movie: 2010 Never Let Me Go
# Adding movie: 2000 X-Men
# Adding movie: 2010 Toy Story 3
# Adding movie: 2014 Seventh Son
# Adding movie: 2011 The Descendants
# Adding movie: 2013 The Monuments Men
# Adding movie: 2011 Unknown
# Adding movie: 2013 Out of the Furnace
# Adding movie: 2002 The Ring
# Adding movie: 2009 The Road
# Adding movie: 2012 Project X
# Adding movie: 2011 Real Steel
# Adding movie: 2013 Enemy
# Adding movie: 2014 The Lego Movie
# Adding movie: 1955 East of Eden
# Adding movie: 2003 Big Fish
# Adding movie: 2011 Just Go with It
# Adding movie: 2013 Yi dai zong shi
# Adding movie: 2011 Mission: Impossible - Ghost Protocol
# Adding movie: 1973 The Exorcist
# Adding movie: 2012 Brave
# Adding movie: 2014 Interstellar
# Adding movie: 2007 Hot Fuzz
# Adding movie: 2002 The Lord of the Rings: The Two Towers
# Adding movie: 2004 Shaun of the Dead
# Adding movie: 2003 Kill Bill: Vol. 1
# Adding movie: 1999 The Sixth Sense
# Adding movie: 2012 LOL
# Adding movie: 2001 Monsters, Inc.
# Adding movie: 2012 The Bourne Legacy
# Adding movie: 2010 TRON: Legacy
# Adding movie: 2007 Juno
# Adding movie: 2013 La migliore offerta
# Adding movie: 2011 Fright Night
# Adding movie: 2010 Machete
# Adding movie: 2003 Lost in Translation
# Adding movie: 2013 August: Osage County
# Adding movie: 2008 The Incredible Hulk
# Adding movie: 2012 To the Wonder
# Adding movie: 1998 Mulan
# Adding movie: 2009 District 9
# Adding movie: 2012 The Man with the Iron Fists
# Adding movie: 2006 El laberinto del fauno
# Adding movie: 2012 Here Comes the Boom
# Adding movie: 2012 Taken 2
# Adding movie: 2012 The First Time
# Adding movie: 2014 Hercules: The Thracian Wars
# Adding movie: 2013 A Good Day to Die Hard
# Adding movie: 2004 Crash
# Adding movie: 2010 The Other Guys
# Adding movie: 2011 Rio
# Adding movie: 2008 Gran Torino
# Adding movie: 1978 Animal House
# Adding movie: 1986 Ferris Bueller's Day Off
# Adding movie: 2012 Parental Guidance
# Adding movie: 2006 The Fast and the Furious: Tokyo Drift
# Adding movie: 2011 Hall Pass
# Adding movie: 2010 Harry Potter and the Deathly Hallows: Part 1
# Adding movie: 2009 The Last House on the Left
# Adding movie: 2011 We Need to Talk About Kevin
# Adding movie: 2013 Saving Mr. Banks
# Adding movie: 2012 Ice Age: Continental Drift
# Adding movie: 2009 He's Just Not That Into You
# Adding movie: 1998 Fear and Loathing in Las Vegas
# Adding movie: 2011 The Hangover Part II
# Adding movie: 1963 The Great Escape
# Adding movie: 2011 Colombiana
# Adding movie: 2012 House at the End of the Street
# Adding movie: 2006 Children of Men
# Adding movie: 2002 My Big Fat Greek Wedding
# Adding movie: 1994 The Little Rascals
# Adding movie: 2014 22 Jump Street
# Adding movie: 2012 Step Up Revolution
# Adding movie: 2011 Tinker Tailor Soldier Spy
# Adding movie: 2012 The Lucky One
# Adding movie: 2011 The Three Musketeers
# Adding movie: 2010 The Last Song
# Adding movie: 1986 Aliens
# Adding movie: 2011 Source Code
# Adding movie: 2007 Stardust
# Adding movie: 2003 Dumb and Dumberer: When Harry Met Lloyd
# Adding movie: 2010 The Expendables
# Adding movie: 2011 Super 8
# Adding movie: 1997 Hercules
# Adding movie: 1990 Home Alone
# Adding movie: 2013 The Last Stand
# Adding movie: 2013 Her
# Adding movie: 2014 Fury
# Adding movie: 1999 The Boondock Saints
# Adding movie: 2009 Up
# Adding movie: 2008 Quantum of Solace
# Adding movie: 2011 We Bought a Zoo
# Adding movie: 2013 A Single Shot
# Adding movie: 2011 Killer Joe
# Adding movie: 2011 Sherlock Holmes: A Game of Shadows
# Adding movie: 2010 The Fighter
# Adding movie: 2014 How to Train Your Dragon 2
# Adding movie: 2009 Sherlock Holmes
# Adding movie: 2014 Sabotage
# Adding movie: 2012 The Possession
# Adding movie: 2012 Killing Them Softly
# Adding movie: 2011 Hugo
# Adding movie: 2005 Charlie and the Chocolate Factory
# Adding movie: 2005 The Adventures of Sharkboy and Lavagirl 3-D
# Adding movie: 2013 A.C.O.D.
# Adding movie: 2005 Serenity
# Adding movie: 1987 Full Metal Jacket
# Adding movie: 2002 Gangs of New York
# Adding movie: 2004 Dawn of the Dead
# Adding movie: 2001 A Knight's Tale
# Adding movie: 1979 The Warriors
# Adding movie: 2006 Cars
# Adding movie: 2007 The Bourne Ultimatum
# Adding movie: 2009 Up in the Air
# Adding movie: 2006 Pirates of the Caribbean: Dead Man's Chest
# Adding movie: 2012 What to Expect When You're Expecting
# Adding movie: 2012 American Reunion
# Adding movie: 2011 Contagion
# Adding movie: 2013 Blackfish
# Adding movie: 2010 Blue Valentine
# Adding movie: 2013 In a World...
# Adding movie: 1997 Con Air
# Adding movie: 2004 Harold & Kumar Go to White Castle
# Adding movie: 2000 Almost Famous
# Adding movie: 2012 This Means War
# Adding movie: 2009 A Single Man
# Adding movie: 2013 Vikingdom
# Adding movie: 1997 Lolita
# Adding movie: 2002 The Pianist
# Adding movie: 2013 Inside Llewyn Davis
# Adding movie: 2010 Incendies
# Adding movie: 2007 Pirates of the Caribbean: At World's End
# Adding movie: 1995 Toy Story
# Adding movie: 2013 Bounty Killer
# Adding movie: 1988 Who Framed Roger Rabbit
# Adding movie: 2010 The Book of Eli
# Adding movie: 2011 Our Idiot Brother
# Adding movie: 2012 Man on a Ledge
# Adding movie: 2012 Safety Not Guaranteed
# Adding movie: 2012 On the Road
# Adding movie: 2004 The Machinist
# Adding movie: 2007 Spider-Man 3
# Adding movie: 2004 Ocean's Twelve
# Adding movie: 2001 Black Hawk Down
# Adding movie: 2012 Resident Evil: Retribution
# Adding movie: 2007 P.S. I Love You
# Adding movie: 1975 Jaws
# Adding movie: 2006 Casino Royale
# Adding movie: 1993 The Nightmare Before Christmas
# Adding movie: 2012 Premium Rush
# Adding movie: 2005 The Island
# Adding movie: 1995 Clueless
# Adding movie: 2002 28 Days Later...
# Adding movie: 2008 Tropic Thunder
# Adding movie: 2006 Little Miss Sunshine
# Adding movie: 2004 The Day After Tomorrow
# Adding movie: 2013 Labor Day
# Adding movie: 2007 Atonement
# Adding movie: 2012 Gambit
# Adding movie: 2013 Peeples
# Adding movie: 2004 Harry Potter and the Prisoner of Azkaban
# Adding movie: 2008 Bolt
# Adding movie: 2004 Saw
# Adding movie: 2006 The Pursuit of Happyness
# Adding movie: 2013 The Lunchbox
# Adding movie: 1992 Aladdin
# Adding movie: 2013 Closed Circuit
# Adding movie: 1974 The Great Gatsby
# Adding movie: 2006 The Fountain
# Adding movie: 1996 Sleepers
# Adding movie: 2004 50 First Dates
# Adding movie: 2010 Prince of Persia: The Sands of Time
# Adding movie: 2012 Upside Down
# Adding movie: 2012 Bullet to the Head
# Adding movie: 1980 Star Wars: Episode V - The Empire Strikes Back
# Adding movie: 2005 Wedding Crashers
# Adding movie: 1988 Beetle Juice
# Adding movie: 1997 Starship Troopers
# Adding movie: 1991 City Slickers
# Adding movie: 1996 Matilda
# Adding movie: 1989 Batman
# Adding movie: 2010 Clash of the Titans
# Adding movie: 2007 Harry Potter and the Order of the Phoenix
# Adding movie: 2010 Let Me In
# Adding movie: 2011 Footloose
# Adding movie: 2014 Pompeii
# Adding movie: 2002 Catch Me If You Can
# Adding movie: 2012 Chronicle
# Adding movie: 1976 Rocky
# Adding movie: 1993 A Bronx Tale
# Adding movie: 2007 I Am Legend
# Adding movie: 2008 Step Brothers
# Adding movie: 1996 The Hunchback of Notre Dame
# Adding movie: 2012 The Watch
# Adding movie: 2004 White Chicks
# Adding movie: 2013 I Give It a Year
# Adding movie: 1999 Office Space
# Adding movie: 1994 Legends of the Fall
# Adding movie: 2003 Old School
# Adding movie: 1984 The Terminator
# Adding movie: 2002 Harry Potter and the Chamber of Secrets
# Adding movie: 1942 Casablanca
# Adding movie: 2008 The Curious Case of Benjamin Button
# Adding movie: 1993 What's Eating Gilbert Grape
# Adding movie: 2007 Hairspray
# Adding movie: 1981 Raiders of the Lost Ark
# Adding movie: 1997 Batman & Robin
# Adding movie: 2013 Admission
# Adding movie: 2004 The Butterfly Effect
# Adding movie: 2014 The Hunger Games: Mockingjay - Part 1
# Adding movie: 2012 Stand Up Guys
# Adding movie: 2011 The Ides of March
# Adding movie: 2012 The Campaign
# Adding movie: 2011 Hanna
# Adding movie: 2010 127 Hours
# Adding movie: 1981 The Evil Dead
# Adding movie: 2002 Scooby-Doo
# Adding movie: 2006 The Devil Wears Prada
# Adding movie: 1968 2001: A Space Odyssey
# Adding movie: 2010 The King's Speech
# Adding movie: 2009 The Proposal
# Adding movie: 2003 Mystic River
# Adding movie: 2008 The Hurt Locker
# Adding movie: 2011 Green Lantern
# Adding movie: 2008 The Spiderwick Chronicles
# Adding movie: 2010 The Last Airbender
# Adding movie: 1984 Ghost Busters
# Adding movie: 2007 Sweeney Todd: The Demon Barber of Fleet Street
# Adding movie: 2009 The Ugly Truth
# Adding movie: 2013 Sunshine on Leith
# Adding movie: 2010 Valentine's Day
# Adding movie: 2009 Public Enemies
# Adding movie: 2009 Fantastic Mr. Fox
# Adding movie: 1941 Citizen Kane
# Adding movie: 2004 The Phantom of the Opera
# Adding movie: 1991 Beauty and the Beast
# Adding movie: 2009 Moon
# Adding movie: 1994 Stargate
# Adding movie: 1987 Predator
# Adding movie: 2008 Kung Fu Panda
# Adding movie: 2012 Emperor
# Adding movie: 1998 Lock, Stock and Two Smoking Barrels
# Adding movie: 2013 Jeune & jolie
# Adding movie: 2004 Napoleon Dynamite
# Adding movie: 2002 A Walk to Remember
# Adding movie: 2010 The Sorcerer's Apprentice
# Adding movie: 2014 Exodus
# Adding movie: 2003 The School of Rock
# Adding movie: 1996 Fargo
# Adding movie: 2012 The Paperboy
# Adding movie: 2004 Van Helsing
# Adding movie: 2001 Hannibal
# Adding movie: 1999 The Mummy
# Adding movie: 1984 A Nightmare on Elm Street
# Adding movie: 2002 The Count of Monte Cristo
# Adding movie: 1998 The Truman Show
# Adding movie: 2013 Legends of Oz: Dorothy's Return
# Adding movie: 2013 Paradise
# Adding movie: 2006 Mission: Impossible III
# Adding movie: 2004 EuroTrip
# Adding movie: 2014 Veronica Mars
# Adding movie: 2004 The Passion of the Christ
# Adding movie: 2003 The Italian Job
# Adding movie: 2012 The Dictator
# Adding movie: 2012 Contraband
# Adding movie: 2001 Pearl Harbor
# Adding movie: 2004 Der Untergang
# Adding movie: 2010 Winter's Bone
# Adding movie: 2002 Insomnia
# Adding movie: 1997 The Lost World: Jurassic Park
# Adding movie: 2013 Snowpiercer
# Adding movie: 2012 Truth or Dare
# Adding movie: 2001 Moulin Rouge!
# Adding movie: 2012 Trouble with the Curve
# Adding movie: 1988 Child's Play
# Adding movie: 2008 Slumdog Millionaire
# Adding movie: 2012 Wrath of the Titans
# Adding movie: 1982 Poltergeist
# Adding movie: 2012 What Maisie Knew
# Adding movie: 2012 Safe House
# Adding movie: 2012 The Expatriate
# Adding movie: 2012 Mirror Mirror
# Adding movie: 2013 Third Person
# Adding movie: 1984 The Karate Kid
# Adding movie: 2010 Piranha 3D
# Adding movie: 2002 8 Mile
# Adding movie: 2000 Chocolat
# Adding movie: 2012 Abraham Lincoln: Vampire Hunter
# Adding movie: 2012 Think Like a Man
# Adding movie: 2013 Hammer of the Gods
# Adding movie: 2011 War Horse
# Adding movie: 2008 Never Back Down
# Adding movie: 2010 13
# Adding movie: 1997 The Fifth Element
# Adding movie: 2011 New Year's Eve
# Adding movie: 2012 Wanderlust
# Adding movie: 2009 My Sister's Keeper
# Adding movie: 1983 Star Wars: Episode VI - Return of the Jedi
# Adding movie: 1997 Jackie Brown
# Adding movie: 2011 Scream 4
# Adding movie: 1995 Before Sunrise
# Adding movie: 1988 Die Hard
# Adding movie: 2010 Salt
# Adding movie: 2013 Justin and the Knights of Valour
# Adding movie: 2007 Bridge to Terabithia
# Adding movie: 1999 Tarzan
# Adding movie: 2007 Ocean's Thirteen
# Adding movie: 2007 Ghost Rider
# Adding movie: 2012 Great Expectations
# Adding movie: 2005 Walk the Line
# Adding movie: 2012 American Mary
# Adding movie: 1998 The Parent Trap
# Adding movie: 2013 The Stranger Within
# Adding movie: 2008 Jumper
# Adding movie: 2011 Priest
# Adding movie: 2001 Blow
# Adding movie: 2006 Invincible
# Adding movie: 2009 Transformers: Revenge of the Fallen
# Adding movie: 2012 Lockout
# Adding movie: 2011 The Twilight Saga: Breaking Dawn - Part 1
# Adding movie: 2013 Delivery Man
# Adding movie: 2012 The Five-Year Engagement
# Adding movie: 1965 The Sound of Music
# Adding movie: 1961 Breakfast at Tiffany's
# Adding movie: 2005 Mr. & Mrs. Smith
# Adding movie: 2007 Beowulf
# Adding movie: 2008 RocknRolla
# Adding movie: 2013 Welcome to the Punch
# Adding movie: 2009 Friday the 13th
# Adding movie: 2012 Stolen
# Adding movie: 2009 Orphan
# Adding movie: 2012 The Words
# Adding movie: 2008 The Bank Job
# Adding movie: 2003 Underworld
# Adding movie: 2009 Knowing
# Adding movie: 2013 The English Teacher
# Adding movie: 1986 Labyrinth
# Adding movie: 1997 Men in Black
# Adding movie: 2004 Thunderbirds
# Adding movie: 1997 L.A. Confidential
# Adding movie: 2008 Vicky Cristina Barcelona
# Adding movie: 2012 Madagascar 3: Europe's Most Wanted
# Adding movie: 2008 WALL-E
# Adding movie: 2012 The Lorax
# Adding movie: 2009 Harry Potter and the Half-Blood Prince
# Adding movie: 1984 Footloose
# Adding movie: 1999 Dogma
# Adding movie: 2014 Grace of Monaco
# Adding movie: 1997 Liar Liar
# Adding movie: 2011 10 Years
# Adding movie: 1995 Jumanji
# Adding movie: 2008 Forgetting Sarah Marshall
# Adding movie: 2009 Law Abiding Citizen
# Adding movie: 1993 Tombstone
# Adding movie: 2013 Texas Chainsaw 3D
# Adding movie: 2004 Lemony Snicket's A Series of Unfortunate Events
# Adding movie: 1995 Batman Forever
# Adding movie: 1989 Back to the Future Part II
# Adding movie: 2000 The Beach
# Adding movie: 1989 Field of Dreams
# Adding movie: 1991 Father of the Bride
# Adding movie: 2013 Breakout
# Adding movie: 2009 Whiteout
# Adding movie: 2012 Bachelorette
# Adding movie: 2012 At Any Price
# Adding movie: 1991 Hook
# Adding movie: 1984 Once Upon a Time in America
# Adding movie: 2010 Resident Evil: Afterlife
# Adding movie: 2009 Terminator Salvation
# Adding movie: 2008 Wanted
# Adding movie: 2010 Due Date
# Adding movie: 1982 The Thing
# Adding movie: 1990 Edward Scissorhands
# Adding movie: 2012 Passion
# Adding movie: 2011 Your Highness
# Adding movie: 2012 Smashed
# Adding movie: 1996 Happy Gilmore
# Adding movie: 2003 X2
# Adding movie: 2008 The Strangers
# Adding movie: 2008 In Bruges
# Adding movie: 2011 The Rum Diary
# Adding movie: 2006 John Tucker Must Die
# Adding movie: 2007 American Gangster
# Adding movie: 1995 Casino
# Adding movie: 2014 Mad Max: Fury Road
# Adding movie: 2014 Muppets Most Wanted
# Adding movie: 1985 Weird Science
# Adding movie: 2001 Artificial Intelligence: AI
# Adding movie: 2005 Memoirs of a Geisha
# Adding movie: 2000 The Patriot
# Adding movie: 1984 Die unendliche Geschichte
# Adding movie: 1990 Total Recall
# Adding movie: 2011 The Tree of Life
# Adding movie: 1987 Dirty Dancing
# Adding movie: 1971 Fiddler on the Roof
# Adding movie: 2003 Peter Pan
# Adding movie: 2004 Blade: Trinity
# Adding movie: 2013 Man of Tai Chi
# Adding movie: 2011 The Smurfs
# Adding movie: 2006 The Illusionist
# Adding movie: 1994 The Mask
# Adding movie: 2013 Only Lovers Left Alive
# Adding movie: 2012 The Reluctant Fundamentalist
# Adding movie: 2012 Aftershock
# Adding movie: 2011 The Artist
# Adding movie: 2009 Jennifer's Body
# Adding movie: 2001 Training Day
# Adding movie: 2012 Deadfall
# Adding movie: 1971 Willy Wonka & the Chocolate Factory
# Adding movie: 2003 Cold Mountain
# Adding movie: 2013 Assault on Wall Street
# Adding movie: 1991 The Addams Family
# Adding movie: 2009 Angels & Demons
# Adding movie: 2011 Water for Elephants
# Adding movie: 2011 The Grey
# Adding movie: 2016 Avatar 2
# Adding movie: 2011 Beastly
# Adding movie: 2006 Alpha Dog
# Adding movie: 2011 The Good Doctor
# Adding movie: 1992 Unforgiven
# Adding movie: 2010 True Grit
# Adding movie: 1978 Halloween
# Adding movie: 1999 Varsity Blues
# Adding movie: 2013 Pawn Shop Chronicles
# Adding movie: 1998 Armageddon
# Adding movie: 2009 Hachi: A Dog's Tale
# Adding movie: 1995 GoldenEye
# Adding movie: 2002 Star Wars: Episode II - Attack of the Clones
# Adding movie: 2011 What's Your Number?
# Adding movie: 1989 Christmas Vacation
# Adding movie: 2008 Hancock
# Adding movie: 2011 Killer Elite
# Adding movie: 2004 Spider-Man 2
# Adding movie: 2005 Kingdom of Heaven
# Adding movie: 1991 My Girl
# Adding movie: 2005 Jarhead
# Adding movie: 2002 Equilibrium
# Adding movie: 2013 Los amantes pasajeros
# Adding movie: 1999 Notting Hill
# Adding movie: 2013 Fruitvale Station
# Adding movie: 2003 The Matrix Reloaded
# Adding movie: 2008 Role Models
# Adding movie: 2000 Cast Away
# Adding movie: 1980 Airplane!
# Adding movie: 2001 Shrek
# Adding movie: 1988 Rain Man
# Adding movie: 2012 Arbitrage
# Adding movie: 1995 Twelve Monkeys
# Adding movie: 2012 Chasing Mavericks
# Adding movie: 2006 Step Up
# Adding movie: 2007 Mr. Magorium's Wonder Emporium
# Adding movie: 2001 Mulholland Dr.
# Adding movie: 2013 Rapture-Palooza
# Adding movie: 1968 C'era una volta il West
# Adding movie: 1987 The Untouchables
# Adding movie: 1958 Vertigo
# Adding movie: 2004 Hauru no ugoku shiro
# Adding movie: 2011 Rise of the Planet of the Apes
# Adding movie: 2012 Silent Hill: Revelation 3D
# Adding movie: 2004 The Village
# Adding movie: 2006 Apocalypto
# Adding movie: 2006 Click
# Adding movie: 1964 Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Adding movie: 2010 The Way Back
# Adding movie: 1998 There's Something About Mary
# Adding movie: 2005 Fantastic Four
# Adding movie: 2009 The Joneses
# Adding movie: 2012 The Imposter
# Adding movie: 2010 Remember Me
# Adding movie: 1978 Superman
# Adding movie: 2008 Revolutionary Road
# Adding movie: 2001 Jurassic Park III
# Adding movie: 2008 Yip Man
# Adding movie: 2009 Gamer
# Adding movie: 1986 Platoon
# Adding movie: 2012 To Rome with Love
# Adding movie: 2009 The Twilight Saga: New Moon
# Adding movie: 2006 Silent Hill
# Adding movie: 2002 The Bourne Identity
# Adding movie: 2012 The Collection
# Adding movie: 2004 Hellboy
# Adding movie: 2002 Sweet Home Alabama
# Adding movie: 2011 My Week with Marilyn
# Adding movie: 2012 Best Man Down
# Adding movie: 2012 Would You Rather
# Adding movie: 2012 The Raven
# Adding movie: 2004 The Aviator
# Adding movie: 2009 The Imaginarium of Doctor Parnassus
# Adding movie: 2005 The Longest Yard
# Adding movie: 2009 Pandorum
# Adding movie: 2005 Constantine
# Adding movie: 2009 2012
# Adding movie: 2008 Seven Pounds
# Adding movie: 2009 Man som hatar kvinnor
# Adding movie: 2008 Definitely, Maybe
# Adding movie: 2011 Like Crazy
# Adding movie: 2007 Death Proof
# Adding movie: 2004 The Bourne Supremacy
# Adding movie: 2005 Madagascar
# Adding movie: 2012 Beasts of the Southern Wild
# Adding movie: 2006 Rocky Balboa
# Adding movie: 2012 Alex Cross
# Adding movie: 2014 Transcendence
# Adding movie: 2005 The New World
# Adding movie: 2003 The Last Samurai
# Adding movie: 1980 The Elephant Man
# Adding movie: 2012 People Like Us
# Adding movie: 1964 Mary Poppins
# Adding movie: 2005 King Kong
# Adding movie: 2000 Gone in Sixty Seconds
# Adding movie: 2014 Tomorrowland
# Adding movie: 2004 Before Sunset
# Adding movie: 2004 Friday Night Lights
# Adding movie: 2011 J. Edgar
# Adding movie: 2008 The Boy in the Striped Pyjamas
# Adding movie: 2002 Signs
# Adding movie: 2000 Road Trip
# Adding movie: 2005 Hitch
# Adding movie: 2009 Brothers
# Adding movie: 2013 Magic Magic
# Adding movie: 2010 Robin Hood
# Adding movie: 2009 The Princess and the Frog
# Adding movie: 2010 The A-Team
# Adding movie: 2006 Perfume: The Story of a Murderer
# Adding movie: 2012 Kon-Tiki
# Adding movie: 2006 Superman Returns
# Adding movie: 2006 Blood Diamond
# Adding movie: 2002 The Time Machine
# Adding movie: 2000 Dracula 2000
# Adding movie: 1996 Scream
# Adding movie: 2003 Daredevil
# Adding movie: 2000 Scary Movie
# Adding movie: 1994 Angels in the Outfield
# Adding movie: 1987 Can't Buy Me Love
# Adding movie: 2013 Grand Masti
# Adding movie: 2005 The Amityville Horror
# Adding movie: 1954 Rear Window
# Adding movie: 2001 Scary Movie 2
# Adding movie: 2012 Promised Land
# Adding movie: 2010 The Twilight Saga: Eclipse
# Adding movie: 1993 The Sandlot
# Adding movie: 2009 Coraline
# Adding movie: 2001 Not Another Teen Movie
# Adding movie: 2007 August Rush
# Adding movie: 2012 The Woman in Black
# Adding movie: 1992 Batman Returns
# Adding movie: 2011 Serbuan maut
# Adding movie: 2002 Panic Room
# Adding movie: 1996 The Rock
# Adding movie: 1984 Amadeus
# Adding movie: 1985 St. Elmo's Fire
# Adding movie: 2004 Dodgeball: A True Underdog Story
# Adding movie: 2012 Celeste & Jesse Forever
# Adding movie: 2005 The Exorcism of Emily Rose
# Adding movie: 2012 Underworld: Awakening
# Adding movie: 2013 The Lifeguard
# Adding movie: 1975 Monty Python and the Holy Grail
# Adding movie: 2005 Match Point
# Adding movie: 2008 The Other Boleyn Girl
# Adding movie: 2002 Van Wilder
# Adding movie: 1997 Mononoke-hime
# Adding movie: 2011 Cars 2
# Adding movie: 2012 So Undercover
# Adding movie: 2003 2 Fast 2 Furious
# Adding movie: 2010 The Kids Are All Right
# Adding movie: 2003 The Dreamers
# Adding movie: 2011 Jane Eyre
# Adding movie: 2011 Apollo 18
# Adding movie: 1999 Girl, Interrupted
# Adding movie: 2011 Haywire
# Adding movie: 1963 The Birds
# Adding movie: 1997 Austin Powers: International Man of Mystery
# Adding movie: 2012 Playing for Keeps
# Adding movie: 1987 Empire of the Sun
# Adding movie: 2011 La piel que habito
# Adding movie: 2011 Red Riding Hood
# Adding movie: 2013 As I Lay Dying
# Adding movie: 2012 Jewtopia
# Adding movie: 2013 Short Term 12
# Adding movie: 2012 ParaNorman
# Adding movie: 2013 The Zero Theorem
# Adding movie: 1989 Uncle Buck
# Adding movie: 2009 The Human Centipede (First Sequence)
# Adding movie: 2007 30 Days of Night
# Adding movie: 2012 The Guilt Trip
# Adding movie: 2006 The Da Vinci Code
# Adding movie: 2012 The Odd Life of Timothy Green
# Adding movie: 2000 Coyote Ugly
# Adding movie: 2011 The Muppets
# Adding movie: 2004 I, Robot
# Adding movie: 2004 Closer
# Adding movie: 1954 Shichinin no samurai
# Adding movie: 1978 The Deer Hunter
# Adding movie: 2006 Talladega Nights: The Ballad of Ricky Bobby
# Adding movie: 2011 Margin Call
# Adding movie: 2003 Hulk
# Adding movie: 2005 The Devil's Rejects
# Adding movie: 1994 Natural Born Killers
# Adding movie: 2012 No One Lives
# Adding movie: 2010 Unstoppable
# Adding movie: 2007 The Heartbreak Kid
# Adding movie: 2012 The Three Stooges
# Adding movie: 1992 The Last of the Mohicans
# Adding movie: 1997 The Game
# Adding movie: 2010 Shrek Forever After
# Adding movie: 2005 House of Wax
# Adding movie: 2011 Johnny English Reborn
# Adding movie: 2007 Gone Baby Gone
# Adding movie: 2010 A Nightmare on Elm Street
# Adding movie: 2009 17 Again
# Adding movie: 1994 Interview with the Vampire: The Vampire Chronicles
# Adding movie: 2010 Dear John
# Adding movie: 2008 You Don't Mess with the Zohan
# Adding movie: 2009 Adventureland
# Adding movie: 2011 The Lincoln Lawyer
# Adding movie: 2010 Tucker and Dale vs Evil
# Adding movie: 2010 You Again
# Adding movie: 2011 Rango
# Adding movie: 2010 Get Him to the Greek
# Adding movie: 2000 How the Grinch Stole Christmas
# Adding movie: 2003 Holes
# Adding movie: 2007 Paranormal Activity
# Adding movie: 2012 Act of Valor
# Adding movie: 2002 Minority Report
# Adding movie: 2008 Transporter 3
# Adding movie: 2013 The Railway Man
# Adding movie: 2012 Fire with Fire
# Adding movie: 2004 Alexander
# Adding movie: 2007 Lars and the Real Girl
# Adding movie: 2008 The Happening
# Adding movie: 2009 Ghosts of Girlfriends Past
# Adding movie: 1996 Jerry Maguire
# Adding movie: 2012 De rouille et d'os
# Adding movie: 2011 Extremely Loud & Incredibly Close
# Adding movie: 2010 Predators
# Adding movie: 2003 Identity
# Adding movie: 2007 St. Trinian's
# Adding movie: 2008 Rambo
# Adding movie: 2010 The Chronicles of Narnia: The Voyage of the Dawn Treader
# Adding movie: 1985 Pale Rider
# Adding movie: 1999 Big Daddy
# Adding movie: 1980 The Blues Brothers
# Adding movie: 2012 Chernobyl Diaries
# Adding movie: 2012 Wadjda
# Adding movie: 2010 Shelter
# Adding movie: 2004 13 Going on 30
# Adding movie: 2002 About a Boy
# Adding movie: 2006 Happy Feet
# Adding movie: 1990 Misery
# Adding movie: 2009 Antichrist
# Adding movie: 2011 Ghost Rider: Spirit of Vengeance
# Adding movie: 2014 Jupiter Ascending
# Adding movie: 1998 Blade
# Adding movie: 1973 American Graffiti
# Adding movie: 2005 Kiss Kiss Bang Bang
# Adding movie: 2003 Tears of the Sun
# Adding movie: 2006 The Hills Have Eyes
# Adding movie: 2008 Wild Child
# Adding movie: 2010 Legion
# Adding movie: 1996 Twister
# Adding movie: 1989 Indiana Jones and the Last Crusade
# Adding movie: 2004 Seed of Chucky
# Adding movie: 2012 Red Lights
# Adding movie: 2004 A Cinderella Story
# Adding movie: 1987 The Lost Boys
# Adding movie: 2010 Dinner for Schmucks
# Adding movie: 2013 La grande bellezza
# Adding movie: 2004 Collateral
# Adding movie: 2013 A Belfast Story
# Adding movie: 1982 Annie
# Adding movie: 2012 Safe
# Adding movie: 2010 Flipped
# Adding movie: 2012 The Brass Teapot
# Adding movie: 2002 The Transporter
# Adding movie: 2004 Kill Bill: Vol. 2
# Adding movie: 2006 The Holiday
# Adding movie: 2010 Hereafter
# Adding movie: 2011 Goon
# Adding movie: 2004 Garden State
# Adding movie: 2003 Terminator 3: Rise of the Machines
# Adding movie: 2013 Pawn
# Adding movie: 2005 The Hitchhiker's Guide to the Galaxy
# Adding movie: 2003 Elf
# Adding movie: 2008 Death Race
# Adding movie: 2010 Life as We Know It
# Adding movie: 1946 It's a Wonderful Life
# Adding movie: 2010 Skyline
# Adding movie: 2013 Odd Thomas
# Adding movie: 1998 Bride of Chucky
# Adding movie: 1995 Friday
# Adding movie: 1995 Apollo 13
# Adding movie: 1997 Event Horizon
# Adding movie: 1992 The Mighty Ducks
# Adding movie: 2003 The Matrix Revolutions
# Adding movie: 2008 Body of Lies
# Adding movie: 2010 StreetDance 3D
# Adding movie: 2004 National Treasure
# Adding movie: 2011 Hick
# Adding movie: 1988 Willow
# Adding movie: 1998 Meet Joe Black
# Adding movie: 1959 North by Northwest
# Adding movie: 2009 Solomon Kane
# Adding movie: 2010 It's Kind of a Funny Story
# Adding movie: 2008 Changeling
# Adding movie: 1996 From Dusk Till Dawn
# Adding movie: 2012 Black Rock
# Adding movie: 2009 Daybreakers
# Adding movie: 2008 Mamma Mia!
# Adding movie: 2002 Die Another Day
# Adding movie: 2005 Brick
# Adding movie: 2007 Dead Silence
# Adding movie: 2011 Cowboys & Aliens
# Adding movie: 1990 The Godfather: Part III
# Adding movie: 2007 Grindhouse
# Adding movie: 1998 A Bug's Life
# Adding movie: 2013 Temptation: Confessions of a Marriage Counselor
# Adding movie: 2013 Escape from Planet Earth
# Adding movie: 2008 10,000 BC
# Adding movie: 1974 Blazing Saddles
# Adding movie: 2006 Deja Vu
# Adding movie: 1997 Gattaca
# Adding movie: 2007 Sunshine
# Adding movie: 1995 Mortal Kombat
# Adding movie: 2001 Lara Croft: Tomb Raider
# Adding movie: 2006 The History Boys
# Adding movie: 2000 Unbreakable
# Adding movie: 2011 The Adventures of Tintin
# Adding movie: 1996 The Crucible
# Adding movie: 1999 Magnolia
# Adding movie: 2014 Rio 2
# Adding movie: 2007 Hot Rod
# Adding movie: 1997 The Devil's Advocate
# Adding movie: 2001 I Am Sam
# Adding movie: 2007 Halloween
# Adding movie: 2013 Prince Avalanche
# Adding movie: 2009 I Love You, Man
# Adding movie: 2002 Ice Age
# Adding movie: 2008 21
# Adding movie: 2007 Premonition
# Adding movie: 1968 Rosemary's Baby
# Adding movie: 2012 Hit and Run
# Adding movie: 1995 Pocahontas
# Adding movie: 2007 1408
# Adding movie: 2007 3:10 to Yuma
# Adding movie: 1999 The World Is Not Enough
# Adding movie: 1972 Deliverance
# Adding movie: 2011 Machine Gun Preacher
# Adding movie: 2011 Soul Surfer
# Adding movie: 2010 Locked In
# Adding movie: 1993 Groundhog Day
# Adding movie: 2001 The Mummy Returns
# Adding movie: 2005 Sky High
# Adding movie: 2002 Chicago
# Adding movie: 1992 Home Alone 2: Lost in New York
# Adding movie: 2013 Serena
# Adding movie: 2002 Red Dragon
# Adding movie: 1998 The Man in the Iron Mask
# Adding movie: 2008 Bronson
# Adding movie: 2007 Live Free or Die Hard
# Adding movie: 2010 Date Night
# Adding movie: 2012 Seeking a Friend for the End of the World
# Adding movie: 1995 Waterworld
# Adding movie: 2010 Hot Tub Time Machine
# Adding movie: 2010 The Switch
# Adding movie: 2003 Wrong Turn
# Adding movie: 2013 The Best Man Holiday
# Adding movie: 2012 Paranormal Activity 4
# Adding movie: 1983 Krull
# Adding movie: 2001 Swordfish
# Adding movie: 2003 Bad Boys II
# Adding movie: 2012 Amour
# Adding movie: 2001 Ghost World
# Adding movie: 1985 Clue
# Adding movie: 1997 Donnie Brasco
# Adding movie: 2017 Justice League
# Adding movie: 2000 O Brother, Where Art Thou?
# Adding movie: 2011 Sleeping Beauty
# Adding movie: 2007 The Man from Earth
# Adding movie: 2002 Resident Evil
# Adding movie: 2013 The Haunting in Connecticut 2: Ghosts of Georgia
# Adding movie: 2010 The Karate Kid
# Adding movie: 2006 Marie Antoinette
# Adding movie: 2002 Blade II
# Adding movie: 1994 Ace Ventura: Pet Detective
# Adding movie: 1983 Risky Business
# Adding movie: 2011 Take This Waltz
# Adding movie: 1997 Face/Off
# Adding movie: 2011 The Best Exotic Marigold Hotel
# Adding movie: 1960 Spartacus
# Adding movie: 2001 Vanilla Sky
# Adding movie: 2011 Blitz
# Adding movie: 2004 Catwoman
# Adding movie: 1983 WarGames
# Adding movie: 2011 The Sitter
# Adding movie: 1991 Robin Hood: Prince of Thieves
# Adding movie: 2011 Battle Los Angeles
# Adding movie: 2004 Layer Cake
# Adding movie: 2014 Annie
# Adding movie: 2012 Girl Most Likely
# Adding movie: 2009 Precious
# Adding movie: 2012 Room 237
# Adding movie: 1992 A Few Good Men
# Adding movie: 2007 Planet Terror
# Adding movie: 2011 The Human Centipede II (Full Sequence)
# Adding movie: 1966 Torn Curtain
# Adding movie: 1998 The Faculty
# Adding movie: 2001 Le fabuleux destin d'Amelie Poulain
# Adding movie: 2010 The Next Three Days
# Adding movie: 2001 The Others
# Adding movie: 2009 Cirque du Freak: The Vampire's Assistant
# Adding movie: 2012 Gone
# Adding movie: 2008 Yes Man
# Adding movie: 2013 L'ecume des jours
# Adding movie: 1977 Saturday Night Fever
# Adding movie: 2008 27 Dresses
# Adding movie: 2009 Fired Up!
# Adding movie: 2013 Ain't Them Bodies Saints
# Adding movie: 2009 The Time Traveler's Wife
# Adding movie: 2008 The Wrestler
# Adding movie: 2001 Atlantis: The Lost Empire
# Adding movie: 2012 Maniac
# Adding movie: 1984 Police Academy
# Adding movie: 1984 Dune
# Adding movie: 1991 Teenage Mutant Ninja Turtles II: The Secret of the Ooze
# Adding movie: 1995 The Basketball Diaries
# Adding movie: 2006 Stranger Than Fiction
# Adding movie: 2014 Resident Evil 6
# Adding movie: 1984 Red Dawn
# Adding movie: 2010 The Tourist
# Adding movie: 2002 Austin Powers in Goldmember
# Adding movie: 2013 Yip Man: Jung gik yat jin
# Adding movie: 1999 She's All That
# Adding movie: 2010 All Good Things
# Adding movie: 2011 A Dangerous Method
# Adding movie: 2011 Hodejegerne
# Adding movie: 1981 For Your Eyes Only
# Adding movie: 2003 Master and Commander: The Far Side of the World
# Adding movie: 2010 Step Up 3D
# Adding movie: 1999 Any Given Sunday
# Adding movie: 1998 The Thin Red Line
# Adding movie: 2006 Idiocracy
# Adding movie: 2013 The Art of the Steal
# Adding movie: 2008 Burn After Reading
# Adding movie: 2006 We Are Marshall
# Adding movie: 1981 Das Boot
# Adding movie: 2012 Journey 2: The Mysterious Island
# Adding movie: 2007 Hannibal Rising
# Adding movie: 2011 The Darkest Hour
# Adding movie: 1999 Toy Story 2
# Adding movie: 2007 Hitman
# Adding movie: 1999 The Blair Witch Project
# Adding movie: 1988 Coming to America
# Adding movie: 2010 Saw 3D
# Adding movie: 2001 Bridget Jones's Diary
# Adding movie: 1967 The Jungle Book
# Adding movie: 2005 The Descent
# Adding movie: 1996 Primal Fear
# Adding movie: 2004 Along Came Polly
# Adding movie: 1993 Philadelphia
# Adding movie: 2013 Cold Comes the Night
# Adding movie: 1993 Carlito's Way
# Adding movie: 2007 The Number 23
# Adding movie: 1968 Hang 'Em High
# Adding movie: 1993 Mrs. Doubtfire
# Adding movie: 2009 A Perfect Getaway
# Adding movie: 2001 The Princess Diaries
# Adding movie: 2006 Zoom
# Adding movie: 2013 Blood Ties
# Adding movie: 2011 Butter
# Adding movie: 1990 Ghost
# Adding movie: 2005 Into the Blue
# Adding movie: 1984 Gremlins
# Adding movie: 2001 Super Troopers
# Adding movie: 1994 The Crow
# Adding movie: 1999 The Iron Giant
# Adding movie: 1985 Legend
# Adding movie: 2009 Nine
# Adding movie: 2009 Mary and Max
# Adding movie: 2011 30 Minutes or Less
# Adding movie: 1998 Can't Hardly Wait
# Adding movie: 2001 Spy Kids
# Adding movie: 2005 Lord of War
# Adding movie: 2009 Underworld: Rise of the Lycans
# Adding movie: 1998 Dark City
# Adding movie: 2011 Friends with Kids
# Adding movie: 2004 Shark Tale
# Adding movie: 1960 The Time Machine
# Adding movie: 2010 When in Rome
# Adding movie: 2001 Planet of the Apes
# Adding movie: 2006 Accepted
# Adding movie: 1983 Flashdance
# Adding movie: 2011 Justin Bieber: Never Say Never
# Adding movie: 2013 Evidence
# Adding movie: 2007 The Babysitters
# Adding movie: 2008 Step Up 2: The Streets
# Adding movie: 2013 The Numbers Station
# Adding movie: 2003 Cheaper by the Dozen
# Adding movie: 2011 Take Me Home Tonight
# Adding movie: 1998 The Prince of Egypt
# Adding movie: 2012 The Bay
# Adding movie: 2006 Lucky Number Slevin
# Adding movie: 2003 The Texas Chainsaw Massacre
# Adding movie: 2001 Legally Blonde
# Adding movie: 2011 Tower Heist
# Adding movie: 1991 Star Trek VI: The Undiscovered Country
# Adding movie: 2005 Hostel
# Adding movie: 1985 Mask
# Adding movie: 2011 The Eagle
# Adding movie: 2006 Eragon
# Adding movie: 2009 The Uninvited
# Adding movie: 2010 Eat Pray Love
# Adding movie: 1962 Lawrence of Arabia
# Adding movie: 2003 Scary Movie 3
# Adding movie: 2011 The Thing
# Adding movie: 2010 Super
# Adding movie: 2006 The Fall
# Adding movie: 2012 Cosmopolis
# Adding movie: 2012 Iron Sky
# Adding movie: 2005 Coach Carter
# Adding movie: 2005 Corpse Bride
# Adding movie: 2014 The Familymoon
# Adding movie: 1974 Young Frankenstein
# Adding movie: 1997 Alien: Resurrection
# Adding movie: 2006 Take the Lead
# ...
# Adding movie: 2013 Coffee Town
# Adding movie: 2002 Return to Never Land
# Adding movie: 2004 Fat Albert
# Adding movie: 2005 Kinky Boots
# Adding movie: 2012 She Wants Me
# Adding movie: 1965 Repulsion
# Adding movie: 2004 Ladder 49
# Adding movie: 2008 Der Baader Meinhof Komplex
# Adding movie: 2011 The Devil's Rock
# Adding movie: 2009 12 Rounds
# Adding movie: 2005 Cry_Wolf
# Adding movie: 1979 Hair
# Adding movie: 1992 Captain Ron
# Adding movie: 2012 Columbus Circle
# Adding movie: 2002 The Rookie
# Adding movie: 2005 An American Haunting
# Adding movie: 2004 The Final Cut
# Adding movie: 2003 The Hunted
# Adding movie: 2011 Finding Kind
# Adding movie: 1997 Good Burger
# Adding movie: 1955 Les diaboliques
# Adding movie: 2013 The Prototype
# Adding movie: 2000 Boys and Girls
# Adding movie: 1955 The Seven Year Itch
# Adding movie: 2013 Red Obsession
# Adding movie: 2002 The Master of Disguise
# Adding movie: 2006 Catch and Release
# Adding movie: 1995 The Big Green
# Adding movie: 2008 The Secret of Moonacre
# Adding movie: 1978 Up in Smoke
# Adding movie: 1995 To Die For
# Adding movie: 1989 Black Rain
# Adding movie: 2013 The Amityville Asylum
# Adding movie: 1995 Free Willy 2: The Adventure Home
# Adding movie: 2010 Yogi Bear
# Adding movie: 2010 I'm Still Here
# Adding movie: 2012 Perfect Sisters
# Adding movie: 2009 Rampage
# Adding movie: 2009 Hotel for Dogs
# Adding movie: 2000 Dungeons & Dragons
# Adding movie: 2014 Laggies
# Adding movie: 1995 A Kid in King Arthur's Court
# Adding movie: 1986 Sid and Nancy
# Adding movie: 2012 The Patience Stone
# Adding movie: 2007 Smiley Face
# Adding movie: 2014 Cymbeline
# Adding movie: 1970 Kelly's Heroes
# Adding movie: 2006 Bandidas
# Adding movie: 2006 Man cheng jin dai huang jin jia
# Adding movie: 2006 Akeelah and the Bee
# Adding movie: 1985 Enemy Mine
# Adding movie: 1962 The Miracle Worker
# Adding movie: 2013 The Adventures of Mickey Matson and the Copperhead Treasure
# Adding movie: 2009 Sin nombre
# Adding movie: 1957 The Prince and the Showgirl
# Adding movie: 2013 A Resurrection
# Adding movie: 2009 Powder Blue
# Adding movie: 1990 The Rescuers Down Under
# Adding movie: 1986 House
# Adding movie: 1999 The Straight Story
# Adding movie: 1992 The Cutting Edge
# Adding movie: 2014 Every Thing Will Be Fine
# Adding movie: 2014 The Boxtrolls
# Adding movie: 1966 Manos: The Hands of Fate
# Adding movie: 1978 Convoy
# Adding movie: 2012 Greetings from Tim Buckley
# Adding movie: 1993 Son in Law
# Adding movie: 2009 44 Inch Chest
# Adding movie: 1994 The Next Karate Kid
# Adding movie: 2011 The Family Tree
# Adding movie: 1984 Supergirl
# Adding movie: 1986 The Wraith
# Adding movie: 1985 Ladyhawke
# Adding movie: 2012 What Richard Did
# Adding movie: 1989 Always
# Adding movie: 1968 The Legend of Lylah Clare
# Adding movie: 2001 Dr. Dolittle 2
# Adding movie: 1978 Piranha
# Adding movie: 2001 Two Can Play That Game
# Adding movie: 2010 Extraordinary Measures
# Adding movie: 1980 The Changeling
# Adding movie: 2003 House of the Dead
# Adding movie: 2000 100 Girls
# Adding movie: 2006 One Night with the King
# Adding movie: 2010 Kongen av Bastoy
# Adding movie: 2002 Far from Heaven
# Adding movie: 1966 El Dorado
# Adding movie: 2013 Aberration
# Adding movie: 2006 The Good German
# Adding movie: 2012 Interview with a Hitman
# Adding movie: 1981 Body Heat
# Adding movie: 1995 Balto
# Adding movie: 1952 The Member of the Wedding
# Adding movie: 2010 My Soul to Take
# Adding movie: 2007 2 Days in Paris
# Adding movie: 2009 The Vicious Kind
# Adding movie: 2013 Ass Backwards
# Adding movie: 2011 Red Dog
# Adding movie: 2014 Love, Rosie
# Adding movie: 1989 Loverboy
# Adding movie: 2010 The Reef
# Adding movie: 2006 Firewall
# Adding movie: 2014 The Gunman
# Adding movie: 1999 In Dreams
# Adding movie: 2006 Running with Scissors
# Adding movie: 2012 Spike Island
# Adding movie: 2006 Skinwalkers
# Adding movie: 2013 Raze
# Adding movie: 2002 Divine Secrets of the Ya-Ya Sisterhood
# Adding movie: 1984 The Killing Fields
# Adding movie: 1989 Leviathan
# Adding movie: 1971 Billy Jack
# Adding movie: 2008 Happy-Go-Lucky
# Adding movie: 1994 Baby's Day Out
# Adding movie: 1979 Stalker
# Adding movie: 2001 Captain Corelli's Mandolin
# Adding movie: 2012 Mac & Devin Go to High School
# Adding movie: 2011 Puncture
# Adding movie: 2013 Le Week-End
# Adding movie: 2013 La gran familia espanola
# Adding movie: 1983 Class
# Adding movie: 1997 Suicide Kings
# Adding movie: 2010 The Penthouse
# Adding movie: 2014 The Creed of Violence
# Adding movie: 2009 Solitary Man
# Adding movie: 2009 Mammoth
# Adding movie: 2008 The Lazarus Project
# Adding movie: 2001 The Shipping News
# Adding movie: 2012 Noobz
# Adding movie: 1950 Harvey
# Adding movie: 2014 Untitled Woody Allen Project
# Adding movie: 1996 Spy Hard
# Adding movie: 1994 Andre
# Adding movie: 1999 200 Cigarettes
# Adding movie: 2007 Battle in Seattle
# Adding movie: 1994 The Client
# Adding movie: 2013 Summer in February
# Adding movie: 2009 Bandslam
# Adding movie: 1996 Set It Off
# Adding movie: 1996 Evita
# Adding movie: 2002 The Country Bears
# Adding movie: 2010 Every Day
# Adding movie: 1950 Tea for Two
# Adding movie: 2013 Madras Cafe
# Adding movie: 2012 Tower Block
# Adding movie: 2006 Away from Her
# Adding movie: 1994 New Nightmare
# Adding movie: 2012 Therese Desqueyroux
# Adding movie: 2014 Solace
# Adding movie: 2000 Chopper
# Adding movie: 1992 Boomerang
# Adding movie: 1965 Those Magnificent Men in Their Flying Machines or How I Flew from London to Paris in 25 hours 11 minutes
# Adding movie: 2009 St Trinian's 2: The Legend of Fritton's Gold
# Adding movie: 1993 Dave
# Adding movie: 1953 The War of the Worlds
# Adding movie: 1994 Nell
# Adding movie: 1992 Passenger 57
# Adding movie: 1989 Casualties of War
# Adding movie: 2010 How to Make Love to a Woman
# Adding movie: 1957 Old Yeller
# Adding movie: 2012 The Helpers
# Adding movie: 2013 The Bell Witch Haunting
# Adding movie: 1962 What Ever Happened to Baby Jane?
# Adding movie: 2011 In Darkness
# Adding movie: 2001 Saving Silverman
# Adding movie: 2012 The Philly Kid
# Adding movie: 2011 Age of Heroes
# Adding movie: 1986 The Hitcher
# Adding movie: 1985 Perfect
# Adding movie: 2003 Looney Tunes: Back in Action
# Adding movie: 2002 Collateral Damage
# Adding movie: 1967 Divorce American Style
# Adding movie: 2013 200 Cartas
# Adding movie: 1944 I'll Be Seeing You
# Adding movie: 1998 Species II
# Adding movie: 2001 Cats & Dogs
# Adding movie: 2009 Cherrybomb
# Adding movie: 1997 Mousehunt
# Adding movie: 2008 Hell Ride
# Adding movie: 1995 The Net
# Adding movie: 1968 The Odd Couple
# Adding movie: 1998 Buffalo '66
# Adding movie: 2010 Casino Jack
# Adding movie: 2005 White Noise
# Adding movie: 1984 Breakin'
# Adding movie: 1995 Assassins
# Adding movie: 2009 To Save a Life
# Adding movie: 2001 Koroshiya 1
# Adding movie: 1983 The Dead Zone
# Adding movie: 1980 American Gigolo
# Adding movie: 1996 Eraser
# Adding movie: 2013 The Wee Man
# Adding movie: 2004 First Daughter
# Adding movie: 1932 Love Me Tonight
# Adding movie: 2011 The Trouble with Bliss
# Adding movie: 1995 Something to Talk About
# Adding movie: 2000 The Kid
# Adding movie: 1988 The Presidio
# Adding movie: 2014 Everest
# Adding movie: 2007 Things We Lost in the Fire
# Adding movie: 1990 Problem Child
# Adding movie: 2000 Proof of Life
# Adding movie: 2004 Mean Creek
# Adding movie: 1972 Jeremiah Johnson
# Adding movie: 2014 Rudderless
# Adding movie: 1958 Teacher's Pet
# Adding movie: 2010 Henry's Crime
# Adding movie: 2012 Museum Hours
# Adding movie: 2014 Kill the Messenger
# Adding movie: 2010 Howl
# Adding movie: 2012 My Amityville Horror
# Adding movie: 1999 Titus
# Adding movie: 1994 Once Were Warriors
# Adding movie: 2008 Over Her Dead Body
# Adding movie: 2012 The Guest House
# Adding movie: 2013 Dealin' with Idiots
# Adding movie: 2012 No
# Adding movie: 2003 Ondskan
# Adding movie: 2009 Madea Goes to Jail
# Adding movie: 1996 The Arrival
# Adding movie: 1991 Out for Justice
# Adding movie: 2013 The Adventurer: The Curse of the Midas Box
# Adding movie: 1998 Disturbing Behavior
# Adding movie: 1969 Battle of Britain
# Adding movie: 2014 Mission: Blacklist
# Adding movie: 1998 The Players Club
# Adding movie: 2002 Stuart Little 2
# Adding movie: 2006 See No Evil
# Adding movie: 2007 The Visitor
# Adding movie: 1937 La grande illusion
# Adding movie: 2009 My One and Only
# Adding movie: 2005 The Matador
# Adding movie: 2010 My Name Is Khan
# Adding movie: 1994 The Pagemaster
# Adding movie: 2012 The Dinosaur Project
# Adding movie: 2004 My Summer of Love
# Adding movie: 1986 The Mosquito Coast
# Adding movie: 2003 It Runs in the Family
# Adding movie: 2007 Blood and Chocolate
# Adding movie: 2003 Shattered Glass
# Adding movie: 2009 The Pink Panther 2
# Adding movie: 2012 Tai Chi Hero
# Adding movie: 1975 The Eiger Sanction
# Adding movie: 2000 Tigerland
# Adding movie: 2014 The Captive
# Adding movie: 2012 Among Friends
# Adding movie: 1995 Circle of Friends
# Adding movie: 2013 3 Geezers!
# Adding movie: 2013 Trust Me
# Adding movie: 2010 Prowl
# Adding movie: 1994 Thumbelina
# Adding movie: 2000 Here on Earth
# Adding movie: 2001 Dust
# Adding movie: 2011 Panic Button
# Adding movie: 2003 Jeux d'enfants
# Adding movie: 1967 Valley of the Dolls
# Adding movie: 2014 Endless Love
# Adding movie: 1990 Gremlins 2: The New Batch
# Adding movie: 2001 In the Bedroom
# Adding movie: 1978 Force 10 from Navarone
# Adding movie: 1996 Marvin's Room
# Adding movie: 2011 Sisters & Brothers
# Adding movie: 2008 The Stoning of Soraya M.
# Adding movie: 2002 S1m0ne
# Adding movie: 2008 Me and Orson Welles
# Adding movie: 2002 Igby Goes Down
# Adding movie: 2006 The Ant Bully
# Adding movie: 2013 Ashley
# Adding movie: 1991 Freddy's Dead: The Final Nightmare
# Adding movie: 2014 Business Trip
# Adding movie: 1980 Xanadu
# Adding movie: 2003 Ned Kelly
# Adding movie: 2014 Life After Beth
# Adding movie: 2007 Postal
# Adding movie: 2013 The Angriest Man in Brooklyn
# Adding movie: 2001 Kabhi Khushi Kabhie Gham...
# Adding movie: 2005 Three
# Adding movie: 2002 Analyze That
# Adding movie: 1968 Funny Girl
# Adding movie: 2006 Fur: An Imaginary Portrait of Diane Arbus
# Adding movie: 2002 The Importance of Being Earnest
# Adding movie: 2011 Black Butterflies
# Adding movie: 2005 Rebound
# Adding movie: 2002 24 Hour Party People
# Adding movie: 2001 Antitrust
# Adding movie: 1990 Lionheart
# Adding movie: 1935 The Whole Town's Talking
# Adding movie: 2013 Oculus
# Adding movie: 1992 Juice
# Adding movie: 1998 Dirty Work
# Adding movie: 1987 Throw Momma from the Train
# Adding movie: 1995 The Brady Bunch Movie
# Adding movie: 2002 Trapped
# Adding movie: 1983 The Hunger
# Adding movie: 2011 The Loneliest Planet
# Adding movie: 1988 Red Heat
# Adding movie: 2013 Mr. Morgan's Last Love
# Adding movie: 1987 Beverly Hills Cop II
# Adding movie: 2002 The Magdalene Sisters
# Adding movie: 2002 Bowling for Columbine
# Adding movie: 1988 A Nightmare on Elm Street 4: The Dream Master
# Adding movie: 1978 Watership Down
# Adding movie: 2002 The Salton Sea
# Adding movie: 1988 Scrooged
# Adding movie: 2012 Paradies: Glaube
# Adding movie: 2002 Whale Rider
# Adding movie: 2014 Tokarev
# Adding movie: 2009 Gentlemen Broncos
# Adding movie: 2008 Management
# Adding movie: 1994 The Hudsucker Proxy
# Adding movie: 2012 40 Days and Nights
# Adding movie: 1992 Forever Young
# Adding movie: 2013 Don Peyote
# Adding movie: 1993 So I Married an Axe Murderer
# Adding movie: 1986 37.2 le matin
# Adding movie: 1989 UHF
# Adding movie: 1989 Henry V
# Adding movie: 1997 Carne tremula
# Adding movie: 2002 Boksuneun naui geot
# Adding movie: 1999 The General's Daughter
# Adding movie: 2010 Ajeossi
# Adding movie: 1994 The Shadow
# Adding movie: 2012 Girls Gone Dead
# Adding movie: 1993 Rookie of the Year
# Adding movie: 1974 The Towering Inferno
# Adding movie: 1972 The Poseidon Adventure
# Adding movie: 2009 Creation
# Adding movie: 2004 Fahrenheit 9/11
# Adding movie: 1986 The Delta Force
# Adding movie: 2012 Wrong
# Adding movie: 1982 Halloween III: Season of the Witch
# Adding movie: 2011 Rundskop
# Adding movie: 1996 The Glimmer Man
# Adding movie: 2013 Aashiqui 2
# Adding movie: 2007 Anamorph
# Adding movie: 2010 Our Family Wedding
# Adding movie: 2011 Beneath the Darkness
# Adding movie: 1991 Double Impact
# Adding movie: 1999 The Other Sister
# Adding movie: 2007 I Think I Love My Wife
# Adding movie: 2011 La delicatesse
# Adding movie: 2011 The Reunion
# Adding movie: 1994 Trois couleurs: Rouge
# Adding movie: 1995 Total Eclipse
# Adding movie: 2012 Freeloaders
# Adding movie: 2009 Horsemen
# Adding movie: 1995 Welcome to the Dollhouse
# Adding movie: 2014 John Wick
# Adding movie: 1984 Bachelor Party
# Adding movie: 2006 Love and Other Disasters
# Adding movie: 1996 Jane Eyre
# Adding movie: 1982 The World According to Garp
# Adding movie: 1981 Mommie Dearest
# Adding movie: 2006 Madea's Family Reunion
# Adding movie: 2004 The Football Factory
# Adding movie: 2007 Mama's Boy
# Adding movie: 2012 Despues de Lucia
# Adding movie: 2013 uwantme2killhim?
# Adding movie: 2010 Elle s'appelait Sarah
# Adding movie: 2006 Man of the Year
# Adding movie: 2009 I Hate Valentine's Day
# Adding movie: 1981 Gallipoli
# Adding movie: 2012 The Thompsons
# Adding movie: 2012 The Citizen
# Adding movie: 1997 Deconstructing Harry
# Adding movie: 2011 Miss Bala
# Adding movie: 2003 All the Real Girls
# Adding movie: 2010 Barney's Version
# Adding movie: 2008 The Yellow Handkerchief
# Adding movie: 2006 Kidulthood
# Adding movie: 2002 In America
# Adding movie: 2018 Halloween III
# Adding movie: 1984 Repo Man
# Adding movie: 2013 McCanick
# Adding movie: 2009 Dread
# Adding movie: 2012 Grassroots
# Adding movie: 2009 The Maiden Heist
# Adding movie: 2012 Dead Season
# Adding movie: 1986 The Transformers: The Movie
# Adding movie: 1980 Coal Miner's Daughter
# Adding movie: 1999 Brokedown Palace
# Adding movie: 2012 Free Samples
# Adding movie: 2013 Home Sweet Home
# Adding movie: 2001 Say It Isn't So
# Adding movie: 1998 Jack Frost
# Adding movie: 2011 Floquet de Neu
# Adding movie: 1995 Nick of Time
# Adding movie: 1988 Vampire's Kiss
# Adding movie: 1980 Private Benjamin
# Adding movie: 2005 Manderlay
# Adding movie: 2010 Ca$h
# Adding movie: 1957 Man on Fire
# Adding movie: 1999 Blue Streak
# Adding movie: 2011 Guns, Girls and Gambling
# Adding movie: 2012 Good Deeds
# Adding movie: 1988 The Blob
# Adding movie: 1921 The Kid
# Adding movie: 1981 Arthur
# Adding movie: 2013 Self Storage
# Adding movie: 2012 Love Sick Love
# Adding movie: 2013 Where the Devil Hides
# Adding movie: 2007 Taare Zameen Par
# Adding movie: 2009 New in Town
# Adding movie: 2007 Daddy's Little Girls
# Adding movie: 2007 Borderland
# Adding movie: 2010 Triple Dog
# Adding movie: 2006 Griffin & Phoenix
# Adding movie: 2010 A bout portant
# Adding movie: 2011 Retreat
# Adding movie: 2009 This Is It
# Adding movie: 1995 Persuasion
# Adding movie: 2009 Amelia
# Adding movie: 2007 Rise of the Footsoldier
# Adding movie: 2002 Narc
# Adding movie: 2001 Jimmy Neutron: Boy Genius
# Adding movie: 1991 Not Without My Daughter
# Adding movie: 2012 Yi jiu si er
# Adding movie: 2006 Breaking and Entering
# Adding movie: 2002 Barbershop
# Adding movie: 2013 The Last Knights
# Adding movie: 1920 Das Cabinet des Dr. Caligari
# Adding movie: 2012 Biohazard: Damnation
# Adding movie: 1997 Fools Rush In
# Adding movie: 1979 Zombi 2
# Adding movie: 2003 Kangaroo Jack
# Adding movie: 2006 Les anges exterminateurs
# Adding movie: 2013 Monica Z
# Adding movie: 2006 The Sentinel
# Adding movie: 2008 American Violet
# Adding movie: 2012 Les infideles
# Adding movie: 1995 Dolores Claiborne
# Adding movie: 2011 The Entitled
# Adding movie: 1961 The Guns of Navarone
# Adding movie: 1989 Kickboxer
# Adding movie: 2011 The Pill
# Adding movie: 1966 Grand Prix
# Adding movie: 2009 Soul Kitchen
# Adding movie: 1993 Heart and Souls
# Adding movie: 2012 The Attack
# Adding movie: 2012 The Bates Haunting
# Adding movie: 1956 Moby Dick
# Adding movie: 1984 The Philadelphia Experiment
# Adding movie: 1998 Dead Man on Campus
# Adding movie: 2002 Slackers
# Adding movie: 2008 From Within
# Adding movie: 2010 Les aventures extraordinaires d'Adele Blanc-Sec
# Adding movie: 1993 Searching for Bobby Fischer
# Adding movie: 2012 Sassy Pants
# Adding movie: 1982 The Verdict
# Adding movie: 1999 For Love of the Game
# Adding movie: 1998 Dance with Me
# Adding movie: 2008 The Accidental Husband
# Adding movie: 1962 Cape Fear
# Adding movie: 1957 Trooper Hook
# Adding movie: 1963 Lord of the Flies
# Adding movie: 1992 Como agua para chocolate
# Adding movie: 2012 Renoir
# Adding movie: 2006 The Contract
# Adding movie: 2010 The Clinic
# Adding movie: 2004 Little Black Book

# %%
len(movie_list), movie_list[:2]
# Out:
# (4609,
#  [{'year': 2013,
#    'title': 'Rush',
#    'info': {'directors': ['Ron Howard'],
#     'release_date': '2013-09-02T00:00:00Z',
#     'rating': Decimal('8.3'),
#     'genres': ['Action', 'Biography', 'Drama', 'Sport'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTQyMDE0MTY0OV5BMl5BanBnXkFtZTcwMjI2OTI0OQ@@._V1_SX400_.jpg',
#     'plot': 'A re-creation of the merciless 1970s rivalry between Formula One rivals James Hunt and Niki Lauda.',
#     'rank': 2,
#     'running_time_secs': 7380,
#     'actors': ['Daniel Bruhl', 'Chris Hemsworth', 'Olivia Wilde']}},
#   {'year': 2013,
#    'title': 'Prisoners',
#    'info': {'directors': ['Denis Villeneuve'],
#     'release_date': '2013-08-30T00:00:00Z',
#     'rating': Decimal('8.2'),
#     'genres': ['Crime', 'Drama', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTg0NTIzMjQ1NV5BMl5BanBnXkFtZTcwNDc3MzM5OQ@@._V1_SX400_.jpg',
#     'plot': "When Keller Dover's daughter and her friend go missing, he takes matters into his own hands as the police pursue multiple leads and the pressure mounts. But just how far will this desperate father go to protect his family?",
#     'rank': 3,
#     'running_time_secs': 9180,
#     'actors': ['Hugh Jackman', 'Jake Gyllenhaal', 'Viola Davis']}}])

# %% [markdown]
# ### [Step 3: CRUD - Create, Read, Update, and Delete an Item](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStarted.Python.03.html)
#
# given (pk,sk), one can create/update/delete/get item for that primary_key (pk,sk)

# %% [markdown]
# #### Step 3.1: Create a New Item  - put_item()

# %%
# dynamodb = boto3.resource('dynamodb', region_name='us-west-2', endpoint_url="http://localhost:8000")

table = dynamodb.Table('Movies')

title = "The Big New Movie"
year = 2015

response = table.put_item(
   Item={
        'year': year,
        'title': title,
        'info': {
            'plot':"Nothing happens at all.",
            'rating': decimal.Decimal(0)
        }
    }
)

print("put_item succeeded:")
print(json.dumps(response, indent=4, cls=DecimalEncoder))
# Out:
# put_item succeeded:
# {
#     "ResponseMetadata": {
#         "RequestId": "25628f74-f6b0-475b-a81d-0a867ac12832",
#         "HTTPStatusCode": 200,
#         "HTTPHeaders": {
#             "content-type": "application/x-amz-json-1.0",
#             "x-amz-crc32": "2745614147",
#             "x-amzn-requestid": "25628f74-f6b0-475b-a81d-0a867ac12832",
#             "content-length": "2",
#             "server": "Jetty(8.1.12.v20130726)"
#         },
#         "RetryAttempts": 0
#     }
# }

# %% [markdown]
# creating the same New Item will not cause duplicate

# %%
title = "The Big New Movie"
year = 2015

response = table.put_item(
   Item={
        'year': year,
        'title': title,
        'info': {
            'plot':"Nothing happens at all.",
            'rating': decimal.Decimal(-10)
        }
    }
)

print("put_item succeeded:")
print(json.dumps(response, indent=4, cls=DecimalEncoder))
# Out:
# put_item succeeded:
# {
#     "ResponseMetadata": {
#         "RequestId": "b89cdc10-b8d8-4970-86d8-3fb611a90cc1",
#         "HTTPStatusCode": 200,
#         "HTTPHeaders": {
#             "content-type": "application/x-amz-json-1.0",
#             "x-amz-crc32": "2745614147",
#             "x-amzn-requestid": "b89cdc10-b8d8-4970-86d8-3fb611a90cc1",
#             "content-length": "2",
#             "server": "Jetty(8.1.12.v20130726)"
#         },
#         "RetryAttempts": 0
#     }
# }

# %% [markdown]
# #### Step 3.2: Read an Item - get_item()

# %%
table = dynamodb.Table('Movies')

# %%
table
# Out:
# dynamodb.Table(name='Movies')

# %%
title = "The Big New Movie"
year = 2015

try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    print("get_item succeeded:")
    print(json.dumps(item, indent=4, cls=DecimalEncoder))
# Out:
# get_item succeeded:
# {
#     "title": "The Big New Movie",
#     "year": 2015,
#     "info": {
#         "rating": -10,
#         "plot": "Nothing happens at all."
#     }
# }

# %% [markdown]
# #### Step 3.3: Update an Item
#
# `put_item()`  does `update_item()`

# %%
table = dynamodb.Table('Movies')

title = "The Big New Movie"
year = 2015
rating = 5.5
plot = "Everything happens all at once."
actors = ["Larry", "Moe", "Curly"]

try:
    response = table.update_item(
        Key={
            'year': year,
            'title': title
        },
        UpdateExpression="set info.rating=:r, info.plot=:p, info.actors=:a",
        ExpressionAttributeValues={
            ':r': decimal.Decimal(rating),
            ':p': plot,
            ':a': actors
        },
        ReturnValues="UPDATED_NEW"
    )
except ClientError as e:
    print(e.response['Error']['Message'])

# %%
response
# Out:
# {'Attributes': {'info': {'rating': Decimal('5.5'),
#    'actors': ['Larry', 'Moe', 'Curly'],
#    'plot': 'Everything happens all at once.'}},
#  'ResponseMetadata': {'RequestId': '258a044c-9ab5-4935-b764-f900d2afc531',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.0',
#    'x-amz-crc32': '2682384945',
#    'x-amzn-requestid': '258a044c-9ab5-4935-b764-f900d2afc531',
#    'content-length': '156',
#    'server': 'Jetty(8.1.12.v20130726)'},
#   'RetryAttempts': 0}}

# %%
title = "The Big New Movie"
year = 2015

try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    
item
# Out:
# {'title': 'The Big New Movie',
#  'year': Decimal('2015'),
#  'info': {'rating': Decimal('5.5'),
#   'actors': ['Larry', 'Moe', 'Curly'],
#   'plot': 'Everything happens all at once.'}}

# %% [markdown]
# #####  Update an Item conditionally

# %%
actor_count = 2
try:
    response = table.update_item(
        Key={
            'year': year,
            'title': title
        },
        UpdateExpression="remove info.actors[0]",
        ConditionExpression="size(info.actors) > :num",
        ExpressionAttributeValues={':num': actor_count},
        ReturnValues="UPDATED_NEW"
    )
except ClientError as e:
    if e.response['Error']['Code'] == "ConditionalCheckFailedException":
        print(e.response['Error']['Message'])
    else:
        raise

# %%
# update successful if actor_count < 3: "Larry" is removed
# The conditional request failed if actor_count >= 3

# %%
response
# Out:
# {'Attributes': {'info': {'rating': Decimal('5.5'),
#    'actors': ['Moe', 'Curly'],
#    'plot': 'Everything happens all at once.'}},
#  'ResponseMetadata': {'RequestId': 'dc950c7f-fd49-4de1-adc9-f1cf30962ff9',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.0',
#    'x-amz-crc32': '1320246852',
#    'x-amzn-requestid': 'dc950c7f-fd49-4de1-adc9-f1cf30962ff9',
#    'content-length': '142',
#    'server': 'Jetty(8.1.12.v20130726)'},
#   'RetryAttempts': 0}}

# %% [markdown]
# #### Step 3.6: Delete an Item

# %%
year = 2013
title = "Prisoners"

# %%
try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    
item
# Out:
# {'title': 'Prisoners',
#  'year': Decimal('2013'),
#  'info': {'actors': ['Hugh Jackman', 'Jake Gyllenhaal', 'Viola Davis'],
#   'release_date': '2013-08-30T00:00:00Z',
#   'plot': "When Keller Dover's daughter and her friend go missing, he takes matters into his own hands as the police pursue multiple leads and the pressure mounts. But just how far will this desperate father go to protect his family?",
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTg0NTIzMjQ1NV5BMl5BanBnXkFtZTcwNDc3MzM5OQ@@._V1_SX400_.jpg',
#   'directors': ['Denis Villeneuve'],
#   'rating': Decimal('8.2'),
#   'rank': Decimal('3'),
#   'running_time_secs': Decimal('9180')}}

# %%
try:
    response = table.delete_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    if e.response['Error']['Code'] == "ConditionalCheckFailedException":
        print(e.response['Error']['Message'])
    else:
        item = response['Item']

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': '257270bd-367d-484a-b3dd-7d3108d45341',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.0',
#    'x-amz-crc32': '2745614147',
#    'x-amzn-requestid': '257270bd-367d-484a-b3dd-7d3108d45341',
#    'content-length': '2',
#    'server': 'Jetty(8.1.12.v20130726)'},
#   'RetryAttempts': 0}}

# %%
try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    
item
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-bdbcf456cdc2> in <module>
#       9     print(e.response['Error']['Message'])
#      10 else:
# ---> 11     item = response['Item']
#      12
#      13 item
#
# KeyError: 'Item'

# %% [markdown]
# ##### Delete an Item conditionally

# %%
year = 2013
title = "The Hunger Games: Catching Fire"
rank = 5

# %%
try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    
item
# Out:
# {'title': 'The Hunger Games: Catching Fire',
#  'year': Decimal('2013'),
#  'info': {'actors': ['Jennifer Lawrence', 'Josh Hutcherson', 'Liam Hemsworth'],
#   'release_date': '2013-11-11T00:00:00Z',
#   'plot': 'Katniss Everdeen and Peeta Mellark become targets of the Capitol after their victory in the 74th Hunger Games sparks a rebellion in the Districts of Panem.',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTAyMjQ3OTAxMzNeQTJeQWpwZ15BbWU4MDU0NzA1MzAx._V1_SX400_.jpg',
#   'directors': ['Francis Lawrence'],
#   'rank': Decimal('4'),
#   'running_time_secs': Decimal('8760')}}

# %% [raw]
# ## avoid update/delete item using reserved keyword
# https://intellipaat.com/community/17771/update-attribute-timestamp-reserved-word

# %%
try:
    response = table.delete_item(
        Key={
            'year': year,
            'title': title
        },
        ConditionExpression="info.#rnk <= :val",
        ExpressionAttributeValues={
            ":val": decimal.Decimal(rank)
        },
        ExpressionAttributeNames={
            "#rnk": "rank"
        }
    )
except ClientError as e:
    if e.response['Error']['Code'] == "ConditionalCheckFailedException":
        print(e.response['Error']['Message'])
    else:
        raise

# %%
try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    
item
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-bdbcf456cdc2> in <module>
#       9     print(e.response['Error']['Message'])
#      10 else:
# ---> 11     item = response['Item']
#      12
#      13 item
#
# KeyError: 'Item'

# %% [markdown]
# ### [Step 4: Query and Scan the Data](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStarted.Python.04.html)
#
#
# - [Working with Queries](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/Query.html)
#     - begins_with
#     - between
#     - eq
#     - gt
#     - gte
#     - lt
#     - lte
#     - mro

# %% [markdown]
# #### Query - All Movies Released in a Year
#
# * matching by partition key and sort key

# %%
year = 2009
table = dynamodb.Table('Movies')
response = table.query(
    # KeyConditionExpression=Key('year').eq(year) & Key('title').begins_with('H')
    # KeyConditionExpression=Key('year').eq(year) & Key('title').gt('H')
    KeyConditionExpression=Key('year').eq(year) & Key('title').between('B', 'D')
)

# %%
response
# Out:
# {'Items': [{'title': 'Bakjwi',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Kang-ho Song', 'Ok-bin Kim', 'Hae-suk Kim'],
#     'release_date': '2009-04-30T00:00:00Z',
#     'plot': 'Through a failed medical experiment, a priest is stricken with vampirism and is forced to abandon his ascetic ways.',
#     'genres': ['Drama', 'Horror', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BNDgwODY0MjM3OV5BMl5BanBnXkFtZTcwNzk3MTY2Mg@@._V1_SX400_.jpg',
#     'directors': ['Chan-wook Park'],
#     'rating': Decimal('7.1'),
#     'rank': Decimal('3837'),
#     'running_time_secs': Decimal('7980')}},
#   {'title': 'Bandslam',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Aly Michalka', 'Vanessa Hudgens', 'Gaelan Connell'],
#     'release_date': '2009-08-06T00:00:00Z',
#     'plot': 'A new kid in town assembles a fledgling rock band -- together, they achieve their dreams and compete against the best in the biggest event of the year, a battle of the bands.',
#     'genres': ['Comedy', 'Drama', 'Family', 'Music', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTg0MDI4MTIzMV5BMl5BanBnXkFtZTcwMDU5MjI2Mg@@._V1_SX400_.jpg',
#     'directors': ['Todd Graff'],
#     'rating': Decimal('6.3'),
#     'rank': Decimal('4644'),
#     'running_time_secs': Decimal('6660')}},
#   {'title': 'Banlieue 13 - Ultimatum',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Cyril Raffaelli', 'David Belle', 'Philippe Torreton'],
#     'release_date': '2009-02-18T00:00:00Z',
#     'plot': "Damien and Leito return to District 13 on a mission to bring peace to the troubled sector that is controlled by five different gang bosses, before the city's secret services take drastic measures to solve the problem.",
#     'genres': ['Action', 'Crime', 'Sci-Fi', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTUyNjY5MDU4MF5BMl5BanBnXkFtZTcwNDAzNzEwMw@@._V1_SX400_.jpg',
#     'directors': ['Patrick Alessandrin'],
#     'rating': Decimal('6.4'),
#     'rank': Decimal('3288'),
#     'running_time_secs': Decimal('6060')}},
#   {'title': 'Bitch Slap',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Julia Voth', 'Erin Cummings', 'America Olivo'],
#     'release_date': '2009-09-14T00:00:00Z',
#     'plot': 'Three bad girls travel to a remote desert hideaway to steal $200 million in diamonds from a ruthless underworld kingpin.',
#     'genres': ['Action', 'Comedy', 'Crime', 'Drama', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTk0OTAzOTY2NF5BMl5BanBnXkFtZTcwMzcwMzM4MQ@@._V1_SX400_.jpg',
#     'directors': ['Rick Jacobson'],
#     'rating': Decimal('4.4'),
#     'rank': Decimal('3181'),
#     'running_time_secs': Decimal('6540')}},
#   {'title': 'Black Dynamite',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Arsenio Hall', 'Tommy Davidson', 'Phyllis Applegate'],
#     'release_date': '2009-01-18T00:00:00Z',
#     'plot': "Black Dynamite is the greatest African-American action star of the 1970s. When his only brother is killed by The Man it's up to him to find justice.",
#     'genres': ['Action', 'Comedy'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTExNzUxNDU4NTReQTJeQWpwZ15BbWU3MDc5MDEzNjM@._V1_SX400_.jpg',
#     'directors': ['Scott Sanders'],
#     'rating': Decimal('7.2'),
#     'rank': Decimal('3572'),
#     'running_time_secs': Decimal('5040')}},
#   {'title': 'Blood and Bone',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Michael Jai White', 'Julian Sands', 'Eamonn Walker'],
#     'release_date': '2009-09-15T00:00:00Z',
#     'plot': 'In Los Angeles, an ex-con takes the underground fighting world by storm in his quest to fulfill a promise to a dead friend.',
#     'genres': ['Action', 'Drama'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BNjE0MDc4ODY4Ml5BMl5BanBnXkFtZTcwNDI2NjM4Mg@@._V1_SX400_.jpg',
#     'directors': ['Ben Ramsey'],
#     'rating': Decimal('6.6'),
#     'rank': Decimal('2783'),
#     'running_time_secs': Decimal('5580')}},
#   {'title': 'Bride Wars',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Kate Hudson', 'Anne Hathaway', 'Candice Bergen'],
#     'release_date': '2009-01-05T00:00:00Z',
#     'plot': 'Two best friends become rivals when they schedule their respective weddings on the same day.',
#     'genres': ['Comedy', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTA2MjU3NjQ3NzReQTJeQWpwZ15BbWU3MDEyNzE4OTE@._V1_SX400_.jpg',
#     'directors': ['Gary Winick'],
#     'rating': Decimal('5.1'),
#     'rank': Decimal('1810'),
#     'running_time_secs': Decimal('5340')}},
#   {'title': 'Bright Star',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Abbie Cornish', 'Ben Whishaw', 'Paul Schneider'],
#     'release_date': '2009-05-15T00:00:00Z',
#     'plot': 'The three-year romance between 19th century poet John Keats and Fanny Brawne.',
#     'genres': ['Biography', 'Drama', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTg0NjEwNDgxNF5BMl5BanBnXkFtZTcwMjkyOTM3Mg@@._V1_SX400_.jpg',
#     'directors': ['Jane Campion'],
#     'rating': Decimal('6.9'),
#     'rank': Decimal('2571'),
#     'running_time_secs': Decimal('7140')}},
#   {'title': "Brooklyn's Finest",
#    'year': Decimal('2009'),
#    'info': {'actors': ['Richard Gere', 'Don Cheadle', 'Ethan Hawke'],
#     'release_date': '2009-01-16T00:00:00Z',
#     'plot': 'Three unconnected Brooklyn cops wind up at the same deadly location after enduring vastly different career paths.',
#     'genres': ['Crime', 'Drama', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTUyMTI5MTY5MV5BMl5BanBnXkFtZTcwNzAyOTMwMw@@._V1_SX400_.jpg',
#     'directors': ['Antoine Fuqua'],
#     'rating': Decimal('6.7'),
#     'rank': Decimal('2296'),
#     'running_time_secs': Decimal('7920')}},
#   {'title': 'Brothers',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Jake Gyllenhaal', 'Natalie Portman', 'Tobey Maguire'],
#     'release_date': '2009-12-03T00:00:00Z',
#     'plot': "A young man comforts his older brother's wife and children after he goes missing in Afghanistan.",
#     'genres': ['Drama', 'Thriller', 'War'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTkyMTY5MTcxOV5BMl5BanBnXkFtZTcwMTI3MDE3Mg@@._V1_SX400_.jpg',
#     'directors': ['Jim Sheridan'],
#     'rating': Decimal('7.1'),
#     'rank': Decimal('1020'),
#     'running_time_secs': Decimal('6300')}},
#   {'title': 'Bruno',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Sacha Baron Cohen',
#      'Gustaf Hammarsten',
#      'Clifford Banagale'],
#     'release_date': '2009-06-25T00:00:00Z',
#     'plot': 'Flamboyant Austrian fashionista Bruno takes his show to America.',
#     'genres': ['Comedy'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTUwNDIwNDE5MV5BMl5BanBnXkFtZTcwMDA2MzA1Mg@@._V1_SX400_.jpg',
#     'directors': ['Larry Charles'],
#     'rating': Decimal('5.9'),
#     'rank': Decimal('2115'),
#     'running_time_secs': Decimal('4860')}},
#   {'title': 'Carriers',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Chris Pine', 'Piper Perabo', 'Lou Taylor Pucci'],
#     'release_date': '2009-08-18T00:00:00Z',
#     'plot': 'Four friends fleeing a viral pandemic soon learn they are more dangerous than any virus.',
#     'genres': ['Drama', 'Horror', 'Sci-Fi', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTYwOTcxMzYxMl5BMl5BanBnXkFtZTcwODQyODQ3Mg@@._V1_SX400_.jpg',
#     'directors': ['David Pastor', 'Alex Pastor'],
#     'rating': Decimal('6'),
#     'rank': Decimal('2911'),
#     'running_time_secs': Decimal('5040')}},
#   {'title': 'Case 39',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Renee Zellweger', 'Ian McShane', 'Jodelle Ferland'],
#     'release_date': '2009-08-13T00:00:00Z',
#     'plot': 'A social worker fights to save a girl from her abusive parents, only to discover that the situation is more dangerous than she ever expected.',
#     'genres': ['Horror', 'Mystery', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BNTA4NDUyOTE5NV5BMl5BanBnXkFtZTcwOTQ3NzY3Mw@@._V1_SX400_.jpg',
#     'directors': ['Christian Alvart'],
#     'rating': Decimal('6'),
#     'rank': Decimal('1967'),
#     'running_time_secs': Decimal('6540')}},
#   {'title': 'Celda 211',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Luis Tosar', 'Alberto Ammann', 'Antonio Resines'],
#     'release_date': '2009-09-04T00:00:00Z',
#     'plot': 'The story of two men on different sides of a prison riot -- the inmate leading the rebellion and the young guard trapped in the revolt, who poses as a prisoner in a desperate attempt to survive the ordeal.',
#     'genres': ['Action', 'Drama', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTU5NTQ2NTMyMV5BMl5BanBnXkFtZTcwNzA0MTcyOQ@@._V1_SX400_.jpg',
#     'directors': ['Daniel Monzon'],
#     'rating': Decimal('7.6'),
#     'rank': Decimal('2864'),
#     'running_time_secs': Decimal('6780')}},
#   {'title': 'Cherrybomb',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Rupert Grint', 'Robert Sheehan', 'James Nesbitt'],
#     'release_date': '2009-02-08T00:00:00Z',
#     'plot': 'Three teenagers go on a wild weekend of drink, drugs, shop-lifting and stealing cars that quickly spins beyond their control.',
#     'genres': ['Drama', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTM4MTE1NDQ5M15BMl5BanBnXkFtZTcwMjEwOTM0Mg@@._V1_SX400_.jpg',
#     'directors': ["Lisa Barros D'Sa", 'Glenn Leyburn'],
#     'rating': Decimal('5.9'),
#     'rank': Decimal('4685'),
#     'running_time_secs': Decimal('5160')}},
#   {'title': "Cirque du Freak: The Vampire's Assistant",
#    'year': Decimal('2009'),
#    'info': {'actors': ['Chris Massoglia', 'John C. Reilly', 'Salma Hayek'],
#     'release_date': '2009-10-22T00:00:00Z',
#     'plot': 'Teenager, Darren Shan, meets a mysterious man at a freak show who turns out to be a Vampire. After a series of events Darren must leave his normal life and go on the road with the Cirque Du Freak and become a Vampire.',
#     'genres': ['Action', 'Adventure', 'Fantasy', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTI1NDA1MTMwNl5BMl5BanBnXkFtZTcwNTg0MDE4Mg@@._V1_SX400_.jpg',
#     'directors': ['Paul Weitz'],
#     'rating': Decimal('5.9'),
#     'rank': Decimal('1335'),
#     'running_time_secs': Decimal('6540')}},
#   {'title': 'City Island',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Andy Garcia', 'Julianna Margulies', 'Steven Strait'],
#     'release_date': '2009-03-23T00:00:00Z',
#     'genres': ['Comedy', 'Drama'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTM1MTY2Mjk0Nl5BMl5BanBnXkFtZTcwMDYxODkxMw@@._V1_SX400_.jpg',
#     'directors': ['Raymond De Felitta'],
#     'rating': Decimal('7.3'),
#     'rank': Decimal('3619'),
#     'running_time_secs': Decimal('6240')}},
#   {'title': 'Cloudy with a Chance of Meatballs',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Anna Faris', 'Bill Hader', 'Bruce Campbell'],
#     'release_date': '2009-09-16T00:00:00Z',
#     'plot': "The most delicious event since macaroni met cheese. Inspired by the beloved children's book, the film focuses on a town where food falls from the sky like rain.",
#     'genres': ['Animation', 'Comedy', 'Family', 'Fantasy'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTg0MjAwNDI5MV5BMl5BanBnXkFtZTcwODkyMzg2Mg@@._V1_SX400_.jpg',
#     'directors': ['Phil Lord', 'Chris Miller'],
#     'rating': Decimal('7'),
#     'rank': Decimal('153'),
#     'running_time_secs': Decimal('5400')}},
#   {'title': 'Coco avant Chanel',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Audrey Tautou',
#      'Benoit Poelvoorde',
#      'Alessandro Nivola'],
#     'release_date': '2009-04-22T00:00:00Z',
#     'plot': "The story of Coco Chanel's rise from obscure beginnings to the heights of the fashion world.",
#     'genres': ['Biography', 'Drama'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTA0NjYzMzQxNzBeQTJeQWpwZ15BbWU3MDI2MDA0ODI@._V1_SX400_.jpg',
#     'directors': ['Anne Fontaine'],
#     'rating': Decimal('6.5'),
#     'rank': Decimal('3716'),
#     'running_time_secs': Decimal('6300')}},
#   {'title': 'Confessions of a Shopaholic',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Isla Fisher', 'Hugh Dancy', 'Krysten Ritter'],
#     'release_date': '2009-02-05T00:00:00Z',
#     'plot': 'A college grad lands a job as a financial journalist in New York City to support where she nurtures her shopping addiction and falls for a wealthy entrepreneur.',
#     'genres': ['Comedy', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTQ1MzcyMTkwOF5BMl5BanBnXkFtZTcwMDM3MTc5MQ@@._V1_SX400_.jpg',
#     'directors': ['P.J. Hogan'],
#     'rating': Decimal('5.6'),
#     'rank': Decimal('1953'),
#     'running_time_secs': Decimal('6240')}},
#   {'title': 'Coraline',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Dakota Fanning', 'Teri Hatcher', 'John Hodgman'],
#     'release_date': '2009-02-05T00:00:00Z',
#     'plot': 'An adventurous girl finds another world that is a strangely idealized version of her frustrating home, but it has sinister secrets.',
#     'genres': ['Animation', 'Fantasy', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMzQxNjM5NzkxNV5BMl5BanBnXkFtZTcwMzg5NDMwMg@@._V1_SX400_.jpg',
#     'directors': ['Henry Selick'],
#     'rating': Decimal('7.6'),
#     'rank': Decimal('1047'),
#     'running_time_secs': Decimal('6000')}},
#   {'title': 'Couples Retreat',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Vince Vaughn', 'Malin Akerman', 'Jon Favreau'],
#     'release_date': '2009-10-08T00:00:00Z',
#     'plot': "A comedy centered around four couples who settle into a tropical-island resort for a vacation. While one of the couples is there to work on the marriage, the others fail to realize that participation in the resort's therapy sessions is not optional.",
#     'genres': ['Comedy'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTQxMjI1Nzc0M15BMl5BanBnXkFtZTcwMTc0Mzg2Mg@@._V1_SX400_.jpg',
#     'directors': ['Peter Billingsley'],
#     'rating': Decimal('5.4'),
#     'rank': Decimal('252'),
#     'running_time_secs': Decimal('6780')}},
#   {'title': 'Cracks',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Eva Green', 'Juno Temple', 'Maria Valverde'],
#     'release_date': '2009-09-11T00:00:00Z',
#     'plot': 'A look at the lives and relationships among girls at an elite boarding school.',
#     'genres': ['Drama', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTMwNTEzODc2NF5BMl5BanBnXkFtZTcwOTQ0MTU2NA@@._V1_SX400_.jpg',
#     'directors': ['Jordan Scott'],
#     'rating': Decimal('6.5'),
#     'rank': Decimal('3482'),
#     'running_time_secs': Decimal('6240')}},
#   {'title': 'Crank: High Voltage',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Jason Statham', 'Amy Smart', 'Clifton Collins Jr.'],
#     'release_date': '2009-04-16T00:00:00Z',
#     'plot': 'Chelios faces a Chinese mobster who has stolen his nearly indestructible heart and replaced it with a battery-powered ticker that requires regular jolts of electricity to keep working.',
#     'genres': ['Action', 'Comedy', 'Crime', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTQzNTU1ODkxNl5BMl5BanBnXkFtZTcwMDgyODEzMg@@._V1_SX400_.jpg',
#     'directors': ['Mark Neveldine', 'Brian Taylor'],
#     'rating': Decimal('6.1'),
#     'rank': Decimal('1855'),
#     'running_time_secs': Decimal('5760')}},
#   {'title': 'Crazy Heart',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Jeff Bridges', 'Maggie Gyllenhaal', 'Colin Farrell'],
#     'release_date': '2009-12-06T00:00:00Z',
#     'plot': 'A faded country music musician is forced to reassess his dysfunctional life during a doomed romance that also inspires him.',
#     'genres': ['Drama', 'Music', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTU0NDc5NjgzNl5BMl5BanBnXkFtZTcwNzc0NDIzMw@@._V1_SX400_.jpg',
#     'directors': ['Scott Cooper'],
#     'rating': Decimal('7.3'),
#     'rank': Decimal('2644'),
#     'running_time_secs': Decimal('6720')}},
#   {'title': 'Creation',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Paul Bettany', 'Jennifer Connelly', 'Ian Kelly'],
#     'release_date': '2009-09-10T00:00:00Z',
#     'plot': 'English naturalist Charles Darwin struggles to find a balance between his revolutionary theories on evolution and the relationship with religious wife, whose faith contradicts his work.',
#     'genres': ['Drama', 'Biography'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjAwMjgxMDUwNl5BMl5BanBnXkFtZTcwMjM3ODAxMw@@._V1_SX400_.jpg',
#     'directors': ['Jon Amiel'],
#     'rating': Decimal('6.6'),
#     'rank': Decimal('4847'),
#     'running_time_secs': Decimal('6480')}},
#   {'title': 'Crossing Over',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Harrison Ford', 'Ashley Judd', 'Ray Liotta'],
#     'release_date': '2009-02-26T00:00:00Z',
#     'genres': ['Drama'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjAyMDQ3ODU4NV5BMl5BanBnXkFtZTcwNzU2MTAzMg@@._V1_SX400_.jpg',
#     'directors': ['Wayne Kramer'],
#     'rating': Decimal('6.7'),
#     'rank': Decimal('2502'),
#     'running_time_secs': Decimal('6780')}}],
#  'Count': 27,
#  'ScannedCount': 27,
#  'ResponseMetadata': {'RequestId': 'd1e98232-e2cd-45c0-be7c-dea5c1846d3e',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.0',
#    'x-amz-crc32': '3314946402',
#    'x-amzn-requestid': 'd1e98232-e2cd-45c0-be7c-dea5c1846d3e',
#    'content-length': '17179',
#    'server': 'Jetty(8.1.12.v20130726)'},
#   'RetryAttempts': 0}}

# %%
len(response['Items']), response['Items'][:2]
# Out:
# (27,
#  [{'title': 'Bakjwi',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Kang-ho Song', 'Ok-bin Kim', 'Hae-suk Kim'],
#     'release_date': '2009-04-30T00:00:00Z',
#     'plot': 'Through a failed medical experiment, a priest is stricken with vampirism and is forced to abandon his ascetic ways.',
#     'genres': ['Drama', 'Horror', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BNDgwODY0MjM3OV5BMl5BanBnXkFtZTcwNzk3MTY2Mg@@._V1_SX400_.jpg',
#     'directors': ['Chan-wook Park'],
#     'rating': Decimal('7.1'),
#     'rank': Decimal('3837'),
#     'running_time_secs': Decimal('7980')}},
#   {'title': 'Bandslam',
#    'year': Decimal('2009'),
#    'info': {'actors': ['Aly Michalka', 'Vanessa Hudgens', 'Gaelan Connell'],
#     'release_date': '2009-08-06T00:00:00Z',
#     'plot': 'A new kid in town assembles a fledgling rock band -- together, they achieve their dreams and compete against the best in the biggest event of the year, a battle of the bands.',
#     'genres': ['Comedy', 'Drama', 'Family', 'Music', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTg0MDI4MTIzMV5BMl5BanBnXkFtZTcwMDU5MjI2Mg@@._V1_SX400_.jpg',
#     'directors': ['Todd Graff'],
#     'rating': Decimal('6.3'),
#     'rank': Decimal('4644'),
#     'running_time_secs': Decimal('6660')}}])

# %% [markdown]
# #### Query with pagination
#
# * `ScanIndexForward` controls sort order
# * `LastEvaluatedKey` in `response` indicates there are more results to fetch

# %%
year = 1992
title_range = ('B', 'E')

# Expression attribute names can only reference items in the projection expression.
# year is a reserved word, use ExpressionAttributeNames to remap it
query_kwargs = {
    "ProjectionExpression": "#yr, title, info.genres, info.actors[0]",
    "ExpressionAttributeNames": {"#yr": "year"},
    "KeyConditionExpression": Key('year').eq(year) & Key('title').between(*title_range),
    "ScanIndexForward": False  # sort: ascending if True, descending if False 
}

## paginate
done, start_key = False, None
items = []
while not done:
    if start_key:
        query_kwargs['ExclusiveStartKey'] = start_key
    response = table.query(**query_kwargs)
    items.extend(response.get('Items', []))
    start_key = response.get('LastEvaluatedKey', None)
    done = start_key is None
    
len(items), items
# Out:
# (12,
#  [{'title': 'Death Becomes Her',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Meryl Streep'], 'genres': ['Comedy', 'Fantasy']}},
#   {'title': 'Damage',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Jeremy Irons'], 'genres': ['Drama', 'Romance']}},
#   {'title': 'Como agua para chocolate',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Marco Leonardi'], 'genres': ['Drama', 'Romance']}},
#   {'title': 'Chaplin',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Robert Downey Jr.'],
#     'genres': ['Biography', 'Drama']}},
#   {'title': 'Captain Ron',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Kurt Russell'], 'genres': ['Adventure', 'Comedy']}},
#   {'title': 'Candyman',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Virginia Madsen'], 'genres': ['Horror']}},
#   {'title': 'Buffy the Vampire Slayer',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Kristy Swanson'],
#     'genres': ['Action', 'Comedy', 'Fantasy', 'Horror']}},
#   {'title': 'Braindead',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Timothy Balme'], 'genres': ['Comedy', 'Horror']}},
#   {'title': 'Boomerang',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Eddie Murphy'],
#     'genres': ['Comedy', 'Drama', 'Romance']}},
#   {'title': 'Bitter Moon',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Hugh Grant'],
#     'genres': ['Drama', 'Romance', 'Thriller']}},
#   {'title': 'Beethoven',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Charles Grodin'],
#     'genres': ['Comedy', 'Drama', 'Family']}},
#   {'title': 'Batman Returns',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Michael Keaton'], 'genres': ['Action', 'Fantasy']}}])

# %% [markdown]
# #### Scan with pagination

# %%
year_range = (1950, 1955)
query_kwargs = {
    'FilterExpression': Key('year').between(*year_range),
    'ProjectionExpression': "#yr, title, info.rating",
    'ExpressionAttributeNames': {"#yr": "year"}
}

items = []

done, start_key = False, None
while not done:
    if start_key:
        query_kwargs['ExclusiveStartKey'] = start_key
    response = table.scan(**query_kwargs)
    items.extend(response.get('Items', []))
    start_key = response.get('LastEvaluatedKey', None)
    done = start_key is None

len(items), items[:3]
# Out:
# (38,
#  [{'title': 'High Noon',
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('8.2')}},
#   {'title': "Singin' in the Rain",
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('8.4')}},
#   {'title': 'The Member of the Wedding',
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('6.8')}}])

# %%
year_range = (1950, 1955)
query_kwargs = {
    'FilterExpression': Key('year').between(*year_range),
    'ProjectionExpression': "#yr, title, info.rating",
    'ExpressionAttributeNames': {"#yr": "year"}
}

items = []
response = table.scan(**query_kwargs)
items.extend(response['Items'])

# paginate in another way
while 'LastEvaluatedKey' in response:
    response = table.scan(ExclusiveStartKey=response['LastEvaluatedKey'], **query_kwargs)
    items.extend(response['Items'])

len(items), items[:3]
# Out:
# (38,
#  [{'title': 'High Noon',
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('8.2')}},
#   {'title': "Singin' in the Rain",
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('8.4')}},
#   {'title': 'The Member of the Wedding',
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('6.8')}}])

# %% [markdown]
# * FilterExpression - add condition on info.rating attribute

# %%
year_range = (1950, 1955)
query_kwargs = {
    'FilterExpression': Key('year').between(*year_range) & Attr('info.rating').gt(decimal.Decimal(8.0)),
    'ProjectionExpression': "#yr, title, info.rating",
    'ExpressionAttributeNames': {"#yr": "year"}
}

items = []
response = table.scan(**query_kwargs)
items.extend(response['Items'])

# paginate in another way
while 'LastEvaluatedKey' in response:
    response = table.scan(ExclusiveStartKey=response['LastEvaluatedKey'], **query_kwargs)
    items.extend(response['Items'])

len(items), items[:3]
# Out:
# (13,
#  [{'title': 'High Noon',
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('8.2')}},
#   {'title': "Singin' in the Rain",
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('8.4')}},
#   {'title': 'Dial M for Murder',
#    'year': Decimal('1954'),
#    'info': {'rating': Decimal('8.1')}}])

# %% [markdown]
# ### Delete a Table

# %%
table.delete()

# %% [markdown]
# ### Local Secondary Index (LSI)
#
# - https://highlandsolutions.com/blog/hands-on-examples-for-working-with-dynamodb-boto3-and-python

# %%
import boto3
from boto3.dynamodb.conditions import Key

def create_table_with_lsi():
    dynamodb = boto3.resource('dynamodb', endpoint_url=DYNAMO_ENDPOINT)
    
    table = dynamodb.create_table(
        TableName='Posts',
        KeySchema=[
            {
                'AttributeName': 'user_name',
                'KeyType': 'HASH'
            },
            {
                'AttributeName': 'title',
                'KeyType': 'RANGE'
            }
        ],
        AttributeDefinitions=[
            {
                'AttributeName': 'title',
                'AttributeType': 'S'
            },
            {
                'AttributeName': 'user_name',
                'AttributeType': 'S'
            },
            {
                'AttributeName': 'subject',
                'AttributeType': 'S'
            },
    
        ],
        LocalSecondaryIndexes=[
            {
                'IndexName': 'user_name_subject',
                'KeySchema': [
                    {
                        'AttributeName': 'user_name',
                        'KeyType': 'HASH'
                    },
                    {
                        'AttributeName': 'subject',
                        'KeyType': 'RANGE'
                    },
                ],
                'Projection': {
                    'ProjectionType': 'ALL'
                },
            }
        ],
        ProvisionedThroughput={
            'ReadCapacityUnits': 1,
            'WriteCapacityUnits': 1,
        }
    )

    print("Table status:", table.table_status)

def create_posts():
    post1 = {
        'title': "My favorite hiking spots",
        'user_name': 'jon_doe',
        'subject': 'hiking'
    }
    
    post2 = {
        'title': "My favorite recipes",
        'user_name': 'jon_doe',
        'subject': 'cooking'
    }
    
    post3 = {
        'title': "I love hiking!",
        'user_name': 'jane_doe',
        'subject': 'hiking'
    }
    
    dynamodb = boto3.resource('dynamodb', endpoint_url=DYNAMO_ENDPOINT)
    
    table = dynamodb.Table('Posts')
    
    table.put_item(Item=post1)
    table.put_item(Item=post2)
    table.put_item(Item=post3)

def query_data_with_lsi():
    dynamodb = boto3.resource('dynamodb', endpoint_url=DYNAMO_ENDPOINT)
    
    table = dynamodb.Table('Posts')
    
    response = table.query(
        IndexName='user_name_subject',
        KeyConditionExpression=
            Key('user_name').eq('jon_doe') & Key('subject').eq('hiking')
    )
    
    print(response['Items'][0])
    #{'subject': 'hiking', 'user_name': 'jon_doe', 'title': 'My favorite hiking spots'}

# %%
create_table_with_lsi()
# wait for a while

# %%
create_posts()

# %%
query_data_with_lsi()
# Out:
# {'title': 'My favorite hiking spots', 'user_name': 'jon_doe', 'subject': 'hiking'}

# %% [markdown]
# ### Global Secondary Index (GSI)
#
# - https://highlandsolutions.com/blog/hands-on-examples-for-working-with-dynamodb-boto3-and-python

# %%
import boto3
from boto3.dynamodb.conditions import Key

def create_table_with_gsi():
    dynamodb = boto3.resource('dynamodb', endpoint_url=DYNAMO_ENDPOINT)
    
    table = dynamodb.create_table(
        TableName='Employees',
        KeySchema=[
            {
                'AttributeName': 'emp_id',
                'KeyType': 'HASH'
            },
        ],
        AttributeDefinitions=[
            {
                'AttributeName': 'emp_id',
                'AttributeType': 'N'
            },
            {
                'AttributeName': 'email',
                'AttributeType': 'S'
            },
    
        ],
        GlobalSecondaryIndexes=[
            {
                'IndexName': 'email',
                'KeySchema': [
                    {
                        'AttributeName': 'email',
                        'KeyType': 'HASH'
                    },
                ],
                'Projection': {
                    'ProjectionType': 'ALL'
                },
                'ProvisionedThroughput' :{
                    'ReadCapacityUnits': 1,
                    'WriteCapacityUnits': 1,
                }
            }
        ],
        ProvisionedThroughput={
            'ReadCapacityUnits': 1,
            'WriteCapacityUnits': 1,
        }
    )

    print("Table status:", table.table_status)
    
def create_employee():
    dynamodb = boto3.resource('dynamodb', endpoint_url=DYNAMO_ENDPOINT)
    
    table = dynamodb.Table('Employees')
    for i in range(20):
        user = {
            'emp_id': i,
            'first_name': 'Jon'+str(i),
            'last_name': 'Doe',
            'email': f'jdoe{str(i)}@test.com'
        }    
        table.put_item(Item=user)
    
def query_data_with_gsi():
    dynamodb = boto3.resource('dynamodb', endpoint_url=DYNAMO_ENDPOINT)
    
    table = dynamodb.Table('Employees')
    
    response = table.query(
        IndexName='email',
        KeyConditionExpression=Key('email').eq('jdoe7@test.com')
    )
    
    print(response['Items'])
    #{'last_name': 'Doe', 'email': 'jdoe@test.com', 'first_name': 'Jon', 'emp_id': Decimal('1')}

# %%
create_table_with_gsi()
# Out:
# Table status: ACTIVE

# %%
create_employee()

# %%
query_data_with_gsi()
# Out:
# [{'last_name': 'Doe', 'first_name': 'Jon7', 'email': 'jdoe7@test.com', 'emp_id': Decimal('7')}]
