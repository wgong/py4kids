# %% [markdown]
# [Getting Started Developing with Python and DynamoDB](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStarted.Python.html)
#
#
# use Local DynamoDB

# %%
from boto3.dynamodb.conditions import Key

# %% [markdown]
# ### [Step 1: Create a Table](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStarted.Python.01.html)

# %%
DDB_ENDPOINT_URL="http://localhost:8000"

# %%
import boto3
# Get the service resource.
dynamodb = boto3.resource('dynamodb', endpoint_url=DDB_ENDPOINT_URL)

# %%
def create_movie_table(table_name='Movies', dynamodb=None):
    if not dynamodb:
        dynamodb = boto3.resource('dynamodb', endpoint_url=DDB_ENDPOINT_URL)
        
    try:
        table = dynamodb.Table(table_name)
        status = table.table_status
    except:

        # Error thrown when creating a pre-existing table
        # ResourceInUseException: An error occurred (ResourceInUseException) when calling the CreateTable operation: 
        # Cannot create preexisting table
        table = dynamodb.create_table(
            TableName=table_name,
            KeySchema=[
                {
                    'AttributeName': 'year',
                    'KeyType': 'HASH'  # Partition key
                },
                {
                    'AttributeName': 'title',
                    'KeyType': 'RANGE'  # Sort key
                }
            ],
            AttributeDefinitions=[
                {
                    'AttributeName': 'year',
                    'AttributeType': 'N'
                },
                {
                    'AttributeName': 'title',
                    'AttributeType': 'S'
                },

            ],
            ProvisionedThroughput={
                'ReadCapacityUnits': 5,
                'WriteCapacityUnits': 5
            }
        )
    return table

# %%
table = create_movie_table(table_name="Movies", dynamodb=dynamodb)
print("Table status:", table.table_status)
# Out:
# Table status: ACTIVE

# %% [markdown]
# ### [Step 2: Load Sample Data](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStarted.Python.02.html)

# %%
from decimal import Decimal
import json

def load_movies(movies, dynamodb=None):
    if not dynamodb:
        dynamodb = boto3.resource('dynamodb', endpoint_url="http://localhost:8000")

    table = dynamodb.Table('Movies')
    with table.batch_writer() as batch:
        for i in range(0, len(movies), 50):
            movie = movies[i]
            year = int(movie['year'])
            title = movie['title']
            batch.put_item(Item=movie)
        
with open("moviedata.json") as json_file:
    movie_list = json.load(json_file, parse_float=Decimal)
load_movies(movie_list)

# %% [raw]
# len(movie_list)

# %% [markdown]
# ### [Step 3: CRUD - Create, Read, Update, and Delete an Item](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStarted.Python.03.html)

# %% [markdown]
# #### Step 3.1: Create a New Item

# %%
from __future__ import print_function # Python 2/3 compatibility
import boto3
import json
import decimal

# Helper class to convert a DynamoDB item to JSON.
class DecimalEncoder(json.JSONEncoder):
    def default(self, o):
        if isinstance(o, decimal.Decimal):
            if abs(o) % 1 > 0:
                return float(o)
            else:
                return int(o)
        return super(DecimalEncoder, self).default(o)

# dynamodb = boto3.resource('dynamodb', region_name='us-west-2', endpoint_url="http://localhost:8000")

table = dynamodb.Table('Movies')

title = "The Big New Movie"
year = 2015

response = table.put_item(
   Item={
        'year': year,
        'title': title,
        'info': {
            'plot':"Nothing happens at all.",
            'rating': decimal.Decimal(0)
        }
    }
)

print("put_item succeeded:")
print(json.dumps(response, indent=4, cls=DecimalEncoder))
# Out:
# PutItem succeeded:
# {
#     "ResponseMetadata": {
#         "RequestId": "7b47f10a-e808-4bd4-8144-8e670857d361",
#         "HTTPStatusCode": 200,
#         "HTTPHeaders": {
#             "content-type": "application/x-amz-json-1.0",
#             "x-amz-crc32": "2745614147",
#             "x-amzn-requestid": "7b47f10a-e808-4bd4-8144-8e670857d361",
#             "content-length": "2",
#             "server": "Jetty(8.1.12.v20130726)"
#         },
#         "RetryAttempts": 0
#     }
# }

# %% [markdown]
# #### Step 3.2: Read an Item

# %%
table = dynamodb.Table('Movies')

title = "The Big New Movie"
year = 2015

try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    print("get_item succeeded:")
    print(json.dumps(item, indent=4, cls=DecimalEncoder))
# Out:
# GetItem succeeded:
# {
#     "title": "The Big New Movie",
#     "year": 2015,
#     "info": {
#         "rating": 0,
#         "plot": "Nothing happens at all."
#     }
# }

# %% [markdown]
# #### Step 3.3: Update an Item

# %%
table = dynamodb.Table('Movies')

title = "The Big New Movie"
year = 2015
rating = 5.5
plot = "Everything happens all at once."
actors = ["Larry", "Moe", "Curly"]

try:
    response = table.update_item(
        Key={
            'year': year,
            'title': title
        },
        UpdateExpression="set info.rating=:r, info.plot=:p, info.actors=:a",
        ExpressionAttributeValues={
            ':r': Decimal(rating),
            ':p': plot,
            ':a': actors
        },
        ReturnValues="UPDATED_NEW"
    )
except ClientError as e:
    print(e.response['Error']['Message'])

# %%
response
# Out:
# {'Attributes': {'info': {'rating': Decimal('5.5'),
#    'actors': ['Larry', 'Moe', 'Curly'],
#    'plot': 'Everything happens all at once.'}},
#  'ResponseMetadata': {'RequestId': 'f92ce558-7075-48e7-a6e4-8a4bdb6e9bef',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.0',
#    'x-amz-crc32': '2682384945',
#    'x-amzn-requestid': 'f92ce558-7075-48e7-a6e4-8a4bdb6e9bef',
#    'content-length': '156',
#    'server': 'Jetty(8.1.12.v20130726)'},
#   'RetryAttempts': 0}}

# %%
title = "The Big New Movie"
year = 2015

try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    
item
# Out:
# {'title': 'The Big New Movie',
#  'year': Decimal('2015'),
#  'info': {'rating': Decimal('5.5'),
#   'actors': ['Moe', 'Curly'],
#   'plot': 'Everything happens all at once.'}}

# %% [markdown]
# #####  Update an Item conditionally

# %%
actor_count = 2
try:
    response = table.update_item(
        Key={
            'year': year,
            'title': title
        },
        UpdateExpression="remove info.actors[0]",
        ConditionExpression="size(info.actors) > :num",
        ExpressionAttributeValues={':num': actor_count},
        ReturnValues="UPDATED_NEW"
    )
except ClientError as e:
    if e.response['Error']['Code'] == "ConditionalCheckFailedException":
        print(e.response['Error']['Message'])
    else:
        raise

# %%
# update successful if actor_count < 3: "Larry" is removed
# The conditional request failed if actor_count >= 3

# %% [markdown]
# #### Step 3.6: Delete an Item

# %%
year = 2013
title = "Prisoners"

# %%
try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    
item
# Out:
# {'title': 'Prisoners',
#  'year': Decimal('2013'),
#  'info': {'actors': ['Hugh Jackman', 'Jake Gyllenhaal', 'Viola Davis'],
#   'release_date': '2013-08-30T00:00:00Z',
#   'plot': "When Keller Dover's daughter and her friend go missing, he takes matters into his own hands as the police pursue multiple leads and the pressure mounts. But just how far will this desperate father go to protect his family?",
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTg0NTIzMjQ1NV5BMl5BanBnXkFtZTcwNDc3MzM5OQ@@._V1_SX400_.jpg',
#   'directors': ['Denis Villeneuve'],
#   'rating': Decimal('8.2'),
#   'rank': Decimal('3'),
#   'running_time_secs': Decimal('9180')}}

# %%
try:
    response = table.delete_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    if e.response['Error']['Code'] == "ConditionalCheckFailedException":
        print(e.response['Error']['Message'])
    else:
        item = response['Item']

# %%
response
# Out:
# {'ConsumedCapacity': {'TableName': 'Movies', 'CapacityUnits': 1.0},
#  'ResponseMetadata': {'RequestId': '1e393259-ea64-4015-a245-37f509b59b37',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.0',
#    'x-amz-crc32': '2336287325',
#    'x-amzn-requestid': '1e393259-ea64-4015-a245-37f509b59b37',
#    'content-length': '63',
#    'server': 'Jetty(8.1.12.v20130726)'},
#   'RetryAttempts': 0}}

# %%
try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    
item
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-bdbcf456cdc2> in <module>
#       9     print(e.response['Error']['Message'])
#      10 else:
# ---> 11     item = response['Item']
#      12
#      13 item
#
# KeyError: 'Item'

# %% [markdown]
# ##### Delete an Item conditionally

# %%
year = 2013
title = "The Hunger Games: Catching Fire"
rank = 5

# %%
try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    
item
# Out:
# {'title': 'The Hunger Games: Catching Fire',
#  'year': Decimal('2013'),
#  'info': {'actors': ['Jennifer Lawrence', 'Josh Hutcherson', 'Liam Hemsworth'],
#   'release_date': '2013-11-11T00:00:00Z',
#   'plot': 'Katniss Everdeen and Peeta Mellark become targets of the Capitol after their victory in the 74th Hunger Games sparks a rebellion in the Districts of Panem.',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTAyMjQ3OTAxMzNeQTJeQWpwZ15BbWU4MDU0NzA1MzAx._V1_SX400_.jpg',
#   'directors': ['Francis Lawrence'],
#   'rank': Decimal('4'),
#   'running_time_secs': Decimal('8760')}}

# %% [raw]
# ## avoid update/delete item using reserved keyword
# https://intellipaat.com/community/17771/update-attribute-timestamp-reserved-word

# %%
try:
    response = table.delete_item(
        Key={
            'year': year,
            'title': title
        },
        ConditionExpression="info.#rnk <= :val",
        ExpressionAttributeValues={
            ":val": Decimal(rank)
        },
        ExpressionAttributeNames={
            "#rnk": "rank"
        }
    )
except ClientError as e:
    if e.response['Error']['Code'] == "ConditionalCheckFailedException":
        print(e.response['Error']['Message'])
    else:
        raise

# %%
try:
    response = table.get_item(
        Key={
            'year': year,
            'title': title
        }
    )
except ClientError as e:
    print(e.response['Error']['Message'])
else:
    item = response['Item']
    
item
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-bdbcf456cdc2> in <module>
#       9     print(e.response['Error']['Message'])
#      10 else:
# ---> 11     item = response['Item']
#      12
#      13 item
#
# KeyError: 'Item'

# %% [markdown]
# ### [Step 4: Query and Scan the Data](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStarted.Python.04.html)

# %% [markdown]
# #### Query - All Movies Released in a Year

# %%
year = 1985
table = dynamodb.Table('Movies')
response = table.query(
    KeyConditionExpression=Key('year').eq(year)
)

# %%
response
# Out:
# {'Items': [{'title': "A Nightmare on Elm Street Part 2: Freddy's Revenge",
#    'year': Decimal('1985'),
#    'info': {'actors': ['Robert Englund', 'Mark Patton', 'Kim Myers'],
#     'release_date': '1985-10-01T00:00:00Z',
#     'plot': 'A teenage boy is haunted in his dreams by Freddy Krueger who is out to possess him to continue his murdering in the real world.',
#     'genres': ['Horror'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjA4OTA4NTA4MV5BMl5BanBnXkFtZTYwNTI2MjU5._V1_SX400_.jpg',
#     'directors': ['Jack Sholder'],
#     'rating': Decimal('5.1'),
#     'rank': Decimal('4008'),
#     'running_time_secs': Decimal('5220')}},
#   {'title': 'A Room with a View',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Maggie Smith',
#      'Helena Bonham Carter',
#      'Denholm Elliott'],
#     'release_date': '1985-12-13T00:00:00Z',
#     'genres': ['Drama', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTQyODE1NzMxMl5BMl5BanBnXkFtZTgwMjU2MTUxMDE@._V1_SX400_.jpg',
#     'directors': ['James Ivory'],
#     'rating': Decimal('7.3'),
#     'rank': Decimal('3049'),
#     'running_time_secs': Decimal('7020')}},
#   {'title': 'A View to a Kill',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Roger Moore', 'Christopher Walken', 'Tanya Roberts'],
#     'release_date': '1985-05-22T00:00:00Z',
#     'plot': "An investigation of a horse-racing scam leads 007 to a mad industrialist who plans to create a worldwide microchip monopoly by destroying California's Silicon Valley.",
#     'genres': ['Action', 'Adventure', 'Crime', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTMwMTYzOTIwM15BMl5BanBnXkFtZTcwODY5MDg0NA@@._V1_SX400_.jpg',
#     'directors': ['John Glen'],
#     'rating': Decimal('6.2'),
#     'rank': Decimal('2012'),
#     'running_time_secs': Decimal('7860')}},
#   {'title': 'After Hours',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Griffin Dunne', 'Rosanna Arquette', 'Verna Bloom'],
#     'release_date': '1985-09-13T00:00:00Z',
#     'plot': 'An ordinary word processor has the worst night of his life after he agrees to visit a girl in Soho whom he met that evening at a coffee shop.',
#     'genres': ['Comedy', 'Drama', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTUxMjEzMzI2MV5BMl5BanBnXkFtZTgwNTU3ODAxMDE@._V1_SX400_.jpg',
#     'directors': ['Martin Scorsese'],
#     'rating': Decimal('7.6'),
#     'rank': Decimal('4325'),
#     'running_time_secs': Decimal('5820')}},
#   {'title': 'Back to the Future',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Michael J. Fox', 'Christopher Lloyd', 'Lea Thompson'],
#     'release_date': '1985-07-03T00:00:00Z',
#     'plot': 'A teenager is accidentally sent 30 years into the past in a time-traveling DeLorean invented by his friend, Dr. Emmett Brown, and must make sure his high-school-age parents unite in order to save his own existence.',
#     'genres': ['Adventure', 'Comedy', 'Sci-Fi'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTk4OTQ1OTMwN15BMl5BanBnXkFtZTcwOTIwMzM3MQ@@._V1_SX400_.jpg',
#     'directors': ['Robert Zemeckis'],
#     'rating': Decimal('8.5'),
#     'rank': Decimal('204'),
#     'running_time_secs': Decimal('6960')}},
#   {'title': 'Better Off Dead...',
#    'year': Decimal('1985'),
#    'info': {'actors': ['John Cusack', 'David Ogden Stiers', 'Kim Darby'],
#     'release_date': '1985-08-23T00:00:00Z',
#     'plot': 'A teenager has to deal with his girlfriend dumping him among family crises, homicidal paper boys, and a rival skier.',
#     'genres': ['Comedy', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTI5MjEwNDg3M15BMl5BanBnXkFtZTcwODczNjYyMQ@@._V1_SX400_.jpg',
#     'directors': ['Savage Steve Holland'],
#     'rating': Decimal('7.1'),
#     'rank': Decimal('2585'),
#     'running_time_secs': Decimal('5820')}},
#   {'title': 'Brazil',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Jonathan Pryce', 'Kim Greist', 'Robert De Niro'],
#     'release_date': '1985-02-20T00:00:00Z',
#     'plot': 'A bureaucrat in a retro-future world tries to correct an administrative error and himself becomes an enemy of the state.',
#     'genres': ['Drama', 'Fantasy', 'Sci-Fi'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTIwMDQ1NzQyOF5BMl5BanBnXkFtZTcwMTE4MDQzMQ@@._V1_SX400_.jpg',
#     'directors': ['Terry Gilliam'],
#     'rating': Decimal('7.9'),
#     'rank': Decimal('1862'),
#     'running_time_secs': Decimal('7920')}},
#   {'title': 'Clue',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Eileen Brennan', 'Tim Curry', 'Madeline Kahn'],
#     'release_date': '1985-12-13T00:00:00Z',
#     'plot': 'Six guests are invited to a strange house and must cooperate with the staff to solve a murder mystery.',
#     'genres': ['Comedy', 'Crime', 'Mystery', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BNTc3NDc1ODYxNl5BMl5BanBnXkFtZTcwMjc5MDMyMQ@@._V1_SX400_.jpg',
#     'directors': ['Jonathan Lynn'],
#     'rating': Decimal('7.2'),
#     'rank': Decimal('1293'),
#     'running_time_secs': Decimal('5640')}},
#   {'title': 'Cocoon',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Don Ameche', 'Wilford Brimley', 'Hume Cronyn'],
#     'release_date': '1985-06-21T00:00:00Z',
#     'plot': 'When a group of trespassing seniors swim in a pool containing alien cocoons, they find themselves energized with youthful vigour.',
#     'genres': ['Comedy', 'Drama', 'Sci-Fi'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTc5MjAzMDYxM15BMl5BanBnXkFtZTcwMjE0OTUyMQ@@._V1_SX400_.jpg',
#     'directors': ['Ron Howard'],
#     'rating': Decimal('6.6'),
#     'rank': Decimal('3043'),
#     'running_time_secs': Decimal('7020')}},
#   {'title': 'Commando',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Arnold Schwarzenegger',
#      'Rae Dawn Chong',
#      'Dan Hedaya'],
#     'release_date': '1985-10-04T00:00:00Z',
#     'plot': 'A retired elite Black Ops Commando launches a one man war against a group of South American criminals who have kidnapped his daughter to blackmail him into starting a revolution and getting an exiled dictator back into power.',
#     'genres': ['Action', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTcyNzY4NjA2MF5BMl5BanBnXkFtZTcwNTkzNjk0MQ@@._V1_SX400_.jpg',
#     'directors': ['Mark L. Lester'],
#     'rating': Decimal('6.5'),
#     'rank': Decimal('1770'),
#     'running_time_secs': Decimal('5400')}},
#   {'title': 'Day of the Dead',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Lori Cardille', 'Terry Alexander', 'Joseph Pilato'],
#     'release_date': '1985-07-03T00:00:00Z',
#     'plot': 'A small group of military officers and scientists dwell in an underground bunker as the world above is overrun by zombies.',
#     'genres': ['Horror'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjEwNjQ5NDU4OF5BMl5BanBnXkFtZTYwOTI2NzA5._V1_SX400_.jpg',
#     'directors': ['George A. Romero'],
#     'rating': Decimal('7'),
#     'rank': Decimal('3999'),
#     'running_time_secs': Decimal('5760')}},
#   {'title': 'Enemy Mine',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Dennis Quaid', 'Louis Gossett Jr.', 'Brion James'],
#     'release_date': '1985-12-12T00:00:00Z',
#     'genres': ['Action', 'Adventure', 'Drama', 'Sci-Fi'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTkxODQ1NDMwMl5BMl5BanBnXkFtZTgwMTY4MjQxMDE@._V1_SX400_.jpg',
#     'directors': ['Wolfgang Petersen'],
#     'rating': Decimal('6.7'),
#     'rank': Decimal('4549'),
#     'running_time_secs': Decimal('6480')}},
#   {'title': 'European Vacation',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Chevy Chase', "Beverly D'Angelo", 'Dana Hill'],
#     'release_date': '1985-07-26T00:00:00Z',
#     'plot': 'The Griswalds win a vacation tour across Europe where the usual havoc ensues.',
#     'genres': ['Adventure', 'Comedy', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTU2Nzg1ODM0MF5BMl5BanBnXkFtZTcwMTM5OTMyMQ@@._V1_SX400_.jpg',
#     'directors': ['Amy Heckerling'],
#     'rating': Decimal('5.9'),
#     'rank': Decimal('4097'),
#     'running_time_secs': Decimal('5700')}},
#   {'title': 'Explorers',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Ethan Hawke', 'River Phoenix', 'Bobby Fite'],
#     'release_date': '1985-07-12T00:00:00Z',
#     'genres': ['Adventure', 'Family', 'Sci-Fi'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMzI4MTY4NjQxNl5BMl5BanBnXkFtZTcwNjY5ODM4OA@@._V1_SX400_.jpg',
#     'directors': ['Joe Dante'],
#     'rating': Decimal('6.3'),
#     'rank': Decimal('4320'),
#     'running_time_secs': Decimal('6540')}},
#   {'title': 'Flesh+Blood',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Rutger Hauer',
#      'Jennifer Jason Leigh',
#      'Tom Burlinson'],
#     'release_date': '1985-06-10T00:00:00Z',
#     'genres': ['Adventure', 'Drama'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTU3NTQ1OTA4NF5BMl5BanBnXkFtZTcwNTM4NjczNA@@._V1_SX400_.jpg',
#     'directors': ['Paul Verhoeven'],
#     'rating': Decimal('6.6'),
#     'rank': Decimal('3864'),
#     'running_time_secs': Decimal('7560')}},
#   {'title': 'Friday the 13th: A New Beginning',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Melanie Kinnaman', 'John Shepherd', 'Shavar Ross'],
#     'release_date': '1985-03-22T00:00:00Z',
#     'plot': 'Still haunted by his gruesome past, Tommy Jarvis - the boy who killed Jason Voorhees - wonders if somehow he is connected to brutal slayings occurring in and around the secluded halfway house where he now lives.',
#     'genres': ['Horror', 'Mystery', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BODcxMzY5NDk5NV5BMl5BanBnXkFtZTcwNzAzNzUxMQ@@._V1_SX400_.jpg',
#     'directors': ['Danny Steinmann'],
#     'rating': Decimal('4.3'),
#     'rank': Decimal('3832'),
#     'running_time_secs': Decimal('5520')}},
#   {'title': 'Fright Night',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Chris Sarandon', 'William Ragsdale', 'Amanda Bearse'],
#     'release_date': '1985-08-02T00:00:00Z',
#     'plot': 'When a teenager learns that his next door neighbour is a vampire, no one will believe him.',
#     'genres': ['Comedy', 'Horror', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjc4NjM0NjM1OF5BMl5BanBnXkFtZTYwNDQ0MTg4._V1_SX400_.jpg',
#     'directors': ['Tom Holland'],
#     'rating': Decimal('6.9'),
#     'rank': Decimal('2325'),
#     'running_time_secs': Decimal('6360')}},
#   {'title': 'Girls Just Want to Have Fun',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Sarah Jessica Parker', 'Lee Montgomery', 'Helen Hunt'],
#     'release_date': '1985-04-12T00:00:00Z',
#     'genres': ['Comedy', 'Music', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTg1MzIzNDc3Ml5BMl5BanBnXkFtZTgwMDI1MzQxMDE@._V1_SX400_.jpg',
#     'directors': ['Alan Metter'],
#     'rating': Decimal('5.5'),
#     'rank': Decimal('4023'),
#     'running_time_secs': Decimal('5400')}},
#   {'title': 'Just One of the Guys',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Joyce Hyser', 'Clayton Rohner', 'Billy Jayne'],
#     'release_date': '1985-04-26T00:00:00Z',
#     'genres': ['Comedy', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTI4Mjc3NDQ1N15BMl5BanBnXkFtZTcwNjkyMDUyMQ@@._V1_SX400_.jpg',
#     'directors': ['Lisa Gottlieb'],
#     'rating': Decimal('6.1'),
#     'rank': Decimal('4011'),
#     'running_time_secs': Decimal('5400')}},
#   {'title': 'Ladyhawke',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Matthew Broderick',
#      'Rutger Hauer',
#      'Michelle Pfeiffer'],
#     'release_date': '1985-03-27T00:00:00Z',
#     'genres': ['Adventure', 'Drama', 'Fantasy'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTc1MDI3NDcwOV5BMl5BanBnXkFtZTcwMDkxMTkyMQ@@._V1_SX400_.jpg',
#     'directors': ['Richard Donner'],
#     'rating': Decimal('6.8'),
#     'rank': Decimal('4574'),
#     'running_time_secs': Decimal('7260')}},
#   {'title': 'Legend',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Tom Cruise', 'Mia Sara', 'Tim Curry'],
#     'release_date': '1985-08-28T00:00:00Z',
#     'plot': 'A young man must stop the Lord of Darkness from both destroying daylight and marrying the woman he loves.',
#     'genres': ['Fantasy', 'Adventure', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjI3OTg2NTQ5Nl5BMl5BanBnXkFtZTgwMzY3MjQxMDE@._V1_SX400_.jpg',
#     'directors': ['Ridley Scott'],
#     'rating': Decimal('6.2'),
#     'rank': Decimal('1406'),
#     'running_time_secs': Decimal('5640')}},
#   {'title': 'Lifeforce',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Steve Railsback', 'Mathilda May', 'Peter Firth'],
#     'release_date': '1985-06-21T00:00:00Z',
#     'plot': 'A race of space vampires arrive in London and infect the populace.',
#     'genres': ['Horror', 'Sci-Fi', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTU4MTMxOTQyOV5BMl5BanBnXkFtZTcwMzU1NDk0NA@@._V1_SX400_.jpg',
#     'directors': ['Tobe Hooper'],
#     'rating': Decimal('5.9'),
#     'rank': Decimal('4123'),
#     'running_time_secs': Decimal('6960')}},
#   {'title': 'Mad Max Beyond Thunderdome',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Mel Gibson', 'Tina Turner', 'Bruce Spence'],
#     'release_date': '1985-07-10T00:00:00Z',
#     'plot': "A former Australian policeman is rescued by a tribe of children when he is banished from a desert town and sent into the desert to die by the desert town's evil queen.",
#     'genres': ['Action', 'Adventure', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTk0MDQ5NTYxNV5BMl5BanBnXkFtZTcwNTA0ODYyMQ@@._V1_SX400_.jpg',
#     'directors': ['George Miller', 'George Ogilvie'],
#     'rating': Decimal('6.1'),
#     'rank': Decimal('3378'),
#     'running_time_secs': Decimal('6420')}},
#   {'title': 'Mask',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Cher', 'Eric Stoltz', 'Sam Elliott'],
#     'release_date': '1985-03-08T00:00:00Z',
#     'plot': 'A teenager with a massive facial skull deformity and biker gang mother attempts to live as normal a life as possible under the circumstances.',
#     'genres': ['Biography', 'Drama'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTM5ODkwNTc5OV5BMl5BanBnXkFtZTcwNzcxMzYyMQ@@._V1_SX400_.jpg',
#     'directors': ['Peter Bogdanovich'],
#     'rating': Decimal('7'),
#     'rank': Decimal('1440'),
#     'running_time_secs': Decimal('7200')}},
#   {'title': 'Pale Rider',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Clint Eastwood',
#      'Michael Moriarty',
#      'Carrie Snodgress'],
#     'release_date': '1985-05-01T00:00:00Z',
#     'plot': 'A mysterious preacher protects a humble prospector village from a greedy mining company trying to encroach on their land.',
#     'genres': ['Western'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTc1NzE2NzQwMl5BMl5BanBnXkFtZTcwMjg2MjIyMQ@@._V1_SX400_.jpg',
#     'directors': ['Clint Eastwood'],
#     'rating': Decimal('7.2'),
#     'rank': Decimal('1151'),
#     'running_time_secs': Decimal('6900')}},
#   {'title': "Pee-wee's Big Adventure",
#    'year': Decimal('1985'),
#    'info': {'actors': ['Paul Reubens', 'Elizabeth Daily', 'Mark Holton'],
#     'release_date': '1985-07-26T00:00:00Z',
#     'plot': 'When eccentric man-child Pee-Wee Herman gets his beloved bike stolen in broad daylight, he sets out across the U.S. on the adventure of his life.',
#     'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjEyMjI3MjAxMF5BMl5BanBnXkFtZTYwOTMxNzk4._V1_SX400_.jpg',
#     'directors': ['Tim Burton'],
#     'rating': Decimal('6.8'),
#     'rank': Decimal('309'),
#     'running_time_secs': Decimal('5400')}},
#   {'title': 'Perfect',
#    'year': Decimal('1985'),
#    'info': {'actors': ['John Travolta', 'Jamie Lee Curtis', 'Ramey Ellis'],
#     'release_date': '1985-05-15T00:00:00Z',
#     'plot': "A female aerobics instructor meets a male reporter doing a story on health clubs, but it isn't love at first sight.",
#     'genres': ['Drama', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTIyMDQ3NDIwMV5BMl5BanBnXkFtZTYwODI2MTg4._V1_SX400_.jpg',
#     'directors': ['James Bridges'],
#     'rating': Decimal('3.9'),
#     'rank': Decimal('4677'),
#     'running_time_secs': Decimal('6900')}},
#   {'title': 'Police Academy 2: Their First Assignment',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Steve Guttenberg', 'Bubba Smith', 'David Graf'],
#     'release_date': '1985-03-29T00:00:00Z',
#     'plot': "When a new gang moves into town it's up to the screwball police team to stop them.",
#     'genres': ['Comedy', 'Crime'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTc5NDQ4OTM0Ml5BMl5BanBnXkFtZTYwMDA2MjQ5._V1_SX400_.jpg',
#     'directors': ['Jerry Paris'],
#     'rating': Decimal('5.3'),
#     'rank': Decimal('3847'),
#     'running_time_secs': Decimal('5220')}},
#   {'title': 'Rambo: First Blood Part II',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Sylvester Stallone',
#      'Richard Crenna',
#      'Charles Napier'],
#     'release_date': '1985-05-22T00:00:00Z',
#     'plot': "John Rambo is released from prison by the government for a top-secret covert mission to the last place on Earth he'd want to return - the jungles of Vietnam.",
#     'genres': ['Action', 'Adventure', 'Thriller', 'War'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTc5NTAxNjE4Nl5BMl5BanBnXkFtZTcwOTg2MDcyMQ@@._V1_SX400_.jpg',
#     'directors': ['George P. Cosmatos'],
#     'rating': Decimal('6.2'),
#     'rank': Decimal('2796'),
#     'running_time_secs': Decimal('5760')}},
#   {'title': 'Re-Animator',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Jeffrey Combs', 'Bruce Abbott', 'Barbara Crampton'],
#     'release_date': '1985-10-18T00:00:00Z',
#     'plot': 'A dedicated student at a medical college and his girlfriend become involved in bizarre experiments centering around the re-animation of dead tissue when an odd new student arrives on campus.',
#     'genres': ['Horror', 'Sci-Fi'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTIzODA5NjQwOV5BMl5BanBnXkFtZTcwNTc5NzQ0MQ@@._V1_SX400_.jpg',
#     'directors': ['Stuart Gordon'],
#     'rating': Decimal('7.2'),
#     'rank': Decimal('4194'),
#     'running_time_secs': Decimal('5700')}},
#   {'title': 'Real Genius',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Val Kilmer', 'Gabriel Jarret', 'Michelle Meyrink'],
#     'release_date': '1985-08-07T00:00:00Z',
#     'plot': 'Teenage geniuses deal with their abilities while developing a laser.',
#     'genres': ['Comedy', 'Romance', 'Sci-Fi'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BNTQ5MzU3ODg0OF5BMl5BanBnXkFtZTgwODM0MzQxMDE@._V1_SX400_.jpg',
#     'directors': ['Martha Coolidge'],
#     'rating': Decimal('6.8'),
#     'rank': Decimal('3548'),
#     'running_time_secs': Decimal('6480')}},
#   {'title': 'Return to Oz',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Fairuza Balk', 'Nicol Williamson', 'Jean Marsh'],
#     'release_date': '1985-06-21T00:00:00Z',
#     'plot': 'Dorothy, saved from a psychiatric experiment by a mysterious girl, is somehow called back to Oz when a vain witch and the Nome King destroy everything that makes the magical land beautiful.',
#     'genres': ['Adventure', 'Family', 'Fantasy', 'Mystery'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTQ4ODQyNDU3MV5BMl5BanBnXkFtZTcwODUyNTUyMQ@@._V1_SX400_.jpg',
#     'directors': ['Walter Murch'],
#     'rating': Decimal('6.5'),
#     'rank': Decimal('2859'),
#     'running_time_secs': Decimal('6780')}},
#   {'title': 'Rocky IV',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Sylvester Stallone', 'Talia Shire', 'Burt Young'],
#     'release_date': '1985-11-21T00:00:00Z',
#     'plot': 'When Apollo Creed is killed in a match against a powerful Soviet boxer, Rocky decides to challenge him himself.',
#     'genres': ['Drama', 'Sport'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTg3ODk5ODE0NV5BMl5BanBnXkFtZTcwNDkzODM1NA@@._V1_SX400_.jpg',
#     'directors': ['Sylvester Stallone'],
#     'rating': Decimal('6.4'),
#     'rank': Decimal('1549'),
#     'running_time_secs': Decimal('5460')}},
#   {'title': 'Runaway Train',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Jon Voight', 'Eric Roberts', 'Rebecca De Mornay'],
#     'release_date': '1985-11-15T00:00:00Z',
#     'plot': 'Two escaped convicts and a female railway worker find themselves trapped on a train with no brakes and nobody driving.',
#     'genres': ['Action', 'Adventure', 'Drama', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTk2OTg2MDg4MF5BMl5BanBnXkFtZTcwMTE0NzI5NA@@._V1_SX400_.jpg',
#     'directors': ['Andrey Konchalovskiy'],
#     'rating': Decimal('7.2'),
#     'rank': Decimal('4153'),
#     'running_time_secs': Decimal('6660')}},
#   {'title': 'Silverado',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Kevin Kline', 'Scott Glenn', 'Kevin Costner'],
#     'release_date': '1985-07-10T00:00:00Z',
#     'plot': 'A misfit bunch of friends come together to right the injustices which exist in a small town.',
#     'genres': ['Action', 'Crime', 'Drama', 'Western'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTQ0MTMwMjY0MV5BMl5BanBnXkFtZTcwODMwMjgyMQ@@._V1_SX400_.jpg',
#     'directors': ['Lawrence Kasdan'],
#     'rating': Decimal('7.1'),
#     'rank': Decimal('2631'),
#     'running_time_secs': Decimal('7980')}},
#   {'title': "St. Elmo's Fire",
#    'year': Decimal('1985'),
#    'info': {'actors': ['Demi Moore', 'Rob Lowe', 'Andrew McCarthy'],
#     'release_date': '1985-06-28T00:00:00Z',
#     'plot': "A Group of friends, just out of college, struggle with adulthood. Their main problem is that they're all self-centered and obnoxious.",
#     'genres': ['Drama', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjE3MTE3NDUxMV5BMl5BanBnXkFtZTcwMzExMjUxNw@@._V1_SX400_.jpg',
#     'directors': ['Joel Schumacher'],
#     'rating': Decimal('6.1'),
#     'rank': Decimal('1057'),
#     'running_time_secs': Decimal('6600')}},
#   {'title': 'Teen Wolf',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Michael J. Fox', 'James Hampton', 'Susan Ursitti'],
#     'release_date': '1985-08-23T00:00:00Z',
#     'plot': 'A highschooler discovers that he is a werewolf.',
#     'genres': ['Comedy', 'Fantasy', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTU2OTkxMTg0OV5BMl5BanBnXkFtZTcwMjkzMTM3NA@@._V1_SX400_.jpg',
#     'directors': ['Rod Daniel'],
#     'rating': Decimal('5.8'),
#     'rank': Decimal('2439'),
#     'running_time_secs': Decimal('5460')}},
#   {'title': 'The Black Cauldron',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Grant Bardsley', 'Freddie Jones', 'Susan Sheridan'],
#     'release_date': '1985-07-24T00:00:00Z',
#     'plot': 'A young boy and a bunch of misfit friends embark on a quest to find a dark magic item of ultimate power before a diabolical tyrant can.',
#     'genres': ['Animation', 'Adventure', 'Family', 'Fantasy'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BNjMwNDU2ODk1M15BMl5BanBnXkFtZTcwMjg4MDYyMQ@@._V1_SX400_.jpg',
#     'directors': ['Ted Berman', 'Richard Rich'],
#     'rating': Decimal('6.3'),
#     'rank': Decimal('4303'),
#     'running_time_secs': Decimal('4800')}},
#   {'title': 'The Breakfast Club',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Emilio Estevez', 'Judd Nelson', 'Molly Ringwald'],
#     'release_date': '1985-02-07T00:00:00Z',
#     'plot': 'Five high school students, all different stereotypes, meet in detention, where they pour their hearts out to each other, and discover how they have a lot more in common than they thought.',
#     'genres': ['Comedy', 'Drama'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMzYyNTQ1Nzk2M15BMl5BanBnXkFtZTcwODk0NTQyMQ@@._V1_SX400_.jpg',
#     'directors': ['John Hughes'],
#     'rating': Decimal('7.9'),
#     'rank': Decimal('120'),
#     'running_time_secs': Decimal('5820')}},
#   {'title': 'The Color Purple',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Danny Glover', 'Whoopi Goldberg', 'Oprah Winfrey'],
#     'release_date': '1985-12-16T00:00:00Z',
#     'plot': 'The life and trials of a young African American woman.',
#     'genres': ['Drama'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjEyMTI0NTIzNV5BMl5BanBnXkFtZTYwNjYyMzg5._V1_SX400_.jpg',
#     'directors': ['Steven Spielberg'],
#     'rating': Decimal('7.6'),
#     'rank': Decimal('2233'),
#     'running_time_secs': Decimal('9240')}},
#   {'title': 'The Goonies',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Sean Astin', 'Josh Brolin', 'Jeff Cohen'],
#     'release_date': '1985-06-07T00:00:00Z',
#     'plot': 'A group of kids embark on a wild adventure after finding a pirate treasure map.',
#     'genres': ['Adventure', 'Comedy', 'Family'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTY1Mzk3MTg0M15BMl5BanBnXkFtZTcwOTQzODYyMQ@@._V1_SX400_.jpg',
#     'directors': ['Richard Donner'],
#     'rating': Decimal('7.6'),
#     'rank': Decimal('318'),
#     'running_time_secs': Decimal('6840')}},
#   {'title': 'The Last Dragon',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Taimak', 'Vanity', 'Christopher Murney'],
#     'release_date': '1985-03-22T00:00:00Z',
#     'genres': ['Action', 'Comedy', 'Drama', 'Music'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjE4ODQ1ODA5Ml5BMl5BanBnXkFtZTYwNDAxOTY5._V1_SX400_.jpg',
#     'directors': ['Michael Schultz'],
#     'rating': Decimal('6.3'),
#     'rank': Decimal('3934'),
#     'running_time_secs': Decimal('6540')}},
#   {'title': 'The Return of the Living Dead',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Clu Gulager', 'James Karen', 'Don Calfa'],
#     'release_date': '1985-05-15T00:00:00Z',
#     'genres': ['Comedy', 'Horror', 'Sci-Fi'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjEyNTQ4NDUyM15BMl5BanBnXkFtZTcwNzg0ODU4NA@@._V1_SX400_.jpg',
#     'directors': ["Dan O'Bannon"],
#     'rating': Decimal('7.1'),
#     'rank': Decimal('3640'),
#     'running_time_secs': Decimal('5460')}},
#   {'title': 'Weird Science',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Anthony Michael Hall',
#      'Ilan Mitchell-Smith',
#      'Kelly LeBrock'],
#     'release_date': '1985-08-02T00:00:00Z',
#     'plot': 'Two nerdish boys attempt to create the perfect woman, but she turns out to be more than that.',
#     'genres': ['Comedy', 'Fantasy', 'Romance'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMTY3ODY2NzQ0M15BMl5BanBnXkFtZTcwMzMxMTMyMQ@@._V1_SX400_.jpg',
#     'directors': ['John Hughes'],
#     'rating': Decimal('6.4'),
#     'rank': Decimal('877'),
#     'running_time_secs': Decimal('5640')}},
#   {'title': 'Witness',
#    'year': Decimal('1985'),
#    'info': {'actors': ['Harrison Ford', 'Kelly McGillis', 'Lukas Haas'],
#     'release_date': '1985-02-08T00:00:00Z',
#     'plot': 'A young Amish boy is sole witness to a murder; policeman John Book goes into hiding in Amish country to protect him until the trial.',
#     'genres': ['Crime', 'Drama', 'Romance', 'Thriller'],
#     'image_url': 'http://ia.media-imdb.com/images/M/MV5BMjE4ODQ2MTI3MV5BMl5BanBnXkFtZTcwMzk1ODAwMQ@@._V1_SX400_.jpg',
#     'directors': ['Peter Weir'],
#     'rating': Decimal('7.5'),
#     'rank': Decimal('2693'),
#     'running_time_secs': Decimal('6720')}}],
#  'Count': 45,
#  'ScannedCount': 45,
#  'ResponseMetadata': {'RequestId': '4a36f375-b707-45db-abd7-055c766c94b0',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.0',
#    'x-amz-crc32': '2162880548',
#    'x-amzn-requestid': '4a36f375-b707-45db-abd7-055c766c94b0',
#    'content-length': '27272',
#    'server': 'Jetty(8.1.12.v20130726)'},
#   'RetryAttempts': 0}}

# %%
len(response['Items'])
# Out:
# 45

# %% [markdown]
# #### Query - All Movies Released in a Year with Certain Titles

# %%
year = 1992
title_range = ('A', 'L')

# Expression attribute names can only reference items in the projection expression.
# year is a reserved word, use ExpressionAttributeNames to remap it
response = table.query(
    ProjectionExpression="#yr, title, info.genres, info.actors[0]",
    ExpressionAttributeNames={"#yr": "year"},
    KeyConditionExpression=
        Key('year').eq(year) & Key('title').between(title_range[0], title_range[1])
)

# %%
response
# Out:
# {'Items': [{'title': 'A Few Good Men',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Tom Cruise'],
#     'genres': ['Crime', 'Drama', 'Mystery', 'Thriller']}},
#   {'title': 'A League of Their Own',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Tom Hanks'], 'genres': ['Comedy', 'Drama', 'Sport']}},
#   {'title': 'A River Runs Through It',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Craig Sheffer'], 'genres': ['Drama']}},
#   {'title': 'Aladdin',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Scott Weinger'],
#     'genres': ['Animation',
#      'Adventure',
#      'Comedy',
#      'Family',
#      'Fantasy',
#      'Musical',
#      'Romance']}},
#   {'title': 'Alien 3',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Sigourney Weaver'],
#     'genres': ['Action', 'Sci-Fi', 'Thriller']}},
#   {'title': 'Army of Darkness',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Bruce Campbell'],
#     'genres': ['Comedy', 'Fantasy', 'Horror']}},
#   {'title': 'Batman Returns',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Michael Keaton'], 'genres': ['Action', 'Fantasy']}},
#   {'title': 'Beethoven',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Charles Grodin'],
#     'genres': ['Comedy', 'Drama', 'Family']}},
#   {'title': 'Bitter Moon',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Hugh Grant'],
#     'genres': ['Drama', 'Romance', 'Thriller']}},
#   {'title': 'Boomerang',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Eddie Murphy'],
#     'genres': ['Comedy', 'Drama', 'Romance']}},
#   {'title': 'Braindead',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Timothy Balme'], 'genres': ['Comedy', 'Horror']}},
#   {'title': 'Buffy the Vampire Slayer',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Kristy Swanson'],
#     'genres': ['Action', 'Comedy', 'Fantasy', 'Horror']}},
#   {'title': 'Candyman',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Virginia Madsen'], 'genres': ['Horror']}},
#   {'title': 'Captain Ron',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Kurt Russell'], 'genres': ['Adventure', 'Comedy']}},
#   {'title': 'Chaplin',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Robert Downey Jr.'],
#     'genres': ['Biography', 'Drama']}},
#   {'title': 'Como agua para chocolate',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Marco Leonardi'], 'genres': ['Drama', 'Romance']}},
#   {'title': 'Damage',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Jeremy Irons'], 'genres': ['Drama', 'Romance']}},
#   {'title': 'Death Becomes Her',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Meryl Streep'], 'genres': ['Comedy', 'Fantasy']}},
#   {'title': 'El mariachi',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Carlos Gallardo'],
#     'genres': ['Action', 'Crime', 'Drama', 'Thriller']}},
#   {'title': 'Encino Man',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Sean Astin'], 'genres': ['Comedy', 'Fantasy']}},
#   {'title': 'Far and Away',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Tom Cruise'],
#     'genres': ['Adventure', 'Drama', 'Romance', 'Western']}},
#   {'title': 'FernGully: The Last Rainforest',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Samantha Mathis'],
#     'genres': ['Animation', 'Adventure', 'Family', 'Fantasy', 'Thriller']}},
#   {'title': 'Forever Young',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Mel Gibson'],
#     'genres': ['Drama', 'Romance', 'Sci-Fi']}},
#   {'title': 'Glengarry Glen Ross',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Al Pacino'], 'genres': ['Drama']}},
#   {'title': 'Home Alone 2: Lost in New York',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Macaulay Culkin'],
#     'genres': ['Adventure', 'Comedy', 'Crime', 'Family']}},
#   {'title': 'Howards End',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Anthony Hopkins'], 'genres': ['Drama', 'Romance']}},
#   {'title': 'Jennifer Eight',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Andy Garcia'],
#     'genres': ['Crime', 'Drama', 'Mystery', 'Thriller']}},
#   {'title': 'Juice',
#    'year': Decimal('1992'),
#    'info': {'actors': ['Omar Epps'],
#     'genres': ['Crime', 'Drama', 'Thriller']}}],
#  'Count': 28,
#  'ScannedCount': 28,
#  'ResponseMetadata': {'RequestId': 'bb41ef98-375e-4875-83fb-906d26fa6e8b',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.0',
#    'x-amz-crc32': '1399972180',
#    'x-amzn-requestid': 'bb41ef98-375e-4875-83fb-906d26fa6e8b',
#    'content-length': '4751',
#    'server': 'Jetty(8.1.12.v20130726)'},
#   'RetryAttempts': 0}}

# %%
response['Items']
# Out:
# [{'title': 'A Few Good Men',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Tom Cruise'],
#    'genres': ['Crime', 'Drama', 'Mystery', 'Thriller']}},
#  {'title': 'A League of Their Own',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Tom Hanks'], 'genres': ['Comedy', 'Drama', 'Sport']}},
#  {'title': 'A River Runs Through It',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Craig Sheffer'], 'genres': ['Drama']}},
#  {'title': 'Aladdin',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Scott Weinger'],
#    'genres': ['Animation',
#     'Adventure',
#     'Comedy',
#     'Family',
#     'Fantasy',
#     'Musical',
#     'Romance']}},
#  {'title': 'Alien 3',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Sigourney Weaver'],
#    'genres': ['Action', 'Sci-Fi', 'Thriller']}},
#  {'title': 'Army of Darkness',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Bruce Campbell'],
#    'genres': ['Comedy', 'Fantasy', 'Horror']}},
#  {'title': 'Batman Returns',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Michael Keaton'], 'genres': ['Action', 'Fantasy']}},
#  {'title': 'Beethoven',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Charles Grodin'],
#    'genres': ['Comedy', 'Drama', 'Family']}},
#  {'title': 'Bitter Moon',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Hugh Grant'],
#    'genres': ['Drama', 'Romance', 'Thriller']}},
#  {'title': 'Boomerang',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Eddie Murphy'],
#    'genres': ['Comedy', 'Drama', 'Romance']}},
#  {'title': 'Braindead',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Timothy Balme'], 'genres': ['Comedy', 'Horror']}},
#  {'title': 'Buffy the Vampire Slayer',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Kristy Swanson'],
#    'genres': ['Action', 'Comedy', 'Fantasy', 'Horror']}},
#  {'title': 'Candyman',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Virginia Madsen'], 'genres': ['Horror']}},
#  {'title': 'Captain Ron',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Kurt Russell'], 'genres': ['Adventure', 'Comedy']}},
#  {'title': 'Chaplin',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Robert Downey Jr.'], 'genres': ['Biography', 'Drama']}},
#  {'title': 'Como agua para chocolate',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Marco Leonardi'], 'genres': ['Drama', 'Romance']}},
#  {'title': 'Damage',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Jeremy Irons'], 'genres': ['Drama', 'Romance']}},
#  {'title': 'Death Becomes Her',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Meryl Streep'], 'genres': ['Comedy', 'Fantasy']}},
#  {'title': 'El mariachi',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Carlos Gallardo'],
#    'genres': ['Action', 'Crime', 'Drama', 'Thriller']}},
#  {'title': 'Encino Man',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Sean Astin'], 'genres': ['Comedy', 'Fantasy']}},
#  {'title': 'Far and Away',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Tom Cruise'],
#    'genres': ['Adventure', 'Drama', 'Romance', 'Western']}},
#  {'title': 'FernGully: The Last Rainforest',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Samantha Mathis'],
#    'genres': ['Animation', 'Adventure', 'Family', 'Fantasy', 'Thriller']}},
#  {'title': 'Forever Young',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Mel Gibson'],
#    'genres': ['Drama', 'Romance', 'Sci-Fi']}},
#  {'title': 'Glengarry Glen Ross',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Al Pacino'], 'genres': ['Drama']}},
#  {'title': 'Home Alone 2: Lost in New York',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Macaulay Culkin'],
#    'genres': ['Adventure', 'Comedy', 'Crime', 'Family']}},
#  {'title': 'Howards End',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Anthony Hopkins'], 'genres': ['Drama', 'Romance']}},
#  {'title': 'Jennifer Eight',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Andy Garcia'],
#    'genres': ['Crime', 'Drama', 'Mystery', 'Thriller']}},
#  {'title': 'Juice',
#   'year': Decimal('1992'),
#   'info': {'actors': ['Omar Epps'], 'genres': ['Crime', 'Drama', 'Thriller']}}]

# %% [markdown]
# #### Scan with pagination

# %%
year_range = (1950, 1959)
scan_kwargs = {
    'FilterExpression': Key('year').between(*year_range),
    'ProjectionExpression': "#yr, title, info.rating",
    'ExpressionAttributeNames': {"#yr": "year"}
}

# %%
done = False
start_key = None
movies = []
ipage = 0
while not done:
    ipage += 1
    print(f"ipage = {ipage}")
    if start_key:
        scan_kwargs['ExclusiveStartKey'] = start_key
    response = table.scan(**scan_kwargs)
    movies.extend(response.get('Items', []))
    start_key = response.get('LastEvaluatedKey', None)
    done = start_key is None
# Out:
# ipage = 1
# ipage = 2

# %%
len(movies), movies
# Out:
# (73,
#  [{'title': 'High Noon',
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('8.2')}},
#   {'title': "Singin' in the Rain",
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('8.4')}},
#   {'title': 'The Member of the Wedding',
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('6.8')}},
#   {'title': 'The Quiet Man',
#    'year': Decimal('1952'),
#    'info': {'rating': Decimal('7.8')}},
#   {'title': '20000 Leagues Under the Sea',
#    'year': Decimal('1954'),
#    'info': {'rating': Decimal('7.1')}},
#   {'title': 'Black Widow',
#    'year': Decimal('1954'),
#    'info': {'rating': Decimal('6.7')}},
#   {'title': 'Dial M for Murder',
#    'year': Decimal('1954'),
#    'info': {'rating': Decimal('8.1')}},
#   {'title': 'On the Waterfront',
#    'year': Decimal('1954'),
#    'info': {'rating': Decimal('8.3')}},
#   {'title': 'Rear Window',
#    'year': Decimal('1954'),
#    'info': {'rating': Decimal('8.6')}},
#   {'title': 'Seven Brides for Seven Brothers',
#    'year': Decimal('1954'),
#    'info': {'rating': Decimal('7.2')}},
#   {'title': 'Shichinin no samurai',
#    'year': Decimal('1954'),
#    'info': {'rating': Decimal('8.8')}},
#   {'title': 'A Streetcar Named Desire',
#    'year': Decimal('1951'),
#    'info': {'rating': Decimal('8')}},
#   {'title': 'Alice in Wonderland',
#    'year': Decimal('1951'),
#    'info': {'rating': Decimal('7.4')}},
#   {'title': 'An American in Paris',
#    'year': Decimal('1951'),
#    'info': {'rating': Decimal('7.2')}},
#   {'title': 'Operation Pacific',
#    'year': Decimal('1951'),
#    'info': {'rating': Decimal('6.5')}},
#   {'title': 'Storm Warning',
#    'year': Decimal('1951'),
#    'info': {'rating': Decimal('7')}},
#   {'title': 'Strangers on a Train',
#    'year': Decimal('1951'),
#    'info': {'rating': Decimal('8.2')}},
#   {'title': 'The African Queen',
#    'year': Decimal('1951'),
#    'info': {'rating': Decimal('8')}},
#   {'title': 'The Day the Earth Stood Still',
#    'year': Decimal('1951'),
#    'info': {'rating': Decimal('7.9')}},
#   {'title': 'East of Eden',
#    'year': Decimal('1955'),
#    'info': {'rating': Decimal('8')}},
#   {'title': 'Lady and the Tramp',
#    'year': Decimal('1955'),
#    'info': {'rating': Decimal('7.4')}},
#   {'title': 'Les diaboliques',
#    'year': Decimal('1955'),
#    'info': {'rating': Decimal('8.2')}},
#   {'title': 'Rebel Without a Cause',
#    'year': Decimal('1955'),
#    'info': {'rating': Decimal('7.8')}},
#   {'title': 'The Night of the Hunter',
#    'year': Decimal('1955'),
#    'info': {'rating': Decimal('8.1')}},
#   {'title': 'The Seven Year Itch',
#    'year': Decimal('1955'),
#    'info': {'rating': Decimal('7.2')}},
#   {'title': 'To Catch a Thief',
#    'year': Decimal('1955'),
#    'info': {'rating': Decimal('7.5')}},
#   {'title': 'Forbidden Planet',
#    'year': Decimal('1956'),
#    'info': {'rating': Decimal('7.7')}},
#   {'title': 'Giant',
#    'year': Decimal('1956'),
#    'info': {'rating': Decimal('7.6')}},
#   {'title': 'Moby Dick',
#    'year': Decimal('1956'),
#    'info': {'rating': Decimal('7.3')}},
#   {'title': 'The Killing',
#    'year': Decimal('1956'),
#    'info': {'rating': Decimal('8.1')}},
#   {'title': 'The King and I',
#    'year': Decimal('1956'),
#    'info': {'rating': Decimal('7.4')}},
#   {'title': 'The Man Who Knew Too Much',
#    'year': Decimal('1956'),
#    'info': {'rating': Decimal('7.5')}},
#   {'title': 'The Man in the Gray Flannel Suit',
#    'year': Decimal('1956'),
#    'info': {'rating': Decimal('7')}},
#   {'title': 'The Searchers',
#    'year': Decimal('1956'),
#    'info': {'rating': Decimal('8')}},
#   {'title': 'The Ten Commandments',
#    'year': Decimal('1956'),
#    'info': {'rating': Decimal('7.8')}},
#   {'title': 'World Without End',
#    'year': Decimal('1956'),
#    'info': {'rating': Decimal('5.9')}},
#   {'title': 'Ben-Hur',
#    'year': Decimal('1959'),
#    'info': {'rating': Decimal('8.1')}},
#   {'title': 'Middle of the Night',
#    'year': Decimal('1959'),
#    'info': {'rating': Decimal('7')}},
#   {'title': 'North by Northwest',
#    'year': Decimal('1959'),
#    'info': {'rating': Decimal('8.5')}},
#   {'title': 'Rio Bravo',
#    'year': Decimal('1959'),
#    'info': {'rating': Decimal('8')}},
#   {'title': 'Sleeping Beauty',
#    'year': Decimal('1959'),
#    'info': {'rating': Decimal('7.3')}},
#   {'title': 'Some Like It Hot',
#    'year': Decimal('1959'),
#    'info': {'rating': Decimal('8.4')}},
#   {'title': 'Yellowstone Kelly',
#    'year': Decimal('1959'),
#    'info': {'rating': Decimal('6.3')}},
#   {'title': '12 Angry Men',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('8.9')}},
#   {'title': 'Det sjunde inseglet',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('8.3')}},
#   {'title': 'Funny Face',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('6.9')}},
#   {'title': 'Man on Fire',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('6.2')}},
#   {'title': 'Old Yeller',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('7.2')}},
#   {'title': 'Paths of Glory',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('8.5')}},
#   {'title': 'Quatermass 2',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('7')}},
#   {'title': 'Smultronstallet',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('8.3')}},
#   {'title': 'The Bridge on the River Kwai',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('8.3')}},
#   {'title': 'The Prince and the Showgirl',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('6.5')}},
#   {'title': 'Trooper Hook',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('6.5')}},
#   {'title': 'Witness for the Prosecution',
#    'year': Decimal('1957'),
#    'info': {'rating': Decimal('8.4')}},
#   {'title': 'From Here to Eternity',
#    'year': Decimal('1953'),
#    'info': {'rating': Decimal('7.8')}},
#   {'title': 'How to Marry a Millionaire',
#    'year': Decimal('1953'),
#    'info': {'rating': Decimal('6.8')}},
#   {'title': 'Peter Pan',
#    'year': Decimal('1953'),
#    'info': {'rating': Decimal('7.3')}},
#   {'title': 'Roman Holiday',
#    'year': Decimal('1953'),
#    'info': {'rating': Decimal('8.1')}},
#   {'title': 'Shane',
#    'year': Decimal('1953'),
#    'info': {'rating': Decimal('7.7')}},
#   {'title': 'The War of the Worlds',
#    'year': Decimal('1953'),
#    'info': {'rating': Decimal('7.1')}},
#   {'title': 'Cat on a Hot Tin Roof',
#    'year': Decimal('1958'),
#    'info': {'rating': Decimal('8')}},
#   {'title': 'Monster on the Campus',
#    'year': Decimal('1958'),
#    'info': {'rating': Decimal('5.7')}},
#   {'title': 'No Time for Sergeants',
#    'year': Decimal('1958'),
#    'info': {'rating': Decimal('7.5')}},
#   {'title': "Teacher's Pet",
#    'year': Decimal('1958'),
#    'info': {'rating': Decimal('7')}},
#   {'title': 'Touch of Evil',
#    'year': Decimal('1958'),
#    'info': {'rating': Decimal('8.2')}},
#   {'title': 'Vertigo',
#    'year': Decimal('1958'),
#    'info': {'rating': Decimal('8.5')}},
#   {'title': 'All About Eve',
#    'year': Decimal('1950'),
#    'info': {'rating': Decimal('8.4')}},
#   {'title': 'Cinderella',
#    'year': Decimal('1950'),
#    'info': {'rating': Decimal('7.3')}},
#   {'title': 'Harvey',
#    'year': Decimal('1950'),
#    'info': {'rating': Decimal('8')}},
#   {'title': 'Rashomon',
#    'year': Decimal('1950'),
#    'info': {'rating': Decimal('8.4')}},
#   {'title': 'Sunset Blvd.',
#    'year': Decimal('1950'),
#    'info': {'rating': Decimal('8.6')}},
#   {'title': 'Tea for Two',
#    'year': Decimal('1950'),
#    'info': {'rating': Decimal('6.4')}}])
