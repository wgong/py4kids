# %%
import json
try:  
    from urllib2 import urlopen
except ImportError:  
    from urllib.request import urlopen
#import sys

twitter_api = "https://api.twitter.com/1/statuses/user_timeline.json?screen_name=%s&count=5"
endpoint = urlopen(twitter_api % "wwwgong")
tweets = json.loads(endpoint.read())

for tweet in tweets:
  print("%s\n%s\n" % (tweet["created_at"], tweet["text"]))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-287c02813ca2> in <module>()
#       7
#       8 twitter_api = "https://api.twitter.com/1/statuses/user_timeline.json?screen_name=%s&count=5"
# ----> 9 endpoint = urlopen(twitter_api % "wwwgong")
#      10 tweets = json.loads(endpoint.read())
#      11
#
# C:\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ...
