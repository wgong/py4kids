# %% [markdown]
# [CSV vs Pandas when importing a csv](https://www.reddit.com/r/learnpython/comments/3qln6c/csv_vs_pandas_when_importing_a_csv/)

# %% [markdown]
# https://www.geeksforgeeks.org/working-csv-files-python/

# %%
# importing csv module 
import csv

# %%
# csv file name 
# filename = "aapl.csv"
filename_csv = "pandas-cookbook/data/weather_2012.csv"
filename_csv = "pandas-cookbook/data/bikes-2.csv"

# initializing the titles and rows list 
fields = [] 
rows = []

# %% [markdown]
# encoding=utf-8 failed to decode "Brébeuf",
#
# use latin-1 (http://www.codetable.net/hex/e9)

# %%
with open(filename_csv, 'r', encoding='latin-1') as csvfile: 
    # creating a csv reader object 
    csvreader = csv.reader(csvfile)
    nrow = 0
    for row in csvreader:
        if nrow:
            rows.append(row)
        else:
            fields = row
        nrow += 1

# %%
len(rows)
# Out:
# 313

# %%
fields
# Out:
# ['Date',
#  'Berri 1',
#  'Brébeuf (données non disponibles)',
#  'Côte-Sainte-Catherine',
#  'Maisonneuve 1',
#  'Maisonneuve 2',
#  'du Parc',
#  'Pierre-Dupuy',
#  'Rachel1',
#  'St-Urbain (données non disponibles)']

# %%
rows[:5]
# Out:
# [['01/01/2012', '35', '', '0', '38', '51', '26', '10', '16', ''],
#  ['02/01/2012', '83', '', '1', '68', '153', '53', '6', '43', ''],
#  ['03/01/2012', '135', '', '2', '104', '248', '89', '3', '58', ''],
#  ['04/01/2012', '144', '', '1', '116', '318', '111', '8', '61', ''],
#  ['05/01/2012', '197', '', '2', '124', '330', '97', '13', '95', '']]

# %%
# reading csv file 
with open(filename_csv, 'r', encoding='latin-1') as csvfile: 
	# creating a csv reader object 
	csvreader = csv.reader(csvfile) 
	
	# extracting each data row one by one 
	for row in csvreader: 
		rows.append(row) 

	# get total number of rows 
	print("Total no. of rows: %d"%(csvreader.line_num)) 

# printing the field names 
print('Field names are:' + ', '.join(field for field in fields)) 

# printing first 5 rows 
print('\nFirst 5 rows are:\n') 
for row in rows[:5]: 
	# parsing each column of a row 
	for col in row: 
		print("%10s"%col), 
	print('\n')
# Out:
# Total no. of rows: 314
# Field names are:Date, Berri 1, Brébeuf (données non disponibles), Côte-Sainte-Catherine, Maisonneuve 1, Maisonneuve 2, du Parc, Pierre-Dupuy, Rachel1, St-Urbain (données non disponibles)
#
# First 5 rows are:
#
# 01/01/2012
#         35
#
#          0
#         38
#         51
#         26
#         10
#         16
#
#
#
# 02/01/2012
#         83
#
#          1
#         68
#        153
#         53
#          6
#         43
#
#
#
# 03/01/2012
#        135
#
#          2
#        104
#        248
#         89
#          3
#         58
#
#
#
# 04/01/2012
#        144
#
#          1
#        116
#        318
#        111
#          8
#         61
#
#
#
# 05/01/2012
#        197
#
#          2
#        124
#        330
#         97
#         13
#         95

# %%
import pandas as pd

# %%
filename_xlsx = "pandas-cookbook/data/bikes-2.xlsx"

# %%
df = pd.read_excel(filename_xlsx)

# %%
df
# Out:
#                     Date  Berri 1  Brébeuf (données non disponibles)  \
# 0    2012-01-01 00:00:00       35                                NaN
# 1    2012-02-01 00:00:00       83                                NaN
# 2    2012-03-01 00:00:00      135                                NaN
# 3    2012-04-01 00:00:00      144                                NaN
# 4    2012-05-01 00:00:00      197                                NaN
# 5    2012-06-01 00:00:00      146                                NaN
# 6    2012-07-01 00:00:00       98                                NaN
# 7    2012-08-01 00:00:00       95                                NaN
# 8    2012-09-01 00:00:00      244                                NaN
# 9    2012-10-01 00:00:00      397                                NaN
# 10   2012-11-01 00:00:00      273                                NaN
# 11   2012-12-01 00:00:00      157                                NaN
# 12            13/01/2012       75                                NaN
# ...

# %%
df2 = pd.read_csv(filename_csv, encoding='latin-1', skip_blank_lines=False)

# %%
df2.shape
# Out:
# (313, 10)

# %%
df2.head()
# Out:
#          Date  Berri 1  Brébeuf (données non disponibles)  \
# 0  01/01/2012       35                                NaN
# 1  02/01/2012       83                                NaN
# 2  03/01/2012      135                                NaN
# 3  04/01/2012      144                                NaN
# 4  05/01/2012      197                                NaN
#
#    Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  \
# 0                      0             38             51       26            10
# 1                      1             68            153       53             6
# 2                      2            104            248       89             3
# 3                      1            116            318      111             8
# 4                      2            124            330       97            13
#
#    Rachel1  St-Urbain (données non disponibles)
# 0       16                                  NaN
# 1       43                                  NaN
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 10 columns):
# Date                                   310 non-null object
# Berri 1                                310 non-null int64
# Brébeuf (données non disponibles)      0 non-null float64
# Côte-Sainte-Catherine                  310 non-null int64
# Maisonneuve 1                          310 non-null int64
# Maisonneuve 2                          310 non-null int64
# du Parc                                310 non-null int64
# Pierre-Dupuy                           310 non-null int64
# Rachel1                                310 non-null int64
# St-Urbain (données non disponibles)    0 non-null float64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 24.3+ KB
