# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import treemap, drawing
import tree as tr

# %%
import pandas as pd
import numpy as np

# %%
filename_data="./data/reveal_EEO1_2016-small.csv"

# %% [markdown]
# ## Task0

# %%
eeo_data = pd.read_csv(filename_data, keep_default_na=False)

# exclude job_category in 'Totals', 'Previous_totals'
eeo_data = eeo_data[~eeo_data['job_category'].isin(['Totals', 'Previous_totals'])]

# exclude race in 'Overall_totals'
eeo_data = eeo_data[~eeo_data['race'].isin(['Overall_totals'])]

# convert count to number
eeo_data['count']= pd.to_numeric(eeo_data['count'], errors='coerce').astype(np.int64)

eeo_data.head()
# Out:
#    company  year                race gender   job_category  count
# 0  23andMe  2016  Hispanic_or_Latino   male     Executives      0
# 1  23andMe  2016  Hispanic_or_Latino   male       Managers      1
# 2  23andMe  2016  Hispanic_or_Latino   male  Professionals      7
# 3  23andMe  2016  Hispanic_or_Latino   male    Technicians      0
# 4  23andMe  2016  Hispanic_or_Latino   male  Sales workers      0

# %%
companies = eeo_data.company.unique()
num_companies = companies.shape[0]
print("Number of Companies={}\nThey are:\n {}".format(num_companies, companies))
# Out:
# Number of Companies=3
# They are:
#  ['23andMe' 'Adobe' 'Airbnb']

# %%
eeo_data.head()
# Out:
#    company  year                race gender   job_category  count
# 0  23andMe  2016  Hispanic_or_Latino   male     Executives      0
# 1  23andMe  2016  Hispanic_or_Latino   male       Managers      1
# 2  23andMe  2016  Hispanic_or_Latino   male  Professionals      7
# 3  23andMe  2016  Hispanic_or_Latino   male    Technicians      0
# 4  23andMe  2016  Hispanic_or_Latino   male  Sales workers      0

# %%
# total count
sum(eeo_data['count'])
# Out:
# 9376

# %%
eeo_data.groupby(['gender']).agg({'count':['sum']})
# Out:
#        count
#          sum
# gender
# female  3274
# male    6102

# %%
eeo_data.groupby(['race']).agg({'count':['sum']})
# Out:
#                                     count
#                                       sum
# race
# American_Indian_Alaskan_Native         20
# Asian                                2494
# Black_or_African_American             178
# Hispanic_or_Latino                    477
# Native_Hawaiian_or_Pacific_Islander    33
# Two_or_more_races                     150
# White                                6024

# %%
eeo_data.groupby(['job_category']).agg({'count':['sum']})
# Out:
#                        count
#                          sum
# job_category
# Administrative support   704
# Craft workers              0
# Executives               207
# Managers                2808
# Professionals           4332
# Sales workers           1270
# Service workers           49
# Technicians                6
# laborers and helpers       0
# operatives                 0

# %% [markdown]
# ## Task1

# %%
eeo_data = pd.read_csv(filename_data, keep_default_na=False)

# exclude job_category in 'Totals', 'Previous_totals'
eeo_data = eeo_data[~eeo_data['job_category'].isin(['Totals', 'Previous_totals'])]

# exclude race in 'Overall_totals'
eeo_data = eeo_data[~eeo_data['race'].isin(['Overall_totals'])]

# convert count to number
eeo_data['count']= pd.to_numeric(eeo_data['count'], errors='coerce').astype(np.int64)

eeo_data.head()
# Out:
#    company  year                race gender   job_category  count
# 0  23andMe  2016  Hispanic_or_Latino   male     Executives      0
# 1  23andMe  2016  Hispanic_or_Latino   male       Managers      1
# 2  23andMe  2016  Hispanic_or_Latino   male  Professionals      7
# 3  23andMe  2016  Hispanic_or_Latino   male    Technicians      0
# 4  23andMe  2016  Hispanic_or_Latino   male  Sales workers      0

# %%
eeo_tree = tr.data_to_tree(eeo_data, ["company", "gender"])

eeo_tree.print()
# Out:
#   │
#   ├──23andMe
#   │  │
#   │  ├──male: 148
#   │  │
#   │  └──female: 149
#   │
#   ├──Adobe
#   │  │
#   │  ├──male: 4859
#   │  │
#   │  └──female: 2303
#   │
#   └──Airbnb
#      │
#      ├──male: 1095
#      │
#      └──female: 822

# %%
eeo_tree2 = tr.data_to_tree(eeo_data, ["company", "job_category", "race", "gender"])
eeo_tree2.print()
# Out:
#   │
#   ├──23andMe
#   │  │
#   │  ├──Executives
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 9
#   │  │  │  │
#   │  │  │  └──female: 7
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 1
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 0
#   │  │
#   │  ├──Managers
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 1
#   │  │  │  │
#   │  │  │  └──female: 1
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 30
#   │  │  │  │
#   │  │  │  └──female: 18
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 1
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 5
#   │  │  │  │
#   │  │  │  └──female: 6
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 3
#   │  │
#   │  ├──Professionals
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 7
#   │  │  │  │
#   │  │  │  └──female: 5
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 61
#   │  │  │  │
#   │  │  │  └──female: 37
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 2
#   │  │  │  │
#   │  │  │  └──female: 2
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 23
#   │  │  │  │
#   │  │  │  └──female: 25
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 1
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 4
#   │  │     │
#   │  │     └──female: 2
#   │  │
#   │  ├──Technicians
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 0
#   │  │
#   │  ├──Sales workers
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 0
#   │  │
#   │  ├──Administrative support
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 5
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 2
#   │  │  │  │
#   │  │  │  └──female: 22
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 1
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 3
#   │  │  │  │
#   │  │  │  └──female: 7
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 1
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 5
#   │  │
#   │  ├──Craft workers
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 0
#   │  │
#   │  ├──operatives
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 0
#   │  │
#   │  ├──laborers and helpers
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 0
#   │  │
#   │  └──Service workers
#   │     │
#   │     ├──Hispanic_or_Latino
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     ├──White
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     ├──Black_or_African_American
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     ├──Native_Hawaiian_or_Pacific_Islander
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     ├──Asian
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     ├──American_Indian_Alaskan_Native
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     └──Two_or_more_races
#   │        │
#   │        ├──male: 0
#   │        │
#   │        └──female: 0
#   │
#   ├──Adobe
#   │  │
#   │  ├──Executives
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 3
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 56
#   │  │  │  │
#   │  │  │  └──female: 15
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 1
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 15
#   │  │  │  │
#   │  │  │  └──female: 3
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 0
#   │  │
#   │  ├──Managers
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 51
#   │  │  │  │
#   │  │  │  └──female: 50
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 1197
#   │  │  │  │
#   │  │  │  └──female: 534
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 26
#   │  │  │  │
#   │  │  │  └──female: 9
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 5
#   │  │  │  │
#   │  │  │  └──female: 4
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 310
#   │  │  │  │
#   │  │  │  └──female: 244
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 3
#   │  │  │  │
#   │  │  │  └──female: 2
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 6
#   │  │     │
#   │  │     └──female: 7
#   │  │
#   │  ├──Professionals
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 75
#   │  │  │  │
#   │  │  │  └──female: 60
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 1325
#   │  │  │  │
#   │  │  │  └──female: 403
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 25
#   │  │  │  │
#   │  │  │  └──female: 18
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 9
#   │  │  │  │
#   │  │  │  └──female: 3
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 673
#   │  │  │  │
#   │  │  │  └──female: 392
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 3
#   │  │  │  │
#   │  │  │  └──female: 4
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 25
#   │  │     │
#   │  │     └──female: 13
#   │  │
#   │  ├──Technicians
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 0
#   │  │
#   │  ├──Sales workers
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 33
#   │  │  │  │
#   │  │  │  └──female: 16
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 742
#   │  │  │  │
#   │  │  │  └──female: 266
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 26
#   │  │  │  │
#   │  │  │  └──female: 5
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 115
#   │  │  │  │
#   │  │  │  └──female: 50
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 2
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 10
#   │  │     │
#   │  │     └──female: 5
#   │  │
#   │  ├──Administrative support
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 8
#   │  │  │  │
#   │  │  │  └──female: 38
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 96
#   │  │  │  │
#   │  │  │  └──female: 119
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 3
#   │  │  │  │
#   │  │  │  └──female: 5
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 3
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 8
#   │  │  │  │
#   │  │  │  └──female: 31
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 5
#   │  │     │
#   │  │     └──female: 7
#   │  │
#   │  ├──Craft workers
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 0
#   │  │
#   │  ├──operatives
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 0
#   │  │
#   │  ├──laborers and helpers
#   │  │  │
#   │  │  ├──Hispanic_or_Latino
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──White
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Black_or_African_American
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Native_Hawaiian_or_Pacific_Islander
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──Asian
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  ├──American_Indian_Alaskan_Native
#   │  │  │  │
#   │  │  │  ├──male: 0
#   │  │  │  │
#   │  │  │  └──female: 0
#   │  │  │
#   │  │  └──Two_or_more_races
#   │  │     │
#   │  │     ├──male: 0
#   │  │     │
#   │  │     └──female: 0
#   │  │
#   │  └──Service workers
#   │     │
#   │     ├──Hispanic_or_Latino
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     ├──White
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     ├──Black_or_African_American
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     ├──Native_Hawaiian_or_Pacific_Islander
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     ├──Asian
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     ├──American_Indian_Alaskan_Native
#   │     │  │
#   │     │  ├──male: 0
#   │     │  │
#   │     │  └──female: 0
#   │     │
#   │     └──Two_or_more_races
#   │        │
#   │        ├──male: 0
#   │        │
#   │        └──female: 0
#   │
#   └──Airbnb
#      │
#      ├──Executives
#      │  │
#      │  ├──Hispanic_or_Latino
#      │  │  │
#      │  │  ├──male: 2
#      │  │  │
#      │  │  └──female: 1
#      │  │
#      │  ├──White
#      │  │  │
#      │  │  ├──male: 46
#      │  │  │
#      │  │  └──female: 20
#      │  │
#      │  ├──Black_or_African_American
#      │  │  │
#      │  │  ├──male: 2
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Native_Hawaiian_or_Pacific_Islander
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Asian
#      │  │  │
#      │  │  ├──male: 16
#      │  │  │
#      │  │  └──female: 8
#      │  │
#      │  ├──American_Indian_Alaskan_Native
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  └──Two_or_more_races
#      │     │
#      │     ├──male: 2
#      │     │
#      │     └──female: 0
#      │
#      ├──Managers
#      │  │
#      │  ├──Hispanic_or_Latino
#      │  │  │
#      │  │  ├──male: 9
#      │  │  │
#      │  │  └──female: 8
#      │  │
#      │  ├──White
#      │  │  │
#      │  │  ├──male: 103
#      │  │  │
#      │  │  └──female: 91
#      │  │
#      │  ├──Black_or_African_American
#      │  │  │
#      │  │  ├──male: 6
#      │  │  │
#      │  │  └──female: 3
#      │  │
#      │  ├──Native_Hawaiian_or_Pacific_Islander
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Asian
#      │  │  │
#      │  │  ├──male: 38
#      │  │  │
#      │  │  └──female: 25
#      │  │
#      │  ├──American_Indian_Alaskan_Native
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  └──Two_or_more_races
#      │     │
#      │     ├──male: 9
#      │     │
#      │     └──female: 3
#      │
#      ├──Professionals
#      │  │
#      │  ├──Hispanic_or_Latino
#      │  │  │
#      │  │  ├──male: 26
#      │  │  │
#      │  │  └──female: 33
#      │  │
#      │  ├──White
#      │  │  │
#      │  │  ├──male: 352
#      │  │  │
#      │  │  └──female: 214
#      │  │
#      │  ├──Black_or_African_American
#      │  │  │
#      │  │  ├──male: 15
#      │  │  │
#      │  │  └──female: 16
#      │  │
#      │  ├──Native_Hawaiian_or_Pacific_Islander
#      │  │  │
#      │  │  ├──male: 3
#      │  │  │
#      │  │  └──female: 1
#      │  │
#      │  ├──Asian
#      │  │  │
#      │  │  ├──male: 279
#      │  │  │
#      │  │  └──female: 171
#      │  │
#      │  ├──American_Indian_Alaskan_Native
#      │  │  │
#      │  │  ├──male: 1
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  └──Two_or_more_races
#      │     │
#      │     ├──male: 14
#      │     │
#      │     └──female: 10
#      │
#      ├──Technicians
#      │  │
#      │  ├──Hispanic_or_Latino
#      │  │  │
#      │  │  ├──male: 1
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──White
#      │  │  │
#      │  │  ├──male: 1
#      │  │  │
#      │  │  └──female: 3
#      │  │
#      │  ├──Black_or_African_American
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Native_Hawaiian_or_Pacific_Islander
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Asian
#      │  │  │
#      │  │  ├──male: 1
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──American_Indian_Alaskan_Native
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  └──Two_or_more_races
#      │     │
#      │     ├──male: 0
#      │     │
#      │     └──female: 0
#      │
#      ├──Sales workers
#      │  │
#      │  ├──Hispanic_or_Latino
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──White
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Black_or_African_American
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Native_Hawaiian_or_Pacific_Islander
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Asian
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──American_Indian_Alaskan_Native
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  └──Two_or_more_races
#      │     │
#      │     ├──male: 0
#      │     │
#      │     └──female: 0
#      │
#      ├──Administrative support
#      │  │
#      │  ├──Hispanic_or_Latino
#      │  │  │
#      │  │  ├──male: 15
#      │  │  │
#      │  │  └──female: 24
#      │  │
#      │  ├──White
#      │  │  │
#      │  │  ├──male: 91
#      │  │  │
#      │  │  └──female: 138
#      │  │
#      │  ├──Black_or_African_American
#      │  │  │
#      │  │  ├──male: 6
#      │  │  │
#      │  │  └──female: 6
#      │  │
#      │  ├──Native_Hawaiian_or_Pacific_Islander
#      │  │  │
#      │  │  ├──male: 1
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Asian
#      │  │  │
#      │  │  ├──male: 18
#      │  │  │
#      │  │  └──female: 18
#      │  │
#      │  ├──American_Indian_Alaskan_Native
#      │  │  │
#      │  │  ├──male: 1
#      │  │  │
#      │  │  └──female: 1
#      │  │
#      │  └──Two_or_more_races
#      │     │
#      │     ├──male: 7
#      │     │
#      │     └──female: 9
#      │
#      ├──Craft workers
#      │  │
#      │  ├──Hispanic_or_Latino
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──White
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Black_or_African_American
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Native_Hawaiian_or_Pacific_Islander
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Asian
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──American_Indian_Alaskan_Native
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  └──Two_or_more_races
#      │     │
#      │     ├──male: 0
#      │     │
#      │     └──female: 0
#      │
#      ├──operatives
#      │  │
#      │  ├──Hispanic_or_Latino
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──White
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Black_or_African_American
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Native_Hawaiian_or_Pacific_Islander
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Asian
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──American_Indian_Alaskan_Native
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  └──Two_or_more_races
#      │     │
#      │     ├──male: 0
#      │     │
#      │     └──female: 0
#      │
#      ├──laborers and helpers
#      │  │
#      │  ├──Hispanic_or_Latino
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──White
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Black_or_African_American
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Native_Hawaiian_or_Pacific_Islander
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──Asian
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  ├──American_Indian_Alaskan_Native
#      │  │  │
#      │  │  ├──male: 0
#      │  │  │
#      │  │  └──female: 0
#      │  │
#      │  └──Two_or_more_races
#      │     │
#      │     ├──male: 0
#      │     │
#      │     └──female: 0
#      │
#      └──Service workers
#         │
#         ├──Hispanic_or_Latino
#         │  │
#         │  ├──male: 3
#         │  │
#         │  └──female: 2
#         │
#         ├──White
#         │  │
#         │  ├──male: 14
#         │  │
#         │  └──female: 12
#         │
#         ├──Black_or_African_American
#         │  │
#         │  ├──male: 2
#         │  │
#         │  └──female: 0
#         │
#         ├──Native_Hawaiian_or_Pacific_Islander
#         │  │
#         │  ├──male: 2
#         │  │
#         │  └──female: 0
#         │
#         ├──Asian
#         │  │
#         │  ├──male: 6
#         │  │
#         │  └──female: 3
#         │
#         ├──American_Indian_Alaskan_Native
#         │  │
#         │  ├──male: 0
#         │  │
#         │  └──female: 1
#         │
#         └──Two_or_more_races
#            │
#            ├──male: 3
#            │
#            └──female: 1

# %%
def compute_internal_counts(t):
    '''
    Assign a count to the interior nodes.  The count of the leaves
    should already be set.  The count of an internal node is the sum
    of the counts of its children.

    Inputs:
        t (Tree): a tree

    Returns:
        The input tree t should be modified so that every internal node's
        count is set to be the sum of the counts of its children.

        The return value will be:
        - If the tree has no children: the value of the count attribute
        - If the tree has children: the sum of the counts of the children
    '''

    if t.num_children() < 1:
        return t.count
    node_sum = 0
    for ctr in t.children:
        node_sum += compute_internal_counts(ctr)
    t.count = node_sum
    return node_sum

# %%
def compute_verbose_labels(t, prefix=None):
    '''
    Assign a verbose label to non-root nodes. Verbose labels contain the 
    full path to that node through the tree. For example, following the 
    path "Google" --> "female" --> "white" should create the verbose label 
    "Google: female: white"

    Inputs:
        t (Tree): a tree

    Outputs:
        Nothing. The input tree t should be modified to contain
            verbose labels for all non-root nodes


    '''

        
    for ctr in t.children:
        ctr.label = (prefix + ': ' + ctr.label) if prefix else ctr.label
        compute_verbose_labels(ctr, prefix=ctr.label)

    # Do not modify this return statement.
    # This function doesn't return anything!
    return None

# %%
compute_internal_counts(eeo_tree)

compute_verbose_labels(eeo_tree)

eeo_tree.print()
# Out:
# : 9376
#   │
#   ├──23andMe: 297
#   │  │
#   │  ├──23andMe: male: 148
#   │  │
#   │  └──23andMe: female: 149
#   │
#   ├──Adobe: 7162
#   │  │
#   │  ├──Adobe: male: 4859
#   │  │
#   │  └──Adobe: female: 2303
#   │
#   └──Airbnb: 1917
#      │
#      ├──Airbnb: male: 1095
#      │
#      └──Airbnb: female: 822

# %%
compute_internal_counts(eeo_tree2)

compute_verbose_labels(eeo_tree2)

eeo_tree2.print()
# Out:
# : 9376
#   │
#   ├──23andMe: 297
#   │  │
#   │  ├──23andMe: Executives: 17
#   │  │  │
#   │  │  ├──23andMe: Executives: Hispanic_or_Latino: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Executives: Hispanic_or_Latino: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Executives: Hispanic_or_Latino: female: 0
#   │  │  │
#   │  │  ├──23andMe: Executives: White: 16
#   │  │  │  │
#   │  │  │  ├──23andMe: Executives: White: male: 9
#   │  │  │  │
#   │  │  │  └──23andMe: Executives: White: female: 7
#   │  │  │
#   │  │  ├──23andMe: Executives: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Executives: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Executives: Black_or_African_American: female: 0
#   │  │  │
#   │  │  ├──23andMe: Executives: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Executives: Native_Hawaiian_or_Pacific_Islander: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Executives: Native_Hawaiian_or_Pacific_Islander: female:
#   │  │  │     0
#   │  │  │
#   │  │  ├──23andMe: Executives: Asian: 1
#   │  │  │  │
#   │  │  │  ├──23andMe: Executives: Asian: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Executives: Asian: female: 1
#   │  │  │
#   │  │  ├──23andMe: Executives: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Executives: American_Indian_Alaskan_Native: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Executives: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──23andMe: Executives: Two_or_more_races: 0
#   │  │     │
#   │  │     ├──23andMe: Executives: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──23andMe: Executives: Two_or_more_races: female: 0
#   │  │
#   │  ├──23andMe: Managers: 65
#   │  │  │
#   │  │  ├──23andMe: Managers: Hispanic_or_Latino: 2
#   │  │  │  │
#   │  │  │  ├──23andMe: Managers: Hispanic_or_Latino: male: 1
#   │  │  │  │
#   │  │  │  └──23andMe: Managers: Hispanic_or_Latino: female: 1
#   │  │  │
#   │  │  ├──23andMe: Managers: White: 48
#   │  │  │  │
#   │  │  │  ├──23andMe: Managers: White: male: 30
#   │  │  │  │
#   │  │  │  └──23andMe: Managers: White: female: 18
#   │  │  │
#   │  │  ├──23andMe: Managers: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Managers: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Managers: Black_or_African_American: female: 0
#   │  │  │
#   │  │  ├──23andMe: Managers: Native_Hawaiian_or_Pacific_Islander: 1
#   │  │  │  │
#   │  │  │  ├──23andMe: Managers: Native_Hawaiian_or_Pacific_Islander: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Managers: Native_Hawaiian_or_Pacific_Islander: female: 1
#   │  │  │
#   │  │  ├──23andMe: Managers: Asian: 11
#   │  │  │  │
#   │  │  │  ├──23andMe: Managers: Asian: male: 5
#   │  │  │  │
#   │  │  │  └──23andMe: Managers: Asian: female: 6
#   │  │  │
#   │  │  ├──23andMe: Managers: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Managers: American_Indian_Alaskan_Native: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Managers: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──23andMe: Managers: Two_or_more_races: 3
#   │  │     │
#   │  │     ├──23andMe: Managers: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──23andMe: Managers: Two_or_more_races: female: 3
#   │  │
#   │  ├──23andMe: Professionals: 169
#   │  │  │
#   │  │  ├──23andMe: Professionals: Hispanic_or_Latino: 12
#   │  │  │  │
#   │  │  │  ├──23andMe: Professionals: Hispanic_or_Latino: male: 7
#   │  │  │  │
#   │  │  │  └──23andMe: Professionals: Hispanic_or_Latino: female: 5
#   │  │  │
#   │  │  ├──23andMe: Professionals: White: 98
#   │  │  │  │
#   │  │  │  ├──23andMe: Professionals: White: male: 61
#   │  │  │  │
#   │  │  │  └──23andMe: Professionals: White: female: 37
#   │  │  │
#   │  │  ├──23andMe: Professionals: Black_or_African_American: 4
#   │  │  │  │
#   │  │  │  ├──23andMe: Professionals: Black_or_African_American: male: 2
#   │  │  │  │
#   │  │  │  └──23andMe: Professionals: Black_or_African_American: female: 2
#   │  │  │
#   │  │  ├──23andMe: Professionals: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Professionals: Native_Hawaiian_or_Pacific_Islander: male:
#   │  │  │  │  0
#   │  │  │  │
#   │  │  │  └──23andMe: Professionals: Native_Hawaiian_or_Pacific_Islander:
#   │  │  │     female: 0
#   │  │  │
#   │  │  ├──23andMe: Professionals: Asian: 48
#   │  │  │  │
#   │  │  │  ├──23andMe: Professionals: Asian: male: 23
#   │  │  │  │
#   │  │  │  └──23andMe: Professionals: Asian: female: 25
#   │  │  │
#   │  │  ├──23andMe: Professionals: American_Indian_Alaskan_Native: 1
#   │  │  │  │
#   │  │  │  ├──23andMe: Professionals: American_Indian_Alaskan_Native: male: 1
#   │  │  │  │
#   │  │  │  └──23andMe: Professionals: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──23andMe: Professionals: Two_or_more_races: 6
#   │  │     │
#   │  │     ├──23andMe: Professionals: Two_or_more_races: male: 4
#   │  │     │
#   │  │     └──23andMe: Professionals: Two_or_more_races: female: 2
#   │  │
#   │  ├──23andMe: Technicians: 0
#   │  │  │
#   │  │  ├──23andMe: Technicians: Hispanic_or_Latino: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Technicians: Hispanic_or_Latino: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Technicians: Hispanic_or_Latino: female: 0
#   │  │  │
#   │  │  ├──23andMe: Technicians: White: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Technicians: White: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Technicians: White: female: 0
#   │  │  │
#   │  │  ├──23andMe: Technicians: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Technicians: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Technicians: Black_or_African_American: female: 0
#   │  │  │
#   │  │  ├──23andMe: Technicians: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Technicians: Native_Hawaiian_or_Pacific_Islander: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Technicians: Native_Hawaiian_or_Pacific_Islander: female:
#   │  │  │     0
#   │  │  │
#   │  │  ├──23andMe: Technicians: Asian: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Technicians: Asian: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Technicians: Asian: female: 0
#   │  │  │
#   │  │  ├──23andMe: Technicians: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Technicians: American_Indian_Alaskan_Native: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Technicians: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──23andMe: Technicians: Two_or_more_races: 0
#   │  │     │
#   │  │     ├──23andMe: Technicians: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──23andMe: Technicians: Two_or_more_races: female: 0
#   │  │
#   │  ├──23andMe: Sales workers: 0
#   │  │  │
#   │  │  ├──23andMe: Sales workers: Hispanic_or_Latino: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Sales workers: Hispanic_or_Latino: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Sales workers: Hispanic_or_Latino: female: 0
#   │  │  │
#   │  │  ├──23andMe: Sales workers: White: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Sales workers: White: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Sales workers: White: female: 0
#   │  │  │
#   │  │  ├──23andMe: Sales workers: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Sales workers: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Sales workers: Black_or_African_American: female: 0
#   │  │  │
#   │  │  ├──23andMe: Sales workers: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Sales workers: Native_Hawaiian_or_Pacific_Islander: male:
#   │  │  │  │  0
#   │  │  │  │
#   │  │  │  └──23andMe: Sales workers: Native_Hawaiian_or_Pacific_Islander:
#   │  │  │     female: 0
#   │  │  │
#   │  │  ├──23andMe: Sales workers: Asian: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Sales workers: Asian: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Sales workers: Asian: female: 0
#   │  │  │
#   │  │  ├──23andMe: Sales workers: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Sales workers: American_Indian_Alaskan_Native: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Sales workers: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──23andMe: Sales workers: Two_or_more_races: 0
#   │  │     │
#   │  │     ├──23andMe: Sales workers: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──23andMe: Sales workers: Two_or_more_races: female: 0
#   │  │
#   │  ├──23andMe: Administrative support: 46
#   │  │  │
#   │  │  ├──23andMe: Administrative support: Hispanic_or_Latino: 5
#   │  │  │  │
#   │  │  │  ├──23andMe: Administrative support: Hispanic_or_Latino: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Administrative support: Hispanic_or_Latino: female: 5
#   │  │  │
#   │  │  ├──23andMe: Administrative support: White: 24
#   │  │  │  │
#   │  │  │  ├──23andMe: Administrative support: White: male: 2
#   │  │  │  │
#   │  │  │  └──23andMe: Administrative support: White: female: 22
#   │  │  │
#   │  │  ├──23andMe: Administrative support: Black_or_African_American: 1
#   │  │  │  │
#   │  │  │  ├──23andMe: Administrative support: Black_or_African_American: male:
#   │  │  │  │  0
#   │  │  │  │
#   │  │  │  └──23andMe: Administrative support: Black_or_African_American:
#   │  │  │     female: 1
#   │  │  │
#   │  │  ├──23andMe: Administrative support: Native_Hawaiian_or_Pacific_Islander:
#   │  │  │  0
#   │  │  │  │
#   │  │  │  ├──23andMe: Administrative support:
#   │  │  │  │  Native_Hawaiian_or_Pacific_Islander: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Administrative support:
#   │  │  │     Native_Hawaiian_or_Pacific_Islander: female: 0
#   │  │  │
#   │  │  ├──23andMe: Administrative support: Asian: 10
#   │  │  │  │
#   │  │  │  ├──23andMe: Administrative support: Asian: male: 3
#   │  │  │  │
#   │  │  │  └──23andMe: Administrative support: Asian: female: 7
#   │  │  │
#   │  │  ├──23andMe: Administrative support: American_Indian_Alaskan_Native: 1
#   │  │  │  │
#   │  │  │  ├──23andMe: Administrative support: American_Indian_Alaskan_Native:
#   │  │  │  │  male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Administrative support: American_Indian_Alaskan_Native:
#   │  │  │     female: 1
#   │  │  │
#   │  │  └──23andMe: Administrative support: Two_or_more_races: 5
#   │  │     │
#   │  │     ├──23andMe: Administrative support: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──23andMe: Administrative support: Two_or_more_races: female: 5
#   │  │
#   │  ├──23andMe: Craft workers: 0
#   │  │  │
#   │  │  ├──23andMe: Craft workers: Hispanic_or_Latino: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Craft workers: Hispanic_or_Latino: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Craft workers: Hispanic_or_Latino: female: 0
#   │  │  │
#   │  │  ├──23andMe: Craft workers: White: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Craft workers: White: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Craft workers: White: female: 0
#   │  │  │
#   │  │  ├──23andMe: Craft workers: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Craft workers: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Craft workers: Black_or_African_American: female: 0
#   │  │  │
#   │  │  ├──23andMe: Craft workers: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Craft workers: Native_Hawaiian_or_Pacific_Islander: male:
#   │  │  │  │  0
#   │  │  │  │
#   │  │  │  └──23andMe: Craft workers: Native_Hawaiian_or_Pacific_Islander:
#   │  │  │     female: 0
#   │  │  │
#   │  │  ├──23andMe: Craft workers: Asian: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Craft workers: Asian: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Craft workers: Asian: female: 0
#   │  │  │
#   │  │  ├──23andMe: Craft workers: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: Craft workers: American_Indian_Alaskan_Native: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: Craft workers: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──23andMe: Craft workers: Two_or_more_races: 0
#   │  │     │
#   │  │     ├──23andMe: Craft workers: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──23andMe: Craft workers: Two_or_more_races: female: 0
#   │  │
#   │  ├──23andMe: operatives: 0
#   │  │  │
#   │  │  ├──23andMe: operatives: Hispanic_or_Latino: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: operatives: Hispanic_or_Latino: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: operatives: Hispanic_or_Latino: female: 0
#   │  │  │
#   │  │  ├──23andMe: operatives: White: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: operatives: White: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: operatives: White: female: 0
#   │  │  │
#   │  │  ├──23andMe: operatives: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: operatives: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: operatives: Black_or_African_American: female: 0
#   │  │  │
#   │  │  ├──23andMe: operatives: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: operatives: Native_Hawaiian_or_Pacific_Islander: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: operatives: Native_Hawaiian_or_Pacific_Islander: female:
#   │  │  │     0
#   │  │  │
#   │  │  ├──23andMe: operatives: Asian: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: operatives: Asian: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: operatives: Asian: female: 0
#   │  │  │
#   │  │  ├──23andMe: operatives: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: operatives: American_Indian_Alaskan_Native: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: operatives: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──23andMe: operatives: Two_or_more_races: 0
#   │  │     │
#   │  │     ├──23andMe: operatives: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──23andMe: operatives: Two_or_more_races: female: 0
#   │  │
#   │  ├──23andMe: laborers and helpers: 0
#   │  │  │
#   │  │  ├──23andMe: laborers and helpers: Hispanic_or_Latino: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: laborers and helpers: Hispanic_or_Latino: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: laborers and helpers: Hispanic_or_Latino: female: 0
#   │  │  │
#   │  │  ├──23andMe: laborers and helpers: White: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: laborers and helpers: White: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: laborers and helpers: White: female: 0
#   │  │  │
#   │  │  ├──23andMe: laborers and helpers: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: laborers and helpers: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: laborers and helpers: Black_or_African_American: female:
#   │  │  │     0
#   │  │  │
#   │  │  ├──23andMe: laborers and helpers: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: laborers and helpers:
#   │  │  │  │  Native_Hawaiian_or_Pacific_Islander: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: laborers and helpers:
#   │  │  │     Native_Hawaiian_or_Pacific_Islander: female: 0
#   │  │  │
#   │  │  ├──23andMe: laborers and helpers: Asian: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: laborers and helpers: Asian: male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: laborers and helpers: Asian: female: 0
#   │  │  │
#   │  │  ├──23andMe: laborers and helpers: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──23andMe: laborers and helpers: American_Indian_Alaskan_Native:
#   │  │  │  │  male: 0
#   │  │  │  │
#   │  │  │  └──23andMe: laborers and helpers: American_Indian_Alaskan_Native:
#   │  │  │     female: 0
#   │  │  │
#   │  │  └──23andMe: laborers and helpers: Two_or_more_races: 0
#   │  │     │
#   │  │     ├──23andMe: laborers and helpers: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──23andMe: laborers and helpers: Two_or_more_races: female: 0
#   │  │
#   │  └──23andMe: Service workers: 0
#   │     │
#   │     ├──23andMe: Service workers: Hispanic_or_Latino: 0
#   │     │  │
#   │     │  ├──23andMe: Service workers: Hispanic_or_Latino: male: 0
#   │     │  │
#   │     │  └──23andMe: Service workers: Hispanic_or_Latino: female: 0
#   │     │
#   │     ├──23andMe: Service workers: White: 0
#   │     │  │
#   │     │  ├──23andMe: Service workers: White: male: 0
#   │     │  │
#   │     │  └──23andMe: Service workers: White: female: 0
#   │     │
#   │     ├──23andMe: Service workers: Black_or_African_American: 0
#   │     │  │
#   │     │  ├──23andMe: Service workers: Black_or_African_American: male: 0
#   │     │  │
#   │     │  └──23andMe: Service workers: Black_or_African_American: female: 0
#   │     │
#   │     ├──23andMe: Service workers: Native_Hawaiian_or_Pacific_Islander: 0
#   │     │  │
#   │     │  ├──23andMe: Service workers: Native_Hawaiian_or_Pacific_Islander:
#   │     │  │  male: 0
#   │     │  │
#   │     │  └──23andMe: Service workers: Native_Hawaiian_or_Pacific_Islander:
#   │     │     female: 0
#   │     │
#   │     ├──23andMe: Service workers: Asian: 0
#   │     │  │
#   │     │  ├──23andMe: Service workers: Asian: male: 0
#   │     │  │
#   │     │  └──23andMe: Service workers: Asian: female: 0
#   │     │
#   │     ├──23andMe: Service workers: American_Indian_Alaskan_Native: 0
#   │     │  │
#   │     │  ├──23andMe: Service workers: American_Indian_Alaskan_Native: male: 0
#   │     │  │
#   │     │  └──23andMe: Service workers: American_Indian_Alaskan_Native: female:
#   │     │     0
#   │     │
#   │     └──23andMe: Service workers: Two_or_more_races: 0
#   │        │
#   │        ├──23andMe: Service workers: Two_or_more_races: male: 0
#   │        │
#   │        └──23andMe: Service workers: Two_or_more_races: female: 0
#   │
#   ├──Adobe: 7162
#   │  │
#   │  ├──Adobe: Executives: 93
#   │  │  │
#   │  │  ├──Adobe: Executives: Hispanic_or_Latino: 3
#   │  │  │  │
#   │  │  │  ├──Adobe: Executives: Hispanic_or_Latino: male: 3
#   │  │  │  │
#   │  │  │  └──Adobe: Executives: Hispanic_or_Latino: female: 0
#   │  │  │
#   │  │  ├──Adobe: Executives: White: 71
#   │  │  │  │
#   │  │  │  ├──Adobe: Executives: White: male: 56
#   │  │  │  │
#   │  │  │  └──Adobe: Executives: White: female: 15
#   │  │  │
#   │  │  ├──Adobe: Executives: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Executives: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Executives: Black_or_African_American: female: 0
#   │  │  │
#   │  │  ├──Adobe: Executives: Native_Hawaiian_or_Pacific_Islander: 1
#   │  │  │  │
#   │  │  │  ├──Adobe: Executives: Native_Hawaiian_or_Pacific_Islander: male: 1
#   │  │  │  │
#   │  │  │  └──Adobe: Executives: Native_Hawaiian_or_Pacific_Islander: female: 0
#   │  │  │
#   │  │  ├──Adobe: Executives: Asian: 18
#   │  │  │  │
#   │  │  │  ├──Adobe: Executives: Asian: male: 15
#   │  │  │  │
#   │  │  │  └──Adobe: Executives: Asian: female: 3
#   │  │  │
#   │  │  ├──Adobe: Executives: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Executives: American_Indian_Alaskan_Native: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Executives: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──Adobe: Executives: Two_or_more_races: 0
#   │  │     │
#   │  │     ├──Adobe: Executives: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──Adobe: Executives: Two_or_more_races: female: 0
#   │  │
#   │  ├──Adobe: Managers: 2448
#   │  │  │
#   │  │  ├──Adobe: Managers: Hispanic_or_Latino: 101
#   │  │  │  │
#   │  │  │  ├──Adobe: Managers: Hispanic_or_Latino: male: 51
#   │  │  │  │
#   │  │  │  └──Adobe: Managers: Hispanic_or_Latino: female: 50
#   │  │  │
#   │  │  ├──Adobe: Managers: White: 1731
#   │  │  │  │
#   │  │  │  ├──Adobe: Managers: White: male: 1197
#   │  │  │  │
#   │  │  │  └──Adobe: Managers: White: female: 534
#   │  │  │
#   │  │  ├──Adobe: Managers: Black_or_African_American: 35
#   │  │  │  │
#   │  │  │  ├──Adobe: Managers: Black_or_African_American: male: 26
#   │  │  │  │
#   │  │  │  └──Adobe: Managers: Black_or_African_American: female: 9
#   │  │  │
#   │  │  ├──Adobe: Managers: Native_Hawaiian_or_Pacific_Islander: 9
#   │  │  │  │
#   │  │  │  ├──Adobe: Managers: Native_Hawaiian_or_Pacific_Islander: male: 5
#   │  │  │  │
#   │  │  │  └──Adobe: Managers: Native_Hawaiian_or_Pacific_Islander: female: 4
#   │  │  │
#   │  │  ├──Adobe: Managers: Asian: 554
#   │  │  │  │
#   │  │  │  ├──Adobe: Managers: Asian: male: 310
#   │  │  │  │
#   │  │  │  └──Adobe: Managers: Asian: female: 244
#   │  │  │
#   │  │  ├──Adobe: Managers: American_Indian_Alaskan_Native: 5
#   │  │  │  │
#   │  │  │  ├──Adobe: Managers: American_Indian_Alaskan_Native: male: 3
#   │  │  │  │
#   │  │  │  └──Adobe: Managers: American_Indian_Alaskan_Native: female: 2
#   │  │  │
#   │  │  └──Adobe: Managers: Two_or_more_races: 13
#   │  │     │
#   │  │     ├──Adobe: Managers: Two_or_more_races: male: 6
#   │  │     │
#   │  │     └──Adobe: Managers: Two_or_more_races: female: 7
#   │  │
#   │  ├──Adobe: Professionals: 3028
#   │  │  │
#   │  │  ├──Adobe: Professionals: Hispanic_or_Latino: 135
#   │  │  │  │
#   │  │  │  ├──Adobe: Professionals: Hispanic_or_Latino: male: 75
#   │  │  │  │
#   │  │  │  └──Adobe: Professionals: Hispanic_or_Latino: female: 60
#   │  │  │
#   │  │  ├──Adobe: Professionals: White: 1728
#   │  │  │  │
#   │  │  │  ├──Adobe: Professionals: White: male: 1325
#   │  │  │  │
#   │  │  │  └──Adobe: Professionals: White: female: 403
#   │  │  │
#   │  │  ├──Adobe: Professionals: Black_or_African_American: 43
#   │  │  │  │
#   │  │  │  ├──Adobe: Professionals: Black_or_African_American: male: 25
#   │  │  │  │
#   │  │  │  └──Adobe: Professionals: Black_or_African_American: female: 18
#   │  │  │
#   │  │  ├──Adobe: Professionals: Native_Hawaiian_or_Pacific_Islander: 12
#   │  │  │  │
#   │  │  │  ├──Adobe: Professionals: Native_Hawaiian_or_Pacific_Islander: male: 9
#   │  │  │  │
#   │  │  │  └──Adobe: Professionals: Native_Hawaiian_or_Pacific_Islander: female:
#   │  │  │     3
#   │  │  │
#   │  │  ├──Adobe: Professionals: Asian: 1065
#   │  │  │  │
#   │  │  │  ├──Adobe: Professionals: Asian: male: 673
#   │  │  │  │
#   │  │  │  └──Adobe: Professionals: Asian: female: 392
#   │  │  │
#   │  │  ├──Adobe: Professionals: American_Indian_Alaskan_Native: 7
#   │  │  │  │
#   │  │  │  ├──Adobe: Professionals: American_Indian_Alaskan_Native: male: 3
#   │  │  │  │
#   │  │  │  └──Adobe: Professionals: American_Indian_Alaskan_Native: female: 4
#   │  │  │
#   │  │  └──Adobe: Professionals: Two_or_more_races: 38
#   │  │     │
#   │  │     ├──Adobe: Professionals: Two_or_more_races: male: 25
#   │  │     │
#   │  │     └──Adobe: Professionals: Two_or_more_races: female: 13
#   │  │
#   │  ├──Adobe: Technicians: 0
#   │  │  │
#   │  │  ├──Adobe: Technicians: Hispanic_or_Latino: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Technicians: Hispanic_or_Latino: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Technicians: Hispanic_or_Latino: female: 0
#   │  │  │
#   │  │  ├──Adobe: Technicians: White: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Technicians: White: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Technicians: White: female: 0
#   │  │  │
#   │  │  ├──Adobe: Technicians: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Technicians: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Technicians: Black_or_African_American: female: 0
#   │  │  │
#   │  │  ├──Adobe: Technicians: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Technicians: Native_Hawaiian_or_Pacific_Islander: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Technicians: Native_Hawaiian_or_Pacific_Islander: female: 0
#   │  │  │
#   │  │  ├──Adobe: Technicians: Asian: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Technicians: Asian: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Technicians: Asian: female: 0
#   │  │  │
#   │  │  ├──Adobe: Technicians: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Technicians: American_Indian_Alaskan_Native: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Technicians: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──Adobe: Technicians: Two_or_more_races: 0
#   │  │     │
#   │  │     ├──Adobe: Technicians: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──Adobe: Technicians: Two_or_more_races: female: 0
#   │  │
#   │  ├──Adobe: Sales workers: 1270
#   │  │  │
#   │  │  ├──Adobe: Sales workers: Hispanic_or_Latino: 49
#   │  │  │  │
#   │  │  │  ├──Adobe: Sales workers: Hispanic_or_Latino: male: 33
#   │  │  │  │
#   │  │  │  └──Adobe: Sales workers: Hispanic_or_Latino: female: 16
#   │  │  │
#   │  │  ├──Adobe: Sales workers: White: 1008
#   │  │  │  │
#   │  │  │  ├──Adobe: Sales workers: White: male: 742
#   │  │  │  │
#   │  │  │  └──Adobe: Sales workers: White: female: 266
#   │  │  │
#   │  │  ├──Adobe: Sales workers: Black_or_African_American: 31
#   │  │  │  │
#   │  │  │  ├──Adobe: Sales workers: Black_or_African_American: male: 26
#   │  │  │  │
#   │  │  │  └──Adobe: Sales workers: Black_or_African_American: female: 5
#   │  │  │
#   │  │  ├──Adobe: Sales workers: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Sales workers: Native_Hawaiian_or_Pacific_Islander: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Sales workers: Native_Hawaiian_or_Pacific_Islander: female:
#   │  │  │     0
#   │  │  │
#   │  │  ├──Adobe: Sales workers: Asian: 165
#   │  │  │  │
#   │  │  │  ├──Adobe: Sales workers: Asian: male: 115
#   │  │  │  │
#   │  │  │  └──Adobe: Sales workers: Asian: female: 50
#   │  │  │
#   │  │  ├──Adobe: Sales workers: American_Indian_Alaskan_Native: 2
#   │  │  │  │
#   │  │  │  ├──Adobe: Sales workers: American_Indian_Alaskan_Native: male: 2
#   │  │  │  │
#   │  │  │  └──Adobe: Sales workers: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──Adobe: Sales workers: Two_or_more_races: 15
#   │  │     │
#   │  │     ├──Adobe: Sales workers: Two_or_more_races: male: 10
#   │  │     │
#   │  │     └──Adobe: Sales workers: Two_or_more_races: female: 5
#   │  │
#   │  ├──Adobe: Administrative support: 323
#   │  │  │
#   │  │  ├──Adobe: Administrative support: Hispanic_or_Latino: 46
#   │  │  │  │
#   │  │  │  ├──Adobe: Administrative support: Hispanic_or_Latino: male: 8
#   │  │  │  │
#   │  │  │  └──Adobe: Administrative support: Hispanic_or_Latino: female: 38
#   │  │  │
#   │  │  ├──Adobe: Administrative support: White: 215
#   │  │  │  │
#   │  │  │  ├──Adobe: Administrative support: White: male: 96
#   │  │  │  │
#   │  │  │  └──Adobe: Administrative support: White: female: 119
#   │  │  │
#   │  │  ├──Adobe: Administrative support: Black_or_African_American: 8
#   │  │  │  │
#   │  │  │  ├──Adobe: Administrative support: Black_or_African_American: male: 3
#   │  │  │  │
#   │  │  │  └──Adobe: Administrative support: Black_or_African_American: female:
#   │  │  │     5
#   │  │  │
#   │  │  ├──Adobe: Administrative support: Native_Hawaiian_or_Pacific_Islander: 3
#   │  │  │  │
#   │  │  │  ├──Adobe: Administrative support:
#   │  │  │  │  Native_Hawaiian_or_Pacific_Islander: male: 3
#   │  │  │  │
#   │  │  │  └──Adobe: Administrative support:
#   │  │  │     Native_Hawaiian_or_Pacific_Islander: female: 0
#   │  │  │
#   │  │  ├──Adobe: Administrative support: Asian: 39
#   │  │  │  │
#   │  │  │  ├──Adobe: Administrative support: Asian: male: 8
#   │  │  │  │
#   │  │  │  └──Adobe: Administrative support: Asian: female: 31
#   │  │  │
#   │  │  ├──Adobe: Administrative support: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Administrative support: American_Indian_Alaskan_Native:
#   │  │  │  │  male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Administrative support: American_Indian_Alaskan_Native:
#   │  │  │     female: 0
#   │  │  │
#   │  │  └──Adobe: Administrative support: Two_or_more_races: 12
#   │  │     │
#   │  │     ├──Adobe: Administrative support: Two_or_more_races: male: 5
#   │  │     │
#   │  │     └──Adobe: Administrative support: Two_or_more_races: female: 7
#   │  │
#   │  ├──Adobe: Craft workers: 0
#   │  │  │
#   │  │  ├──Adobe: Craft workers: Hispanic_or_Latino: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Craft workers: Hispanic_or_Latino: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Craft workers: Hispanic_or_Latino: female: 0
#   │  │  │
#   │  │  ├──Adobe: Craft workers: White: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Craft workers: White: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Craft workers: White: female: 0
#   │  │  │
#   │  │  ├──Adobe: Craft workers: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Craft workers: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Craft workers: Black_or_African_American: female: 0
#   │  │  │
#   │  │  ├──Adobe: Craft workers: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Craft workers: Native_Hawaiian_or_Pacific_Islander: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Craft workers: Native_Hawaiian_or_Pacific_Islander: female:
#   │  │  │     0
#   │  │  │
#   │  │  ├──Adobe: Craft workers: Asian: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Craft workers: Asian: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Craft workers: Asian: female: 0
#   │  │  │
#   │  │  ├──Adobe: Craft workers: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: Craft workers: American_Indian_Alaskan_Native: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: Craft workers: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──Adobe: Craft workers: Two_or_more_races: 0
#   │  │     │
#   │  │     ├──Adobe: Craft workers: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──Adobe: Craft workers: Two_or_more_races: female: 0
#   │  │
#   │  ├──Adobe: operatives: 0
#   │  │  │
#   │  │  ├──Adobe: operatives: Hispanic_or_Latino: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: operatives: Hispanic_or_Latino: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: operatives: Hispanic_or_Latino: female: 0
#   │  │  │
#   │  │  ├──Adobe: operatives: White: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: operatives: White: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: operatives: White: female: 0
#   │  │  │
#   │  │  ├──Adobe: operatives: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: operatives: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: operatives: Black_or_African_American: female: 0
#   │  │  │
#   │  │  ├──Adobe: operatives: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: operatives: Native_Hawaiian_or_Pacific_Islander: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: operatives: Native_Hawaiian_or_Pacific_Islander: female: 0
#   │  │  │
#   │  │  ├──Adobe: operatives: Asian: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: operatives: Asian: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: operatives: Asian: female: 0
#   │  │  │
#   │  │  ├──Adobe: operatives: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: operatives: American_Indian_Alaskan_Native: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: operatives: American_Indian_Alaskan_Native: female: 0
#   │  │  │
#   │  │  └──Adobe: operatives: Two_or_more_races: 0
#   │  │     │
#   │  │     ├──Adobe: operatives: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──Adobe: operatives: Two_or_more_races: female: 0
#   │  │
#   │  ├──Adobe: laborers and helpers: 0
#   │  │  │
#   │  │  ├──Adobe: laborers and helpers: Hispanic_or_Latino: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: laborers and helpers: Hispanic_or_Latino: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: laborers and helpers: Hispanic_or_Latino: female: 0
#   │  │  │
#   │  │  ├──Adobe: laborers and helpers: White: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: laborers and helpers: White: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: laborers and helpers: White: female: 0
#   │  │  │
#   │  │  ├──Adobe: laborers and helpers: Black_or_African_American: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: laborers and helpers: Black_or_African_American: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: laborers and helpers: Black_or_African_American: female: 0
#   │  │  │
#   │  │  ├──Adobe: laborers and helpers: Native_Hawaiian_or_Pacific_Islander: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: laborers and helpers: Native_Hawaiian_or_Pacific_Islander:
#   │  │  │  │  male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: laborers and helpers: Native_Hawaiian_or_Pacific_Islander:
#   │  │  │     female: 0
#   │  │  │
#   │  │  ├──Adobe: laborers and helpers: Asian: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: laborers and helpers: Asian: male: 0
#   │  │  │  │
#   │  │  │  └──Adobe: laborers and helpers: Asian: female: 0
#   │  │  │
#   │  │  ├──Adobe: laborers and helpers: American_Indian_Alaskan_Native: 0
#   │  │  │  │
#   │  │  │  ├──Adobe: laborers and helpers: American_Indian_Alaskan_Native: male:
#   │  │  │  │  0
#   │  │  │  │
#   │  │  │  └──Adobe: laborers and helpers: American_Indian_Alaskan_Native:
#   │  │  │     female: 0
#   │  │  │
#   │  │  └──Adobe: laborers and helpers: Two_or_more_races: 0
#   │  │     │
#   │  │     ├──Adobe: laborers and helpers: Two_or_more_races: male: 0
#   │  │     │
#   │  │     └──Adobe: laborers and helpers: Two_or_more_races: female: 0
#   │  │
#   │  └──Adobe: Service workers: 0
#   │     │
#   │     ├──Adobe: Service workers: Hispanic_or_Latino: 0
#   │     │  │
#   │     │  ├──Adobe: Service workers: Hispanic_or_Latino: male: 0
#   │     │  │
#   │     │  └──Adobe: Service workers: Hispanic_or_Latino: female: 0
#   │     │
#   │     ├──Adobe: Service workers: White: 0
#   │     │  │
#   │     │  ├──Adobe: Service workers: White: male: 0
#   │     │  │
#   │     │  └──Adobe: Service workers: White: female: 0
#   │     │
#   │     ├──Adobe: Service workers: Black_or_African_American: 0
#   │     │  │
#   │     │  ├──Adobe: Service workers: Black_or_African_American: male: 0
#   │     │  │
#   │     │  └──Adobe: Service workers: Black_or_African_American: female: 0
#   │     │
#   │     ├──Adobe: Service workers: Native_Hawaiian_or_Pacific_Islander: 0
#   │     │  │
#   │     │  ├──Adobe: Service workers: Native_Hawaiian_or_Pacific_Islander: male:
#   │     │  │  0
#   │     │  │
#   │     │  └──Adobe: Service workers: Native_Hawaiian_or_Pacific_Islander:
#   │     │     female: 0
#   │     │
#   │     ├──Adobe: Service workers: Asian: 0
#   │     │  │
#   │     │  ├──Adobe: Service workers: Asian: male: 0
#   │     │  │
#   │     │  └──Adobe: Service workers: Asian: female: 0
#   │     │
#   │     ├──Adobe: Service workers: American_Indian_Alaskan_Native: 0
#   │     │  │
#   │     │  ├──Adobe: Service workers: American_Indian_Alaskan_Native: male: 0
#   │     │  │
#   │     │  └──Adobe: Service workers: American_Indian_Alaskan_Native: female: 0
#   │     │
#   │     └──Adobe: Service workers: Two_or_more_races: 0
#   │        │
#   │        ├──Adobe: Service workers: Two_or_more_races: male: 0
#   │        │
#   │        └──Adobe: Service workers: Two_or_more_races: female: 0
#   │
#   └──Airbnb: 1917
#      │
#      ├──Airbnb: Executives: 97
#      │  │
#      │  ├──Airbnb: Executives: Hispanic_or_Latino: 3
#      │  │  │
#      │  │  ├──Airbnb: Executives: Hispanic_or_Latino: male: 2
#      │  │  │
#      │  │  └──Airbnb: Executives: Hispanic_or_Latino: female: 1
#      │  │
#      │  ├──Airbnb: Executives: White: 66
#      │  │  │
#      │  │  ├──Airbnb: Executives: White: male: 46
#      │  │  │
#      │  │  └──Airbnb: Executives: White: female: 20
#      │  │
#      │  ├──Airbnb: Executives: Black_or_African_American: 2
#      │  │  │
#      │  │  ├──Airbnb: Executives: Black_or_African_American: male: 2
#      │  │  │
#      │  │  └──Airbnb: Executives: Black_or_African_American: female: 0
#      │  │
#      │  ├──Airbnb: Executives: Native_Hawaiian_or_Pacific_Islander: 0
#      │  │  │
#      │  │  ├──Airbnb: Executives: Native_Hawaiian_or_Pacific_Islander: male: 0
#      │  │  │
#      │  │  └──Airbnb: Executives: Native_Hawaiian_or_Pacific_Islander: female: 0
#      │  │
#      │  ├──Airbnb: Executives: Asian: 24
#      │  │  │
#      │  │  ├──Airbnb: Executives: Asian: male: 16
#      │  │  │
#      │  │  └──Airbnb: Executives: Asian: female: 8
#      │  │
#      │  ├──Airbnb: Executives: American_Indian_Alaskan_Native: 0
#      │  │  │
#      │  │  ├──Airbnb: Executives: American_Indian_Alaskan_Native: male: 0
#      │  │  │
#      │  │  └──Airbnb: Executives: American_Indian_Alaskan_Native: female: 0
#      │  │
#      │  └──Airbnb: Executives: Two_or_more_races: 2
#      │     │
#      │     ├──Airbnb: Executives: Two_or_more_races: male: 2
#      │     │
#      │     └──Airbnb: Executives: Two_or_more_races: female: 0
#      │
#      ├──Airbnb: Managers: 295
#      │  │
#      │  ├──Airbnb: Managers: Hispanic_or_Latino: 17
#      │  │  │
#      │  │  ├──Airbnb: Managers: Hispanic_or_Latino: male: 9
#      │  │  │
#      │  │  └──Airbnb: Managers: Hispanic_or_Latino: female: 8
#      │  │
#      │  ├──Airbnb: Managers: White: 194
#      │  │  │
#      │  │  ├──Airbnb: Managers: White: male: 103
#      │  │  │
#      │  │  └──Airbnb: Managers: White: female: 91
#      │  │
#      │  ├──Airbnb: Managers: Black_or_African_American: 9
#      │  │  │
#      │  │  ├──Airbnb: Managers: Black_or_African_American: male: 6
#      │  │  │
#      │  │  └──Airbnb: Managers: Black_or_African_American: female: 3
#      │  │
#      │  ├──Airbnb: Managers: Native_Hawaiian_or_Pacific_Islander: 0
#      │  │  │
#      │  │  ├──Airbnb: Managers: Native_Hawaiian_or_Pacific_Islander: male: 0
#      │  │  │
#      │  │  └──Airbnb: Managers: Native_Hawaiian_or_Pacific_Islander: female: 0
#      │  │
#      │  ├──Airbnb: Managers: Asian: 63
#      │  │  │
#      │  │  ├──Airbnb: Managers: Asian: male: 38
#      │  │  │
#      │  │  └──Airbnb: Managers: Asian: female: 25
#      │  │
#      │  ├──Airbnb: Managers: American_Indian_Alaskan_Native: 0
#      │  │  │
#      │  │  ├──Airbnb: Managers: American_Indian_Alaskan_Native: male: 0
#      │  │  │
#      │  │  └──Airbnb: Managers: American_Indian_Alaskan_Native: female: 0
#      │  │
#      │  └──Airbnb: Managers: Two_or_more_races: 12
#      │     │
#      │     ├──Airbnb: Managers: Two_or_more_races: male: 9
#      │     │
#      │     └──Airbnb: Managers: Two_or_more_races: female: 3
#      │
#      ├──Airbnb: Professionals: 1135
#      │  │
#      │  ├──Airbnb: Professionals: Hispanic_or_Latino: 59
#      │  │  │
#      │  │  ├──Airbnb: Professionals: Hispanic_or_Latino: male: 26
#      │  │  │
#      │  │  └──Airbnb: Professionals: Hispanic_or_Latino: female: 33
#      │  │
#      │  ├──Airbnb: Professionals: White: 566
#      │  │  │
#      │  │  ├──Airbnb: Professionals: White: male: 352
#      │  │  │
#      │  │  └──Airbnb: Professionals: White: female: 214
#      │  │
#      │  ├──Airbnb: Professionals: Black_or_African_American: 31
#      │  │  │
#      │  │  ├──Airbnb: Professionals: Black_or_African_American: male: 15
#      │  │  │
#      │  │  └──Airbnb: Professionals: Black_or_African_American: female: 16
#      │  │
#      │  ├──Airbnb: Professionals: Native_Hawaiian_or_Pacific_Islander: 4
#      │  │  │
#      │  │  ├──Airbnb: Professionals: Native_Hawaiian_or_Pacific_Islander: male:
#      │  │  │  3
#      │  │  │
#      │  │  └──Airbnb: Professionals: Native_Hawaiian_or_Pacific_Islander:
#      │  │     female: 1
#      │  │
#      │  ├──Airbnb: Professionals: Asian: 450
#      │  │  │
#      │  │  ├──Airbnb: Professionals: Asian: male: 279
#      │  │  │
#      │  │  └──Airbnb: Professionals: Asian: female: 171
#      │  │
#      │  ├──Airbnb: Professionals: American_Indian_Alaskan_Native: 1
#      │  │  │
#      │  │  ├──Airbnb: Professionals: American_Indian_Alaskan_Native: male: 1
#      │  │  │
#      │  │  └──Airbnb: Professionals: American_Indian_Alaskan_Native: female: 0
#      │  │
#      │  └──Airbnb: Professionals: Two_or_more_races: 24
#      │     │
#      │     ├──Airbnb: Professionals: Two_or_more_races: male: 14
#      │     │
#      │     └──Airbnb: Professionals: Two_or_more_races: female: 10
#      │
#      ├──Airbnb: Technicians: 6
#      │  │
#      │  ├──Airbnb: Technicians: Hispanic_or_Latino: 1
#      │  │  │
#      │  │  ├──Airbnb: Technicians: Hispanic_or_Latino: male: 1
#      │  │  │
#      │  │  └──Airbnb: Technicians: Hispanic_or_Latino: female: 0
#      │  │
#      │  ├──Airbnb: Technicians: White: 4
#      │  │  │
#      │  │  ├──Airbnb: Technicians: White: male: 1
#      │  │  │
#      │  │  └──Airbnb: Technicians: White: female: 3
#      │  │
#      │  ├──Airbnb: Technicians: Black_or_African_American: 0
#      │  │  │
#      │  │  ├──Airbnb: Technicians: Black_or_African_American: male: 0
#      │  │  │
#      │  │  └──Airbnb: Technicians: Black_or_African_American: female: 0
#      │  │
#      │  ├──Airbnb: Technicians: Native_Hawaiian_or_Pacific_Islander: 0
#      │  │  │
#      │  │  ├──Airbnb: Technicians: Native_Hawaiian_or_Pacific_Islander: male: 0
#      │  │  │
#      │  │  └──Airbnb: Technicians: Native_Hawaiian_or_Pacific_Islander: female:
#      │  │     0
#      │  │
#      │  ├──Airbnb: Technicians: Asian: 1
#      │  │  │
#      │  │  ├──Airbnb: Technicians: Asian: male: 1
#      │  │  │
#      │  │  └──Airbnb: Technicians: Asian: female: 0
#      │  │
#      │  ├──Airbnb: Technicians: American_Indian_Alaskan_Native: 0
#      │  │  │
#      │  │  ├──Airbnb: Technicians: American_Indian_Alaskan_Native: male: 0
#      │  │  │
#      │  │  └──Airbnb: Technicians: American_Indian_Alaskan_Native: female: 0
#      │  │
#      │  └──Airbnb: Technicians: Two_or_more_races: 0
#      │     │
#      │     ├──Airbnb: Technicians: Two_or_more_races: male: 0
#      │     │
#      │     └──Airbnb: Technicians: Two_or_more_races: female: 0
#      │
#      ├──Airbnb: Sales workers: 0
#      │  │
#      │  ├──Airbnb: Sales workers: Hispanic_or_Latino: 0
#      │  │  │
#      │  │  ├──Airbnb: Sales workers: Hispanic_or_Latino: male: 0
#      │  │  │
#      │  │  └──Airbnb: Sales workers: Hispanic_or_Latino: female: 0
#      │  │
#      │  ├──Airbnb: Sales workers: White: 0
#      │  │  │
#      │  │  ├──Airbnb: Sales workers: White: male: 0
#      │  │  │
#      │  │  └──Airbnb: Sales workers: White: female: 0
#      │  │
#      │  ├──Airbnb: Sales workers: Black_or_African_American: 0
#      │  │  │
#      │  │  ├──Airbnb: Sales workers: Black_or_African_American: male: 0
#      │  │  │
#      │  │  └──Airbnb: Sales workers: Black_or_African_American: female: 0
#      │  │
#      │  ├──Airbnb: Sales workers: Native_Hawaiian_or_Pacific_Islander: 0
#      │  │  │
#      │  │  ├──Airbnb: Sales workers: Native_Hawaiian_or_Pacific_Islander: male:
#      │  │  │  0
#      │  │  │
#      │  │  └──Airbnb: Sales workers: Native_Hawaiian_or_Pacific_Islander:
#      │  │     female: 0
#      │  │
#      │  ├──Airbnb: Sales workers: Asian: 0
#      │  │  │
#      │  │  ├──Airbnb: Sales workers: Asian: male: 0
#      │  │  │
#      │  │  └──Airbnb: Sales workers: Asian: female: 0
#      │  │
#      │  ├──Airbnb: Sales workers: American_Indian_Alaskan_Native: 0
#      │  │  │
#      │  │  ├──Airbnb: Sales workers: American_Indian_Alaskan_Native: male: 0
#      │  │  │
#      │  │  └──Airbnb: Sales workers: American_Indian_Alaskan_Native: female: 0
#      │  │
#      │  └──Airbnb: Sales workers: Two_or_more_races: 0
#      │     │
#      │     ├──Airbnb: Sales workers: Two_or_more_races: male: 0
#      │     │
#      │     └──Airbnb: Sales workers: Two_or_more_races: female: 0
#      │
#      ├──Airbnb: Administrative support: 335
#      │  │
#      │  ├──Airbnb: Administrative support: Hispanic_or_Latino: 39
#      │  │  │
#      │  │  ├──Airbnb: Administrative support: Hispanic_or_Latino: male: 15
#      │  │  │
#      │  │  └──Airbnb: Administrative support: Hispanic_or_Latino: female: 24
#      │  │
#      │  ├──Airbnb: Administrative support: White: 229
#      │  │  │
#      │  │  ├──Airbnb: Administrative support: White: male: 91
#      │  │  │
#      │  │  └──Airbnb: Administrative support: White: female: 138
#      │  │
#      │  ├──Airbnb: Administrative support: Black_or_African_American: 12
#      │  │  │
#      │  │  ├──Airbnb: Administrative support: Black_or_African_American: male: 6
#      │  │  │
#      │  │  └──Airbnb: Administrative support: Black_or_African_American: female:
#      │  │     6
#      │  │
#      │  ├──Airbnb: Administrative support: Native_Hawaiian_or_Pacific_Islander:
#      │  │  1
#      │  │  │
#      │  │  ├──Airbnb: Administrative support:
#      │  │  │  Native_Hawaiian_or_Pacific_Islander: male: 1
#      │  │  │
#      │  │  └──Airbnb: Administrative support:
#      │  │     Native_Hawaiian_or_Pacific_Islander: female: 0
#      │  │
#      │  ├──Airbnb: Administrative support: Asian: 36
#      │  │  │
#      │  │  ├──Airbnb: Administrative support: Asian: male: 18
#      │  │  │
#      │  │  └──Airbnb: Administrative support: Asian: female: 18
#      │  │
#      │  ├──Airbnb: Administrative support: American_Indian_Alaskan_Native: 2
#      │  │  │
#      │  │  ├──Airbnb: Administrative support: American_Indian_Alaskan_Native:
#      │  │  │  male: 1
#      │  │  │
#      │  │  └──Airbnb: Administrative support: American_Indian_Alaskan_Native:
#      │  │     female: 1
#      │  │
#      │  └──Airbnb: Administrative support: Two_or_more_races: 16
#      │     │
#      │     ├──Airbnb: Administrative support: Two_or_more_races: male: 7
#      │     │
#      │     └──Airbnb: Administrative support: Two_or_more_races: female: 9
#      │
#      ├──Airbnb: Craft workers: 0
#      │  │
#      │  ├──Airbnb: Craft workers: Hispanic_or_Latino: 0
#      │  │  │
#      │  │  ├──Airbnb: Craft workers: Hispanic_or_Latino: male: 0
#      │  │  │
#      │  │  └──Airbnb: Craft workers: Hispanic_or_Latino: female: 0
#      │  │
#      │  ├──Airbnb: Craft workers: White: 0
#      │  │  │
#      │  │  ├──Airbnb: Craft workers: White: male: 0
#      │  │  │
#      │  │  └──Airbnb: Craft workers: White: female: 0
#      │  │
#      │  ├──Airbnb: Craft workers: Black_or_African_American: 0
#      │  │  │
#      │  │  ├──Airbnb: Craft workers: Black_or_African_American: male: 0
#      │  │  │
#      │  │  └──Airbnb: Craft workers: Black_or_African_American: female: 0
#      │  │
#      │  ├──Airbnb: Craft workers: Native_Hawaiian_or_Pacific_Islander: 0
#      │  │  │
#      │  │  ├──Airbnb: Craft workers: Native_Hawaiian_or_Pacific_Islander: male:
#      │  │  │  0
#      │  │  │
#      │  │  └──Airbnb: Craft workers: Native_Hawaiian_or_Pacific_Islander:
#      │  │     female: 0
#      │  │
#      │  ├──Airbnb: Craft workers: Asian: 0
#      │  │  │
#      │  │  ├──Airbnb: Craft workers: Asian: male: 0
#      │  │  │
#      │  │  └──Airbnb: Craft workers: Asian: female: 0
#      │  │
#      │  ├──Airbnb: Craft workers: American_Indian_Alaskan_Native: 0
#      │  │  │
#      │  │  ├──Airbnb: Craft workers: American_Indian_Alaskan_Native: male: 0
#      │  │  │
#      │  │  └──Airbnb: Craft workers: American_Indian_Alaskan_Native: female: 0
#      │  │
#      │  └──Airbnb: Craft workers: Two_or_more_races: 0
#      │     │
#      │     ├──Airbnb: Craft workers: Two_or_more_races: male: 0
#      │     │
#      │     └──Airbnb: Craft workers: Two_or_more_races: female: 0
#      │
#      ├──Airbnb: operatives: 0
#      │  │
#      │  ├──Airbnb: operatives: Hispanic_or_Latino: 0
#      │  │  │
#      │  │  ├──Airbnb: operatives: Hispanic_or_Latino: male: 0
#      │  │  │
#      │  │  └──Airbnb: operatives: Hispanic_or_Latino: female: 0
#      │  │
#      │  ├──Airbnb: operatives: White: 0
#      │  │  │
#      │  │  ├──Airbnb: operatives: White: male: 0
#      │  │  │
#      │  │  └──Airbnb: operatives: White: female: 0
#      │  │
#      │  ├──Airbnb: operatives: Black_or_African_American: 0
#      │  │  │
#      │  │  ├──Airbnb: operatives: Black_or_African_American: male: 0
#      │  │  │
#      │  │  └──Airbnb: operatives: Black_or_African_American: female: 0
#      │  │
#      │  ├──Airbnb: operatives: Native_Hawaiian_or_Pacific_Islander: 0
#      │  │  │
#      │  │  ├──Airbnb: operatives: Native_Hawaiian_or_Pacific_Islander: male: 0
#      │  │  │
#      │  │  └──Airbnb: operatives: Native_Hawaiian_or_Pacific_Islander: female: 0
#      │  │
#      │  ├──Airbnb: operatives: Asian: 0
#      │  │  │
#      │  │  ├──Airbnb: operatives: Asian: male: 0
#      │  │  │
#      │  │  └──Airbnb: operatives: Asian: female: 0
#      │  │
#      │  ├──Airbnb: operatives: American_Indian_Alaskan_Native: 0
#      │  │  │
#      │  │  ├──Airbnb: operatives: American_Indian_Alaskan_Native: male: 0
#      │  │  │
#      │  │  └──Airbnb: operatives: American_Indian_Alaskan_Native: female: 0
#      │  │
#      │  └──Airbnb: operatives: Two_or_more_races: 0
#      │     │
#      │     ├──Airbnb: operatives: Two_or_more_races: male: 0
#      │     │
#      │     └──Airbnb: operatives: Two_or_more_races: female: 0
#      │
#      ├──Airbnb: laborers and helpers: 0
#      │  │
#      │  ├──Airbnb: laborers and helpers: Hispanic_or_Latino: 0
#      │  │  │
#      │  │  ├──Airbnb: laborers and helpers: Hispanic_or_Latino: male: 0
#      │  │  │
#      │  │  └──Airbnb: laborers and helpers: Hispanic_or_Latino: female: 0
#      │  │
#      │  ├──Airbnb: laborers and helpers: White: 0
#      │  │  │
#      │  │  ├──Airbnb: laborers and helpers: White: male: 0
#      │  │  │
#      │  │  └──Airbnb: laborers and helpers: White: female: 0
#      │  │
#      │  ├──Airbnb: laborers and helpers: Black_or_African_American: 0
#      │  │  │
#      │  │  ├──Airbnb: laborers and helpers: Black_or_African_American: male: 0
#      │  │  │
#      │  │  └──Airbnb: laborers and helpers: Black_or_African_American: female: 0
#      │  │
#      │  ├──Airbnb: laborers and helpers: Native_Hawaiian_or_Pacific_Islander: 0
#      │  │  │
#      │  │  ├──Airbnb: laborers and helpers: Native_Hawaiian_or_Pacific_Islander:
#      │  │  │  male: 0
#      │  │  │
#      │  │  └──Airbnb: laborers and helpers: Native_Hawaiian_or_Pacific_Islander:
#      │  │     female: 0
#      │  │
#      │  ├──Airbnb: laborers and helpers: Asian: 0
#      │  │  │
#      │  │  ├──Airbnb: laborers and helpers: Asian: male: 0
#      │  │  │
#      │  │  └──Airbnb: laborers and helpers: Asian: female: 0
#      │  │
#      │  ├──Airbnb: laborers and helpers: American_Indian_Alaskan_Native: 0
#      │  │  │
#      │  │  ├──Airbnb: laborers and helpers: American_Indian_Alaskan_Native:
#      │  │  │  male: 0
#      │  │  │
#      │  │  └──Airbnb: laborers and helpers: American_Indian_Alaskan_Native:
#      │  │     female: 0
#      │  │
#      │  └──Airbnb: laborers and helpers: Two_or_more_races: 0
#      │     │
#      │     ├──Airbnb: laborers and helpers: Two_or_more_races: male: 0
#      │     │
#      │     └──Airbnb: laborers and helpers: Two_or_more_races: female: 0
#      │
#      └──Airbnb: Service workers: 49
#         │
#         ├──Airbnb: Service workers: Hispanic_or_Latino: 5
#         │  │
#         │  ├──Airbnb: Service workers: Hispanic_or_Latino: male: 3
#         │  │
#         │  └──Airbnb: Service workers: Hispanic_or_Latino: female: 2
#         │
#         ├──Airbnb: Service workers: White: 26
#         │  │
#         │  ├──Airbnb: Service workers: White: male: 14
#         │  │
#         │  └──Airbnb: Service workers: White: female: 12
#         │
#         ├──Airbnb: Service workers: Black_or_African_American: 2
#         │  │
#         │  ├──Airbnb: Service workers: Black_or_African_American: male: 2
#         │  │
#         │  └──Airbnb: Service workers: Black_or_African_American: female: 0
#         │
#         ├──Airbnb: Service workers: Native_Hawaiian_or_Pacific_Islander: 2
#         │  │
#         │  ├──Airbnb: Service workers: Native_Hawaiian_or_Pacific_Islander:
#         │  │  male: 2
#         │  │
#         │  └──Airbnb: Service workers: Native_Hawaiian_or_Pacific_Islander:
#         │     female: 0
#         │
#         ├──Airbnb: Service workers: Asian: 9
#         │  │
#         │  ├──Airbnb: Service workers: Asian: male: 6
#         │  │
#         │  └──Airbnb: Service workers: Asian: female: 3
#         │
#         ├──Airbnb: Service workers: American_Indian_Alaskan_Native: 1
#         │  │
#         │  ├──Airbnb: Service workers: American_Indian_Alaskan_Native: male: 0
#         │  │
#         │  └──Airbnb: Service workers: American_Indian_Alaskan_Native: female: 1
#         │
#         └──Airbnb: Service workers: Two_or_more_races: 4
#            │
#            ├──Airbnb: Service workers: Two_or_more_races: male: 3
#            │
#            └──Airbnb: Service workers: Two_or_more_races: female: 1

# %% [markdown]
# ## Task 2  - prune tree

# %%
eeo_data = pd.read_csv(filename_data, keep_default_na=False)

# exclude job_category in 'Totals', 'Previous_totals'
eeo_data = eeo_data[~eeo_data['job_category'].isin(['Totals', 'Previous_totals'])]

# exclude race in 'Overall_totals'
eeo_data = eeo_data[~eeo_data['race'].isin(['Overall_totals'])]

# convert count to number
eeo_data['count']= pd.to_numeric(eeo_data['count'], errors='coerce').astype(np.int64)

eeo_data.head()
# Out:
#    company  year                race gender   job_category  count
# 0  23andMe  2016  Hispanic_or_Latino   male     Executives      0
# 1  23andMe  2016  Hispanic_or_Latino   male       Managers      1
# 2  23andMe  2016  Hispanic_or_Latino   male  Professionals      7
# 3  23andMe  2016  Hispanic_or_Latino   male    Technicians      0
# 4  23andMe  2016  Hispanic_or_Latino   male  Sales workers      0

# %%
eeo_data = pd.read_csv(filename_data, keep_default_na=False)

# exclude job_category in 'Totals', 'Previous_totals'
eeo_data = eeo_data[~eeo_data['job_category'].isin(['Totals', 'Previous_totals'])]

# exclude race in 'Overall_totals'
eeo_data = eeo_data[~eeo_data['race'].isin(['Overall_totals'])]

# convert count to number
eeo_data['count']= pd.to_numeric(eeo_data['count'], errors='coerce').astype(np.int64)

# %%
eeo_tree = tr.data_to_tree(eeo_data, ["company", "gender"])

eeo_tree.print()
# Out:
#   │
#   ├──23andMe
#   │  │
#   │  ├──male: 148
#   │  │
#   │  └──female: 149
#   │
#   ├──Adobe
#   │  │
#   │  ├──male: 4859
#   │  │
#   │  └──female: 2303
#   │
#   └──Airbnb
#      │
#      ├──male: 1095
#      │
#      └──female: 822

# %%
def __prune_tree(t, values_to_discard):
    children = []
    for ch in t.children:
        if ch.label not in values_to_discard:
            children.append(__prune_tree(ch, values_to_discard))
            
    t.children = children if len(children) else None

    return t    
    
def prune_tree(t, values_to_discard):
    '''
    Returns a tree with any node whose label is in the list values_to_discard
    (and thus all of its children) pruned. This function should return a copy
    of the original tree and should not destructively modify the original tree.
    The pruning step must be recursive.

    Inputs:
        t (Tree): a tree
        values_to_discard (list of strings): A list of strings specifying the
                  labels of nodes to discard

    Returns: a new Tree object representing the pruned tree
    '''
    import copy
    
    pruned_tr = copy.deepcopy(t)
        
    children = []
    for ch in pruned_tr.children:
        if ch.label not in values_to_discard:
            children.append(__prune_tree(ch, values_to_discard))
    pruned_tr.children = children if len(children) else None

    ### Replace t with the appropriate return value
    return pruned_tr

# %%
prune_tree(eeo_tree,['Adobe','female']).print()
# Out:
#   │
#   ├──23andMe
#   │  │
#   │  └──male: 148
#   │
#   └──Airbnb
#      │
#      └──male: 1095
