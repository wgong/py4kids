# %% [markdown]
# When running `$ python pandas_vs_polars.py` at terminal, one may get errors like
# ```
# 'charmap' codec can't encode characters in position 84-116: character maps to <undefined>
# ```
#
# However, running `main()` in a notebook, no error.

# %%
from pandas_vs_polars import *

# %%
main()
# Out:
# ## use_case_001a: read gzipped csv and df.shape
# [ pandas ]
# (701732, 11)
# [ polars ]
# (701732, 11)
#
# ## use_case_001p: read_parquet and df.shape
# [ pandas ]
# (701732, 11)
# [ polars ]
# (701732, 11)
#
# ## use_case_002: write out parquet
# [ pandas ]
# [ERROR] write_out_parquet(pandas)
#  [WinError 5] Failed to open local file '../data/uber-ride/pandas'. Detail: [Windows error 5] Access is denied.
#
# [ polars ]
#
# ## use_case_002_a: read parquet, concat by n_factor, write parquet
# [ pandas ]
# [ERROR] write_out_parquet(pandas)
#  [WinError 5] Failed to open local file '../data/uber-ride/pandas'. Detail: [Windows error 5] Access is denied.
#
# [ polars ]
#
# ## use_case_003: read_csv and df['id'].str.len()
# [ pandas ]
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# ...
