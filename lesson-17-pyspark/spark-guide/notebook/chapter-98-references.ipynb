# %% [markdown]
# ## Reading materials
#
# ### Books
#
# * [Spark: The Definitive Guide](http://shop.oreilly.com/product/0636920034957.do)
#
# * [Intro to Statistical Learning](http://faculty.marshall.usc.edu/gareth-james/isl/)
#
# * [Elements of
# Statistical Learning](https://web.stanford.edu/~hastie/ElemStatLearn/)
#
# * [Deep Learning by Ian Goodfellow](http://www.deeplearningbook.org/)
#
# ### Blogs
#
# * [Netflix uses Spark](http://bit.ly/2Fkx4Mm)
#
# * [Capital One uses Spark to detect Fraud](https://youtu.be/q5HFMVoN_rc)
#
# ### References
#
# * [Awesome Spark](https://github.com/awesome-spark/awesome-spark)
# * [MingChen0919/learning-apache-spark](https://github.com/MingChen0919/learning-apache-spark)
# * [Programming Guide-Spark SQL, DataFrames, Datasets](http://spark.apache.org/docs/latest/sql-programming-guide.html)
# * [PySpark 2.4.4 documentations](http://spark.apache.org/docs/latest/api/python/index.html)
# * [pySpark Cheatsheet](https://github.com/wgong/pyspark-cheatsheet)
# * [7 Steps to Spark](https://docs.google.com/spreadsheets/d/1AuvsTCTxzx1wBMkG-rvfwNpuoQoG9ISuXqQZwj-GGgQ/edit#gid=257341626)
#
#
#
# ## Instruction materials
#
# ### PDFs
#
# * [Intro to Apache Spark by Paco Nathan](https://stanford.edu/~rezab/sparkclass/slides/itas_workshop.pdf)
#
# ### Videos
#
# * [Spark Summit YouTube Channel](https://www.youtube.com/channel/UCRzsq7k4-kT-h3TDUBQ82-w)
# * [Using Apache Spark 2.0 to Analyze the City of San Francisco's Open Data](https://youtu.be/K14plpZgy_c)
#
#
# ## Hand-on labs
#
# ### Sandbox
#
# * https://community.cloud.databricks.com/
#
# ### Tutorials
#
# * [Spark-Summit-June-2016](https://github.com/erdcpatel/Spark-Summit-June-2016)
# * https://www.digitalocean.com/community/tutorials/how-to-install-anaconda-on-ubuntu-18-04-quickstart
# * http://spark.apache.org/docs/latest/quick-start.html
# * https://www.datacamp.com/community/tutorials/apache-spark-python#gs.fMIIqxM
# * [Databricks Reference Apps](https://github.com/databricks/reference-apps)
# * [PySpark Notebook](https://github.com/jadianes/spark-py-notebooks.git)
# * [PySpark Tutorial](https://github.com/jleetutorial/python-spark-tutorial.git)
#
# ## Packages
#
# * TensorFrames - https://spark-packages.org/package/databricks/tensorframes
# * Spark Deep Learning - https://spark-packages.org/package/databricks/spark-deep-learning
#
# ## Certification
#
# * [Study Notes](https://github.com/wgong/Databricks-Apache-Spark-2X-Certified-Developer)
#
# ## Spark Apps
#
# * [PySpark Examples](https://github.com/abulbasar/pyspark-examples)
# * [ETL with PySpark](https://github.com/AlexIoannides/pyspark-example-project)
# * [Pyspark project](https://becominghuman.ai/real-world-python-workloads-on-spark-standalone-clusters-2246346c7040)
