# %% [markdown]
# ## No good
# - https://github.com/Nasdaq/data-link-python/#local-api-key-environment-variable
# - https://docs.data.nasdaq.com/
#
# ## Working
# - https://towardsdatascience.com/free-stock-data-for-python-using-yahoo-finance-api-9dafd96cad2e

# %%
import nasdaqdatalink

# %%
data = nasdaqdatalink.get_table('WIKI/PRICES', qopts = { 'columns': ['ticker', 'date', 'open', 'high', 'low', 'close', 'volume'] }, ticker = ['AAPL', 'MSFT'], date = { 'gte': '2022-03-15', 'lte': '2022-04-10' })

# %%
data
# Out:
# Empty DataFrame
# Columns: [ticker, date, open, high, low, close, volume]
# Index: []

# %%
data = nasdaqdatalink.get_table('WIKI/PRICES',ticker='AAPL')

# %%
data
# Out:
#      ticker       date    open    high     low    close      volume  \
# None
# 0      AAPL 2018-03-27  173.68  175.15  166.92  168.340  38962839.0
# 1      AAPL 2018-03-26  168.07  173.10  166.44  172.770  36272617.0
# 2      AAPL 2018-03-23  168.39  169.92  164.94  164.940  40248954.0
# 3      AAPL 2018-03-22  170.00  172.68  168.60  168.845  41051076.0
# 4      AAPL 2018-03-21  175.04  175.09  171.26  171.270  35247358.0
# ...     ...        ...     ...     ...     ...      ...         ...
# 9395   AAPL 1980-12-18   26.63   26.75   26.63   26.630    327900.0
# 9396   AAPL 1980-12-17   25.87   26.00   25.87   25.870    385900.0
# 9397   AAPL 1980-12-16   25.37   25.37   25.25   25.250    472000.0
# 9398   AAPL 1980-12-15   27.38   27.38   27.25   27.250    785200.0
# 9399   AAPL 1980-12-12   28.75   28.87   28.75   28.750   2093900.0
#
#       ex-dividend  split_ratio    adj_open    adj_high     adj_low  \
# None
# 0             0.0          1.0  173.680000  175.150000  166.920000
# ...

# %%
data.columns
# Out:
# Index(['ticker', 'date', 'open', 'high', 'low', 'close', 'volume',
#        'ex-dividend', 'split_ratio', 'adj_open', 'adj_high', 'adj_low',
#        'adj_close', 'adj_volume'],
#       dtype='object')

# %%
data[['ticker', 'date', 'open', 'high', 'low', 'close', 'volume']].to_csv("AAPL.csv", index=False)

# %%
# !dir AAPL.csv
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8A04-0EBD
#
#  Directory of C:\Users\w_gon\projects\py4kids\lesson-21-fin
#
# 04/04/2022  10:31 PM           482,454 AAPL.csv
#                1 File(s)        482,454 bytes
#                0 Dir(s)  397,096,833,024 bytes free

# %%
import yfinance as yf
quotes = yf.download("SPY AAPL ORCL", start="2022-03-15", end="2022-04-15")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
quotes
# Out:
#              Adj Close                              Close             \
#                   AAPL       ORCL         SPY        AAPL       ORCL
# Date
# 2022-03-15  155.089996  80.599998  424.850159  155.089996  80.599998
# 2022-03-16  159.589996  79.959999  434.270874  159.589996  79.959999
# 2022-03-17  160.619995  80.599998  439.704010  160.619995  80.599998
# 2022-03-18  163.979996  81.680000  444.519989  163.979996  81.680000
# 2022-03-21  165.380005  80.959999  444.390015  165.380005  80.959999
# 2022-03-22  168.820007  81.800003  449.589996  168.820007  81.800003
# 2022-03-23  170.210007  80.389999  443.799988  170.210007  80.389999
# 2022-03-24  174.070007  82.239998  450.489990  174.070007  82.239998
# 2022-03-25  174.720001  81.730003  452.690002  174.720001  81.730003
# 2022-03-28  175.600006  83.599998  455.910004  175.600006  83.599998
# 2022-03-29  178.960007  84.290001  461.549988  178.960007  84.290001
# ...
