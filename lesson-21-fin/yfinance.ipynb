# %% [markdown]
# - [yfinance](https://pypi.org/project/yfinance/)
#
# - [a tutorial](https://towardsdatascience.com/algorithmic-trading-with-macd-and-python-fef3d013e9f3)

# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")

# %%
# get stock info
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 163000,
# ...

# %%
# get historical market data
hist = msft.history(period="max")

# %%
type(hist)
# Out:
# pandas.core.frame.DataFrame

# %%
hist.size
# Out:
# 60914

# %%
hist
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.06    0.06    0.06  1031788800        0.0
# 1986-03-14    0.06    0.07    0.06    0.06   308160000        0.0
# 1986-03-17    0.06    0.07    0.06    0.07   133171200        0.0
# 1986-03-18    0.07    0.07    0.06    0.06    67766400        0.0
# 1986-03-19    0.06    0.06    0.06    0.06    47894400        0.0
# ...            ...     ...     ...     ...         ...        ...
# 2020-09-14  204.24  209.20  204.03  205.41    30375800        0.0
# 2020-09-15  208.42  209.78  206.93  208.78    21823900        0.0
# 2020-09-16  210.62  210.65  204.64  205.05    26328100        0.0
# 2020-09-17  200.05  204.33  199.96  202.91    34011300        0.0
# 2020-09-18  202.80  203.65  196.25  200.39    55199500        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0
# ...

# %%
# show actions (dividends, splits)
msft.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-09-21       0.00           2.0
# 1990-04-16       0.00           2.0
# 1991-06-27       0.00           1.5
# 1992-06-15       0.00           1.5
# 1994-05-23       0.00           2.0
# ...               ...           ...
# 2019-08-14       0.46           0.0
# 2019-11-20       0.51           0.0
# 2020-02-19       0.51           0.0
# 2020-05-20       0.51           0.0
# 2020-08-19       0.51           0.0
#
# [76 rows x 2 columns]

# %%
# show dividends
msft.dividends

# %%
# show splits
msft.splits

# %%
# show financials
msft.financials
msft.quarterly_financials

# show major holders
stock.major_holders

# show institutional holders
stock.institutional_holders

# show balance heet
msft.balance_sheet
msft.quarterly_balance_sheet

# show cashflow
msft.cashflow
msft.quarterly_cashflow

# show earnings
msft.earnings
msft.quarterly_earnings

# show sustainability
msft.sustainability

# show analysts recommendations
msft.recommendations

# show next event (earnings, etc)
msft.calendar

# %%
# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# %%
# show options expirations
msft.options

# get option chain for specific expiration
opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts

# %% [markdown]
# ### Multiple tickers

# %%
import yfinance as yf

tickers = yf.Tickers('msft aapl goog')
# ^ returns a named tuple of Ticker objects

# %%
# access each ticker using (example)
tickers.msft.info
tickers.aapl.history(period="1mo")
tickers.goog.actions
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f86ee6c7cdda> in <module>
#       1 # access each ticker using (example)
# ----> 2 tickers.msft.info
#       3 tickers.aapl.history(period="1mo")
#       4 tickers.goog.actions
#
# AttributeError: 'Tickers' object has no attribute 'msft'

# %%
tickers.symbols
# Out:
# ['MSFT', 'AAPL', 'GOOG']

# %%
type(tickers)
# Out:
# yfinance.tickers.Tickers

# %%
tickers["AAPL"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-dbf885bc7975> in <module>
# ----> 1 tickers["AAPL"]
#
# TypeError: 'Tickers' object is not subscriptable

# %%
tickers.history(period='1mo')
# Out:
# [*********************100%***********************]  3 of 3 completed
#                  Close                          Dividends             \
#                   AAPL         GOOG        MSFT      AAPL GOOG  MSFT
# Date
# 2020-08-19  115.707497  1547.530029  209.699997         0    0  0.51
# 2020-08-20  118.275002  1581.750000  214.580002         0    0  0.00
# 2020-08-21  124.370003  1580.420044  213.020004         0    0  0.00
# 2020-08-24  125.857498  1588.199951  213.690002         0    0  0.00
# 2020-08-25  124.824997  1608.219971  216.470001         0    0  0.00
# 2020-08-26  126.522499  1652.380005  221.149994         0    0  0.00
# 2020-08-27  125.010002  1634.329956  226.580002         0    0  0.00
# 2020-08-28  124.807503  1644.410034  228.910004         0    0  0.00
# 2020-08-31  129.039993  1634.180054  225.529999         0    0  0.00
# 2020-09-01  134.179993  1660.709961  227.270004         0    0  0.00
# ...

# %%
data0 = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
type(data0)
# Out:
# pandas.core.frame.DataFrame

# %%
data0.head()
# Out:
#             Adj Close                  Close                   High  \
#                  AAPL         SPY       AAPL         SPY       AAPL
# Date
# 2017-01-03  27.548414  209.785889  29.037500  225.240005  29.082500
# 2017-01-04  27.517582  211.033981  29.004999  226.580002  29.127501
# 2017-01-05  27.657520  210.866318  29.152500  226.399994  29.215000
# 2017-01-06  27.965857  211.620728  29.477501  227.210007  29.540001
# 2017-01-09  28.222006  210.922211  29.747499  226.460007  29.857500
#
#                               Low                   Open              \
#                    SPY       AAPL         SPY       AAPL         SPY
# Date
# 2017-01-03  225.830002  28.690001  223.880005  28.950001  225.039993
# 2017-01-04  226.750000  28.937500  225.610001  28.962500  225.619995
# 2017-01-05  226.580002  28.952499  225.479996  28.980000  226.270004
# 2017-01-06  227.750000  29.117500  225.899994  29.195000  226.529999
# ...

# %%
dd = data0.to_dict()

# %%
type(dd)
# Out:
# dict

# %%
dd.keys()
# Out:
# dict_keys([('Adj Close', 'AAPL'), ('Adj Close', 'SPY'), ('Close', 'AAPL'), ('Close', 'SPY'), ('High', 'AAPL'), ('High', 'SPY'), ('Low', 'AAPL'), ('Low', 'SPY'), ('Open', 'AAPL'), ('Open', 'SPY'), ('Volume', 'AAPL'), ('Volume', 'SPY')])

# %%
type(dd[('Adj Close', 'AAPL')])
# Out:
# dict

# %%
import pandas as pd
from pandas import Timestamp

# %%
dd[('Adj Close','AAPL')][Timestamp('2017-01-03 00:00:00')]
# Out:
# 27.54841423034668

# %%
dd[('Close','AAPL')][Timestamp('2017-01-03 00:00:00')]
# Out:
# 29.037500381469727

# %%
from pandas_datareader import data as pdr

# %%
import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# %%
# download dataframe
data = pdr.get_data_yahoo("QQQ", start="2019-01-01", end="2019-04-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-02  150.990005  155.750000  150.880005  154.880005  153.021332
# 2019-01-03  152.600006  153.259995  149.490005  149.820007  148.022064
# 2019-01-04  152.339996  157.000000  151.740005  156.229996  154.355118
# 2019-01-07  156.619995  158.860001  156.110001  158.089996  156.192795
# 2019-01-08  159.539993  160.110001  157.199997  159.520004  157.605637
# ...                ...         ...         ...         ...         ...
# 2019-04-23  188.399994  190.539993  188.130005  190.309998  188.368332
# 2019-04-24  190.470001  190.710007  189.649994  189.710007  187.774460
# 2019-04-25  191.130005  191.220001  189.449997  190.479996  188.536591
# 2019-04-26  190.179993  190.690002  188.589996  190.649994  188.704849
# 2019-04-29  190.649994  191.320007  190.339996  191.020004  189.071091
#
#               Volume
# Date
# 2019-01-02  58576700
# 2019-01-03  74820200
# 2019-01-04  74709300
# ...

# %%
data2 = pdr.get_data_yahoo("CYDY", start="2019-01-01", end="2020-10-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data2
# Out:
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2019-01-02  0.48  0.48  0.46   0.48       0.48   120500
# 2019-01-03  0.49  0.54  0.49   0.53       0.53   192100
# 2019-01-04  0.55  0.56  0.52   0.54       0.54   141100
# 2019-01-07  0.56  0.58  0.54   0.57       0.57   311200
# 2019-01-08  0.59  0.59  0.57   0.57       0.57   332800
# ...          ...   ...   ...    ...        ...      ...
# 2020-09-14  3.95  4.22  3.68   4.12       4.12  3061200
# 2020-09-15  4.12  4.12  3.91   4.09       4.09  2530800
# 2020-09-16  4.15  4.27  4.00   4.03       4.03  2303800
# 2020-09-17  3.23  3.47  3.06   3.42       3.42  8768900
# 2020-09-18  3.51  3.56  3.37   3.55       3.55  2376200
#
# [433 rows x 6 columns]

# %% [markdown]
# ## [Algorithmic Trading with MACD and Python](https://towardsdatascience.com/algorithmic-trading-with-macd-and-python-fef3d013e9f3)
#
# ` $ pip install ta`
#
# https://github.com/bukosabino/ta

# %%
import yfinance
import talib
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-51-2cbf970e4f15> in <module>
#       1 import yfinance
# ----> 2 import talib
#       3 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'talib'
