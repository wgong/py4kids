# %%
"""
pip install opencv-python  # required for cv2
"""

import cv2
import numpy as np
from pathlib import Path
from glob import glob

# %%
def collate_images(background_path, image_paths, output_dir=Path("output"), scale_factor=0.8, prefix="", suffix="bgd"):
    """
    Collates images with a background, preserving aspect ratio and using a fixed scale factor.

    Args:
        background_path: Path to the background image.
        image_paths: List of paths to images to be collated.
        output_dir: Output directory Path for the collated images.
        scale_factor: The scaling factor for the images (0.0 - 1.0).
        suffix: added to the new output filename
    """
    # Ensure output directory exists
    output_dir.mkdir(parents=True, exist_ok=True)
    
    try:
        background = cv2.imread(str(background_path))
    except cv2.error as e:
        print(f"Error reading background image: {e}")
        return False

    bg_height, bg_width, _ = background.shape

    ok_images = 0
    for image_path in image_paths:
        print(f"Collating {image_path} ...")
        try:
            image = cv2.imread(str(image_path))
        except cv2.error as e:
            print(f"Error reading image: {image_path}, {e}")
            continue  # Skip to the next image            

        if image is None: 
            continue
            
        img_height, img_width, _ = image.shape

        
        try:
            # Determine the larger dimension and calculate new size based on scale factor
            if img_width > img_height:
                new_width = int(bg_width * scale_factor)
                new_height = int(img_height * (new_width / img_width))
            else:
                new_height = int(bg_height * scale_factor)
                new_width = int(img_width * (new_height / img_height))

            # Resize image
            resized_image = cv2.resize(image, (new_width, new_height))

            # Create a mask for the image
            mask = np.zeros_like(resized_image)
            mask[0:new_height, 0:new_width] = 255

            # Calculate position for placing the image on the background
            x = (bg_width - new_width) // 2
            y = (bg_height - new_height) // 2

            # Create a copy of the background image
            result = background.copy()

            # Put the resized image on the background
            result[y:y+new_height, x:x+new_width] = resized_image

            # Save the resulting image
            if prefix:
                new_filename = f"{prefix}__" + Path(image_path).stem + f"-{suffix}" + Path(image_path).suffix
            else:
                new_filename = Path(image_path).stem + f"-{suffix}" + Path(image_path).suffix
            output_path = output_dir / Path(new_filename)
            print(f"\tOutput file: {output_path}")
            cv2.imwrite(str(output_path), result)
            ok_images += 1
        except Exception as e:
            print(f"\t[ERROR] Failed processing '{image_path}'\n {e}")
            continue  # Skip to the next image    
            
    return len(image_paths), ok_images

# %%
background_path = "00-background-stary-universe.png"

# %%
ROOT_DIR = "2-A-Compassionate-Man"
ITER_DIR = "iter-2"

# %%
subfolders = [ 
    '0-td_lee', '1-family', '1-friend', 
    '2-teacher', '3-collab', '4-leader', '5-institutions', '6-cuspea', '7-artwork','8-milestone'
]

# %%
excluded_images = [
    'archive',
]
excluded_images = [f"{ROOT_DIR}\\{x}" for x in excluded_images]

# %%
for sub_folder in subfolders:
    print(f"\n\nProcessing sub-folder: {sub_folder} ========> ")
    source_images = glob(f"{ROOT_DIR}/{sub_folder}/original/*")
    image_paths = [x for x in source_images if "-bgd" not in x]
    total_images, ok_images = collate_images(Path(background_path), image_paths, output_dir=Path(f"{ROOT_DIR}/{ITER_DIR}"), prefix=sub_folder)
    num_input_images = len(source_images)
    if num_input_images != ok_images:
        print(f"[ERROR] input_images, total_images, ok_images = {num_input_images}, {total_images}, {ok_images}")
    else:
        print(f"Successfully processed {num_input_images} images")
# Out:
# Processing sub-folder: 0-td_lee ========>
# Collating 2-A-Compassionate-Man/0-td_lee/original\01-td-lee.jpeg ...
# 	Output file: 2-A-Compassionate-Man\iter-2
milestone.png ...
# 	Output file: 2-A-Compassionate-Man\iter-2\8-milestone__06-milestone-bgd.png
# Collating 2-A-Compassionate-Man/8-milestone/original\07-milestone.png ...
# 	Output file: 2-A-Compassionate-Man\iter-2\8-milestone__07-milestone-bgd.png
# Collating 2-A-Compassionate-Man/8-milestone/original\08-milestone.png ...
# 	Output file: 2-A-Compassionate-Man\iter-2\8-milestone__08-milestone-bgd.png
# Collating 2-A-Compassionate-Man/8-milestone/original\09-milestone.png ...
# 	Output file: 2-A-Compassionate-Man\iter-2\8-milestone__09-milestone-bgd.png
# Collating 2-A-Compassionate-Man/8-milestone/original\10-milestone.png ...
# 	Output file: 2-A-Compassionate-Man\iter-2\8-milestone__10-milestone-bgd.png
# Collating 2-A-Compassionate-Man/8-milestone/original\11-milestone.png ...
# 	Output file: 2-A-Compassionate-Man\iter-2\8-milestone__11-milestone-bgd.png
# Successfully processed 11 images

# %% [markdown]
# ### Fix failed image manually
# ```
# [ERROR] Failed processing '2-A-Compassionate-Man/1-family/original\01-3-family-photo.jpeg'
#
# [ERROR] Failed processing '2-A-Compassionate-Man/4-leader/original\td-lee-qian-san-qiang.png'
# ```

# %% [markdown]
# ### Compare iter-2 vs iter-1

# %%
iter1_images = glob(f"{ROOT_DIR}/iter-1/*")
iter2_images = glob(f"{ROOT_DIR}/iter-2/*")
len(iter1_images), len(iter2_images)
# Out:
# (69, 94)

# %%
set([x.replace("/iter-1", "") for x in iter1_images]).difference(set([x.replace("/iter-2", "") for x in iter2_images]))
# Out:
# {'2-A-Compassionate-Man\\99-stary-universe-bgd.png'}

# %%
set([x.replace("/iter-2", "") for x in iter2_images]).difference(set([x.replace("/iter-1", "") for x in iter1_images]))
# Out:
# {'2-A-Compassionate-Man\\0-td_lee__99-td-lee-color-final-bgd.jpeg',
#  '2-A-Compassionate-Man\\000-cover.png',
#  '2-A-Compassionate-Man\\3-collab__01-td-lee-cn-yang-ias-bgd.png',
#  '2-A-Compassionate-Man\\5-institutions__06-BEPC-beijing-electron-positron-collider-bgd.png',
#  '2-A-Compassionate-Man\\5-institutions__07-td-lee-80th-birthday-bgd.png',
#  '2-A-Compassionate-Man\\5-institutions__09-td-lee-beijing-forum-2006-bgd.png',
#  '2-A-Compassionate-Man\\6-cuspea__04-01-td-lee-lecture-bgd.png',
#  '2-A-Compassionate-Man\\7-artwork__00-question-answer-bgd.png',
#  '2-A-Compassionate-Man\\7-artwork__01-math-physics-bgd.png',
#  '2-A-Compassionate-Man\\7-artwork__02-bamboo-bgd.png',
#  '2-A-Compassionate-Man\\7-artwork__03-integrity-bgd.png',
#  '2-A-Compassionate-Man\\7-artwork__05-flower-bamboo-bgd.png',
#  '2-A-Compassionate-Man\\7-artwork__06-flower-bgd.png',
#  '2-A-Compassionate-Man\\7-artwork__07-flowers-bgd.png',
#  '2-A-Compassionate-Man\\7-artwork__09-china-tree-bgd.png',
#  '2-A-Compassionate-Man\\8-milestone__01-milestone-bgd.png',
#  '2-A-Compassionate-Man\\8-milestone__02-milestone-bgd.png',
#  '2-A-Compassionate-Man\\8-milestone__03-milestone-bgd.png',
#  '2-A-Compassionate-Man\\8-milestone__04-milestone-bgd.png',
#  '2-A-Compassionate-Man\\8-milestone__05-milestone-bgd.png',
#  '2-A-Compassionate-Man\\8-milestone__06-milestone-bgd.png',
#  '2-A-Compassionate-Man\\8-milestone__07-milestone-bgd.png',
#  '2-A-Compassionate-Man\\8-milestone__08-milestone-bgd.png',
#  '2-A-Compassionate-Man\\8-milestone__09-milestone-bgd.png',
#  '2-A-Compassionate-Man\\8-milestone__10-milestone-bgd.png',
#  '2-A-Compassionate-Man\\8-milestone__11-milestone-bgd.png'}
