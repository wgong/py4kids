# %% [markdown]
# ### How to scrape google search result
#
# https://hackernoon.com/how-to-scrape-google-with-python-bo7d2tal
#
# https://serpwow.com/
#
# https://pythondata.com/quick-tip-consuming-google-search-results-to-use-for-web-scraping/

# %%
import urllib
import requests
from bs4 import BeautifulSoup

# %%
from concurrent.futures import ThreadPoolExecutor

# %%
CONFIG = {
    "USER_AGENT": {
        "desktop": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:65.0) Gecko/20100101 Firefox/65.0",
        "mobile": "Mozilla/5.0 (Linux; Android 7.0; SM-G930V Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.125 Mobile Safari/537.36"
    },
    "SEARCH_BASE_URL": {
        "bing": "https://www.bing.com/search",
        "google": "https://google.com/search"
    }
}

HEADERS = {"user-agent" : CONFIG["USER_AGENT"]["desktop"]}

# %%
def get_search_url(query:str, start:int = 0, engine:str = "google") -> str:
    """Get search url
    
    args:
        query (str): search text
        start (int): starting result index
        engine (str): "bing" or "google"
    """
    engine = engine.lower()
    query = urllib.parse.quote(query)

    if engine == "bing":
        url = CONFIG["SEARCH_BASE_URL"][engine] + \
                "?q="+ urllib.parse.quote(query) + \
                ("" if start==0 else f"&first={start}")
    elif engine == "google":
        url = CONFIG["SEARCH_BASE_URL"][engine] + \
                "?q="+ urllib.parse.quote(query) + \
                ("" if start==0 else f"&start={start}")
    else:
        raise ValueError(f"Unimplemented search engine {engine}")
    
    return url

# get_search_url("tensorflow", start=10, engine="google")   # 'https://google.com/search?q=tensorflow&start=10'
# get_search_url("tensor flow", start=10, engine="bing")   # 'https://www.bing.com/search?q=tensor%20flow&first=10'

# %%
def get_search_result(url_header):
    global link_title_map
    url, headers = url_header
    resp = requests.get(url, headers=headers)

    res_dic = {}  # key=link, val=title
    if resp.status_code == 200:
        soup = BeautifulSoup(resp.content, "html.parser")

        if "google.com/search" in url:     # pickup link,title from Google page
            for g in soup.find_all('div', class_='r'):
                anchors = g.find_all('a')
                if len(anchors):                
                    link = anchors[0]['href']
                    if "http" in link:
                        link_title_map[link] = g.find('h3').text

            for g in soup.find_all('h3', class_='r'):
                anchors = g.find_all('a')
                if len(anchors):                
                    link = anchors[0]['href']
                    if "http" in link:
                        link_title_map[link] = g.text
                        
        elif "bing.com/search" in url:   # pickup link,title from Bing page                       
            for tag in ["h2", "h3"]:
                for g in soup.find_all(tag):
                    anchors = g.find_all('a')
                    if len(anchors):
                        link = anchors[0]['href']
                        if "http" in link:
                            link_title_map[link] = g.text
        
    return

# %%
search_text = "tensorflow"
MAX_RESULTS = 50

search_urls = []
for start in range(0,MAX_RESULTS,10):
    for engine in ["google", "bing"]:
        URL = get_search_url(search_text, start=start, engine=engine)
        search_urls.append(URL)

# print(search_urls)

url_headers = [(url, HEADERS) for url in search_urls]

# %%
# %%time

link_title_map = {}
for x in url_headers:
    get_search_result(x)

len(link_title_map), link_title_map
# Out:
# CPU times: user 9.23 s, sys: 47.9 ms, total: 9.28 s
# Wall time: 17.8 s
# (93,
#  {'https://www.tensorflow.org/': 'TensorFlow',
#   'https://github.com/tensorflow/tensorflow': 'GitHub - tensorflow/tensorflow: An Open Source Machine ...',
#   'https://github.com/tensorflow': 'tensorflow Â· GitHub',
#   'https://en.wikipedia.org/wiki/TensorFlow': 'TensorFlow - Wikipedia',
#   'https://www.youtube.com/channel/UC0rqucBdTuFTjJiefW5t-IQ': 'TensorFlow - YouTube',
#   'https://www.tensorflow.org/tutorials': 'Tutorials',
#   'https://www.tensorflow.org/overview': 'TensorFlow Core',
#   'https://www.tensorflow.org/install': 'Install',
#   'https://www.tensorflow.org/guide': 'Guide',
#   'https://www.tensorflow.org/learn': 'Learn',
#   'https://www.tensorflow.org/tutorials/keras/classification': 'Basic classification: Classify ...',
#   'https://pypi.org/project/tensorflow/': 'tensorflow · PyPI',
#   'https://www.tensorflow.org/about': 'About',
#   'https://www.tensorflow.org/versions': 'API',
#   'https://www.tensorflow.org/tfx': 'TFX',
#   'https://www.tensorflow.org/resources/learn-ml': 'Learn Ml',
#   'https://www.tensorflow.org/guide/effective_tf2': 'Effective Tensorflow 2',
#   'https://www.tensorflow.org/about/case-studies': 'Case Studies',
#   'https://www.tensorflow.org/community': 'Community',
#   'https://www.tensorflow.org/tutorials/generative/dcgan': 'Deep Convolutional Generati…',
#   'https://www.tensorflow.org/trusted-partners': 'Trusted Partner Program',
#   'https://developers.google.com/machine-learning/crash-course/first-steps-with-tensorflow/toolkit': 'Introduction to TensorFlow | Machine Learning Crash Course',
#   'https://tensorflow.rstudio.com/': 'TensorFlow for R',
#   'https://twitter.com/tensorflow?lang=en': 'TensorFlow (@TensorFlow) | Twitter',
#   'https://www.wired.com/2015/11/google-open-sources-its-artificial-intelligence-engine/': 'Google Just Open Sourced TensorFlow, Its Artificial ... - Wired',
#   'https://www.infoworld.com/article/3278008/what-is-tensorflow-the-machine-learning-library-explained.html': 'What is TensorFlow? The machine learning library explained ...',
#   'https://opensource.google/projects/tensorflow': 'TensorFlow – opensource.google',
#   'https://www.udacity.com/course/intro-to-tensorflow-for-deep-learning--ud187': 'Intro to TensorFlow for Deep Learning - Udacity',
#   'https://aws.amazon.com/tensorflow/': 'TensorFlow on AWS - Deep Learning on the Cloud',
#   'https://opensource.com/article/17/11/intro-tensorflow': 'What is TensorFlow? | Opensource.com',
#   'https://tensorflow.org': 'TensorFlow',
#   'https://www.tutorialspoint.com/tensorflow/index.htm': 'TensorFlow Tutorial - Tutorialspoint',
#   'https://en.wikipedia.org/wiki/Tensor_Flow': 'TensorFlow - Wikipedia',
#   'https://www.simpliv.com/python/learning-path-the-road-to-tensorflow': 'Learning Path: The Road to Tensorflow',
#   'https://www.tutorialspoint.com/tensorflow/tensorflow_installation.htm': 'TensorFlow - Installation - Tutorialspoint',
#   'https://towardsdatascience.com/a-tensorflow-modeling-pipeline-using-tensorflow-datasets-and-tensorboard-2152bb7f1023': 'A TensorFlow Modeling Pipeline using TensorFlow Datasets ...',
#   'https://docs.microsoft.com/en-us/azure/machine-learning/how-to-train-tensorflow': 'Train and deploy a TensorFlow model - Azure Machine ...',
#   'https://software.intel.com/content/www/us/en/develop/articles/intel-optimization-for-tensorflow-installation-guide.html': 'Intel® Optimization for TensorFlow* Installation Guide',
#   'https://www.anaconda.com/blog/tensorflow-in-anaconda': 'TensorFlow in Anaconda | Anaconda',
#   'https://builtin.com/data-science/pytorch-vs-tensorflow': 'PyTorch vs. TensorFlow: Which Framework Is Best? | Built In',
#   'https://www.udemy.com/course/complete-guide-to-tensorflow-for-deep-learning-with-python/': 'Total TensorFlow Guide: Deep Learning with Python Course ...',
#   'https://www.coursera.org/specializations/tensorflow-in-practice': 'TensorFlow in Practice | Coursera',
#   'https://codelabs.developers.google.com/codelabs/tensorflow-for-poets/': 'TensorFlow For Poets - Codelabs',
#   'https://medium.com/tensorflow': 'TensorFlow – Medium',
#   'https://ngc.nvidia.com/catalog/containers/nvidia:tensorflow': 'TensorFlow | NVIDIA NGC',
#   'https://hub.docker.com/r/tensorflow/tensorflow/': 'tensorflow/tensorflow - Docker Hub',
#   'https://stackoverflow.com/questions/tagged/tensorflow': "Newest 'tensorflow' Questions - Stack Overflow",
#   'https://tensorflow.google.cn/tutorials?hl=zh-cn': 'Tutorials | TensorFlow Core - TensorFlow 的机器学习 - Google',
#   'https://machinelearningmastery.com/introduction-python-deep-learning-library-tensorflow/': 'Introduction to the Python Deep Learning Library TensorFlow',
#   'https://www.guru99.com/what-is-tensorflow.html': 'What is TensorFlow? Introduction, Architecture & Example',
#   'https://cran.r-project.org/package=tensorflow': 'CRAN - Package tensorflow',
#   'https://searchdatamanagement.techtarget.com/definition/TensorFlow': 'What is TensorFlow? - Definition from WhatIs.com',
#   'https://tensorflow.rstudio.com/installation/': 'TensorFlow for R',
#   'https://cloud.google.com/tensorflow-enterprise/': 'TensorFlow Enterprise | Google Cloud',
#   'https://www.edx.org/course/deep-learning-with-tensorflow': 'Deep Learning with Tensorflow | edX',
#   'https://docs.nvidia.com/deeplearning/frameworks/install-tf-jetson-platform/index.html': 'Installing TensorFlow For Jetson Platform :: NVIDIA Deep ...',
#   'https://cloud.google.com/solutions/creating-object-detection-application-tensorflow': 'Creating an Object Detection Application Using TensorFlow ...',
#   'https://pypi.org/project/tensorflow-hub/': 'tensorflow-hub · PyPI',
#   'https://www.zhihu.com/question/49909565': 'TensorFlow 如何入门，如何快速学习？ - 知乎',
#   'https://docs.microsoft.com/en-us/azure/azure-functions/functions-machine-learning-tensorflow': 'Use Python and TensorFlow for machine learning in Azure ...',
#   'https://www.youtube.com/channel/UC0rqucBdTuFTjJiefW5t-IQ/featured': 'TensorFlow - YouTube',
#   'https://cloud.google.com/tensorflow-enterprise': 'TensorFlow Enterprise | Google Cloud',
#   'https://www.simplilearn.com/tutorials/deep-learning-tutorial/what-is-tensorflow': 'What is Tensorflow: Deep Learning Libraries and Program ...',
#   'https://www.instagram.com/explore/tags/tensorflow/?hl=en': '#tensorflow hashtag on Instagram • Photos and Videos',
#   'https://www.datacamp.com/community/tutorials/tensorflow-tutorial': 'TensorFlow Tutorial For Beginners - DataCamp',
#   'https://www.usenix.org/system/files/conference/osdi16/osdi16-abadi.pdf': 'TensorFlow: A System for Large-Scale Machine ... - Usenix',
#   'https://www.exastax.com/deep-learning/top-five-use-cases-of-tensorflow/': 'Top Five Use Cases of TensorFlow - Exastax',
#   'https://www.kdnuggets.com/tag/tensorflow': 'TensorFlow - KDnuggets',
#   'https://keras.io/': 'Keras: the Python deep learning API',
#   'https://docs.openvinotoolkit.org/latest/_docs_MO_DG_prepare_model_convert_model_Convert_Model_From_TensorFlow.html': 'Converting a TensorFlow* Model - OpenVINO™ Toolkit',
#   'https://docs.aws.amazon.com/dlami/latest/devguide/tutorial-tensorflow.html': 'TensorFlow - Deep Learning AMI',
#   'https://anaconda.org/anaconda/tensorflow': 'Tensorflow :: Anaconda Cloud',
#   'https://codelabs.developers.google.com/codelabs/recognize-flowers-with-tensorflow-on-android/': 'Recognize Flowers with TensorFlow Lite on Android',
#   'https://magenta.tensorflow.org/': 'Magenta',
#   'https://stackoverflow.com/questions/43990046/tensorflow-blas-gemm-launch-failed': 'python - TensorFlow: Blas GEMM launch failed - Stack Overflow',
#   'https://sourceforge.net/projects/tensorflow.mirror/': 'TensorFlow download | SourceForge.net',
#   'https://www.deeplearning.ai/tensorflow-in-practice/': 'TensorFlow in Practice - deeplearning.ai',
#   'https://www.infoq.com/tensorflow/': 'TensorFlow - InfoQ',
#   'https://towardsdatascience.com/covid-19-face-mask-detection-using-tensorflow-and-opencv-702dd833515b': 'COVID-19: Face Mask Detection using TensorFlow and OpenCV',
#   'https://www.crunchbase.com/organization/tensorflow': 'TensorFlow | Crunchbase',
#   'https://cognitiveclass.ai/courses/deep-learning-tensorflow': 'Deep Learning With Tensorflow Course by BDU',
#   'https://www.analyticsvidhya.com/blog/2020/03/tensorflow-2-tutorial-deep-learning/': 'TensorFlow 2.0 Tutorial | Deep Learning With TensorFlow 2.0',
#   'https://www.linkedin.com/learning/topics/tensorflow': 'TensorFlow Online Courses | LinkedIn Learning, formerly ...',
#   'https://www.packtpub.com/tech/tensorflow': 'Learn TensorFlow with TensorFlow eBooks & Videos | Packt',
#   'https://www.math.purdue.edu/~nwinovic/tensorflow.html': 'TensorFlow - Purdue Math',
#   'https://docs.wandb.com/library/frameworks/tensorflow': 'TensorFlow - Documentation - Weights & Biases',
#   'https://www.guru99.com/tensorflow-tutorial.html': 'TensorFlow Tutorial: Deep Learning for Beginner’s',
#   'https://docs.anaconda.com/anaconda/user-guide/tasks/tensorflow/': 'TensorFlow — Anaconda documentation',
#   'https://www.amazon.com/Deep-Learning-TensorFlow-Keras-Regression/dp/1838823417': 'Deep Learning with TensorFlow 2 and Keras: Regression ...',
#   'http://playground.tensorflow.org/': 'Tensorflow - A Neural Network Playground',
#   'https://stackoverflow.com/questions/38549253/how-to-find-which-version-of-tensorflow-is-installed-in-my-system': 'How to find which version of TensorFlow is installed in my ...',
#   'https://www.codeproject.com/Articles/5265273/Deep-Learning-AI-on-Low-Power-Microcontrollers-MNI': 'Deep-Learning AI on Low-Power Microcontrollers: MNIST ...',
#   'https://archive.shivam.dev/tensorflow-on-windows-10/': 'Installing TensorFlow on Windows 10 - Codability'})

# %%
# %%time

link_title_map = {}
with ThreadPoolExecutor() as executor:
    executor.map(get_search_result, url_headers, timeout=60)

len(link_title_map), link_title_map
# Out:
# CPU times: user 12.5 s, sys: 171 ms, total: 12.7 s
# Wall time: 13.3 s
# (95,
#  {'https://tensorflow.org': 'TensorFlow',
#   'https://pypi.org/project/tensorflow/': 'tensorflow · PyPI',
#   'https://aws.amazon.com/tensorflow/': 'TensorFlow on AWS - Deep Learning on the Cloud',
#   'https://www.datacamp.com/community/tutorials/tensorflow-tutorial': 'TensorFlow Tutorial For Beginners - DataCamp',
#   'https://medium.com/tensorflow': 'TensorFlow – Medium',
#   'https://opensource.com/article/17/11/intro-tensorflow': 'What is TensorFlow? | Opensource.com',
#   'https://en.wikipedia.org/wiki/Tensor_Flow': 'TensorFlow - Wikipedia',
#   'https://www.edx.org/course/deep-learning-with-tensorflow': 'Deep Learning with Tensorflow | edX',
#   'https://playground.tensorflow.org/': 'Tensorflow - A Neural Network Playground',
#   'https://software.intel.com/content/www/us/en/develop/articles/intel-optimization-for-tensorflow-installation-guide.html': 'Intel® Optimization for TensorFlow* Installation Guide',
#   'https://www.zhihu.com/question/49909565': 'TensorFlow 如何入门，如何快速学习？ - 知乎',
#   'https://towardsdatascience.com/a-tensorflow-modeling-pipeline-using-tensorflow-datasets-and-tensorboard-2152bb7f1023': 'A TensorFlow Modeling Pipeline using TensorFlow Datasets ...',
#   'https://builtin.com/data-science/pytorch-vs-tensorflow': 'PyTorch vs. TensorFlow: Which Framework Is Best? | Built In',
#   'https://adventuresinmachinelearning.com/python-tensorflow-tutorial/': 'Python TensorFlow Tutorial - Build a Neural Network ...',
#   'https://www.guru99.com/what-is-tensorflow.html': 'What is TensorFlow? Introduction, Architecture & Example',
#   'https://www.infoworld.com/article/3278008/what-is-tensorflow-the-machine-learning-library-explained.html': 'What is TensorFlow? The machine learning library explained ...',
#   'https://machinelearningmedium.com/2018/01/02/understanding-tensorflow/': 'Understanding TensorFlow | Machine Learning Medium',
#   'https://www.guru99.com/tensorflow-tutorial.html': 'TensorFlow Tutorial: Deep Learning for Beginner’s',
#   'https://docs.aws.amazon.com/dlami/latest/devguide/tutorial-tensorflow.html': 'TensorFlow - Deep Learning AMI',
#   'https://tensorflow.rstudio.com/installation/': 'TensorFlow for R',
#   'https://docs.anaconda.com/anaconda/user-guide/tasks/tensorflow/': 'TensorFlow — Anaconda documentation',
#   'https://pypi.org/project/tensorflow-hub/': 'tensorflow-hub · PyPI',
#   'https://www.reddit.com/r/MachineLearning/comments/go95w2/d_is_tensorflow_doomed/': '[D] Is TensorFlow doomed? : MachineLearning',
#   'https://docs.nvidia.com/deeplearning/frameworks/tensorflow-release-notes/index.html': 'TensorFlow Release Notes :: NVIDIA Deep Learning ...',
#   'https://www.codeproject.com/Articles/5265273/Deep-Learning-AI-on-Low-Power-Microcontrollers-MNI': 'Deep-Learning AI on Low-Power Microcontrollers: MNIST ...',
#   'https://awesomeopensource.com/project/guillaume-chevalier/GloVe-as-a-TensorFlow-Embedding-Layer?categoryPage=26': 'Glove As A Tensorflow Embedding Layer',
#   'https://www.edureka.co/blog/tensorflow-tutorial/': 'TensorFlow Tutorial | Deep Learning Using TensorFlow | Edureka',
#   'https://docs.nvidia.com/deeplearning/frameworks/install-tf-jetson-platform/index.html': 'Installing TensorFlow For Jetson Platform :: NVIDIA Deep ...',
#   'https://www.amazon.com/Deep-Learning-TensorFlow-Keras-Regression/dp/1838823417': 'Deep Learning with TensorFlow 2 and Keras: Regression ...',
#   'https://www.simplilearn.com/deep-learning-course-with-tensorflow-training': 'Deep Learning Course with Tensorflow Certification Training',
#   'https://stackoverflow.com/questions/38549253/how-to-find-which-version-of-tensorflow-is-installed-in-my-system': 'How to find which version of TensorFlow is installed in my ...',
#   'https://magenta.tensorflow.org/ddsp': 'DDSP: Differentiable Digital Signal Processing',
#   'https://stackoverflow.com/questions/43990046/tensorflow-blas-gemm-launch-failed': 'python - TensorFlow: Blas GEMM launch failed - Stack Overflow',
#   'https://www.amazon.com/Hands-Machine-Learning-Scikit-Learn-TensorFlow/dp/1492032646': 'Hands-On Machine Learning with Scikit-Learn, Keras, and ...',
#   'https://docs.microsoft.com/en-us/azure/azure-functions/functions-machine-learning-tensorflow': 'Use Python and TensorFlow for machine learning in Azure ...',
#   'https://www.prnewswire.com/news-releases/synopsys-announces-support-of-tensorflow-lite-for-microcontrollers-on-energy-efficient-arc-em-and-arc-hs-processor-ip-301065763.html': 'Synopsys Announces Support of TensorFlow Lite for ...',
#   'https://www.tutorialspoint.com/tensorflow/index.htm': 'TensorFlow Tutorial - Tutorialspoint',
#   'https://www.udemy.com/course/complete-guide-to-tensorflow-for-deep-learning-with-python/': 'Total TensorFlow Guide: Deep Learning with Python Course ...',
#   'https://www.tutorialspoint.com/tensorflow/tensorflow_installation.htm': 'TensorFlow - Installation - Tutorialspoint',
#   'https://www.youtube.com/playlist?list=PLQY2H8rRoyvzuJw20FG82Lgm2SZjTdIXU': 'TensorFlow Developer Summit 2020 - YouTube',
#   'https://www.tensorflow.org/': 'TensorFlow',
#   'https://en.wikipedia.org/wiki/TensorFlow': 'TensorFlow - Wikipedia',
#   'https://www.tensorflow.org/install/': 'Install TensorFlow 2',
#   'https://github.com/tensorflow/tensorflow': 'tensorflow/tensorflow: An Open Source Machine ... - GitHub',
#   'https://blog.tensorflow.org/2020/04/quantization-aware-training-with-tensorflow-model-optimization-toolkit.html': 'Quantization Aware Training with TensorFlow Model ...',
#   'https://codelabs.developers.google.com/codelabs/recognize-flowers-with-tensorflow-on-android/': 'Recognize Flowers with TensorFlow Lite on Android',
#   'https://www.tensorflow.org/learn': 'Learn',
#   'https://www.tensorflow.org/about': 'About',
#   'https://www.tensorflow.org/versions': 'API',
#   'https://www.tensorflow.org/tfx': 'TFX',
#   'https://www.tensorflow.org/resources/learn-ml': 'Learn Ml',
#   'https://www.tensorflow.org/guide/effective_tf2': 'Effective Tensorflow 2',
#   'https://www.tensorflow.org/about/case-studies': 'Case Studies',
#   'https://www.tensorflow.org/community': 'Community',
#   'https://www.tensorflow.org/tutorials/generative/dcgan': 'Deep Convolutional Generati…',
#   'https://www.tensorflow.org/trusted-partners': 'Trusted Partner Program',
#   'https://www.deeplearning.ai/tensorflow-in-practice/': 'TensorFlow in Practice - deeplearning.ai',
#   'https://www.infoq.com/tensorflow/': 'TensorFlow - InfoQ',
#   'https://towardsdatascience.com/covid-19-face-mask-detection-using-tensorflow-and-opencv-702dd833515b': 'COVID-19: Face Mask Detection using TensorFlow and OpenCV',
#   'https://www.crunchbase.com/organization/tensorflow': 'TensorFlow | Crunchbase',
#   'https://cognitiveclass.ai/courses/deep-learning-tensorflow': 'Deep Learning With Tensorflow Course by BDU',
#   'https://www.analyticsvidhya.com/blog/2020/03/tensorflow-2-tutorial-deep-learning/': 'TensorFlow 2.0 Tutorial | Deep Learning With TensorFlow 2.0',
#   'https://www.packtpub.com/tech/tensorflow': 'Learn TensorFlow with TensorFlow eBooks & Videos | Packt',
#   'https://www.math.purdue.edu/~nwinovic/tensorflow.html': 'TensorFlow - Purdue Math',
#   'https://docs.wandb.com/library/frameworks/tensorflow': 'TensorFlow - Documentation - Weights & Biases',
#   'https://deepai.org/machine-learning-glossary-and-terms/tensorflow': 'Tensorflow Definition | DeepAI',
#   'https://www.coursera.org/specializations/tensorflow-in-practice': 'TensorFlow in Practice | Coursera',
#   'https://codelabs.developers.google.com/codelabs/tensorflow-for-poets/': 'TensorFlow For Poets - Codelabs',
#   'https://hub.docker.com/r/tensorflow/tensorflow/': 'tensorflow/tensorflow - Docker Hub',
#   'https://ngc.nvidia.com/catalog/containers/nvidia:tensorflow': 'TensorFlow | NVIDIA NGC',
#   'https://tensorflow.google.cn/tutorials?hl=zh-cn': 'Tutorials | TensorFlow Core - TensorFlow 的机器学习 - Google',
#   'https://machinelearningmastery.com/introduction-python-deep-learning-library-tensorflow/': 'Introduction to the Python Deep Learning Library TensorFlow',
#   'https://stackoverflow.com/questions/tagged/tensorflow': "Newest 'tensorflow' Questions - Stack Overflow",
#   'https://cran.r-project.org/package=tensorflow': 'CRAN - Package tensorflow',
#   'https://cloud.google.com/tensorflow-enterprise': 'TensorFlow Enterprise | Google Cloud',
#   'https://www.simplilearn.com/tutorials/deep-learning-tutorial/what-is-tensorflow': 'What is Tensorflow: Deep Learning Libraries and Program ...',
#   'https://www.instagram.com/explore/tags/tensorflow/?hl=en': '#tensorflow hashtag on Instagram • Photos and Videos',
#   'https://www.usenix.org/system/files/conference/osdi16/osdi16-abadi.pdf': 'TensorFlow: A System for Large-Scale Machine ... - Usenix',
#   'https://www.exastax.com/deep-learning/top-five-use-cases-of-tensorflow/': 'Top Five Use Cases of TensorFlow - Exastax',
#   'https://www.kdnuggets.com/tag/tensorflow': 'TensorFlow - KDnuggets',
#   'https://keras.io/': 'Keras: the Python deep learning API',
#   'https://docs.openvinotoolkit.org/latest/_docs_MO_DG_prepare_model_convert_model_Convert_Model_From_TensorFlow.html': 'Converting a TensorFlow* Model - OpenVINO™ Toolkit',
#   'https://developers.google.com/machine-learning/crash-course/first-steps-with-tensorflow/toolkit': 'Introduction to TensorFlow | Machine Learning Crash Course',
#   'https://tensorflow.rstudio.com/': 'TensorFlow for R',
#   'https://twitter.com/tensorflow?lang=en': 'TensorFlow (@TensorFlow) | Twitter',
#   'https://www.wired.com/2015/11/google-open-sources-its-artificial-intelligence-engine/': 'Google Just Open Sourced TensorFlow, Its Artificial ... - Wired',
#   'https://opensource.google/projects/tensorflow': 'TensorFlow – opensource.google',
#   'https://www.udacity.com/course/intro-to-tensorflow-for-deep-learning--ud187': 'Intro to TensorFlow for Deep Learning - Udacity',
#   'https://github.com/tensorflow': 'tensorflow Â· GitHub',
#   'https://www.youtube.com/channel/UC0rqucBdTuFTjJiefW5t-IQ': 'TensorFlow YouTube channel - TensorFlow - YouTube',
#   'https://www.tensorflow.org/tutorials': 'Tutorials',
#   'https://www.tensorflow.org/overview': 'TensorFlow Core',
#   'https://www.tensorflow.org/install': 'Install',
#   'https://www.tensorflow.org/guide': 'Guide',
#   'https://www.tensorflow.org/tutorials/keras/classification': 'Basic classification: Classify ...'})
