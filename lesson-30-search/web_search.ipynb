# %% [markdown]
# ### How to scrape google search result
#
# https://hackernoon.com/how-to-scrape-google-with-python-bo7d2tal
#
# https://serpwow.com/
#
# https://pythondata.com/quick-tip-consuming-google-search-results-to-use-for-web-scraping/

# %%
import urllib
import requests
from bs4 import BeautifulSoup

# %%
# desktop user-agent
USER_AGENT = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:65.0) Gecko/20100101 Firefox/65.0"
# mobile user-agent
MOBILE_USER_AGENT = "Mozilla/5.0 (Linux; Android 7.0; SM-G930V Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.125 Mobile Safari/537.36"
HEADERS = {"user-agent" : USER_AGENT}
MAX_RESULTS = 100

# %%
def _get_search_url(query, start=0, engine='google'):
    """
    Get search result
    args:
        query: search text
        start: starting result index
        engine: bing or google
    """
    if engine == 'bing':
        SEARCH_URL = "https://www.bing.com/search"
        url = SEARCH_URL + "?q="+ urllib.parse.quote(query) + \
                ("" if start==0 else f"&first={start}")
    elif engine == 'google':
        SEARCH_URL = "https://google.com/search"
        url = SEARCH_URL + "?q="+ urllib.parse.quote(query) + \
                ("" if start==0 else f"&start={start}")
    else:
        raise ValueError('invalid search engine', engine)
    
    return url

# %%
def _get_search_result(url, headers):
    results = []
    resp = requests.get(url, headers=headers)

    if resp.status_code == 200:
        soup = BeautifulSoup(resp.content, "html.parser")

        for g in soup.find_all('div', class_='r'):
            anchors = g.find_all('a')
            if len(anchors) < 1:
                continue
                
            link = anchors[0]['href']
            title = g.find('h3').text
            item = {"title": title, "link": link}
            results.append(item)
            
    return results

# %%
engine = 'google'
search_text = "tensorflow"

# %%
search_text = urllib.parse.quote(search_text)

results = []
for start in range(0,MAX_RESULTS,10):
    URL = _get_search_url(search_text, start=start, engine=engine)
    res = _get_search_result(URL, HEADERS)
    if len(res):
        results.extend(res)

# %%
len(results), results
# Out:
# (95,
#  [{'title': 'TensorFlow', 'link': 'https://www.tensorflow.org/'},
#   {'title': 'tensorflow/tensorflow: An Open Source Machine ... - GitHub',
#    'link': 'https://github.com/tensorflow/tensorflow'},
#   {'title': 'TensorFlow - Wikipedia',
#    'link': 'https://en.wikipedia.org/wiki/TensorFlow'},
#   {'title': 'TensorFlow YouTube channel - TensorFlow - YouTube',
#    'link': 'https://www.youtube.com/channel/UC0rqucBdTuFTjJiefW5t-IQ'},
#   {'title': 'TensorFlow for R', 'link': 'https://tensorflow.rstudio.com/'},
#   {'title': 'Introduction to TensorFlow | Machine Learning Crash Course',
#    'link': 'https://developers.google.com/machine-learning/crash-course/first-steps-with-tensorflow/toolkit'},
#   {'title': 'TensorFlow (@TensorFlow) | Twitter',
#    'link': 'https://twitter.com/tensorflow?lang=en'},
#   {'title': 'Google Just Open Sourced TensorFlow, Its Artificial ... - Wired',
#    'link': 'https://www.wired.com/2015/11/google-open-sources-its-artificial-intelligence-engine/'},
#   {'title': 'What is TensorFlow? The machine learning library explained ...',
#    'link': 'https://www.infoworld.com/article/3278008/what-is-tensorflow-the-machine-learning-library-explained.html'},
#   {'title': 'tensorflow · PyPI',
#    'link': 'https://pypi.org/project/tensorflow/'},
#   {'title': 'TensorFlow – opensource.google',
#    'link': 'https://opensource.google/projects/tensorflow'},
#   {'title': 'Intro to TensorFlow for Deep Learning - Udacity',
#    'link': 'https://www.udacity.com/course/intro-to-tensorflow-for-deep-learning--ud187'},
#   {'title': 'TensorFlow on AWS - Deep Learning on the Cloud',
#    'link': 'https://aws.amazon.com/tensorflow/'},
#   {'title': 'TensorFlow For Poets - Codelabs',
#    'link': 'https://codelabs.developers.google.com/codelabs/tensorflow-for-poets/'},
#   {'title': 'TensorFlow in Practice | Coursera',
#    'link': 'https://www.coursera.org/specializations/tensorflow-in-practice'},
#   {'title': 'Introduction to TensorFlow for Artificial Intelligence, Machine ...',
#    'link': 'https://www.coursera.org/learn/introduction-tensorflow'},
#   {'title': 'What is TensorFlow? | Opensource.com',
#    'link': 'https://opensource.com/article/17/11/intro-tensorflow'},
#   {'title': 'tensorflow/tensorflow - Docker Hub',
#    'link': 'https://hub.docker.com/r/tensorflow/tensorflow/'},
#   {'title': 'TensorFlow | NVIDIA NGC',
#    'link': 'https://ngc.nvidia.com/catalog/containers/nvidia:tensorflow'},
#   {'title': 'TensorFlow – Medium', 'link': 'https://medium.com/tensorflow'},
#   {'title': 'Tutorials | TensorFlow Core - TensorFlow 的机器学习 - Google',
#    'link': 'https://tensorflow.google.cn/tutorials?hl=zh-cn'},
#   {'title': "Newest 'tensorflow' Questions - Stack Overflow",
#    'link': 'https://stackoverflow.com/questions/tagged/tensorflow'},
#   {'title': 'Introduction to the Python Deep Learning Library TensorFlow',
#    'link': 'https://machinelearningmastery.com/introduction-python-deep-learning-library-tensorflow/'},
#   {'title': 'What is TensorFlow? Introduction, Architecture & Example',
#    'link': 'https://www.guru99.com/what-is-tensorflow.html'},
#   {'title': 'Keras: the Python deep learning API',
#    'link': 'https://keras.io/'},
#   {'title': 'CRAN - Package tensorflow',
#    'link': 'https://cran.r-project.org/package=tensorflow'},
#   {'title': 'What is Tensorflow: Deep Learning Libraries and Program ...',
#    'link': 'https://www.simplilearn.com/tutorials/deep-learning-tutorial/what-is-tensorflow'},
#   {'title': 'TensorFlow Enterprise | Google Cloud',
#    'link': 'https://cloud.google.com/tensorflow-enterprise'},
#   {'title': 'PyTorch vs. TensorFlow: Which Framework Is Best? | Built In',
#    'link': 'https://builtin.com/data-science/pytorch-vs-tensorflow'},
#   {'title': '#tensorflow hashtag on Instagram • Photos and Videos',
#    'link': 'https://www.instagram.com/explore/tags/tensorflow/?hl=en'},
#   {'title': 'TensorFlow Tutorial For Beginners - DataCamp',
#    'link': 'https://www.datacamp.com/community/tutorials/tensorflow-tutorial'},
#   {'title': 'TensorFlow - KDnuggets',
#    'link': 'https://www.kdnuggets.com/tag/tensorflow'},
#   {'title': 'TensorFlow in Practice - deeplearning.ai',
#    'link': 'https://www.deeplearning.ai/tensorflow-in-practice/'},
#   {'title': 'Converting a TensorFlow* Model - OpenVINO™ Toolkit',
#    'link': 'https://docs.openvinotoolkit.org/latest/_docs_MO_DG_prepare_model_convert_model_Convert_Model_From_TensorFlow.html'},
#   {'title': 'Learn TensorFlow with TensorFlow eBooks & Videos | Packt',
#    'link': 'https://www.packtpub.com/tech/tensorflow'},
#   {'title': 'TensorFlow | Crunchbase',
#    'link': 'https://www.crunchbase.com/organization/tensorflow'},
#   {'title': 'Deep Learning With Tensorflow Course by BDU',
#    'link': 'https://cognitiveclass.ai/courses/deep-learning-tensorflow'},
#   {'title': 'TensorFlow: A System for Large-Scale Machine ... - Usenix',
#    'link': 'https://www.usenix.org/system/files/conference/osdi16/osdi16-abadi.pdf'},
#   {'title': 'TensorFlow - InfoQ', 'link': 'https://www.infoq.com/tensorflow/'},
#   {'title': 'Using TensorFlow to Create a Neural Network (with Examples ...',
#    'link': 'https://www.bmc.com/blogs/create-neural-network-with-tensorflow/'},
#   {'title': 'Total TensorFlow Guide: Deep Learning with Python Course ...',
#    'link': 'https://www.udemy.com/course/complete-guide-to-tensorflow-for-deep-learning-with-python/'},
#   {'title': 'TensorFlow Hub: Home', 'link': 'https://tfhub.dev/'},
#   {'title': 'TensorFlow — Anaconda documentation',
#    'link': 'https://docs.anaconda.com/anaconda/user-guide/tasks/tensorflow/'},
#   {'title': 'What is TensorFlow? - Definition from WhatIs.com',
#    'link': 'https://searchdatamanagement.techtarget.com/definition/TensorFlow'},
#   {'title': 'Top Five Use Cases of TensorFlow - Exastax',
#    'link': 'https://www.exastax.com/deep-learning/top-five-use-cases-of-tensorflow/'},
#   {'title': 'Explore Deep Learning: A TensorFlow Python Tutorial | Toptal',
#    'link': 'https://www.toptal.com/machine-learning/tensorflow-python-tutorial'},
#   {'title': 'TensorFlow 2.2 kicks Python 2 to the curb, adds new profiler ...',
#    'link': 'https://devclass.com/2020/05/11/tensorflow-2_2/'},
#   {'title': 'Tensorflow :: Anaconda Cloud',
#    'link': 'https://anaconda.org/anaconda/tensorflow'},
#   {'title': 'TensorFlow Support | Intel® Movidius™ Neural Compute SDK ...',
#    'link': 'https://movidius.github.io/ncsdk/tensorflow.html'},
#   {'title': 'Introduction to Deep Learning with TensorFlow - Python ...',
#    'link': 'https://pythonprogramming.net/tensorflow-introduction-machine-learning-tutorial/'},
#   {'title': 'What is TensorFlow? Top various uses of TensorFlow',
#    'link': 'https://www.mygreatlearning.com/blog/what-is-tensorflow-machine-learning-library-explained/'},
#   {'title': 'Deep Learning with Tensorflow | edX',
#    'link': 'https://www.edx.org/course/deep-learning-with-tensorflow'},
#   {'title': 'Announcing TensorFlow Quantum: An Open ... - Google AI Blog',
#    'link': 'http://ai.googleblog.com/2020/03/announcing-tensorflow-quantum-open.html'},
#   {'title': 'TensorFlow: A system for large-scale machine learning ...',
#    'link': 'https://research.google/pubs/pub45381/'},
#   {'title': 'TensorFlow Programming | Kaggle',
#    'link': 'https://www.kaggle.com/dansbecker/tensorflow-programming'},
#   {'title': 'TensorFlow Programming | Kaggle',
#    'link': 'https://www.kaggle.com/dansbecker/tensorflow-programming'},
#   {'title': 'TensorFlow vs PyTorch — Linear Regression - Towards Data ...',
#    'link': 'https://towardsdatascience.com/tensorflow-vs-pytorch-linear-regression-e07781a83525'},
#   {'title': 'Python TensorFlow Tutorial - Build a Neural Network ...',
#    'link': 'https://adventuresinmachinelearning.com/python-tensorflow-tutorial/'},
#   {'title': 'TensorFlow Dev Summit - Home - Partner Summit',
#    'link': 'https://events.withgoogle.com/tensorflow-dev-summit/'},
#   {'title': "Can Deep Learning with TensorFlow Fund Highways? Let's ...",
#    'link': 'https://blogs.cisco.com/developer/deep-learning-with-tensorflow'},
#   {'title': 'Creative Applications of Deep Learning with TensorFlow, an ...',
#    'link': 'https://www.kadenze.com/courses/creative-applications-of-deep-learning-with-tensorflow/info'},
#   {'title': 'Tensorflow for Deep Learning Research - Stanford University',
#    'link': 'https://web.stanford.edu/class/cs20si/syllabus.html'},
#   {'title': 'TensorFlow - Basics - Tutorialspoint',
#    'link': 'https://www.tutorialspoint.com/tensorflow/tensorflow_basics.htm'},
#   {'title': 'Machine Learning with TensorFlow - Manning',
#    'link': 'https://www.manning.com/books/machine-learning-with-tensorflow'},
#   {'title': 'Intel® Optimization for TensorFlow* Installation Guide',
#    'link': 'https://software.intel.com/content/www/us/en/develop/articles/intel-optimization-for-tensorflow-installation-guide.html'},
#   {'title': 'TensorFlow Quantum: A Software Framework for Quantum ...',
#    'link': 'https://arxiv.org/abs/2003.02989'},
#   {'title': 'Introduction to Implementing Neural Networks using TensorFlow',
#    'link': 'https://www.analyticsvidhya.com/blog/2016/10/an-introduction-to-implementing-neural-networks-using-tensorflow/'},
#   {'title': 'What is TensorFlow? - Databricks',
#    'link': 'https://databricks.com/glossary/what-is-tensorflow'},
#   {'title': 'Implementing a CNN for Text Classification in TensorFlow ...',
#    'link': 'http://www.wildml.com/2015/12/implementing-a-cnn-for-text-classification-in-tensorflow/'},
#   {'title': '9 Things You Should Know About TensorFlow | Hacker Noon',
#    'link': 'https://hackernoon.com/9-things-you-should-know-about-tensorflow-9cf0a05e4995'},
#   {'title': 'Big deep learning news: Google Tensorflow chooses Keras ...',
#    'link': 'https://www.fast.ai/2017/01/03/keras/'},
#   {'title': 'TensorFlow for Deep Learning: What You Need to Know',
#    'link': 'https://missinglink.ai/blog/ml-frameworks/what-you-need-to-know-about-tensorflow/'},
#   {'title': 'TensorFlow in a Nutshell - DZone AI',
#    'link': 'https://dzone.com/articles/tensorflow-in-a-nutshell'},
#   {'title': 'TensorFlow London (London, United Kingdom) | Meetup',
#    'link': 'https://www.meetup.com/TensorFlow-London/'},
#   {'title': 'COVID-19: Face Mask Detector with OpenCV, Keras ...',
#    'link': 'https://www.pyimagesearch.com/2020/05/04/covid-19-face-mask-detector-with-opencv-keras-tensorflow-and-deep-learning/'},
#   {'title': 'TensorFlow - Reviews – Finances Online',
#    'link': 'https://reviews.financesonline.com/p/tensorflow/'},
#   {'title': '@tensorflow/tfjs - npm',
#    'link': 'https://www.npmjs.com/package/@tensorflow/tfjs'},
#   {'title': 'TensorFlow Training (TFJob) | Kubeflow',
#    'link': 'https://www.kubeflow.org/docs/components/training/tftraining/'},
#   {'title': 'Intro to TensorFlow for Deep Learning - Google Digital Garage',
#    'link': 'https://learndigital.withgoogle.com/digitalgarage/course/intro-to-tensorflow-for-deep-learning'},
#   {'title': 'The State of Machine Learning Frameworks in 2019',
#    'link': 'https://thegradient.pub/state-of-ml-frameworks-2019-pytorch-dominates-research-tensorflow-dominates-industry/'},
#   {'title': 'tensorflow - Reddit',
#    'link': 'https://www.reddit.com/r/tensorflow2/'},
#   {'title': 'TensorFlow Tutorial | Deep Learning Using TensorFlow ...',
#    'link': 'https://www.edureka.co/blog/tensorflow-tutorial/'},
#   {'title': "A Look Inside TensorFlow, Google's Open Source Deep ...",
#    'link': 'https://thenewstack.io/look-inside-tensorflow-googles-open-source-deep-learning-framework/'},
#   {'title': 'Official Google Blog: TensorFlow: smarter machine learning ...',
#    'link': 'https://googleblog.blogspot.com/2015/11/tensorflow-smarter-machine-learning-for.html'},
#   {'title': 'TensorFlow - ImageJ', 'link': 'https://imagej.net/TensorFlow'},
#   {'title': 'TensorFlow Hub - Show notebooks in Drive',
#    'link': 'https://colab.research.google.com/github/tensorflow/hub/blob/master/examples/colab/tf2_image_retraining.ipynb'},
#   {'title': 'Easy TensorFlow - Home',
#    'link': 'https://www.easy-tensorflow.com/'},
#   {'title': 'Tensorflow - Pittsburgh Supercomputing Center',
#    'link': 'https://www.psc.edu/user-resources/software/tensorflow'},
#   {'title': "Hello, TensorFlow! – O'Reilly",
#    'link': 'https://www.oreilly.com/content/hello-tensorflow/'},
#   {'title': 'TensorFlow for machine learning: Everything you need to know',
#    'link': 'http://techgenix.com/tensorflow-machine-learning/'},
#   {'title': 'Study: Deep Learning Shifting from TensorFlow to PyTorch ...',
#    'link': 'https://pureai.com/articles/2019/10/10/machine-learning-framework-popularity.aspx'},
#   {'title': 'TensorFlow KR 커뮤니티 - Facebook',
#    'link': 'https://www.facebook.com/groups/TensorFlowKR/'},
#   {'title': "Google's TensorFlow Lite brings machine learning to Android ...",
#    'link': 'https://techcrunch.com/2017/05/17/googles-tensorflow-lite-brings-machine-learning-to-android-devices/'},
#   {'title': "Google's latest platform play is artificial intelligence, and it's ...",
#    'link': 'https://www.theverge.com/2017/5/18/15657256/google-ai-machine-learning-tensorflow-io-2017-platform-play'},
#   {'title': 'NN Modules (Tensorflow) — DGL 0.4.3post2 documentation',
#    'link': 'https://docs.dgl.ai/en/0.4.x/api/python/nn.tensorflow.html'}])

# %%
import json

with open(f"{search_text}-{engine}.json", "w") as f:
    f.write(json.dumps(results))

# %% [raw]
# def urlopen(url, proxies=None):
#     headers = [
#         # ('User-Agent', "Mozilla/5.0 (Windows NT 6.1; WOW64) " \
#         #     "AppleWebKit/537.36 (KHTML, like Gecko) " \
#         #     "Chrome/ 58.0.3029.81 Safari/537.36"),
#         ('User-Agent', "Mozilla/5.0 (X11; Linux x86_64) " \
#             "AppleWebKit/537.36 (KHTML, like Gecko) " \
#             "Chrome/51.0.2704.103 Safari/537.36"),
#         ("Accept-Language", "en-US,en;q=0.5"),
#     ]
#
#     if proxies is not None:
#         # print(proxies)
#         handler = urllib.request.ProxyHandler(proxies)
#         opener = urllib.request.build_opener(handler)
#     else:
#         opener = urllib.request.build_opener()
#
#     opener.addheaders = headers
#
#     with opener.open(url) as response:
#         text = response.read()
#
#     return text
#
# text = urlopen(url)
# file_html = f"{search_text}-{engine}.html"
# with open(file_html, "w") as f:
#     f.write(text.decode("utf-8"))
