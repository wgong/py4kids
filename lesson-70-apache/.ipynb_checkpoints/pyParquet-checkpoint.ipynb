# %% [markdown]
# ### Python and Parquet
#
# https://www.confessionsofadataguy.com/python-and-apache-parquet-yes-please/

# %% [markdown]
# download Chicago crimes file at https://catalog.data.gov/dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("crimes_1yr.csv")

# %%
df.head()
# Out:
#       CASE#     DATE  OF OCCURRENCE                   BLOCK  IUCR  \
# 0  JB234215  04/23/2018 05:09:00 AM    034XX W LEXINGTON ST  1345
# 1  JB252109  04/23/2018 05:27:00 AM     096XX S MERRION AVE  2820
# 2  JB234739  04/23/2018 05:30:00 AM  088XX S MARSHFIELD AVE  2826
# 3  JB235067  04/23/2018 05:45:00 AM         007XX E 83RD PL  1310
# 4  JB234240  04/23/2018 05:45:00 AM         0000X W 69TH ST  0820
#
#    PRIMARY DESCRIPTION           SECONDARY DESCRIPTION  LOCATION DESCRIPTION  \
# 0      CRIMINAL DAMAGE     TO CITY OF CHICAGO PROPERTY             APARTMENT
# 1        OTHER OFFENSE                TELEPHONE THREAT             RESIDENCE
# 2        OTHER OFFENSE  HARASSMENT BY ELECTRONIC MEANS             RESIDENCE
# 3      CRIMINAL DAMAGE                     TO PROPERTY             APARTMENT
# 4                THEFT                  $500 AND UNDER             CTA TRAIN
#
#   ARREST DOMESTIC  BEAT  ...    X COORDINATE Y COORDINATE   LATITUDE  \
# ...

# %%
df['CASE#'].head()
# Out:
# 0    JB234215
# 1    JB252109
# 2    JB234739
# 3    JB235067
# 4    JB234240
# Name: CASE#, dtype: object

# %%
# write the dataframe out to a parquet file
df.to_parquet('crimes.snappy.parquet' ,engine='auto', compression='snappy')

# %%
# !ls
# Out:
# crimes_1yr.csv	crimes.snappy.parquet  pyParquet.ipynb

# %%
import pyarrow.parquet as pq
data = pq.read_pandas('crimes.snappy.parquet', columns=['CASE#', 'DATE OF OCCURRENCE', 'SECONDARY DESCRIPTION']).to_pandas()

# %%
data.head()
# Out:
#       CASE#
# 0  JB234215
# 1  JB252109
# 2  JB234739
# 3  JB235067
# 4  JB234240

# %%
data2 = pq.read_pandas('crimes.snappy.parquet').to_pandas()

# %%
data2.head()
# Out:
#       CASE#     DATE  OF OCCURRENCE                   BLOCK  IUCR  \
# 0  JB234215  04/23/2018 05:09:00 AM    034XX W LEXINGTON ST  1345
# 1  JB252109  04/23/2018 05:27:00 AM     096XX S MERRION AVE  2820
# 2  JB234739  04/23/2018 05:30:00 AM  088XX S MARSHFIELD AVE  2826
# 3  JB235067  04/23/2018 05:45:00 AM         007XX E 83RD PL  1310
# 4  JB234240  04/23/2018 05:45:00 AM         0000X W 69TH ST  0820
#
#    PRIMARY DESCRIPTION           SECONDARY DESCRIPTION  LOCATION DESCRIPTION  \
# 0      CRIMINAL DAMAGE     TO CITY OF CHICAGO PROPERTY             APARTMENT
# 1        OTHER OFFENSE                TELEPHONE THREAT             RESIDENCE
# 2        OTHER OFFENSE  HARASSMENT BY ELECTRONIC MEANS             RESIDENCE
# 3      CRIMINAL DAMAGE                     TO PROPERTY             APARTMENT
# 4                THEFT                  $500 AND UNDER             CTA TRAIN
#
#   ARREST DOMESTIC  BEAT  ...    X COORDINATE Y COORDINATE   LATITUDE  \
# ...
