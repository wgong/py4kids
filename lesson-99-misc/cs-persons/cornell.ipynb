# %%
s = """
Mohamed Abdelfattah

Assistant Professor ; Electrical and Computer Engineering, Cornell Tech, CS Field Member; ; Ph.D., University of Toronto, 2016
Research Areas: Artificial Intelligence, Machine Learning

Research Concentration: Artificial Intelligence

Jayadev Acharya

Assistant Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., University of California, San Diego, 2014
Research Focus: Information theory, machine learning, and algorithmic statistics

Research Areas: Artificial Intelligence, Theory of Computing

Research Concentration: Artificial Intelligence, Theory of Computation

Rachit Agarwal

Associate Professor ; Computer Science, CS Field Member ; Ph.D., University of Illinois, Urbana-Champaign, 2013
Research Focus: Distributed systems, systems for big data analytics, networking, design and analysis of algorithms

Research Areas: Systems and Networking, Theory of Computing

Research Concentration: Systems, Theory of Computation

David Albonesi

Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., University of Massachusetts, Amherst, 1996
Research Focus: Adaptive and reconfigurable multi-core and processor architectures, power- and reliability-aware computing, and high performance interconnect architectures using silicon nanophotonics

Research Areas: Computer Architecture & VLSI, Systems and Networking

Research Concentration: Systems

Lorenzo Alvisi

Professor ; Computer Science, CS Field Member, Tisch University Professor ; Ph.D., Cornell University, 1996
Research Focus: Theory and practice of dependable distributed computing

Research Areas: Systems and Networking

Research Concentration: Systems

Yoav Artzi

Associate Professor ; Computer Science, Cornell Tech, CS Field Member ; Ph.D., Univ of Washington, 2015
Research Focus: Natural language processing, situated language understanding, automated natural language interaction, machine learning

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Shiri Azenkot

Associate Professor ; Jacobs Technion-Cornell Institute; CS Field Member ; Ph.D. University of Washington, 2014
Research Focus: Human-computer Interactions and Accessibility

Research Areas: Human Interaction

Research Concentration: Scientific Computing and Applications

Graeme Bailey

Adjunct Professor ; Ph.D., University of Birmingham
Research Focus: Mathematics

Kavita Bala

Professor and Dean of Cornell Bowers CIS ; Computer Science, Chair, CS Field Member ; Ph.D., M.I.T., 1999
Research Focus: Computer graphics—scalable graphics; perceptually-based, realistic rendering; image-based texturing and modeling

Research Areas: Artificial Intelligence, Graphics, Vision

Research Concentration: Artificial Intelligence, Programming Languages and Logics, Scientific Computing and Applications

Siddhartha Banerjee

Assistant Professor ; Operations Research and Information Engineering, CS Field Member ; PhD, University of Texas - Austin, 2013
Research Focus: Stochastic Modeling, Design of Scalable Algorithms, Matching Markets and Social Computing, Control of Information-Flows, Learning and Recommendation

Research Areas: Theory of Computing

Research Concentration: Theory of Computation

Christopher Batten

Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., M.I.T., 2010
Research Focus: Computer Architecture, Electronic Design Automation, Digital VLSI

Research Areas: Computer Architecture & VLSI, Systems and Networking

Research Concentration: Systems

Tapomayukh Bhattacharjee

Assistant Professor ; Computer Science, CS Field Member ; Ph.D., Georgia Institute of Technology, 2017
Research Focus: Human-Robot Interaction, Robot Manipulation, Haptic Perception, Assistive Robotics

Research Areas: Artificial Intelligence, Human Interaction, Machine Learning, Robotics

Research Concentration: Artificial Intelligence, Scientific Computing and Applications, Systems

David Bindel

Associate Professor and Associate Dean for Diversity, Equity, and Inclusion ; Computer Science, CS Field Member ; Ph.D., University of California, Berkeley, 2006
Research Focus: Microelectromechanical systems (MEMS), numerical linear algebra, finite element analysis, floating point computation and network tomography

Research Areas: Scientific Computing

Research Concentration: Scientific Computing and Applications

Ken Birman

Professor ; Computer Science, CS Field Member; N. Rama Rao Professor of Computer Science ; Ph.D., University of California, Berkeley, 1981
Research Focus: Reliability and security in modern networked environments

Research Areas: Security, Systems and Networking

Research Concentration: Systems

Ronald Brachman

Director; Professor ; Jacobs Technion-Cornell Institute ; Ph.D., Harvard Univ, 1977
Research Focus: Artificial intelligence, information retrieval, database management

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Anne Bracy

Senior Lecturer ; Computer Science, CS Minor Field Member ; Ph.D., Univ of Penn, 2008
Research Focus: Computer Architecture, Instruction Fusion, Hardware Support for Thread Synchronization

Research Areas: Computer Architecture & VLSI

Florentina Bunea 

Professor ; Statistics and Data Science, CS Field Member ; Ph.D. University of Washington, 2000
Research Focus: Statistical Machine Learning Theory, Statistical Foundations for Data Science, High Dimensional Statistics

Research Areas: Machine Learning

Research Concentration: Artificial Intelligence, Theory of Computation

Mark Campbell

Professor ; Mechanical Engineering; CS Field Member ; Ph.D. Massachusetts Institute of Technology 1996
Research Focus: Robotics, Sensor fusion, Machine learning and Perception

Research Areas: Artificial Intelligence, Robotics

Claire Cardie

On sabbatical: AY 2022-2023

Professor and Associate Dean for Education ; Computer Science, CS Field Member; Joseph C. Ford Professor of Engineering ; Ph.D., Univ of Mass, Amherst, 1994
Research Focus: Natural language processing

Research Areas: Artificial Intelligence, Human Interaction

Research Concentration: Artificial Intelligence

Eshan Chattopadhyay

Assistant Professor ; Computer Science, CS Field Member ; Ph.D. University of Texas at Ausin, 2016
Research Focus: Use of Randomness in Computation, Computational Complexity Theory and Cryptography

Research Areas: Theory of Computing

Research Concentration: Theory of Computation

Sanjiban Choudhury

Assistant Professor ; Computer Science ; Ph.D., Carnegie Mellon University, 2018
Research Focus: Imitation Learning, Planning and Learning, Robot Manipulation

Research Areas: Artificial Intelligence, Machine Learning, Robotics

Research Concentration: Artificial Intelligence, Scientific Computing and Applications

Tanzeem Choudhury

Roger and Joelle Burnell Professor in Integrated Health and Technology ; Information Science, CS Field Member ; Ph.D., M.I.T., 2004
Research Focus: Machine learning techniques for systems that can reason about human activities, interactions, and social networks in everyday environments

Research Areas: Artificial Intelligence, Human Interaction

Research Concentration: Artificial Intelligence

Michael Clarkson

Senior Lecturer ; Computer Science, CS Minor Field Member ; PhD, Cornell, 2010
Research Focus: Security, programming languages, electronic voting

Research Areas: Programming Languages, Security

Robert Constable

Professor Emeritus ; Computer Science, CS Field Member ; Ph.D., Univ of Wisconsin, Madison, 1968
Research Focus: Type theory and automated reasoning

Research Areas: Programming Languages, Theory of Computing

Research Concentration: Programming Languages and Logics

Anil Damle

Assistant Professor ; Computer Science, CS Field Member, Ph.D., Stanford University, 2016
Research Focus: Development of algorithms in applied and computational mathematics (e.g. numerical linear algebra, computational quantum chemistry, and spectral clustering)

Research Areas: Scientific Computing

Research Concentration: Scientific Computing and Applications

Cristian Danescu-Niculescu-Mizil

Assistant Professor ; Information Science, CS Field Member ; PhD, Cornell University, 2012
Research Focus: Computational Social Science, Social Computing, Computational Linguistics, Natural Language Processing

Research Areas: Artificial Intelligence, Human Interaction

Research Concentration: Artificial Intelligence

Abe Davis

Assistant Professor ; Computer Science, CS Field Member ; Ph.D., Massachusetts Institute of Technology, 2016
Research Focus: Computer Graphics, Vision, HCI

Research Areas: Artificial Intelligence, Graphics, Human Interaction, Vision

Christopher De Sa

Assistant Professor ; Computer Science, CS Field Member, PhD., Stanford University, 2017
Research Focus: Developing and understanding algorithmic, software, and hardware techniques for high-performance machine learning

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence, Systems

Sarah Dean

Assistant Professor ; Computer Science; CS Field Member ; Ph.D., University of California, Berkeley, 2021
Research Focus: Understanding tradeoffs and limitations arising from the interplay between Control and Optimization, Machine Learning, and Dynamics in real-world systems

Research Areas: Machine Learning, Robotics

Research Concentration: Artificial Intelligence, Theory of Computation

Nicola Dell

Assistant Professor ; Information Science, Cornell Tech, CS Field Member ; Ph.D., Univ of Washington, 2015
Research Focus: Human computer interaction (HCI) and Information and Communication Technologies for Development (ICTD)

Research Areas: Human Interaction

Research Concentration: Artificial Intelligence

Alan Demers

Principal Research Scientist (Retired) ; Computer Science, CS Field Member ; Ph.D., Princeton Univ, 1975
Research Focus: Database systems, database replication, and algorithms

Research Areas: Database Systems

Shimon Edelman

Professor ; Psychology, CS Field Member ; Ph.D., Weizmann Institue of Science, 1988
Research Focus: Consciousness, computational social science, computational linguistics

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Ahmed El Alaoui

Assistant Professor ; Statistics and Data Science, CS Field Member ; PhD UC Berkeley, 2018
Research Focus: High-dimensional statistics and probability, algorithms, statistical physics

Research Areas: Theory of Computing

Research Concentration: Theory of Computation

Kevin Ellis

Assistant Professor ; Computer Science, CS Field Member ; Ph.D., M.I.T., 2020
Research Focus: AI, ML, Program Induction

Research Areas: Artificial Intelligence, Machine Learning

Research Concentration: Artificial Intelligence

Deborah Estrin

Professor ; Computer Science, Cornell Tech, CS Field Member; Associate Dean for Impact at Cornell Tech; Robert V. Tishman Founder's Chair ; Ph.D., M.I.T., 1985
Research Focus: Mobile systems and applications, participatory sensing, health applications, privacy

Research Areas: Human Interaction, Systems and Networking

Research Concentration: Systems

K-Y. Daisy Fan

On leave Fall 2022

Senior Lecturer ; Computer Science ; Ph.D., Cornell Univ, 2001
Research Focus: The application of systems analysis techniques for water resources and environmental problems

Silvia Ferrari

Professor ; Mechanical and Aerospace Engineering, CS Field Member ; Ph.D. Princeton University, 2002
Research Focus: Distributed systems, computer vision, and robotics

Research Areas: Robotics

Research Concentration: Artificial Intelligence

Nate Foster

Professor ; Computer Science, CS Field Member ; Ph.D., Univ of Penn, 2009
Research Focus: Programming languages, data management, and security

Research Areas: Programming Languages, Security, Systems and Networking

Research Concentration: Programming Languages and Logics, Systems

Nikhil Garg

Assistant Professor ; Operations Research and Information Engineering, CS Field Member ; Ph.D., Stanford University, 2020
Research Focus: Mechanism/Market design and data science, with a focus on design of democracy, markets, and other societal systems

Research Concentration: Artificial Intelligence, Theory of Computation

Ziv Goldfeld

Assistant Professor ; ECE, CS Field Member ; Ph.D., Ben Gurion University,
Research Focus: Optimal transport theory, Statistical machine learning, information theory, high-dimensional statistic, applied probability and interacting particle systems

Research Areas: Theory of Computing

Carla Gomes

Professor ; CIS and Applied Economics and Management; Computer Science, CS Field Member; Ronald C. and Antonia V. Nielsen Professor ; Ph.D., Univ of Edinburgh, 1993
Research Focus: Solving hard combinatorial problems, with an emphasis on planning and scheduling problems

Research Areas: Artificial Intelligence, Computational Biology

Research Concentration: Artificial Intelligence

Donald Greenberg

Professor ; Architecture, Computer Science, CS Field Member; Director, Program of Computer Graphics; Jacob Gould Schurman Professor of Computer Science ; Ph.D., Cornell Univ, 1968
Research Focus: Computer graphics and its applications in a range of disciplines, from animation to architecture to biology

Research Areas: Graphics

Research Concentration: Scientific Computing and Applications

David Gries

Professor Emeritus ; Computer Science ; Ph.D., Technische Hochschule Muenchen, Munich, 1966
Research Focus: Program methodology and related areas; logic; teaching in lower level courses

Giulia Guidi

Assistant Professor ; Computer Science; Ph.D., University of California, Berkeley, 2022
Research Focus: Parallel and Distributed Programming and Systems for Computational Sciences (e.g. Computational Biology), Combinatorics, Cloud Computing for Scientific Applications

Research Areas: Computational Biology, Scientific Computing, Systems and Networking

Research Concentration: Scientific Computing and Applications

Francois Guimbretiere

Professor ; Information Science, CS Field Member ; Ph.D., Stanford University, 2002
Research Focus: Computer Interfaces

Research Areas: Human Interaction

Research Concentration: Systems

Joseph Halpern

Professor ; Computer Science, CS Field Member, Joseph C Ford Professor of Engineering ; Ph.D., Harvard Univ, 1981
Research Focus: Reasoning about knowledge and uncertainty, distributed computing, causality, security, game theory

Research Areas: Artificial Intelligence, Security, Theory of Computing

Research Concentration: Artificial Intelligence, Programming Languages and Logics, Theory of Computation

Bharath Hariharan

Assistant Professor ; Computer Science, CS Field Member, Ph.D., University of California, Berkeley, 2015
Research Focus: Rich visual understanding (object recognition, object detection, segmentation and beyond), machine learning (deep learning, convolutional networks)

Research Areas: Artificial Intelligence, Scientific Computing, Vision

Research Concentration: Artificial Intelligence, Scientific Computing and Applications

Haym Hirsh

Professor ; Computer Science, Information Science, CS Field Member, Director CS M.Eng Program ; Ph.D., Stanford University, 1989
Research Focus: Artificial intelligence, collective intelligence, crowdsourcing, data mining, human computation, information retrieval, machine learning

Research Areas: Artificial Intelligence, Human Interaction

Research Concentration: Artificial Intelligence

Guy Hoffman

Assistant Professor ; Mechanical and Aerospace Engineering, CS Field Member ; Ph.D., M.I.T., 2007
Research Focus: Human-Robot Interaction; human-robot teamwork and collaboration; robotic personal companions; non-anthropomorphic robot design; embodied cognition in probots

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

John Hopcroft

Professor Emeritus ; Computer Science, CS Field Member, IBM Professor of Engineering and Applied Mathematics in Computer Science; Turing Award Winner ; Ph.D., Stanford University, 1964
Research Focus: Algorithms, information capture and access, random graphs and spectral methods

Research Areas: Artificial Intelligence, Theory of Computing

Research Concentration: Artificial Intelligence, Theory of Computation

Justin Hsu

Assistant Professor ; Computer Science, CS Field Member ; Ph.D., University of Pennsylvania, 2017
Research Focus: Programming languages, formal verification, algorithms, differential privacy.

Research Areas: Programming Languages, Theory of Computing

Research Concentration: Programming Languages and Logics, Theory of Computation

Thorsten Joachims

On sabbatical: AY 2022-2023

Professor and Associate Dean for Research ; Computer Science, CS Field Member ; Ph.D., Univ of Dortmund, 2001
Research Focus: Machine learning and learning theory, with a focus on problems arising in information retrieval and natural language understanding

Research Areas: Artificial Intelligence, Human Interaction

Research Concentration: Artificial Intelligence

Wendy Ju

Associate Professor ; Information Science, CS Field Member ; Ph.D., Stanford University, 2008
Research Focus: Interaction with Automation; Interaction Design Research; Human Robot Interaction; Automotive Interaction Design

Research Areas: Human Interaction

Research Concentration: Artificial Intelligence

Ari Juels

Professor ; Computer Science, Cornell Tech (Jacobs Inst), CS Field Member ; Ph.D., University California, Berkeley, 1996
Research Focus: Big Data, Security Analytics, Cybersecurity, Cloud security, User authentication, Privacy, Medical-device security, Biometric security, and RFID / NFC security

Research Areas: Security, Systems and Networking

Research Concentration: Systems

Malte Jung

Associate Professor ; Information Science, CS Field Member ; Ph.D., Stanford University, 2011
Research Focus: Computer-supported cooperative work, teamwork, emotion, human-robot interaction, design

Research Areas: Artificial Intelligence, Human Interaction

Research Concentration: Artificial Intelligence

Nathan Kallus

Assistant Professor ; Operations Research and Information Engineering, Cornell Tech, CS Field Member ; Ph.D., M.I.T., 2015
Research Focus: Causal inference; Machine learning; Personalization; Optimization in statistics; Data-driven optimization under uncertainty; Online decision making; Decision making and operations in healthcare.

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Jon Kleinberg

Professor ; Computer Science, CS Field Member; Tisch Univ Professor ; Ph.D., M.I.T., 1996
Research Focus: Algorithm design, with an emphasis on the social and information networks that underpin the Web and other on-line media

Research Areas: Human Interaction, Theory of Computing

Research Concentration: Artificial Intelligence, Theory of Computation

Robert Kleinberg

On sabbatical: AY 2022-2023

Professor ; Computer Science, CS Field Member ; Ph.D., M.I.T., 2005
Research Focus: Design and analysis of algorithms, especially randomized and on-line algorithms for networked systems and electronic markets

Research Areas: Artificial Intelligence, Theory of Computing

Research Concentration: Artificial Intelligence, Theory of Computation

Dexter Kozen

Professor ; Computer Science, CS Field Member; Joseph Newton Pew, Jr. Professor in Engineering ; Ph.D., Cornell Univ, 1977
Research Focus: Computational complexity, program logic and semantics, computational algebra

Research Areas: Programming Languages, Theory of Computing

Research Concentration: Programming Languages and Logics, Theory of Computation

Hadas Kress-Gazit

Professor ; Mechanical and Aerospace Engineering, CS Field Member ; Ph.D., Univ of Pennsylvania, 2008
Research Focus: Robotics, motion planning, task planning, language for robotics and human robot interaction

Research Areas: Artificial Intelligence, Human Interaction, Robotics

Research Concentration: Artificial Intelligence

Volodymyr Kuleshov

Assistant Professor ; Computer Science, Cornell Tech, CS Field Member ; Ph.D., Stanford University, 2017
Research Focus: Artificial intelligence, machine learning, and computational genomics

Research Areas: Artificial Intelligence, Computational Biology, Scientific Computing

Research Concentration: Artificial Intelligence

Daniel Lee

Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., M.I.T., 1995
Research Focus: Machine Learning, Robotics, Computational Neuroscience

Research Areas: Artificial Intelligence, Robotics

Research Concentration: Artificial Intelligence

Lillian Lee

Professor ; Computer Science, Director of Undergraduate Studies; CS Field Member; Charles Roy Davis Professor ; Ph.D., Harvard Univ, 1997
Research Focus: Natural language processing

Research Areas: Artificial Intelligence, Human Interaction

Research Concentration: Artificial Intelligence

Owolabi Legunsen

Assistant Professor ; Computer Science, CS Field Member ; Ph.D., University of Illinois at Urbana-Champaign, 2019
Research Focus: Software Engineering, Applied Formal Methods

Research Areas: Programming Languages, Software Engineering, Systems and Networking

Research Concentration: Programming Languages and Logics, Systems

Steve Marschner

Professor ; Computer Science, CS Field Member ; Ph.D., Cornell Univ, 1998
Research Focus: Computer graphics, realistic rendering and simulation, material models for surfaces, volumes, and deformable objects

Research Areas: Graphics, Vision

Research Concentration: Scientific Computing and Applications

Jose Martinez

Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., Univ of Illinois, 2002
Research Focus: Reconfigurable and self-optimizing multicore architectures, architectural implications of disruptive technologies

Research Areas: Computer Architecture & VLSI, Systems and Networking

Research Concentration: Systems

David Matteson

Associate Professor ; Statistics and Data Science, CS Field Member ; PhD University of Chicago, 2008
Research Focus: Uncertainty in Artificial Intelligence

Research Areas: Artificial Intelligence, Machine Learning

Research Concentration: Artificial Intelligence

David Mimno

Assistant Professor ; Information Science, CS Field Member ; Ph.D., Univ. Mass. Amherst, 2012
Research Focus: Machine learning, text mining, digital humanities

Research Areas: Artificial Intelligence, Human Interaction

Research Concentration: Artificial Intelligence

Greg Morrisett

Professor and Dean and Vice Provost Cornell Tech ; Computer Science, Cornell Tech, CS Field Member ; Ph.D., Carnegie Mellon, 1995
Research Focus: Programming languages, software security, formal methods

Research Areas: Programming Languages, Security, Systems and Networking

Research Concentration: Programming Languages and Logics, Systems

Curran Muhlberger

Lecturer ; Computer Science ; Ph.D. Cornell University, 2014
Research Areas: Scientific Computing, Software Engineering

Andrew Myers

Professor ; Computer Science, CS Field Member ; Ph.D., M.I.T., 1999
Research Focus: Security, programming language design and implementation, persistent and distributed object systems

Research Areas: Programming Languages, Security, Systems and Networking

Research Concentration: Programming Languages and Logics

Mor Naaman

Associate Professor ; Information Science, Cornell Tech, CS field member ; Ph.D., Stanford University, 2005
Research Focus: Social media, data mining, human-computer interaction, computational social science, interactive systems

Research Areas: Human Interaction

Research Concentration: Systems

Rajalakshmi Nandakumar

Assistant Professor ; Information Science, Cornell Tech, CS Field Member ; Ph.D. University of Washington, 2020
Research Focus: Wireless networking, Mobile Systems and Mobile Health.

Research Areas: Systems and Networking

Research Concentration: Systems

Anil Nerode

Professor ; Mathematics, CS Field Member ; Ph.D., Univ of Chicago, 1956
Research Focus: Mathematical logic, computational theory, recursive mathematics, nonstandard logics, nonmontonic logics, AI, applied mathematics.

Research Areas: Artificial Intelligence, Theory of Computing

Research Concentration: Artificial Intelligence

Tapan Parikh

Associate Professor ; Information Science, Cornell Tech, CS Field Member ; Ph.D., Univ of Washington, 2007
Research Focus: Human-Computer Interaction (HCI), Information and Communication Technologies for Development (ICTD), Computer Science Education

Research Areas: Artificial Intelligence, Systems and Networking

Research Concentration: Artificial Intelligence, Systems

Francesca Parise

Assistant Professor ; Electrical and Computer Engineering; CS Field Member ; Ph.D., ETH, Zurich , 2016
Research Focus: Network Systems, Game Theory, Control Theory, Social and Economics Networks

Research Areas: Artificial Intelligence, Theory of Computing

Research Concentration: Artificial Intelligence, Theory of Computation

Rafael Pass

On leave: Spring 2023 & Fall 2023

Professor ; Computer Science, Cornell Tech, CS Field Member ; Ph.D., M.I.T., 2006
Research Focus: Cryptography and its interplay with computational complexity and game theory.

Research Areas: Theory of Computing

Research Concentration: Artificial Intelligence, Theory of Computation

Kirstin Petersen

Assistant Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., Harvard, 2014
Research Focus: Design and coordination of bio-inspired robot collectives and their natural counterparts

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Emma Pierson

Assistant Professor ; Computer Science, Cornell Tech; CS Field Member ; Ph.D., Stanford University, 2020
Research Focus: Data Science and Machine Learning, Healthcare, Inequality, and Algorithmic Fairness

Research Areas: Artificial Intelligence, Human Interaction, Machine Learning

Research Concentration: Artificial Intelligence

Martha E. Pollack

Cornell University President; Professor ; Computer Science, CS Field Member ; Ph.D., University of Pennsylvania, 1986
Research Focus: Artificial intelligence

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Tom Ristenpart

Associate Professor ; Computer Science, Cornell Tech, CS Field Member ; Ph.D., University of California, San Diego
Research Focus: Software security, applied and theoretical cryptography

Research Areas: Security, Systems and Networking, Theory of Computing

Research Concentration: Systems, Theory of Computation

Thijs Roumen

Assistant Professor, IS ; CS field member ; Ph.D. , Hasso Plattner Institute, Germany 2022
Research Focus: Digital Fabrication, Human-Computer Interaction

Research Areas: Human Interaction

Research Concentration: Systems

Alexander "Sasha" Rush

Associate Professor ; Computer Science, Cornell Tech, CS Field Member ; Ph.D., Massachusetts Institute of Technology, 2014
Research Focus: Natural Language Processing, Machine Learning

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Mert Sabuncu

Assistant Professor ; Engineering, CS Field Member ; Ph.D., Princeton, 2006
Research Focus: biomedical image analysis, with an emphasis on neuroimaging. My group works at the intersection of computer vision, applied machine learning, and biomedical imaging

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Adrian Sampson

On sabbatical: AY 2022-2023

Associate Professor ; Computer Science, CS Field Member ; Ph.D., Univ of Washington, 2015
Research Focus: Hardware-software abstractions,computer architecture, programming languages, compilers, and software engineering

Research Areas: Computer Architecture & VLSI, Programming Languages, Systems and Networking

Research Concentration: Programming Languages and Logics

Katya Scheinberg

Professor ; Operations Research and Information Engineering, CS Field Member ; Ph.D. Columbia University; 1997
Research Focus: continuous optimization, stochastic optimization, optimization in machine learning, complexity analysis

Research Concentration: Scientific Computing and Applications, Theory of Computation

Fred Schneider

On sabbatical: Spring 2023

Professor ; Computer Science, CS Field Member; Samuel B. Eckert Professor of Computer Science ; Ph.D., Stony Brook Univ, 1978
Research Focus: Concurrent and distributed systems; computer and network security

Research Areas: Programming Languages, Security, Systems and Networking

Research Concentration: Programming Languages and Logics, Systems

Bart Selman

Professor ; Computer Science, CS Field Member; Joseph C Ford Professor of Engineering ; Ph.D., Univ of Toronto, 1991
Research Focus: Knowledge representation, reasoning and search, algorithms and complexity, planning, machine learning, cognitive science, software agents, and connections between computational complexity and statistical physics

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Phoebe Sengers

Associate Professor ; Information Science and Science & Technology Studies, CS Field Member ; Ph.D., Carnegie Mellon University, 1998
Research Focus: Designing technology for social impact, rural infrastructure, critical data studies

Research Areas: Artificial Intelligence, Human Interaction

Research Concentration: Artificial Intelligence

Vitaly Shmatikov

Professor ; Computer Science, Cornell Tech, CS Field Member ; Ph.D., Stanford University, 2000
Research Focus: Reseach focus: Computer Security and privacy

Research Areas: Artificial Intelligence, Security, Systems and Networking

Research Concentration: Systems

David Shmoys

Professor ; Operations Research and Information Engineering; Computer Science; and Director, Center for Data Science for Enterprise and Society ; Ph.D., University of California, Berkeley, 1984
Research Focus: Data Science; Design and analysis of efficient algorithms for discrete optimization problems, in particular approximation algorithms for NP-hard problems

Research Areas: Computational Biology, Scientific Computing, Theory of Computing

Research Concentration: Scientific Computing and Applications, Theory of Computation

Alexandra Silva

Professor ; Computer Science ; Ph.D., Radboud University Nijmegen, 2010
Research Focus: Programming language semantics and verification

Research Areas: Programming Languages, Theory of Computing

Research Concentration: Programming Languages and Logics, Theory of Computation

Rachee Singh

Assistant Professor ; Computer Science; Ph.D., University of Massachusetts, Amherst 2021
Research Focus: Computer systems and networking, dynamic optical networks, network security

Research Areas: Security, Systems and Networking

Research Concentration: Systems

Noah Snavely

Associate Professor ; Computer Science, Cornell Tech, CS Field Member ; Ph.D., Univ of Washington, 2008
Research Focus: Computer vision and computer graphics, specifically 3D reconstruction and rendering from large community photo collections

Research Areas: Graphics, Human Interaction, Vision

Research Concentration: Artificial Intelligence, Scientific Computing and Applications

Karthik Sridharan

Associate Professor ; Computer Science, CS Field Member ; Ph.D., Toyota Technological Institute at Chicago, 2012
Research Focus: Machine learning with a focus on theoretical analysis and design of learning algorithms. Online learning, statistical learning theory, stochastic optimization and empirical process theory

Research Areas: Artificial Intelligence, Theory of Computing

Research Concentration: Artificial Intelligence, Theory of Computation

Noah Stephens-Davidowitz

Assistant Professor ; Computer Science, CS Field Member ; Ph.D., New York University, 2017
Research Focus: Theoretical Computer Science, Security, Cryptography

Research Areas: Security, Theory of Computing

Research Concentration: Theory of Computation

G. Edward Suh

Associate Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., M.I.T., 2005
Research Focus: Architectural support for security, reliability, and programmability; field extensible/repairable architecture; non-volatile microprocessors for highly embedded systems; intelligent on-chip networks

Research Areas: Security, Systems and Networking

Research Concentration: Systems

Wen Sun

Assistant Professor ; Computer Science, CS Field Member ; Ph.D., Carnegie Mellon University, 2019
Research Focus: Machine Learning, Reinforcement Learning, Decision Making under Uncertainty

Research Areas: Artificial Intelligence, Robotics, Theory of Computing

Research Concentration: Artificial Intelligence, Theory of Computation

A. Kevin Tang

Associate Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., Caltech, 2006
Research Focus: Management and optimization of computer networks; non-convex optimization

Research Areas: Systems and Networking, Theory of Computing

Research Concentration: Systems, Theory of Computation

Eva Tardos

Professor and Chair of CS ; Jacob Gould Schurman Professor of Computer Science and CIS Associate Dean for Diversity and Inclusion ; Ph.D., Eotvos University, Hungary, 1984
Research Focus: Algorithm Design and Algorithmic Game Theory

Research Areas: Human Interaction, Theory of Computing

Research Concentration: Theory of Computation

Angelique Taylor

Assistant Professor ; Ph.D. , University of California, San Diego, 2021
Research Focus: Human-robot interaction (HRI)

Research Areas: Artificial Intelligence, Robotics

Tim Teitelbaum

Professor Emeritus ; Computer Science ; Ph.D., Carnegie-Mellon University, 1976
Research Focus: Automatic Program Analysis

Alex Townsend

Associate Professor ; Mathematics; CS Field Member ; Ph.D. University of Oxford, 2014
Research Focus: Scientific Computing

Research Areas: Scientific Computing

Research Concentration: Scientific Computing and Applications

Immanuel Trummer

Assistant Professor ; Computer Science, CS Field Member ; Ph.D., EPFL, 2016
Research Focus: Databases, data science, optimization

Research Areas: Database Systems, Systems and Networking

Research Concentration: Systems

Charles Van Loan

Professor Emeritus ; Computer Science ; Ph.D., Univ of Michigan, 1973
Research Focus: Numerical linear and multilinear algebra

Research Areas: Scientific Computing

Robbert van Renesse

Professor ; Computer Science, CS Field Member, Director of Graduate Studies ; Ph.D., Vrije Universiteit, 1989
Research Focus: Scalable, adaptive, and secure group communication protocols

Research Areas: Security, Systems and Networking

Research Concentration: Systems

Marten van Schijndel

Assistant Professor ; Linguistics, CS Field Member ; Ph.D., The Ohio State University; 2017
Research Focus: Natural language processing, machine learning, cognitive modeling

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Anke van Zuylen

Senior Lecturer ; Computer Science , CS Minor Field Member ; Ph.D., Cornell University, 2008 (Operations Research)
Research Focus: Theory of Computation, Computational Biology, Discrete Optimization, Operations Research

Research Areas: Computational Biology, Theory of Computing

Aaron Wagner

Associate Professor ; Electrical and Computer Engineering; CS Field Member ; Ph.D., University of California, Berkeley, 2005
Research Focus: information theory, especially compression, feedback communication, security, and quantum information.

Research Areas: Security, Theory of Computing

Research Concentration: Theory of Computation

Fei Wang

Associate Professor ; Weill Medical, CS Field Member ; Ph.D., Tsinghua University, 2008
Research Focus: Data Mining, Machine Learning, Health Data Science, Clinical Decision Support, Computational Drug Discovery

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Hakim Weatherspoon

On leave: Fall 2022 & Spring 2023

Professor and Associate Director of the Cornell Institute for Digital Agriculture (CIDA) ; Computer Science, CS Field Member ; Ph.D., University of California, Berkeley, 2006
Research Focus: Fault-tolerance, reliability, security, and performance of Internet-scale systems

Research Areas: Security, Systems and Networking

Research Concentration: Systems

Kilian Weinberger

Professor ; Computer Science, CS Field Member ; PhD, UPenn, 2007
Research Focus: Machine Learning with a focus on real-world problems

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Walker White

Senior Lecturer ; Computer Science ; Ph.D., Cornell Univ, 2000
Research Focus: Database Theory, Information Privacy, Logic applications to Computer Science

Research Areas: Database Systems, Human Interaction

Stephen Wicker

Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., Univ of Southern California, 1987
Research Focus: Artificial intelligence, game theory and wireless information networks

Research Areas: Artificial Intelligence, Theory of Computing

Research Concentration: Artificial Intelligence, Theory of Computation

Mark Wilde

Associate Professor ; Ph.D. , University of Southern California, 2008
Research Focus: Quantum computation

Research Areas: Theory of Computing

Research Concentration: Theory of Computation

David Williamson

Professor ; Operations Research and Information Engineering, CS Field Member ; Ph.D., M.I.T., 1993
Research Focus: Algorithms, combinatorial optimization, computer science

Research Areas: Theory of Computing

Research Concentration: Theory of Computation

Qian Yang

Assistant Professor ; Information Science, CS Field Member ; Ph.D. Carnegie Mellon University, 2020
Research Areas: Artificial Intelligence, Scientific Computing

Research Concentration: Artificial Intelligence, Scientific Computing and Applications

Fengqi You

Roxanne E. and Michael J. Zak Professor in Energy Systems Engineering at Cornell University ; Chair of Ph.D. Studies in Cornell Systems Engineering, Co-director of the Cornell University AI for Science Institute, Associate Director of Cornell Energy Systems Institute, Co-lead of Schmidt AI in Science Program at Cornell, and Associate Director of C ; Ph.D. Carnegie Mellon University, 2009
Research Focus: Fundamental theory and methods in systems engineering and artificial intelligence, as well as their applications to materials informatics, smart manufacturing, digital agriculture, quantum computing, energy systems, and sustainability

Research Areas: Artificial Intelligence

Research Concentration: Artificial Intelligence

Christina Lee Yu

Assistant Professor ; ORIE, CS Field Member ; Ph.D. Massachusetts Institute of Technology
Research Focus: Theory of Computing, Artificial Intelligence (Machine Learning), Scientific Computing

Research Areas: Theory of Computing

Research Concentration: Theory of Computation

Haiyuan Yu

Professor ; Biological Statistics & Computational Biology, CS Field Member ; Ph.D., Yale, 2005
Research Focus: Biomedical systems biology, machine learning, algorithm development, with an emphasis on network analysis, to understand human disease and evolution of species

Research Areas: Computational Biology

Research Concentration: Scientific Computing and Applications

Ramin Zabih

Professor ; Computer Science, Cornell Tech, CS Field Member ; Ph.D., Stanford University, 1994
Research Focus: Computer vision and its applications, especially in medical imaging, with an emphasis on the use of combinatorial optimization algorithms

Research Areas: Human Interaction, Vision

Research Concentration: Artificial Intelligence, Theory of Computation

Cheng Zhang

Assistant Professor ; Information Science, CS Field Member ; Ph.D., Georgia Institute of Technology, 2018
Research Focus: Ubiquitous Computing, Wearable Computing, Human Computer Interaction

Research Areas: Artificial Intelligence

Research Concentration: Systems

Zhiru Zhang

Assistant Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., Univ of California, LA, 2007
Research Focus: Computer-aided design methodologies, optimization algorithms, compilers, and computer architectures of gigascale integrated systems; esp. system-on-chips

Research Areas: Systems and Networking

Research Concentration: Systems
"""

# %%
lines = [l.strip() for l in s.split("\n") if l.strip()]

# %%
len(lines), lines
# Out:
# (599,
#  ['Mohamed Abdelfattah',
#   'Assistant Professor ; Electrical and Computer Engineering, Cornell Tech, CS Field Member; ; Ph.D., University of Toronto, 2016',
#   'Research Areas: Artificial Intelligence, Machine Learning',
#   'Research Concentration: Artificial Intelligence',
#   'Jayadev Acharya',
#   'Assistant Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., University of California, San Diego, 2014',
#   'Research Focus: Information theory, machine learning, and algorithmic statistics',
#   'Research Areas: Artificial Intelligence, Theory of Computing',
#   'Research Concentration: Artificial Intelligence, Theory of Computation',
#   'Rachit Agarwal',
#   'Associate Professor ; Computer Science, CS Field Member ; Ph.D., University of Illinois, Urbana-Champaign, 2013',
#   'Research Focus: Distributed systems, systems for big data analytics, networking, design and analysis of algorithms',
# ...

# %%
professors = [l.strip() for l in lines if "professor" in l.lower()]

# %%
len(professors), professors
# Out:
# (116,
#  ['Assistant Professor ; Electrical and Computer Engineering, Cornell Tech, CS Field Member; ; Ph.D., University of Toronto, 2016',
#   'Assistant Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., University of California, San Diego, 2014',
#   'Associate Professor ; Computer Science, CS Field Member ; Ph.D., University of Illinois, Urbana-Champaign, 2013',
#   'Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., University of Massachusetts, Amherst, 1996',
#   'Professor ; Computer Science, CS Field Member, Tisch University Professor ; Ph.D., Cornell University, 1996',
#   'Associate Professor ; Computer Science, Cornell Tech, CS Field Member ; Ph.D., Univ of Washington, 2015',
#   'Associate Professor ; Jacobs Technion-Cornell Institute; CS Field Member ; Ph.D. University of Washington, 2014',
#   'Adjunct Professor ; Ph.D., University of Birmingham',
# ...

# %%
phd_schools = []

for p in professors:
    p = p.replace("Ph.D.,", "PhD").replace("Ph.D.", "PhD").replace("PhD.", "PhD")
    school_year = p.split("PhD")[-1]
    school = " ".join(school_year.split(" ")[:-1])
    (
        phd_schools.append(school
                       .replace(",", " ").replace(".", "")  
                       .replace(" of", "").replace(" at ", " ").replace(" - ", " ")
                       .replace('UC Berkeley', "University California Berkeley")
                       .replace('Pennsylvaniasylvania', "Pennsylvania").replace('UPenn', "University Pennsylvania").replace('Univ Penn', "University Pennsylvania")
                       .replace("University", "Univ")
                       .strip())
    )

len(phd_schools), sorted(phd_schools)
# Out:
# (116,
#  ['Ben Gurion',
#   'Caltech',
#   'Carnegie Mellon',
#   'Carnegie Mellon Univ',
#   'Carnegie Mellon Univ',
#   'Carnegie Mellon Univ',
#   'Carnegie Mellon Univ',
#   'Carnegie Mellon Univ',
#   'Carnegie-Mellon Univ',
#   'Columbia Univ;',
#   'Cornell Univ',
#   'Cornell Univ',
#   'Cornell Univ',
#   'Cornell Univ',
#   'Cornell Univ',
#   'EPFL',
#   'ETH  Zurich',
#   'Eotvos Univ  Hungary',
#   'Georgia Institute Technology',
#   'Georgia Institute Technology',
#   'Harvard',
#   'Harvard Univ',
#   'Harvard Univ',
#   'Harvard Univ',
#   'Hasso Plattner Institute  Germany',
#   'MIT',
#   'MIT',
#   'MIT',
#   'MIT',
#   'MIT',
#   'MIT',
#   'MIT',
#   'MIT',
#   'MIT',
#   'MIT',
#   'MIT',
#   'MIT',
#   'MIT',
#   'MIT',
#   'Massachusetts Institute',
#   'Massachusetts Institute Technology',
#   'Massachusetts Institute Technology',
#   'Massachusetts Institute Technology',
#   'New York Univ',
#   'Princeton',
#   'Princeton Univ',
# ...

# %%
assistant_profs = []
associate_profs = []
adjunct_profs = []
emeritus_profs = []
other_profs = []

for p in professors:
    if "assistant professor" in p.lower():
        assistant_profs.append(p)
    elif "emeritus" in p.lower():
        emeritus_profs.append(p)
    elif "adjunct professor" in p.lower():
        adjunct_profs.append(p)
    elif "associate professor" in p.lower():
        associate_profs.append(p)
    else:
        other_profs.append(p)

# %%
print("full_profs: \t",len(other_profs), len(other_profs) == len(set(other_profs)))
print("associate_profs: \t",len(associate_profs), len(associate_profs) == len(set(associate_profs)))
print("assistant_profs: \t",len(assistant_profs), len(assistant_profs) == len(set(assistant_profs)))
print("emeritus_profs: \t",len(emeritus_profs), len(emeritus_profs) == len(set(emeritus_profs)))
print("adjunct_profs: \t",len(adjunct_profs), len(adjunct_profs) == len(set(adjunct_profs)))
# Out:
# full_profs: 	 49 True
# associate_profs: 	 21 True
# assistant_profs: 	 40 True
# emeritus_profs: 	 5 True
# adjunct_profs: 	 1 True

# %%
len(emeritus_profs), emeritus_profs
# Out:
# (5,
#  ['Professor Emeritus ; Computer Science, CS Field Member ; Ph.D., Univ of Wisconsin, Madison, 1968',
#   'Professor Emeritus ; Computer Science ; Ph.D., Technische Hochschule Muenchen, Munich, 1966',
#   'Professor Emeritus ; Computer Science, CS Field Member, IBM Professor of Engineering and Applied Mathematics in Computer Science; Turing Award Winner ; Ph.D., Stanford University, 1964',
#   'Professor Emeritus ; Computer Science ; Ph.D., Carnegie-Mellon University, 1976',
#   'Professor Emeritus ; Computer Science ; Ph.D., Univ of Michigan, 1973'])

# %%
len(other_profs), other_profs
# Out:
# (49,
#  ['Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., University of Massachusetts, Amherst, 1996',
#   'Professor ; Computer Science, CS Field Member, Tisch University Professor ; Ph.D., Cornell University, 1996',
#   'Professor and Dean of Cornell Bowers CIS ; Computer Science, Chair, CS Field Member ; Ph.D., M.I.T., 1999',
#   'Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., M.I.T., 2010',
#   'Professor ; Computer Science, CS Field Member; N. Rama Rao Professor of Computer Science ; Ph.D., University of California, Berkeley, 1981',
#   'Director; Professor ; Jacobs Technion-Cornell Institute ; Ph.D., Harvard Univ, 1977',
#   'Professor ; Statistics and Data Science, CS Field Member ; Ph.D. University of Washington, 2000',
#   'Professor ; Mechanical Engineering; CS Field Member ; Ph.D. Massachusetts Institute of Technology 1996',
# ...

# %%
len(associate_profs), associate_profs
# Out:
# (21,
#  ['Associate Professor ; Computer Science, CS Field Member ; Ph.D., University of Illinois, Urbana-Champaign, 2013',
#   'Associate Professor ; Computer Science, Cornell Tech, CS Field Member ; Ph.D., Univ of Washington, 2015',
#   'Associate Professor ; Jacobs Technion-Cornell Institute; CS Field Member ; Ph.D. University of Washington, 2014',
#   'Associate Professor and Associate Dean for Diversity, Equity, and Inclusion ; Computer Science, CS Field Member ; Ph.D., University of California, Berkeley, 2006',
#   'Associate Professor ; Information Science, CS Field Member ; Ph.D., Stanford University, 2008',
#   'Associate Professor ; Information Science, CS Field Member ; Ph.D., Stanford University, 2011',
#   'Associate Professor ; Statistics and Data Science, CS Field Member ; PhD University of Chicago, 2008',
#   'Associate Professor ; Information Science, Cornell Tech, CS field member ; Ph.D., Stanford University, 2005',
# ...

# %%
len(assistant_profs), assistant_profs
# Out:
# (40,
#  ['Assistant Professor ; Electrical and Computer Engineering, Cornell Tech, CS Field Member; ; Ph.D., University of Toronto, 2016',
#   'Assistant Professor ; Electrical and Computer Engineering, CS Field Member ; Ph.D., University of California, San Diego, 2014',
#   'Assistant Professor ; Operations Research and Information Engineering, CS Field Member ; PhD, University of Texas - Austin, 2013',
#   'Assistant Professor ; Computer Science, CS Field Member ; Ph.D., Georgia Institute of Technology, 2017',
#   'Assistant Professor ; Computer Science, CS Field Member ; Ph.D. University of Texas at Ausin, 2016',
#   'Assistant Professor ; Computer Science ; Ph.D., Carnegie Mellon University, 2018',
#   'Assistant Professor ; Computer Science, CS Field Member, Ph.D., Stanford University, 2016',
#   'Assistant Professor ; Information Science, CS Field Member ; PhD, Cornell University, 2012',
# ...
