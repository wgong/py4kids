# %% [markdown]
# https://chat.openai.com/chat
#
# ## display image in jupyter notebook

# %%
from IPython.display import Image

# %%
url_img = "https://www.thechinesezodiac.org/wp-content/uploads/2022/02/yearoftherabbit2023.jpg"

# %%
Image(url_img)

# %%
file_img = "display-img.PNG"

# %%
Image(file_img)

# %%
from IPython.display import display

display(Image(file_img))

# %%
from IPython.display import HTML

HTML(f'<img src="{file_img}">')
# Out:
# <img src="display-img.PNG">

# %%
import matplotlib.pyplot as plt

plt.imshow(plt.imread(file_img))
plt.show()
